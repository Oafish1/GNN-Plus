# %%
from collections import defaultdict
import operator
import os
from itertools import product

import matplotlib as mpl
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import pandas as pd
import pecanpy as pp
import scipy
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.metrics import auc, confusion_matrix, precision_recall_curve, roc_curve
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPClassifier
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch_geometric as tg
import torch_geometric.nn as gnn
from umap import UMAP

# %%
sns.set(style='white', palette='Accent')
plt.rcParams.update({'font.weight': 'normal',
                     'font.size': 18,
                     'axes.titlesize': 'large',
                     'axes.labelsize': 'large',
                     'xtick.labelsize': 'small',
                     'ytick.labelsize': 'small'})

# %% [markdown]
# # Params

# %%
# Data params
directed = True
disease_type = 'SCZ-AD'  # Either 'disease' or 'graph-labels' e.g. 'AD', 'AD-SCZ'
def create_dirs(dirs):
    for d in dirs:
        if not os.path.exists(d):
            os.mkdir(d)
def get_dirs(disease_type):
    model_dir = f'./models/{disease_type}'
    results_dir = f'./results/{disease_type}'
    output = (model_dir, results_dir)
    create_dirs(output)
    return output
model_dir, results_dir = get_dirs(disease_type)

# Run params
runs = 20  # Number of runs
folds = 5  # Folds per run
run, fold = 0, 0  # Current stat
percentile = 90  # Data filtering
# RW params
param_grid = {
    'dim': [16, 32, 64, 128, 248, 512],
    'num_walks': [20, 40, 60, 80, 100],
    'walk_length': [10],
    'dropout': [0, .4, .6, .8],
    'gamma': [.96, .99, .995],
    'lr': [1e-1, 1e-2, 1e-3, 1e-4],
}
np.random.seed(42)
dim_list = np.random.choice(param_grid['dim'], runs)
num_walks_list = np.random.choice(param_grid['num_walks'], runs)
walk_length_list = np.random.choice(param_grid['walk_length'], runs)
dropout_list = np.random.choice(param_grid['dropout'], runs)
gamma_list = np.random.choice(param_grid['gamma'], runs)
lr_list = np.random.choice(param_grid['lr'], runs)

# %% [markdown]
# # Dataset

# %%
def get_cells(disease_type, directed=False):
    cell_fnames = np.array([s for s in os.listdir(f'./data/psychAD_merged_GRN_0.2_0.2/{disease_type.split("-")[0]}') if s[0] != '_'])
    cell_types = [ct.split('.')[0] for ct in cell_fnames]
    cell_fname = cell_fnames[0]
    cell_type = cell_fname.split('.')[0]
    
    return (cell_fnames, cell_types), (cell_fname, cell_type)

(cell_fnames, cell_types), (cell_fname, cell_type) = get_cells(disease_type, directed=directed)
for ct in cell_types:
    print(ct) if ct != cell_type else print(f'--{ct}')
# Out:
# --Astrocyte
# Endothelial
# GABAergic neuron
# GABAergic PVALB interneuron
# GABAergic SST interneuron
# GABAergic VIP interneuron
# Glutamatergic neuron
# Microglia
# Mural
# Oligodendrocyte
# OPC

# %%
def get_data(cell_fname, method='scGRNom', directed=True, output='_elist.edg'):  # 'scGRNom', 'SCENIC'
    # Read data
    tftg = pd.read_csv(f'./data/psychAD_merged_GRN_0.2_0.2/{disease_type.split("-")[0]}/{cell_fname}', sep='\t', low_memory=False)  # low_memory avoids loading warning
    # Control data
    is_pec2 = (cell_fname.split('.')[1] == 'PEC2')
    coef_col = 'edgeWeight' if not is_pec2 else 'coef'
    # Filter to one method (SCENIC, scGRNom)
    if method is not None and not is_pec2:
        tftg = tftg.iloc[np.argwhere((tftg['method']==method).to_numpy()).flatten(), :]
    # Remove all zero weights
    tftg = tftg.iloc[np.argwhere(tftg[coef_col].to_numpy() != 0).flatten(), :]
    # Remove negatives
    tftg = tftg.iloc[np.argwhere(tftg[coef_col].to_numpy() > 0).flatten(), :]
    # Set all nonzero weights to one
    if method is None and not is_pec2:
        tftg[[coef_col]] = 1.
    # Filter to targets
    tftg = tftg[['TF', 'TG', coef_col]]
    # Make undirected
    tg_genes = np.unique(tftg['TG'])
    if not directed:
        tftg = pd.DataFrame(
            np.concatenate([tftg[['TF', 'TG', coef_col]].to_numpy(), tftg[['TG', 'TF', coef_col]].to_numpy()]))
    # Save file
    tftg.to_csv(output, sep='\t', header=None, index=None)
    
    return tg_genes

def get_labels(genes, disease_type, gene_filter=[]):
    # # DisGeNet
    # disDict = {'AD': 'Alzheimer', 'SCZ': 'Schizophrenia', 'PK': 'Parkinson', 'BD': 'Bipolar Disorder'}
    # meta = pd.read_csv(f'./data/training_labels_disgenet_raw/all_gene_disease_associations.tsv', index_col=None, sep='\t')
    # dis_strs = [s for s in np.unique(meta['diseaseName']) if f'{disDict[disease_type.split("-")[-1]].lower()}' in s.lower() and f'Non-{disDict[disease_type.split("-")[-1]]}'.lower() not in s.lower()]
    # filtered_meta = meta.iloc[[np.array([ds==s for ds in dis_strs]).any() for s in meta['diseaseName']]]
    # filtered_meta = filtered_meta.sort_values('score', ascending=False)
    # filtered_meta = filtered_meta.iloc[:int(.1 * filtered_meta.shape[0])]  # TODO, more fine-tuning
    # positive_genes = np.array(filtered_meta['geneSymbol'])
    
    # Assoc
    positive_genes = pd.read_csv(f'./data/new_labels/{disease_type.split("-")[-1]}.txt', index_col=None, header=None).to_numpy().flatten()
    
    # Get labels
    labels = np.array([('pos' if (g in positive_genes) else 'neg') if (g in gene_filter) else 'unk' for g in genes])  # TODO, better method than unknown being neg
    return labels

def filter_elist(percentile):
    elist = pd.read_csv('_elist.edg', sep='\t', header=None)

    # Eliminate low-value data
    reg_threshold = np.percentile(elist.iloc[:, 2].to_numpy().flatten(), percentile)
    elist = elist.iloc[np.argwhere((elist.iloc[:, 2] >= reg_threshold).to_numpy()).flatten(), :]
    elist.to_csv('_elist.edg', sep='\t', header=None, index=None)
    
    return reg_threshold

print(f'Generating {cell_type} graph...')
# Load data
tg_genes = get_data(cell_fname, directed=directed)

# Plot approximate distribution
elist = pd.read_csv('_elist.edg', sep='\t', header=None)
sns.displot(elist.iloc[:, 2].to_numpy().flatten(), log_scale=True)

# Eliminate low-value data
print(f'Filtering data...')
reg_threshold = filter_elist(percentile)
plt.axvline(reg_threshold, ymax=.1, color='black');
# Out:
# Generating Astrocyte graph...
# Filtering data...

# %% [markdown]
# # Pipeline

# %% [markdown]
# ## Node2Vec+

# %%
def get_embeddings_from_elist(model_dir, cell_type, tg_genes, dim, num_walks, walk_length, percentile, run, verbose=False, return_g=False):
    if verbose:
        print('Reading graph...')
    # Load as precomp
    g = pp.pecanpy.SparseOTF(p=1, q=1, workers=4, verbose=False, random_state=42+run)
    g.read_edg('_elist.edg', weighted=True, directed=directed)
    # g.preprocess_transition_probs()

    fname = f'{model_dir}/embeddings-{cell_type}-{run}.npy'
    if os.path.exists(fname):
        if verbose:
            print('Loading embeddings...')
        # Load embeddings
        emb_pp = np.load(fname)
    else:
        if verbose:
            print('Generating embeddings...')
        # Generate embeddings
        emb_pp = g.embed(dim=dim, num_walks=num_walks, walk_length=walk_length)
        np.save(fname, emb_pp)
        hparams = np.array([
            ['percentile', 'dim', 'num_walks', 'walk_length'],
            [percentile, dim, num_walks, walk_length],
        ])
        np.savetxt(fname[:-4]+'.txt', hparams, fmt=' '.join(hparams.shape[1]*['%s']))

    # Chart connected subgraph
    # surviving_nodes = [np.argwhere(genes==gn).flatten()[0] for gn in g.nodes]
    genes = np.array(g.nodes)
    labels = get_labels(genes, disease_type, gene_filter=tg_genes)
    
    output = (genes, labels, emb_pp)
    if return_g:
        return output, g
    return output

dim, num_walks, walk_length = dim_list[run], num_walks_list[run], walk_length_list[run]
genes, labels, emb_pp = get_embeddings_from_elist(model_dir, cell_type, tg_genes, dim, num_walks, walk_length, percentile, run, verbose=True)
# Out:
# Reading graph...
# Generating embeddings...

# %%
# Additional Graph Information
_, g = get_embeddings_from_elist(model_dir, cell_type, tg_genes, dim, num_walks, walk_length, percentile, run, verbose=False, return_g=True)
walks = g.simulate_walks(num_walks, walk_length)
walk_lengths = np.array([len(walk) for walk in walks])
walk_length_counts = {u: c for u, c in zip(*np.unique(walk_lengths, return_counts=True))}
print(f'Max: {walk_lengths.max()}\nMean: {walk_lengths.mean():.2f}\nMedian: {np.median(walk_lengths):.1f}\n{walk_length_counts}')
# Out:
# Max: 4
# Mean: 1.19
# Median: 1.0
# {1: 130800, 2: 29539, 3: 555, 4: 6}

# %% [markdown]
# ## Dataset

# %%
def generate_dataset(genes, labels, emb_pp, fold, folds, run):
    # Load dataset
    elist = np.loadtxt('_elist.edg', dtype=str)
    gene_to_index = {g: i for g, i in zip(genes, range(len(genes)))}
    edge_index = np.array([[gene_to_index[f] for f in e[:2]] for e in elist]).T
    edge_weight = np.array([float(e[2]) for e in elist])

    # Add embeddings and labels
    x = emb_pp
    y = np.array([{'pos': 1, 'neg': 0, 'unk': 2}[l] for l in labels])

    # Split data
    np.random.seed(42 + run)
    unk_idx = np.argwhere(y==2).flatten()
    unk_mask = np.zeros(x.shape[0], dtype=bool)
    unk_mask[unk_idx] = True
    groups = np.random.choice(folds, x.shape[0])
    train_idx = np.argwhere(groups!=fold).flatten()
    train_idx = np.array(list(set(train_idx) - set(unk_idx)))
    train_mask = np.zeros(x.shape[0], dtype=bool)
    train_mask[train_idx] = True
    val_idx = np.array(list(set(list(range(x.shape[0]))) - set(train_idx)))
    val_idx = np.array(list(set(val_idx) - set(unk_idx)))
    val_mask = np.zeros(x.shape[0], dtype=bool)
    val_mask[val_idx] = True

    # Create dataset
    dataset = tg.data.Data(
        x=torch.tensor(x).float(),
        edge_index=torch.tensor(edge_index, dtype=int),
        edge_weight=torch.tensor(edge_weight).float(),
        y=torch.tensor(y, dtype=int),
        train_mask=torch.tensor(train_mask),
        val_mask=torch.tensor(val_mask),
        unk_mask=torch.tensor(unk_mask))
    assert dataset.is_directed() == directed

    return dataset

dataset = generate_dataset(genes, labels, emb_pp, fold, folds, run)
dataset
# Out:
# Data(x=[1609, 128], edge_index=[2, 21276], y=[1609], edge_weight=[21276], train_mask=[1609], val_mask=[1609], unk_mask=[1609])

# %% [markdown]
# ## Model Types

# %%
# class GCN(torch.nn.Module):
#     def __init__(self, input_size, **kwargs):
#         super().__init__()
#         self.encode = gnn.Sequential('x, edge_index, edge_weight', [
#             (nn.Linear(input_size, 2*input_size), 'x -> x'),
#             # (gnn.GCNConv(32, 64), 'x, edge_index, edge_weight -> x'),
#             # (nn.LeakyReLU(), 'x -> x'),
#             (gnn.GCNConv(2*input_size, input_size), 'x, edge_index, edge_weight -> x'),
#             (nn.LeakyReLU(), 'x -> x'),
#             (gnn.GCNConv(input_size, int(input_size/2)), 'x, edge_index, edge_weight -> x'),
#             (nn.LeakyReLU(), 'x -> x'),
#         ])
#         self.decode = gnn.Sequential('x, edge_index, edge_weight', [
#             (nn.Linear(int(input_size/2), 2), 'x -> x'),
#             # (gnn.GCNConv(16, 2), 'x, edge_index, edge_weight -> x'),
#             (nn.LogSoftmax(dim=-1), 'x -> x'),
#         ])

#     def forward(self, data):
#         x, edge_index, edge_weight = data.x, data.edge_index, data.edge_weight
#         return self.decode(self.encode(x, edge_index, edge_weight), edge_index, edge_weight)

# model_str = 'gcn'
# model_class = GCN

class MLP(torch.nn.Module):
    def __init__(self, input_size, dropout=.6, **kwargs):
        super().__init__()
        self.encode = nn.Sequential(
            # nn.Dropout(dropout),
            
            nn.Linear(input_size, 2*input_size),
            nn.Dropout(dropout),
            nn.BatchNorm1d(2*input_size),
            nn.LeakyReLU(),
            
            nn.Linear(2*input_size, input_size),
            nn.Dropout(dropout),
            nn.BatchNorm1d(input_size),
            nn.LeakyReLU(),
            
            nn.Linear(input_size, int(input_size/2)),
            nn.Dropout(dropout),
            nn.BatchNorm1d(int(input_size/2)),
            nn.LeakyReLU(),
        )
        self.decode = nn.Sequential(
            nn.Linear(int(input_size/2), 2),
            nn.LogSoftmax(dim=-1),
        )

    def forward(self, data):
        x, edge_index, edge_weight = data.x, data.edge_index, data.edge_weight
        return self.decode(self.encode(x))
    
model_str = 'mlp'
model_class = MLP

# %% [markdown]
# ## Training

# %%
def generate_model(model_class, dataset, model_dir, model_str, cell_type, dim, num_walks, walk_length, dropout, lr, gamma, percentile, fold, folds, run, verbose=False, return_epoch=False):
    torch.manual_seed(42 + run*folds + fold)
    np.random.seed(42 + run*folds + fold)

    # Train model
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = model_class(dataset.x.shape[1], dropout=dropout).to(device)
    data = dataset.to(device)
    # Optim with lr decay
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer=optimizer, gamma=gamma)

    fname = f'{model_dir}/{model_str}-{cell_type}-{run}-{fold}_{folds}.h5'
    hp_fname = f'{model_dir}/{model_str}-{cell_type}-{run}.txt'
    model.train()
    if os.path.exists(fname):
        epoch = 0
        model.load_state_dict(torch.load(fname))
    else:
        max_lapses = 100; min_improvement = 1e-2  # 500, 50
        min_loss = np.inf; lapses = 0
        for epoch in range(10_001):
            # Step
            optimizer.zero_grad()
            out = model(data)
            loss = F.nll_loss(out[data.train_mask], data.y[data.train_mask])
            loss.backward()
            optimizer.step()
            scheduler.step()
            
            # Use validation loss
            val_loss = F.nll_loss(out[data.val_mask], data.y[data.val_mask])
            use_loss = val_loss
            
            # CLI
            if use_loss < min_loss - min_improvement:
                min_loss = use_loss.detach()
                lapses = 0
            else:
                lapses += 1
            if lapses >= max_lapses:
                if verbose:
                    print(f'Epoch {epoch}\nTrain Loss: {float(loss.detach()):.4f}\nValid Loss: {float(val_loss.detach()):.4f}')
                break
            if epoch % 100 == 0:
                # val_loss = F.nll_loss(out[data.val_mask], data.y[data.val_mask])
                if verbose:
                    print(f'Epoch {epoch}\nTrain Loss: {float(loss.detach()):.4f}\nValid Loss: {float(val_loss.detach()):.4f}')
        torch.save(model.state_dict(), fname)
        hparams = np.array([
            ['percentile', 'dim', 'num_walks', 'walk_length', 'dropout', 'lr', 'gamma'],
            [percentile, dim, num_walks, walk_length, dropout, lr, gamma],
        ])
        np.savetxt(hp_fname, hparams, fmt=' '.join(hparams.shape[1]*['%s']))
    model.eval()
    
    if return_epoch:
        return model, epoch
    return model


dropout, lr, gamma = dropout_list[run], lr_list[run], gamma_list[run]
model = generate_model(model_class, dataset, model_dir, model_str, cell_type, dim, num_walks, walk_length, dropout, lr, gamma, percentile, fold, folds, run, verbose=True)
# Out:
# Epoch 0
# Train Loss: 0.7088
# Valid Loss: 0.7192
# Epoch 100
# Train Loss: 0.2500
# Valid Loss: 0.2450
# Epoch 200
# Train Loss: 0.2441
# Valid Loss: 0.2666
# Epoch 268
# Train Loss: 0.2429
# Valid Loss: 0.2539

# %%
def evaluate_predictions(model, dataset, labels):
    pred_raw = model(dataset).detach()
    pred = pred_raw.argmax(dim=1)
    threshold = pred_raw[dataset.train_mask, 1].flatten().quantile(1 - (sum(labels=='pos') / (sum(labels=='pos') + sum(labels=='neg'))))
    logits = pred_raw[:, 1][dataset.val_mask]
    trans = {'pos': 1, 'neg': 0, 'unk': 2}
    trans_inv = {v: k for k, v in trans.items()}
    true = torch.Tensor([trans[l] for l in labels[dataset.val_mask]]).long()

    # AUROC
    fpr, tpr, thresholds = roc_curve(true[np.argwhere(true!=2).squeeze()], logits[np.argwhere(true!=2).squeeze()])
    auroc = auc(fpr, tpr)

    return auroc, pred_raw

auroc, pred_raw = evaluate_predictions(model, dataset, labels)
print(f'AUROC:\t{auroc:.4f}')
# Out:
# AUROC:	0.5506

# %% [markdown]
# ### Advanced Evaluation

# %%
# pred_raw = model(dataset.to(device)).detach()
# pred = pred_raw.argmax(dim=1)
# threshold = pred_raw[data.train_mask, 1].flatten().quantile(1 - (sum(labels=='pos') / (sum(labels=='pos') + sum(labels=='neg'))))

# print('Evaluating performance...')
# print('Train')
# ## Train
# # Perform prediction
# logits = pred_raw[:, 1][data.train_mask]
# trans = {'pos': 1, 'neg': 0, 'unk': 2}
# trans_inv = {v: k for k, v in trans.items()}
# true = torch.Tensor([trans[l] for l in labels[dataset.train_mask]]).long()

# # Get confusion
# conf = confusion_matrix(true, 1*(logits > threshold))
# # conf = confusion_matrix(true, pred)
# print('T\P\t' + '\t'.join([trans_inv[i] for i in range(len(trans_inv)-1)]))
# for i, row in enumerate(conf):
#     print(trans_inv[i] + '\t' + '\t'.join([str(e) for e in row]))

# # Other statistics
# fpr, tpr, thresholds = roc_curve(true[np.argwhere(true!=2).squeeze()], logits[np.argwhere(true!=2).squeeze()])
# print(f'AUROC:\t{auc(fpr, tpr):.4f}')
# prec, rec, thresholds = precision_recall_curve(true[np.argwhere(true!=2).squeeze()], logits[np.argwhere(true!=2).squeeze()])
# print(f'AUPRC:\t{auc(rec, prec):.4f}')
# correct = (pred[data.train_mask] == data.y[dataset.train_mask]).sum()
# acc = int(correct) / int(dataset.train_mask.sum())
# print(f'Accuracy: {acc:.4f}')
# print()

# print('Eval')
# ## Eval
# # Perform prediction
# logits = pred_raw[:, 1][data.val_mask]
# trans = {'pos': 1, 'neg': 0, 'unk': 2}
# trans_inv = {v: k for k, v in trans.items()}
# true = torch.Tensor([trans[l] for l in labels[dataset.val_mask]]).long()

# # Get confusion
# conf = confusion_matrix(true, 1*(logits > threshold))
# # conf = confusion_matrix(true, pred)
# print('T\P\t' + '\t'.join([trans_inv[i] for i in range(len(trans_inv))]))
# for i, row in enumerate(conf):
#     print(trans_inv[i] + '\t' + '\t'.join([str(e) for e in row]))

# # Other statistics
# fpr, tpr, thresholds = roc_curve(true[np.argwhere(true!=2).squeeze()], logits[np.argwhere(true!=2).squeeze()])
# print(f'AUROC:\t{auc(fpr, tpr):.4f}')
# prec, rec, thresholds = precision_recall_curve(true[np.argwhere(true!=2).squeeze()], logits[np.argwhere(true!=2).squeeze()])
# print(f'AUPRC:\t{auc(rec, prec):.4f}')
# correct = (pred[dataset.val_mask] == dataset.y[dataset.val_mask]).sum()
# acc = int(correct) / int(dataset.val_mask.sum())
# print(f'Accuracy: {acc:.4f}')
# print()

# %% [markdown]
# ## Folds

# %%
auroc_list = []
ad_dict = defaultdict(lambda: np.zeros(3))
for cell_fname in cell_fnames:
    cell_type = cell_fname.split('.')[0]
    print(f'---------{cell_type}')

    auroc_list.append([])
    for run in range(runs):
        print(f'------Run {run+1}')
        
        auroc_list[-1].append([])
        for fold in range(folds):
            print(f'---Fold {fold+1}', end='\t')
            
            ### Generate graph
            tg_genes = get_data(cell_fname, directed=directed)
            reg_threshold = filter_elist(percentile)

            ### Read graph
            dim, num_walks, walk_length = dim_list[run], num_walks_list[run], walk_length_list[run]
            dropout, lr, gamma = dropout_list[run], lr_list[run], gamma_list[run]
            genes, labels, emb_pp = get_embeddings_from_elist(model_dir, cell_type, tg_genes, dim, num_walks, walk_length, percentile, run)
                                        
            ### Make dataset
            dataset = generate_dataset(genes, labels, emb_pp, fold, folds, run)

            ### Train model
            model, end_epoch = generate_model(model_class, dataset, model_dir, model_str, cell_type, dim, num_walks, walk_length, dropout, lr, gamma, percentile, fold, folds, run, return_epoch=True)
            
            ### Perform predictions
            auroc, pred_raw = evaluate_predictions(model, dataset, labels)
            auroc_list[-1][-1].append(auroc)
            # for i, g in enumerate(genes):
            #     if (dataset.unk_mask[i] or dataset.val_mask[i]) and auroc > .5:
            #         ad_dict[g] += np.array([auroc**2 * np.exp(float(pred_raw[i, 1])), auroc**2, 1])
            
            ### CLI
            print(f'AUROC:\t{auroc:.4f}', end='\t')
            print(f'Epochs:\t{end_epoch}')
# Out:
# ---------Astrocyte
# ------Run 1
# ---Fold 1	AUROC:	0.5506	Epochs:	0
# ---Fold 2	AUROC:	0.5197	Epochs:	222
# ---Fold 3	AUROC:	0.4604	Epochs:	226
# ---Fold 4	AUROC:	0.7447	Epochs:	168
# ---Fold 5	AUROC:	0.4704	Epochs:	264
# ------Run 2
# ---Fold 1	AUROC:	0.6575	Epochs:	100
# ---Fold 2	AUROC:	0.4476	Epochs:	100
# ---Fold 3	AUROC:	0.4611	Epochs:	100
# ---Fold 4	AUROC:	0.3416	Epochs:	100
# ---Fold 5	AUROC:	0.6742	Epochs:	100
# ------Run 3
# ---Fold 1	AUROC:	0.6002	Epochs:	117
# ---Fold 2	AUROC:	0.4872	Epochs:	100
# ---Fold 3	AUROC:	0.3852	Epochs:	116
# ---Fold 4	AUROC:	0.6230	Epochs:	110
# ---Fold 5	AUROC:	0.5592	Epochs:	114
# ------Run 4
# ---Fold 1	AUROC:	0.5055	Epochs:	332
# ---Fold 2	AUROC:	0.5590	Epochs:	385
# ---Fold 3	AUROC:	0.3646	Epochs:	356
# ---Fold 4	AUROC:	0.5790	Epochs:	306
# ---Fold 5	AUROC:	0.5150	Epochs:	415
# ------Run 5
# ---Fold 1	AUROC:	0.5549	Epochs:	102
# ---Fold 2	AUROC:	0.4939	Epochs:	103
# ---Fold 3	AUROC:	0.4741	Epochs:	106
# ---Fold 4	AUROC:	0.5169	Epochs:	102
# ---Fold 5	AUROC:	0.5385	Epochs:	103
# ------Run 6
# ---Fold 1	AUROC:	0.5867	Epochs:	429
# ---Fold 2	AUROC:	0.5646	Epochs:	356
# ---Fold 3	AUROC:	0.2977	Epochs:	425
# ---Fold 4	AUROC:	0.5273	Epochs:	375
# ---Fold 5	AUROC:	0.2838	Epochs:	341
# ------Run 7
# ---Fold 1	AUROC:	0.5693	Epochs:	100
# ---Fold 2	AUROC:	0.3366	Epochs:	100
# ---Fold 3	AUROC:	0.4497	Epochs:	100
# ---Fold 4	AUROC:	0.4868	Epochs:	124
# ---Fold 5	AUROC:	0.5925	Epochs:	100
# ------Run 8
# ---Fold 1	AUROC:	0.4831	Epochs:	120
# ---Fold 2	AUROC:	0.3802	Epochs:	125
# ---Fold 3	AUROC:	0.5678	Epochs:	119
# ---Fold 4	AUROC:	0.5509	Epochs:	111
# ---Fold 5	AUROC:	0.4846	Epochs:	184
# ------Run 9
# ---Fold 1	AUROC:	0.3876	Epochs:	111
# ---Fold 2	AUROC:	0.5660	Epochs:	110
# ---Fold 3	AUROC:	0.4163	Epochs:	113
# ---Fold 4	AUROC:	0.4536	Epochs:	109
# ---Fold 5	AUROC:	0.4760	Epochs:	110
# ------Run 10
# ---Fold 1	AUROC:	0.5524	Epochs:	297
# ---Fold 2	AUROC:	0.5586	Epochs:	340
# ---Fold 3	AUROC:	0.3908	Epochs:	341
# ---Fold 4	AUROC:	0.5635	Epochs:	299
# ---Fold 5	AUROC:	0.2506	Epochs:	317
# ------Run 11
# ---Fold 1	AUROC:	0.4665	Epochs:	112
# ---Fold 2	AUROC:	0.5645	Epochs:	122
# ---Fold 3	AUROC:	0.4331	Epochs:	110
# ---Fold 4	AUROC:	0.4363	Epochs:	119
# ---Fold 5	AUROC:	0.4363	Epochs:	116
# ------Run 12
# ---Fold 1	AUROC:	0.4653	Epochs:	156
# ---Fold 2	AUROC:	0.4141	Epochs:	133
# ---Fold 3	AUROC:	0.4615	Epochs:	100
# ---Fold 4	AUROC:	0.4080	Epochs:	100
# ---Fold 5	AUROC:	0.6746	Epochs:	100
# ------Run 13
# ---Fold 1	AUROC:	0.3931	Epochs:	121
# ---Fold 2	AUROC:	0.5493	Epochs:	121
# ---Fold 3	AUROC:	0.5572	Epochs:	118
# ---Fold 4	AUROC:	0.4937	Epochs:	117
# ---Fold 5	AUROC:	0.4794	Epochs:	148
# ------Run 14
# ---Fold 1	AUROC:	0.5896	Epochs:	122
# ---Fold 2	AUROC:	0.4324	Epochs:	114
# ---Fold 3	AUROC:	0.2571	Epochs:	107
# ---Fold 4	AUROC:	0.4660	Epochs:	104
# ---Fold 5	AUROC:	0.5021	Epochs:	104
# ------Run 15
# ---Fold 1	AUROC:	0.4133	Epochs:	298
# ---Fold 2	AUROC:	0.6198	Epochs:	348
# ---Fold 3	AUROC:	0.3318	Epochs:	273
# ---Fold 4	AUROC:	0.6224	Epochs:	309
# ---Fold 5	AUROC:	0.3787	Epochs:	322
# ------Run 16
# ---Fold 1	AUROC:	0.5197	Epochs:	114
# ---Fold 2	AUROC:	0.4330	Epochs:	117
# ---Fold 3	AUROC:	0.5333	Epochs:	110
# ---Fold 4	AUROC:	0.4601	Epochs:	101
# ---Fold 5	AUROC:	0.4261	Epochs:	121
# ------Run 17
# ---Fold 1	AUROC:	0.5078	Epochs:	291
# ---Fold 2	AUROC:	0.4919	Epochs:	318
# ---Fold 3	AUROC:	0.6126	Epochs:	311
# ---Fold 4	AUROC:	0.4901	Epochs:	266
# ---Fold 5	AUROC:	0.4847	Epochs:	340
# ------Run 18
# ---Fold 1	AUROC:	0.5032	Epochs:	116
# ---Fold 2	AUROC:	0.5693	Epochs:	121
# ---Fold 3	AUROC:	0.4780	Epochs:	101
# ---Fold 4	AUROC:	0.4669	Epochs:	122
# ---Fold 5	AUROC:	0.5788	Epochs:	102
# ------Run 19
# ---Fold 1	AUROC:	0.6768	Epochs:	115
# ---Fold 2	AUROC:	0.4655	Epochs:	124
# ---Fold 3	AUROC:	0.3992	Epochs:	128
# ---Fold 4	AUROC:	0.4452	Epochs:	131
# ---Fold 5	AUROC:	0.2785	Epochs:	121
# ------Run 20
# ---Fold 1	AUROC:	0.4482	Epochs:	355
# ---Fold 2	AUROC:	0.2968	Epochs:	330
# ---Fold 3	AUROC:	0.3064	Epochs:	417
# ---Fold 4	AUROC:	0.5296	Epochs:	347
# ---Fold 5	AUROC:	0.5658	Epochs:	393
# ---------Endothelial
# ------Run 1
# ---Fold 1	AUROC:	0.4503	Epochs:	266
# ---Fold 2	AUROC:	0.5048	Epochs:	305
# ---Fold 3	AUROC:	0.6895	Epochs:	198
# ---Fold 4	AUROC:	0.5078	Epochs:	154
# ---Fold 5	AUROC:	0.4722	Epochs:	273
# ------Run 2
# ---Fold 1	AUROC:	0.6278	Epochs:	100
# ---Fold 2	AUROC:	0.6321	Epochs:	100
# ---Fold 3	AUROC:	0.4855	Epochs:	100
# ---Fold 4	AUROC:	0.5254	Epochs:	100
# ---Fold 5	AUROC:	0.5655	Epochs:	100
# ------Run 3
# ---Fold 1	AUROC:	0.6789	Epochs:	100
# ---Fold 2	AUROC:	0.6442	Epochs:	100
# ---Fold 3	AUROC:	0.4972	Epochs:	100
# ---Fold 4	AUROC:	0.4705	Epochs:	100
# ---Fold 5	AUROC:	0.5033	Epochs:	100
# ------Run 4
# ---Fold 1	AUROC:	0.6502	Epochs:	386
# ---Fold 2	AUROC:	0.4048	Epochs:	301
# ---Fold 3	AUROC:	0.5133	Epochs:	361
# ---Fold 4	AUROC:	0.5089	Epochs:	373
# ---Fold 5	AUROC:	0.4704	Epochs:	293
# ------Run 5
# ---Fold 1	AUROC:	0.5012	Epochs:	103
# ---Fold 2	AUROC:	0.4688	Epochs:	102
# ---Fold 3	AUROC:	0.6594	Epochs:	146
# ---Fold 4	AUROC:	0.4653	Epochs:	102
# ---Fold 5	AUROC:	0.3865	Epochs:	103
# ------Run 6
# ---Fold 1	AUROC:	0.4160	Epochs:	443
# ---Fold 2	AUROC:	0.2601	Epochs:	513
# ---Fold 3	AUROC:	0.7160	Epochs:	310
# ---Fold 4	AUROC:	0.5018	Epochs:	339
# ---Fold 5	AUROC:	0.5140	Epochs:	384
# ------Run 7
# ---Fold 1	AUROC:	0.5960	Epochs:	100
# ---Fold 2	AUROC:	0.5034	Epochs:	100
# ---Fold 3	AUROC:	0.6063	Epochs:	100
# ---Fold 4	AUROC:	0.5066	Epochs:	100
# ---Fold 5	AUROC:	0.4000	Epochs:	100
# ------Run 8
# ---Fold 1	AUROC:	0.5630	Epochs:	102
# ---Fold 2	AUROC:	0.6649	Epochs:	318
# ---Fold 3	AUROC:	0.6789	Epochs:	123
# ---Fold 4	AUROC:	0.5589	Epochs:	150
# ---Fold 5	AUROC:	0.4647	Epochs:	110
# ------Run 9
# ---Fold 1	AUROC:	0.5552	Epochs:	122
# ---Fold 2	AUROC:	0.5664	Epochs:	114
# ---Fold 3	AUROC:	0.4776	Epochs:	116
# ---Fold 4	AUROC:	0.4183	Epochs:	108
# ---Fold 5	AUROC:	0.5062	Epochs:	127
# ------Run 10
# ---Fold 1	AUROC:	0.4430	Epochs:	270
# ---Fold 2	AUROC:	0.4871	Epochs:	345
# ---Fold 3	AUROC:	0.4650	Epochs:	394
# ---Fold 4	AUROC:	0.6205	Epochs:	304
# ---Fold 5	AUROC:	0.3764	Epochs:	340
# ------Run 11
# ---Fold 1	AUROC:	0.5648	Epochs:	109
# ---Fold 2	AUROC:	0.6620	Epochs:	111
# ---Fold 3	AUROC:	0.6344	Epochs:	109
# ---Fold 4	AUROC:	0.7730	Epochs:	101
# ---Fold 5	AUROC:	0.5598	Epochs:	118
# ------Run 12
# ---Fold 1	AUROC:	0.5959	Epochs:	100
# ---Fold 2	AUROC:	0.5680	Epochs:	100
# ---Fold 3	AUROC:	0.5776	Epochs:	100
# ---Fold 4	AUROC:	0.5959	Epochs:	100
# ---Fold 5	AUROC:	0.8217	Epochs:	100
# ------Run 13
# ---Fold 1	AUROC:	0.4293	Epochs:	121
# ---Fold 2	AUROC:	0.6839	Epochs:	113
# ---Fold 3	AUROC:	0.5194	Epochs:	117
# ---Fold 4	AUROC:	0.5019	Epochs:	116
# ---Fold 5	AUROC:	0.7652	Epochs:	121
# ------Run 14
# ---Fold 1	AUROC:	0.4138	Epochs:	107
# ---Fold 2	AUROC:	0.4235	Epochs:	109
# ---Fold 3	AUROC:	0.5325	Epochs:	124
# ---Fold 4	AUROC:	0.3625	Epochs:	105
# ---Fold 5	AUROC:	0.8654	Epochs:	119
# ------Run 15
# ---Fold 1	AUROC:	0.4940	Epochs:	513
# ---Fold 2	AUROC:	0.7415	Epochs:	302
# ---Fold 3	AUROC:	0.4268	Epochs:	245
# ---Fold 4	AUROC:	0.4328	Epochs:	413
# ---Fold 5	AUROC:	0.4300	Epochs:	388
# ------Run 16
# ---Fold 1	AUROC:	0.5430	Epochs:	151
# ---Fold 2	AUROC:	0.3479	Epochs:	128
# ---Fold 3	AUROC:	0.7276	Epochs:	106
# ---Fold 4	AUROC:	0.4204	Epochs:	126
# ---Fold 5	AUROC:	0.4860	Epochs:	134
# ------Run 17
# ---Fold 1	AUROC:	0.4569	Epochs:	265
# ---Fold 2	AUROC:	0.4466	Epochs:	263
# ---Fold 3	AUROC:	0.4327	Epochs:	309
# ---Fold 4	AUROC:	0.4823	Epochs:	280
# ---Fold 5	AUROC:	0.3988	Epochs:	338
# ------Run 18
# ---Fold 1	AUROC:	0.3987	Epochs:	101
# ---Fold 2	AUROC:	0.4435	Epochs:	102
# ---Fold 3	AUROC:	0.4902	Epochs:	101
# ---Fold 4	AUROC:	0.5696	Epochs:	101
# ---Fold 5	AUROC:	0.4129	Epochs:	121
# ------Run 19
# ---Fold 1	AUROC:	0.4969	Epochs:	133
# ---Fold 2	AUROC:	0.5630	Epochs:	133
# ---Fold 3	AUROC:	0.2528	Epochs:	103
# ---Fold 4	AUROC:	0.6572	Epochs:	131
# ---Fold 5	AUROC:	0.6123	Epochs:	124
# ------Run 20
# ---Fold 1	AUROC:	0.4994	Epochs:	231
# ---Fold 2	AUROC:	0.6219	Epochs:	341
# ---Fold 3	AUROC:	0.5455	Epochs:	381
# ---Fold 4	AUROC:	0.5782	Epochs:	347
# ---Fold 5	AUROC:	0.5344	Epochs:	301
# ---------GABAergic neuron
# ------Run 1
# ---Fold 1	AUROC:	0.4337	Epochs:	183
# ---Fold 2	AUROC:	0.4062	Epochs:	212
# ---Fold 3	AUROC:	0.4478	Epochs:	223
# ---Fold 4	AUROC:	0.4700	Epochs:	229
# ---Fold 5	AUROC:	0.6305	Epochs:	185
# ------Run 2
# ---Fold 1	AUROC:	0.2746	Epochs:	100
# ---Fold 2	AUROC:	0.7690	Epochs:	100
# ---Fold 3	AUROC:	0.3725	Epochs:	100
# ---Fold 4	AUROC:	0.5722	Epochs:	100
# ---Fold 5	AUROC:	0.3347	Epochs:	100
# ------Run 3
# ---Fold 1	AUROC:	0.5095	Epochs:	100
# ---Fold 2	AUROC:	0.5701	Epochs:	100
# ---Fold 3	AUROC:	0.2456	Epochs:	100
# ---Fold 4	AUROC:	0.5312	Epochs:	100
# ---Fold 5	AUROC:	0.6051	Epochs:	100
# ------Run 4
# ---Fold 1	AUROC:	0.5856	Epochs:	355
# ---Fold 2	AUROC:	0.7986	Epochs:	338
# ---Fold 3	AUROC:	0.4862	Epochs:	239
# ---Fold 4	AUROC:	0.6744	Epochs:	425
# ---Fold 5	AUROC:	0.5437	Epochs:	344
# ------Run 5
# ---Fold 1	AUROC:	0.6175	Epochs:	103
# ---Fold 2	AUROC:	0.6615	Epochs:	120
# ---Fold 3	AUROC:	0.3669	Epochs:	104
# ---Fold 4	AUROC:	0.3996	Epochs:	102
# ---Fold 5	AUROC:	0.6532	Epochs:	108
# ------Run 6
# ---Fold 1	AUROC:	0.4688	Epochs:	330
# ---Fold 2	AUROC:	0.5440	Epochs:	337
# ---Fold 3	AUROC:	0.3507	Epochs:	383
# ---Fold 4	AUROC:	0.4807	Epochs:	452
# ---Fold 5	AUROC:	0.4664	Epochs:	298
# ------Run 7
# ---Fold 1	AUROC:	0.4609	Epochs:	100
# ---Fold 2	AUROC:	0.3378	Epochs:	100
# ---Fold 3	AUROC:	0.2087	Epochs:	100
# ---Fold 4	AUROC:	0.5447	Epochs:	100
# ---Fold 5	AUROC:	0.6618	Epochs:	100
# ------Run 8
# ---Fold 1	AUROC:	0.2467	Epochs:	155
# ---Fold 2	AUROC:	0.7411	Epochs:	111
# ---Fold 3	AUROC:	0.5132	Epochs:	132
# ---Fold 4	AUROC:	0.5328	Epochs:	139
# ---Fold 5	AUROC:	0.5869	Epochs:	184
# ------Run 9
# ---Fold 1	AUROC:	0.3341	Epochs:	157
# ---Fold 2	AUROC:	0.6982	Epochs:	128
# ---Fold 3	AUROC:	0.5403	Epochs:	138
# ---Fold 4	AUROC:	0.5872	Epochs:	116
# ---Fold 5	AUROC:	0.4401	Epochs:	116
# ------Run 10
# ---Fold 1	AUROC:	0.7125	Epochs:	425
# ---Fold 2	AUROC:	0.4948	Epochs:	313
# ---Fold 3	AUROC:	0.6074	Epochs:	416
# ---Fold 4	AUROC:	0.5599	Epochs:	343
# ---Fold 5	AUROC:	0.5735	Epochs:	263
# ------Run 11
# ---Fold 1	AUROC:	0.3160	Epochs:	120
# ---Fold 2	AUROC:	0.1656	Epochs:	101
# ---Fold 3	AUROC:	0.2992	Epochs:	124
# ---Fold 4	AUROC:	0.4703	Epochs:	111
# ---Fold 5	AUROC:	0.4080	Epochs:	111
# ------Run 12
# ---Fold 1	AUROC:	0.7730	Epochs:	100
# ---Fold 2	AUROC:	0.2471	Epochs:	100
# ---Fold 3	AUROC:	0.3550	Epochs:	100
# ---Fold 4	AUROC:	0.4625	Epochs:	100
# ---Fold 5	AUROC:	0.5586	Epochs:	100
# ------Run 13
# ---Fold 1	AUROC:	0.3463	Epochs:	121
# ---Fold 2	AUROC:	0.4678	Epochs:	119
# ---Fold 3	AUROC:	0.4380	Epochs:	119
# ---Fold 4	AUROC:	0.4780	Epochs:	117
# ---Fold 5	AUROC:	0.0000	Epochs:	127
# ------Run 14
# ---Fold 1	AUROC:	0.5642	Epochs:	108
# ---Fold 2	AUROC:	0.6276	Epochs:	114
# ---Fold 3	AUROC:	0.5224	Epochs:	125
# ---Fold 4	AUROC:	0.5804	Epochs:	120
# ---Fold 5	AUROC:	0.6704	Epochs:	112
# ------Run 15
# ---Fold 1	AUROC:	0.3931	Epochs:	256
# ---Fold 2	AUROC:	0.8632	Epochs:	411
# ---Fold 3	AUROC:	0.2139	Epochs:	205
# ---Fold 4	AUROC:	0.6896	Epochs:	403
# ---Fold 5	AUROC:	0.3367	Epochs:	361
# ------Run 16
# ---Fold 1	AUROC:	0.4319	Epochs:	112
# ---Fold 2	AUROC:	0.5976	Epochs:	107
# ---Fold 3	AUROC:	0.3972	Epochs:	205
# ---Fold 4	AUROC:	0.5887	Epochs:	117
# ---Fold 5	AUROC:	0.3875	Epochs:	128
# ------Run 17
# ---Fold 1	AUROC:	0.2938	Epochs:	327
# ---Fold 2	AUROC:	0.2755	Epochs:	382
# ---Fold 3	AUROC:	0.6150	Epochs:	266
# ---Fold 4	AUROC:	0.5213	Epochs:	340
# ---Fold 5	AUROC:	0.4746	Epochs:	286
# ------Run 18
# ---Fold 1	AUROC:	0.2774	Epochs:	145
# ---Fold 2	AUROC:	0.6251	Epochs:	101
# ---Fold 3	AUROC:	0.4967	Epochs:	116
# ---Fold 4	AUROC:	0.4316	Epochs:	115
# ---Fold 5	AUROC:	0.4520	Epochs:	119
# ------Run 19
# ---Fold 1	AUROC:	0.4892	Epochs:	104
# ---Fold 2	AUROC:	0.4744	Epochs:	118
# ---Fold 3	AUROC:	0.5023	Epochs:	117
# ---Fold 4	AUROC:	0.3270	Epochs:	170
# ---Fold 5	AUROC:	0.4394	Epochs:	126
# ------Run 20
# ---Fold 1	AUROC:	0.2979	Epochs:	216
# ---Fold 2	AUROC:	0.3359	Epochs:	429
# ---Fold 3	AUROC:	0.6741	Epochs:	364
# ---Fold 4	AUROC:	0.5948	Epochs:	314
# ---Fold 5	AUROC:	0.3591	Epochs:	263
# ---------GABAergic PVALB interneuron
# ------Run 1
# ---Fold 1	AUROC:	0.2834	Epochs:	195
# ---Fold 2	AUROC:	0.4655	Epochs:	164
# ---Fold 3	AUROC:	0.5893	Epochs:	151
# ---Fold 4	AUROC:	0.5258	Epochs:	252
# ---Fold 5	AUROC:	0.2884	Epochs:	158
# ------Run 2
# ---Fold 1	AUROC:	0.5292	Epochs:	100
# ---Fold 2	AUROC:	0.4359	Epochs:	100
# ---Fold 3	AUROC:	0.5647	Epochs:	100
# ---Fold 4	AUROC:	0.3382	Epochs:	100
# ---Fold 5	AUROC:	0.2982	Epochs:	100
# ------Run 3
# ---Fold 1	AUROC:	0.5137	Epochs:	100
# ---Fold 2	AUROC:	0.4377	Epochs:	100
# ---Fold 3	AUROC:	0.5151	Epochs:	100
# ---Fold 4	AUROC:	0.5451	Epochs:	100
# ---Fold 5	AUROC:	0.4966	Epochs:	100
# ------Run 4
# ---Fold 1	AUROC:	0.4355	Epochs:	411
# ---Fold 2	AUROC:	0.5029	Epochs:	280
# ---Fold 3	AUROC:	0.5123	Epochs:	263
# ---Fold 4	AUROC:	0.5157	Epochs:	279
# ---Fold 5	AUROC:	0.7134	Epochs:	329
# ------Run 5
# ---Fold 1	AUROC:	0.6655	Epochs:	190
# ---Fold 2	AUROC:	0.5494	Epochs:	110
# ---Fold 3	AUROC:	0.3903	Epochs:	104
# ---Fold 4	AUROC:	0.3981	Epochs:	102
# ---Fold 5	AUROC:	0.6716	Epochs:	112
# ------Run 6
# ---Fold 1	AUROC:	0.7159	Epochs:	345
# ---Fold 2	AUROC:	0.4032	Epochs:	389
# ---Fold 3	AUROC:	0.2683	Epochs:	368
# ---Fold 4	AUROC:	0.5224	Epochs:	375
# ---Fold 5	AUROC:	0.7404	Epochs:	415
# ------Run 7
# ---Fold 1	AUROC:	0.5717	Epochs:	100
# ---Fold 2	AUROC:	0.3304	Epochs:	100
# ---Fold 3	AUROC:	0.4243	Epochs:	100
# ---Fold 4	AUROC:	0.5000	Epochs:	100
# ---Fold 5	AUROC:	0.3778	Epochs:	100
# ------Run 8
# ---Fold 1	AUROC:	0.3496	Epochs:	102
# ---Fold 2	AUROC:	0.4780	Epochs:	113
# ---Fold 3	AUROC:	0.5648	Epochs:	114
# ---Fold 4	AUROC:	0.7472	Epochs:	101
# ---Fold 5	AUROC:	0.5600	Epochs:	106
# ------Run 9
# ---Fold 1	AUROC:	0.6416	Epochs:	118
# ---Fold 2	AUROC:	0.5083	Epochs:	121
# ---Fold 3	AUROC:	0.4940	Epochs:	115
# ---Fold 4	AUROC:	0.6325	Epochs:	164
# ---Fold 5	AUROC:	0.4017	Epochs:	111
# ------Run 10
# ---Fold 1	AUROC:	0.4372	Epochs:	326
# ---Fold 2	AUROC:	0.4548	Epochs:	363
# ---Fold 3	AUROC:	0.4859	Epochs:	381
# ---Fold 4	AUROC:	0.3712	Epochs:	360
# ---Fold 5	AUROC:	0.4348	Epochs:	384
# ------Run 11
# ---Fold 1	AUROC:	0.4745	Epochs:	109
# ---Fold 2	AUROC:	0.6519	Epochs:	129
# ---Fold 3	AUROC:	0.3860	Epochs:	123
# ---Fold 4	AUROC:	0.4014	Epochs:	113
# ---Fold 5	AUROC:	0.4363	Epochs:	115
# ------Run 12
# ---Fold 1	AUROC:	0.7426	Epochs:	100
# ---Fold 2	AUROC:	0.5621	Epochs:	100
# ---Fold 3	AUROC:	0.6047	Epochs:	100
# ---Fold 4	AUROC:	0.6143	Epochs:	100
# ---Fold 5	AUROC:	0.5540	Epochs:	100
# ------Run 13
# ---Fold 1	AUROC:	0.6808	Epochs:	122
# ---Fold 2	AUROC:	0.6339	Epochs:	117
# ---Fold 3	AUROC:	0.8397	Epochs:	121
# ---Fold 4	AUROC:	0.6417	Epochs:	109
# ---Fold 5	AUROC:	0.6462	Epochs:	119
# ------Run 14
# ---Fold 1	AUROC:	0.4543	Epochs:	107
# ---Fold 2	AUROC:	0.4879	Epochs:	112
# ---Fold 3	AUROC:	0.4355	Epochs:	120
# ---Fold 4	AUROC:	0.4450	Epochs:	107
# ---Fold 5	AUROC:	0.3925	Epochs:	104
# ------Run 15
# ---Fold 1	AUROC:	0.5662	Epochs:	327
# ---Fold 2	AUROC:	0.3364	Epochs:	337
# ---Fold 3	AUROC:	0.5203	Epochs:	266
# ---Fold 4	AUROC:	0.7172	Epochs:	408
# ---Fold 5	AUROC:	0.4464	Epochs:	319
# ------Run 16
# ---Fold 1	AUROC:	0.7381	Epochs:	105
# ---Fold 2	AUROC:	0.4872	Epochs:	114
# ---Fold 3	AUROC:	0.5525	Epochs:	109
# ---Fold 4	AUROC:	0.4236	Epochs:	116
# ---Fold 5	AUROC:	0.2890	Epochs:	115
# ------Run 17
# ---Fold 1	AUROC:	0.2919	Epochs:	224
# ---Fold 2	AUROC:	0.3981	Epochs:	281
# ---Fold 3	AUROC:	0.2609	Epochs:	343
# ---Fold 4	AUROC:	0.4827	Epochs:	324
# ---Fold 5	AUROC:	0.6107	Epochs:	440
# ------Run 18
# ---Fold 1	AUROC:	0.3072	Epochs:	101
# ---Fold 2	AUROC:	0.3383	Epochs:	124
# ---Fold 3	AUROC:	0.4248	Epochs:	125
# ---Fold 4	AUROC:	0.6914	Epochs:	102
# ---Fold 5	AUROC:	0.4684	Epochs:	131
# ------Run 19
# ---Fold 1	AUROC:	0.3487	Epochs:	112
# ---Fold 2	AUROC:	0.6646	Epochs:	134
# ---Fold 3	AUROC:	0.3571	Epochs:	124
# ---Fold 4	AUROC:	0.6841	Epochs:	103
# ---Fold 5	AUROC:	0.6957	Epochs:	130
# ------Run 20
# ---Fold 1	AUROC:	0.6143	Epochs:	443
# ---Fold 2	AUROC:	0.5462	Epochs:	506
# ---Fold 3	AUROC:	0.3437	Epochs:	284
# ---Fold 4	AUROC:	0.4075	Epochs:	313
# ---Fold 5	AUROC:	0.4579	Epochs:	321
# ---------GABAergic SST interneuron
# ------Run 1
# ---Fold 1	AUROC:	0.3805	Epochs:	147
# ---Fold 2	AUROC:	0.3222	Epochs:	259
# ---Fold 3	AUROC:	0.3228	Epochs:	215
# ---Fold 4	AUROC:	0.4335	Epochs:	224
# ---Fold 5	AUROC:	0.3333	Epochs:	254
# ------Run 2
# ---Fold 1	AUROC:	0.3469	Epochs:	100
# ---Fold 2	AUROC:	0.6018	Epochs:	100
# ---Fold 3
# C:\Users\nck\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_ranking.py:1029: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# AUROC:	nan	Epochs:	100
# ---Fold 4	AUROC:	0.4222	Epochs:	100
# ---Fold 5	AUROC:	0.4067	Epochs:	100
# ------Run 3
# ---Fold 1	AUROC:	0.7261	Epochs:	100
# ---Fold 2	AUROC:	0.4059	Epochs:	100
# ---Fold 3	AUROC:	0.2084	Epochs:	100
# ---Fold 4	AUROC:	0.4298	Epochs:	100
# ---Fold 5	AUROC:	0.4451	Epochs:	100
# ------Run 4
# ---Fold 1	AUROC:	0.6343	Epochs:	319
# ---Fold 2	AUROC:	0.4065	Epochs:	317
# ---Fold 3	AUROC:	0.4699	Epochs:	304
# ---Fold 4	AUROC:	0.5577	Epochs:	332
# ---Fold 5	AUROC:	0.6431	Epochs:	347
# ------Run 5
# ---Fold 1	AUROC:	0.6943	Epochs:	233
# ---Fold 2	AUROC:	0.2101	Epochs:	103
# ---Fold 3	AUROC:	0.6816	Epochs:	202
# ---Fold 4	AUROC:	0.5193	Epochs:	103
# ---Fold 5	AUROC:	0.4471	Epochs:	102
# ------Run 6
# ---Fold 1	AUROC:	0.5098	Epochs:	355
# ---Fold 2	AUROC:	0.3464	Epochs:	285
# ---Fold 3	AUROC:	0.5645	Epochs:	254
# ---Fold 4	AUROC:	0.3082	Epochs:	477
# ---Fold 5	AUROC:	0.4719	Epochs:	379
# ------Run 7
# ---Fold 1	AUROC:	0.5076	Epochs:	100
# ---Fold 2	AUROC:	0.4103	Epochs:	100
# ---Fold 3	AUROC:	0.2595	Epochs:	100
# ---Fold 4	AUROC:	0.5483	Epochs:	100
# ---Fold 5	AUROC:	0.4717	Epochs:	100
# ------Run 8
# ---Fold 1	AUROC:	0.6069	Epochs:	101
# ---Fold 2	AUROC:	0.2798	Epochs:	102
# ---Fold 3	AUROC:	0.3200	Epochs:	131
# ---Fold 4	AUROC:	0.5931	Epochs:	117
# ---Fold 5	AUROC:	0.5737	Epochs:	117
# ------Run 9
# ---Fold 1	AUROC:	0.4687	Epochs:	115
# ---Fold 2	AUROC:	0.4422	Epochs:	109
# ---Fold 3	AUROC:	0.4773	Epochs:	135
# ---Fold 4	AUROC:	0.4137	Epochs:	114
# ---Fold 5	AUROC:	0.2266	Epochs:	114
# ------Run 10
# ---Fold 1	AUROC:	0.5260	Epochs:	367
# ---Fold 2	AUROC:	0.3750	Epochs:	315
# ---Fold 3	AUROC:	0.6095	Epochs:	416
# ---Fold 4	AUROC:	0.4386	Epochs:	324
# ---Fold 5	AUROC:	0.5745	Epochs:	340
# ------Run 11
# ---Fold 1	AUROC:	0.5661	Epochs:	118
# ---Fold 2	AUROC:	0.5461	Epochs:	114
# ---Fold 3	AUROC:	0.6088	Epochs:	120
# ---Fold 4	AUROC:	0.4076	Epochs:	119
# ---Fold 5	AUROC:	0.5163	Epochs:	116
# ------Run 12
# ---Fold 1	AUROC:	0.4722	Epochs:	100
# ---Fold 2	AUROC:	0.3812	Epochs:	100
# ---Fold 3	AUROC:	0.5614	Epochs:	100
# ---Fold 4	AUROC:	0.4842	Epochs:	100
# ---Fold 5	AUROC:	0.3914	Epochs:	100
# ------Run 13
# ---Fold 1	AUROC:	0.4869	Epochs:	112
# ---Fold 2	AUROC:	0.4681	Epochs:	126
# ---Fold 3	AUROC:	0.3455	Epochs:	108
# ---Fold 4	AUROC:	0.4906	Epochs:	113
# ---Fold 5	AUROC:	0.3211	Epochs:	118
# ------Run 14
# ---Fold 1	AUROC:	0.5337	Epochs:	107
# ---Fold 2	AUROC:	0.5941	Epochs:	132
# ---Fold 3	AUROC:	0.6267	Epochs:	119
# ---Fold 4	AUROC:	0.3476	Epochs:	101
# ---Fold 5	AUROC:	0.6319	Epochs:	120
# ------Run 15
# ---Fold 1	AUROC:	0.6256	Epochs:	251
# ---Fold 2	AUROC:	0.3993	Epochs:	297
# ---Fold 3	AUROC:	0.5430	Epochs:	286
# ---Fold 4	AUROC:	0.3930	Epochs:	432
# ---Fold 5	AUROC:	0.3478	Epochs:	387
# ------Run 16
# ---Fold 1	AUROC:	0.5725	Epochs:	175
# ---Fold 2	AUROC:	0.4697	Epochs:	197
# ---Fold 3	AUROC:	0.5486	Epochs:	132
# ---Fold 4	AUROC:	0.5370	Epochs:	152
# ---Fold 5	AUROC:	0.5516	Epochs:	132
# ------Run 17
# ---Fold 1	AUROC:	0.4264	Epochs:	286
# ---Fold 2	AUROC:	0.7000	Epochs:	190
# ---Fold 3	AUROC:	0.4633	Epochs:	282
# ---Fold 4	AUROC:	0.4380	Epochs:	341
# ---Fold 5	AUROC:	0.4085	Epochs:	290
# ------Run 18
# ---Fold 1	AUROC:	0.4639	Epochs:	114
# ---Fold 2	AUROC:	0.5308	Epochs:	115
# ---Fold 3	AUROC:	0.4313	Epochs:	113
# ---Fold 4	AUROC:	0.3155	Epochs:	111
# ---Fold 5	AUROC:	0.3695	Epochs:	115
# ------Run 19
# ---Fold 1	AUROC:	0.4757	Epochs:	110
# ---Fold 2	AUROC:	0.2784	Epochs:	102
# ---Fold 3	AUROC:	0.4922	Epochs:	102
# ---Fold 4	AUROC:	0.4808	Epochs:	146
# ---Fold 5	AUROC:	0.5223	Epochs:	134
# ------Run 20
# ---Fold 1	AUROC:	0.4554	Epochs:	337
# ---Fold 2	AUROC:	0.5617	Epochs:	419
# ---Fold 3	AUROC:	0.4833	Epochs:	357
# ---Fold 4	AUROC:	0.5213	Epochs:	339
# ---Fold 5	AUROC:	0.3056	Epochs:	354
# ---------GABAergic VIP interneuron
# ------Run 1
# ---Fold 1	AUROC:	0.4762	Epochs:	159
# ---Fold 2	AUROC:	0.3115	Epochs:	169
# ---Fold 3	AUROC:	0.6698	Epochs:	231
# ---Fold 4	AUROC:	0.6523	Epochs:	192
# ---Fold 5	AUROC:	0.3447	Epochs:	188
# ------Run 2
# ---Fold 1	AUROC:	0.2795	Epochs:	100
# ---Fold 2	AUROC:	0.3925	Epochs:	100
# ---Fold 3	AUROC:	0.4124	Epochs:	100
# ---Fold 4	AUROC:	0.6510	Epochs:	100
# ---Fold 5	AUROC:	0.6352	Epochs:	100
# ------Run 3
# ---Fold 1	AUROC:	0.4819	Epochs:	100
# ---Fold 2	AUROC:	0.3994	Epochs:	100
# ---Fold 3	AUROC:	0.6531	Epochs:	100
# ---Fold 4	AUROC:	0.4402	Epochs:	100
# ---Fold 5	AUROC:	0.4609	Epochs:	100
# ------Run 4
# ---Fold 1	AUROC:	0.4261	Epochs:	332
# ---Fold 2	AUROC:	0.4704	Epochs:	399
# ---Fold 3	AUROC:	0.3519	Epochs:	341
# ---Fold 4	AUROC:	0.6349	Epochs:	354
# ---Fold 5	AUROC:	0.5527	Epochs:	347
# ------Run 5
# ---Fold 1	AUROC:	0.4143	Epochs:	103
# ---Fold 2	AUROC:	0.4983	Epochs:	132
# ---Fold 3	AUROC:	0.6196	Epochs:	134
# ---Fold 4	AUROC:	0.6149	Epochs:	124
# ---Fold 5	AUROC:	0.6856	Epochs:	105
# ------Run 6
# ---Fold 1	AUROC:	0.6059	Epochs:	332
# ---Fold 2	AUROC:	0.5034	Epochs:	373
# ---Fold 3	AUROC:	0.5278	Epochs:	422
# ---Fold 4	AUROC:	0.6222	Epochs:	420
# ---Fold 5	AUROC:	0.5526	Epochs:	415
# ------Run 7
# ---Fold 1	AUROC:	0.5771	Epochs:	100
# ---Fold 2	AUROC:	0.5368	Epochs:	100
# ---Fold 3	AUROC:	0.3495	Epochs:	100
# ---Fold 4	AUROC:	0.5857	Epochs:	100
# ---Fold 5	AUROC:	0.6120	Epochs:	100
# ------Run 8
# ---Fold 1	AUROC:	0.4379	Epochs:	128
# ---Fold 2	AUROC:	0.4377	Epochs:	109
# ---Fold 3	AUROC:	0.3089	Epochs:	140
# ---Fold 4	AUROC:	0.6420	Epochs:	147
# ---Fold 5	AUROC:	0.6333	Epochs:	101
# ------Run 9
# ---Fold 1	AUROC:	0.5460	Epochs:	126
# ---Fold 2	AUROC:	0.5510	Epochs:	122
# ---Fold 3	AUROC:	0.6019	Epochs:	168
# ---Fold 4	AUROC:	0.6246	Epochs:	153
# ---Fold 5	AUROC:	0.3878	Epochs:	115
# ------Run 10
# ---Fold 1	AUROC:	0.3480	Epochs:	340
# ---Fold 2	AUROC:	0.5884	Epochs:	361
# ---Fold 3	AUROC:	0.5094	Epochs:	402
# ---Fold 4	AUROC:	0.6820	Epochs:	329
# ---Fold 5	AUROC:	0.5614	Epochs:	247
# ------Run 11
# ---Fold 1	AUROC:	0.5908	Epochs:	121
# ---Fold 2	AUROC:	0.5197	Epochs:	108
# ---Fold 3	AUROC:	0.6015	Epochs:	116
# ---Fold 4	AUROC:	0.5180	Epochs:	115
# ---Fold 5	AUROC:	0.4416	Epochs:	116
# ------Run 12
# ---Fold 1	AUROC:	0.3908	Epochs:	100
# ---Fold 2	AUROC:	0.4495	Epochs:	100
# ---Fold 3	AUROC:	0.4680	Epochs:	100
# ---Fold 4	AUROC:	0.8385	Epochs:	100
# ---Fold 5	AUROC:	0.8161	Epochs:	100
# ------Run 13
# ---Fold 1	AUROC:	0.2633	Epochs:	115
# ---Fold 2	AUROC:	0.3685	Epochs:	119
# ---Fold 3	AUROC:	0.1779	Epochs:	167
# ---Fold 4	AUROC:	0.3696	Epochs:	111
# ---Fold 5	AUROC:	0.5850	Epochs:	117
# ------Run 14
# ---Fold 1	AUROC:	0.4825	Epochs:	107
# ---Fold 2	AUROC:	0.6790	Epochs:	108
# ---Fold 3	AUROC:	0.4125	Epochs:	125
# ---Fold 4	AUROC:	0.4652	Epochs:	101
# ---Fold 5	AUROC:	0.5236	Epochs:	101
# ------Run 15
# ---Fold 1	AUROC:	0.5630	Epochs:	276
# ---Fold 2	AUROC:	0.2500	Epochs:	438
# ---Fold 3	AUROC:	0.3708	Epochs:	201
# ---Fold 4	AUROC:	0.4588	Epochs:	270
# ---Fold 5	AUROC:	0.4720	Epochs:	364
# ------Run 16
# ---Fold 1	AUROC:	0.3212	Epochs:	112
# ---Fold 2	AUROC:	0.4168	Epochs:	180
# ---Fold 3	AUROC:	0.6391	Epochs:	106
# ---Fold 4	AUROC:	0.1973	Epochs:	228
# ---Fold 5	AUROC:	0.5333	Epochs:	138
# ------Run 17
# ---Fold 1	AUROC:	0.4691	Epochs:	365
# ---Fold 2	AUROC:	0.4793	Epochs:	220
# ---Fold 3	AUROC:	0.4424	Epochs:	316
# ---Fold 4	AUROC:	0.5015	Epochs:	342
# ---Fold 5	AUROC:	0.2851	Epochs:	268
# ------Run 18
# ---Fold 1	AUROC:	0.4812	Epochs:	122
# ---Fold 2	AUROC:	0.6638	Epochs:	102
# ---Fold 3	AUROC:	0.5789	Epochs:	123
# ---Fold 4	AUROC:	0.5358	Epochs:	101
# ---Fold 5	AUROC:	0.5250	Epochs:	101
# ------Run 19
# ---Fold 1	AUROC:	0.4720	Epochs:	105
# ---Fold 2	AUROC:	0.8304	Epochs:	109
# ---Fold 3	AUROC:	0.5169	Epochs:	135
# ---Fold 4	AUROC:	0.4868	Epochs:	109
# ---Fold 5	AUROC:	0.4619	Epochs:	152
# ------Run 20
# ---Fold 1	AUROC:	0.5360	Epochs:	273
# ---Fold 2	AUROC:	0.6315	Epochs:	224
# ---Fold 3	AUROC:	0.4146	Epochs:	313
# ---Fold 4	AUROC:	0.4760	Epochs:	248
# ---Fold 5	AUROC:	0.4840	Epochs:	416
# ---------Glutamatergic neuron
# ------Run 1
# ---Fold 1	AUROC:	0.5324	Epochs:	244
# ---Fold 2	AUROC:	0.5861	Epochs:	190
# ---Fold 3	AUROC:	0.4454	Epochs:	182
# ---Fold 4	AUROC:	0.3939	Epochs:	171
# ---Fold 5	AUROC:	0.4105	Epochs:	185
# ------Run 2
# ---Fold 1	AUROC:	0.6391	Epochs:	100
# ---Fold 2	AUROC:	0.4874	Epochs:	100
# ---Fold 3	AUROC:	0.4310	Epochs:	100
# ---Fold 4	AUROC:	0.4400	Epochs:	100
# ---Fold 5	AUROC:	0.5351	Epochs:	100
# ------Run 3
# ---Fold 1	AUROC:	0.4790	Epochs:	100
# ---Fold 2	AUROC:	0.5333	Epochs:	100
# ---Fold 3	AUROC:	0.6360	Epochs:	100
# ---Fold 4	AUROC:	0.6177	Epochs:	102
# ---Fold 5	AUROC:	0.6576	Epochs:	100
# ------Run 4
# ---Fold 1	AUROC:	0.2612	Epochs:	462
# ---Fold 2	AUROC:	0.4044	Epochs:	306
# ---Fold 3	AUROC:	0.4652	Epochs:	306
# ---Fold 4	AUROC:	0.6786	Epochs:	389
# ---Fold 5	AUROC:	0.6860	Epochs:	361
# ------Run 5
# ---Fold 1	AUROC:	0.4154	Epochs:	102
# ---Fold 2	AUROC:	0.3083	Epochs:	103
# ---Fold 3	AUROC:	0.7252	Epochs:	104
# ---Fold 4	AUROC:	0.3594	Epochs:	102
# ---Fold 5	AUROC:	0.3300	Epochs:	102
# ------Run 6
# ---Fold 1	AUROC:	0.5535	Epochs:	259
# ---Fold 2	AUROC:	0.5417	Epochs:	523
# ---Fold 3	AUROC:	0.4197	Epochs:	376
# ---Fold 4	AUROC:	0.4429	Epochs:	362
# ---Fold 5	AUROC:	0.5579	Epochs:	415
# ------Run 7
# ---Fold 1	AUROC:	0.6169	Epochs:	100
# ---Fold 2	AUROC:	0.7143	Epochs:	100
# ---Fold 3	AUROC:	0.4887	Epochs:	100
# ---Fold 4	AUROC:	0.3582	Epochs:	100
# ---Fold 5	AUROC:	0.5962	Epochs:	100
# ------Run 8
# ---Fold 1	AUROC:	0.1274	Epochs:	115
# ---Fold 2	AUROC:	0.3729	Epochs:	112
# ---Fold 3	AUROC:	0.3969	Epochs:	116
# ---Fold 4	AUROC:	0.4677	Epochs:	174
# ---Fold 5	AUROC:	0.6206	Epochs:	101
# ------Run 9
# ---Fold 1	AUROC:	0.6824	Epochs:	130
# ---Fold 2	AUROC:	0.4447	Epochs:	110
# ---Fold 3	AUROC:	0.4576	Epochs:	112
# ---Fold 4	AUROC:	0.3977	Epochs:	111
# ---Fold 5	AUROC:	0.3879	Epochs:	115
# ------Run 10
# ---Fold 1	AUROC:	0.5546	Epochs:	289
# ---Fold 2	AUROC:	0.6107	Epochs:	466
# ---Fold 3	AUROC:	0.5217	Epochs:	336
# ---Fold 4	AUROC:	0.6680	Epochs:	367
# ---Fold 5	AUROC:	0.6260	Epochs:	368
# ------Run 11
# ---Fold 1	AUROC:	0.3250	Epochs:	110
# ---Fold 2	AUROC:	0.5211	Epochs:	109
# ---Fold 3	AUROC:	0.5234	Epochs:	109
# ---Fold 4	AUROC:	0.6987	Epochs:	122
# ---Fold 5	AUROC:	0.6514	Epochs:	117
# ------Run 12
# ---Fold 1	AUROC:	0.4160	Epochs:	100
# ---Fold 2	AUROC:	0.4336	Epochs:	100
# ---Fold 3	AUROC:	0.4767	Epochs:	100
# ---Fold 4	AUROC:	0.4897	Epochs:	100
# ---Fold 5	AUROC:	0.5320	Epochs:	100
# ------Run 13
# ---Fold 1	AUROC:	0.6426	Epochs:	122
# ---Fold 2	AUROC:	0.7017	Epochs:	112
# ---Fold 3	AUROC:	0.6086	Epochs:	111
# ---Fold 4	AUROC:	0.4986	Epochs:	122
# ---Fold 5	AUROC:	0.6468	Epochs:	118
# ------Run 14
# ---Fold 1	AUROC:	0.6092	Epochs:	113
# ---Fold 2	AUROC:	0.4415	Epochs:	110
# ---Fold 3	AUROC:	0.6194	Epochs:	136
# ---Fold 4	AUROC:	0.5620	Epochs:	118
# ---Fold 5	AUROC:	0.4394	Epochs:	112
# ------Run 15
# ---Fold 1	AUROC:	0.5143	Epochs:	409
# ---Fold 2	AUROC:	0.5500	Epochs:	312
# ---Fold 3	AUROC:	0.6776	Epochs:	273
# ---Fold 4	AUROC:	0.5071	Epochs:	465
# ---Fold 5	AUROC:	0.6416	Epochs:	294
# ------Run 16
# ---Fold 1	AUROC:	0.4125	Epochs:	115
# ---Fold 2	AUROC:	0.4801	Epochs:	188
# ---Fold 3	AUROC:	0.4241	Epochs:	115
# ---Fold 4	AUROC:	0.3348	Epochs:	108
# ---Fold 5	AUROC:	0.2973	Epochs:	121
# ------Run 17
# ---Fold 1	AUROC:	0.5380	Epochs:	319
# ---Fold 2	AUROC:	0.4820	Epochs:	239
# ---Fold 3	AUROC:	0.4939	Epochs:	411
# ---Fold 4	AUROC:	0.5234	Epochs:	286
# ---Fold 5	AUROC:	0.5116	Epochs:	312
# ------Run 18
# ---Fold 1	AUROC:	0.4012	Epochs:	121
# ---Fold 2	AUROC:	0.5661	Epochs:	101
# ---Fold 3	AUROC:	0.5706	Epochs:	112
# ---Fold 4	AUROC:	0.6932	Epochs:	115
# ---Fold 5	AUROC:	0.5611	Epochs:	101
# ------Run 19
# ---Fold 1	AUROC:	0.3986	Epochs:	116
# ---Fold 2	AUROC:	0.6594	Epochs:	107
# ---Fold 3	AUROC:	0.5216	Epochs:	122
# ---Fold 4	AUROC:	0.7434	Epochs:	130
# ---Fold 5	AUROC:	0.3841	Epochs:	130
# ------Run 20
# ---Fold 1	AUROC:	0.5064	Epochs:	378
# ---Fold 2	AUROC:	0.3894	Epochs:	435
# ---Fold 3	AUROC:	0.3201	Epochs:	305
# ---Fold 4	AUROC:	0.4490	Epochs:	388
# ---Fold 5	AUROC:	0.6776	Epochs:	294
# ---------Microglia
# ------Run 1
# ---Fold 1	AUROC:	0.5506	Epochs:	210
# ---Fold 2	AUROC:	0.6548	Epochs:	227
# ---Fold 3	AUROC:	0.5886	Epochs:	151
# ---Fold 4	AUROC:	0.2725	Epochs:	228
# ---Fold 5	AUROC:	0.6897	Epochs:	207
# ------Run 2
# ---Fold 1	AUROC:	0.5882	Epochs:	100
# ---Fold 2	AUROC:	0.4816	Epochs:	100
# ---Fold 3	AUROC:	0.5506	Epochs:	100
# ---Fold 4	AUROC:	0.3036	Epochs:	100
# ---Fold 5	AUROC:	0.2905	Epochs:	100
# ------Run 3
# ---Fold 1	AUROC:	0.4612	Epochs:	100
# ---Fold 2	AUROC:	0.5735	Epochs:	100
# ---Fold 3	AUROC:	0.4428	Epochs:	100
# ---Fold 4	AUROC:	0.4208	Epochs:	100
# ---Fold 5	AUROC:	0.5211	Epochs:	100
# ------Run 4
# ---Fold 1	AUROC:	0.5371	Epochs:	334
# ---Fold 2	AUROC:	0.4496	Epochs:	383
# ---Fold 3	AUROC:	0.4921	Epochs:	395
# ---Fold 4	AUROC:	0.5791	Epochs:	314
# ---Fold 5	AUROC:	0.7187	Epochs:	365
# ------Run 5
# ---Fold 1	AUROC:	0.3833	Epochs:	113
# ---Fold 2	AUROC:	0.3629	Epochs:	102
# ---Fold 3	AUROC:	0.3433	Epochs:	103
# ---Fold 4	AUROC:	0.4949	Epochs:	101
# ---Fold 5	AUROC:	0.4615	Epochs:	102
# ------Run 6
# ---Fold 1	AUROC:	0.3661	Epochs:	330
# ---Fold 2	AUROC:	0.4536	Epochs:	427
# ---Fold 3	AUROC:	0.5698	Epochs:	452
# ---Fold 4	AUROC:	0.4414	Epochs:	397
# ---Fold 5	AUROC:	0.6367	Epochs:	272
# ------Run 7
# ---Fold 1	AUROC:	0.5326	Epochs:	100
# ---Fold 2	AUROC:	0.3979	Epochs:	100
# ---Fold 3	AUROC:	0.3422	Epochs:	100
# ---Fold 4	AUROC:	0.6406	Epochs:	100
# ---Fold 5	AUROC:	0.2508	Epochs:	100
# ------Run 8
# ---Fold 1	AUROC:	0.4286	Epochs:	118
# ---Fold 2	AUROC:	0.3512	Epochs:	122
# ---Fold 3	AUROC:	0.4156	Epochs:	101
# ---Fold 4	AUROC:	0.8109	Epochs:	124
# ---Fold 5	AUROC:	0.5341	Epochs:	148
# ------Run 9
# ---Fold 1	AUROC:	0.5342	Epochs:	134
# ---Fold 2	AUROC:	0.4071	Epochs:	105
# ---Fold 3	AUROC:	0.5133	Epochs:	111
# ---Fold 4	AUROC:	0.4693	Epochs:	112
# ---Fold 5	AUROC:	0.3294	Epochs:	108
# ------Run 10
# ---Fold 1	AUROC:	0.5030	Epochs:	310
# ---Fold 2	AUROC:	0.3720	Epochs:	365
# ---Fold 3	AUROC:	0.4877	Epochs:	336
# ---Fold 4	AUROC:	0.4326	Epochs:	444
# ---Fold 5	AUROC:	0.6647	Epochs:	263
# ------Run 11
# ---Fold 1	AUROC:	0.3342	Epochs:	107
# ---Fold 2	AUROC:	0.6188	Epochs:	122
# ---Fold 3	AUROC:	0.4545	Epochs:	112
# ---Fold 4	AUROC:	0.6986	Epochs:	122
# ---Fold 5	AUROC:	0.5714	Epochs:	109
# ------Run 12
# ---Fold 1	AUROC:	0.5907	Epochs:	100
# ---Fold 2	AUROC:	0.6151	Epochs:	100
# ---Fold 3	AUROC:	0.4811	Epochs:	100
# ---Fold 4	AUROC:	0.1970	Epochs:	100
# ---Fold 5	AUROC:	0.7381	Epochs:	100
# ------Run 13
# ---Fold 1	AUROC:	0.6220	Epochs:	119
# ---Fold 2	AUROC:	0.6215	Epochs:	111
# ---Fold 3	AUROC:	0.4833	Epochs:	116
# ---Fold 4	AUROC:	0.2883	Epochs:	118
# ---Fold 5	AUROC:	0.5278	Epochs:	113
# ------Run 14
# ---Fold 1	AUROC:	0.4550	Epochs:	106
# ---Fold 2	AUROC:	0.6396	Epochs:	120
# ---Fold 3	AUROC:	0.6500	Epochs:	125
# ---Fold 4	AUROC:	0.4881	Epochs:	100
# ---Fold 5	AUROC:	0.7120	Epochs:	107
# ------Run 15
# ---Fold 1	AUROC:	0.5456	Epochs:	366
# ---Fold 2	AUROC:	0.5009	Epochs:	267
# ---Fold 3	AUROC:	0.7805	Epochs:	261
# ---Fold 4	AUROC:	0.3391	Epochs:	337
# ---Fold 5	AUROC:	0.4657	Epochs:	296
# ------Run 16
# ---Fold 1	AUROC:	0.5864	Epochs:	107
# ---Fold 2	AUROC:	0.7384	Epochs:	216
# ---Fold 3	AUROC:	0.6571	Epochs:	128
# ---Fold 4	AUROC:	0.4800	Epochs:	106
# ---Fold 5	AUROC:	0.7462	Epochs:	115
# ------Run 17
# ---Fold 1	AUROC:	0.7179	Epochs:	257
# ---Fold 2	AUROC:	0.4886	Epochs:	234
# ---Fold 3	AUROC:	0.3804	Epochs:	245
# ---Fold 4	AUROC:	0.4494	Epochs:	293
# ---Fold 5	AUROC:	0.3690	Epochs:	295
# ------Run 18
# ---Fold 1	AUROC:	0.6735	Epochs:	101
# ---Fold 2	AUROC:	0.5394	Epochs:	101
# ---Fold 3	AUROC:	0.5602	Epochs:	111
# ---Fold 4	AUROC:	0.3868	Epochs:	101
# ---Fold 5	AUROC:	0.3701	Epochs:	102
# ------Run 19
# ---Fold 1	AUROC:	0.4175	Epochs:	121
# ---Fold 2	AUROC:	0.4512	Epochs:	105
# ---Fold 3	AUROC:	0.3561	Epochs:	106
# ---Fold 4	AUROC:	0.4549	Epochs:	112
# ---Fold 5	AUROC:	0.5849	Epochs:	122
# ------Run 20
# ---Fold 1	AUROC:	0.5209	Epochs:	270
# ---Fold 2	AUROC:	0.4953	Epochs:	383
# ---Fold 3	AUROC:	0.8044	Epochs:	263
# ---Fold 4	AUROC:	0.5388	Epochs:	323
# ---Fold 5	AUROC:	0.2554	Epochs:	302
# ---------Mural
# ------Run 1
# ---Fold 1	AUROC:	0.5490	Epochs:	199
# ---Fold 2	AUROC:	0.5517	Epochs:	183
# ---Fold 3	AUROC:	0.4478	Epochs:	160
# ---Fold 4	AUROC:	0.6767	Epochs:	162
# ---Fold 5	AUROC:	0.7931	Epochs:	185
# ------Run 2
# ---Fold 1	AUROC:	0.5511	Epochs:	100
# ---Fold 2	AUROC:	0.3391	Epochs:	100
# ---Fold 3	AUROC:	0.5319	Epochs:	100
# ---Fold 4	AUROC:	0.4957	Epochs:	100
# ---Fold 5	AUROC:	0.5760	Epochs:	100
# ------Run 3
# ---Fold 1	AUROC:	0.5226	Epochs:	100
# ---Fold 2	AUROC:	0.4853	Epochs:	100
# ---Fold 3	AUROC:	0.6256	Epochs:	100
# ---Fold 4	AUROC:	0.6708	Epochs:	104
# ---Fold 5	AUROC:	0.4716	Epochs:	100
# ------Run 4
# ---Fold 1	AUROC:	0.6573	Epochs:	388
# ---Fold 2	AUROC:	0.4475	Epochs:	453
# ---Fold 3	AUROC:	0.3540	Epochs:	269
# ---Fold 4	AUROC:	0.5902	Epochs:	400
# ---Fold 5	AUROC:	0.3414	Epochs:	481
# ------Run 5
# ---Fold 1	AUROC:	0.5882	Epochs:	103
# ---Fold 2	AUROC:	0.4598	Epochs:	103
# ---Fold 3	AUROC:	0.7086	Epochs:	137
# ---Fold 4	AUROC:	0.6970	Epochs:	140
# ---Fold 5	AUROC:	0.5051	Epochs:	102
# ------Run 6
# ---Fold 1	AUROC:	0.6455	Epochs:	429
# ---Fold 2	AUROC:	0.4624	Epochs:	357
# ---Fold 3	AUROC:	0.5023	Epochs:	450
# ---Fold 4	AUROC:	0.6107	Epochs:	303
# ---Fold 5	AUROC:	0.3715	Epochs:	377
# ------Run 7
# ---Fold 1	AUROC:	0.8195	Epochs:	100
# ---Fold 2	AUROC:	0.3965	Epochs:	100
# ---Fold 3	AUROC:	0.5750	Epochs:	100
# ---Fold 4	AUROC:	0.6558	Epochs:	100
# ---Fold 5	AUROC:	0.4244	Epochs:	100
# ------Run 8
# ---Fold 1	AUROC:	0.5760	Epochs:	151
# ---Fold 2	AUROC:	0.4364	Epochs:	135
# ---Fold 3	AUROC:	0.5637	Epochs:	105
# ---Fold 4	AUROC:	0.5184	Epochs:	111
# ---Fold 5	AUROC:	0.3673	Epochs:	121
# ------Run 9
# ---Fold 1	AUROC:	0.4444	Epochs:	180
# ---Fold 2	AUROC:	0.4406	Epochs:	167
# ---Fold 3	AUROC:	0.4214	Epochs:	168
# ---Fold 4	AUROC:	0.3475	Epochs:	134
# ---Fold 5	AUROC:	0.5474	Epochs:	114
# ------Run 10
# ---Fold 1	AUROC:	0.1561	Epochs:	364
# ---Fold 2	AUROC:	0.5168	Epochs:	353
# ---Fold 3	AUROC:	0.4607	Epochs:	496
# ---Fold 4	AUROC:	0.5966	Epochs:	458
# ---Fold 5	AUROC:	0.2538	Epochs:	368
# ------Run 11
# ---Fold 1	AUROC:	0.3219	Epochs:	119
# ---Fold 2	AUROC:	0.3813	Epochs:	114
# ---Fold 3	AUROC:	0.3796	Epochs:	116
# ---Fold 4	AUROC:	0.4396	Epochs:	116
# ---Fold 5	AUROC:	0.4853	Epochs:	119
# ------Run 12
# ---Fold 1	AUROC:	0.3340	Epochs:	100
# ---Fold 2	AUROC:	0.4110	Epochs:	100
# ---Fold 3	AUROC:	0.5335	Epochs:	100
# ---Fold 4	AUROC:	0.6124	Epochs:	100
# ---Fold 5	AUROC:	0.4902	Epochs:	100
# ------Run 13
# ---Fold 1	AUROC:	0.5018	Epochs:	196
# ---Fold 2	AUROC:	0.5035	Epochs:	116
# ---Fold 3	AUROC:	0.6052	Epochs:	118
# ---Fold 4	AUROC:	0.5609	Epochs:	115
# ---Fold 5	AUROC:	0.5061	Epochs:	118
# ------Run 14
# ---Fold 1	AUROC:	0.5079	Epochs:	116
# ---Fold 2	AUROC:	0.4067	Epochs:	125
# ---Fold 3	AUROC:	0.3969	Epochs:	124
# ---Fold 4	AUROC:	0.6368	Epochs:	119
# ---Fold 5	AUROC:	0.5389	Epochs:	104
# ------Run 15
# ---Fold 1	AUROC:	0.5986	Epochs:	322
# ---Fold 2	AUROC:	0.5115	Epochs:	360
# ---Fold 3
# C:\Users\nck\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_ranking.py:1029: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# AUROC:	nan	Epochs:	404
# ---Fold 4	AUROC:	0.6427	Epochs:	382
# ---Fold 5	AUROC:	0.4525	Epochs:	395
# ------Run 16
# ---Fold 1	AUROC:	0.5187	Epochs:	287
# ---Fold 2	AUROC:	0.5371	Epochs:	126
# ---Fold 3	AUROC:	0.4443	Epochs:	153
# ---Fold 4	AUROC:	0.3861	Epochs:	136
# ---Fold 5	AUROC:	0.4080	Epochs:	153
# ------Run 17
# ---Fold 1	AUROC:	0.5000	Epochs:	328
# ---Fold 2	AUROC:	0.4775	Epochs:	366
# ---Fold 3	AUROC:	0.4411	Epochs:	386
# ---Fold 4	AUROC:	0.5747	Epochs:	319
# ---Fold 5	AUROC:	0.5268	Epochs:	259
# ------Run 18
# ---Fold 1	AUROC:	0.4909	Epochs:	116
# ---Fold 2	AUROC:	0.4587	Epochs:	101
# ---Fold 3	AUROC:	0.5774	Epochs:	101
# ---Fold 4	AUROC:	0.5546	Epochs:	113
# ---Fold 5	AUROC:	0.4634	Epochs:	113
# ------Run 19
# ---Fold 1	AUROC:	0.4986	Epochs:	106
# ---Fold 2	AUROC:	0.5066	Epochs:	102
# ---Fold 3	AUROC:	0.5098	Epochs:	120
# ---Fold 4	AUROC:	0.4580	Epochs:	126
# ---Fold 5	AUROC:	0.4792	Epochs:	166
# ------Run 20
# ---Fold 1	AUROC:	0.5903	Epochs:	224
# ---Fold 2	AUROC:	0.5051	Epochs:	494
# ---Fold 3	AUROC:	0.5701	Epochs:	357
# ---Fold 4	AUROC:	0.5740	Epochs:	347
# ---Fold 5	AUROC:	0.3598	Epochs:	371
# ---------Oligodendrocyte
# ------Run 1
# ---Fold 1	AUROC:	0.5187	Epochs:	242
# ---Fold 2	AUROC:	0.2711	Epochs:	164
# ---Fold 3	AUROC:	0.4656	Epochs:	149
# ---Fold 4	AUROC:	0.2661	Epochs:	167
# ---Fold 5	AUROC:	0.7234	Epochs:	216
# ------Run 2
# ---Fold 1	AUROC:	0.3817	Epochs:	100
# ---Fold 2	AUROC:	0.4029	Epochs:	100
# ---Fold 3	AUROC:	0.4066	Epochs:	100
# ---Fold 4	AUROC:	0.4842	Epochs:	100
# ---Fold 5	AUROC:	0.4952	Epochs:	100
# ------Run 3
# ---Fold 1	AUROC:	0.2637	Epochs:	100
# ---Fold 2	AUROC:	0.7500	Epochs:	100
# ---Fold 3	AUROC:	0.1850	Epochs:	100
# ---Fold 4	AUROC:	0.3798	Epochs:	100
# ---Fold 5	AUROC:	0.6835	Epochs:	100
# ------Run 4
# ---Fold 1	AUROC:	0.0489	Epochs:	332
# ---Fold 2	AUROC:	0.6310	Epochs:	360
# ---Fold 3	AUROC:	0.4312	Epochs:	249
# ---Fold 4	AUROC:	0.5145	Epochs:	311
# ---Fold 5	AUROC:	0.5659	Epochs:	404
# ------Run 5
# ---Fold 1	AUROC:	0.5500	Epochs:	117
# ---Fold 2	AUROC:	0.5997	Epochs:	102
# ---Fold 3	AUROC:	0.2717	Epochs:	106
# ---Fold 4	AUROC:	0.6250	Epochs:	114
# ---Fold 5	AUROC:	0.6157	Epochs:	223
# ------Run 6
# ---Fold 1	AUROC:	0.3883	Epochs:	330
# ---Fold 2	AUROC:	0.5343	Epochs:	486
# ---Fold 3	AUROC:	0.4643	Epochs:	391
# ---Fold 4	AUROC:	0.7694	Epochs:	365
# ---Fold 5	AUROC:	0.5351	Epochs:	289
# ------Run 7
# ---Fold 1	AUROC:	0.4237	Epochs:	100
# ---Fold 2	AUROC:	0.2152	Epochs:	100
# ---Fold 3	AUROC:	0.4542	Epochs:	100
# ---Fold 4	AUROC:	0.2467	Epochs:	100
# ---Fold 5	AUROC:	0.4643	Epochs:	100
# ------Run 8
# ---Fold 1	AUROC:	0.2596	Epochs:	115
# ---Fold 2	AUROC:	0.5077	Epochs:	131
# ---Fold 3	AUROC:	0.4848	Epochs:	136
# ---Fold 4	AUROC:	0.0878	Epochs:	109
# ---Fold 5	AUROC:	0.4681	Epochs:	103
# ------Run 9
# ---Fold 1	AUROC:	0.5556	Epochs:	164
# ---Fold 2	AUROC:	0.4708	Epochs:	110
# ---Fold 3	AUROC:	0.5896	Epochs:	127
# ---Fold 4	AUROC:	0.7050	Epochs:	195
# ---Fold 5	AUROC:	0.5000	Epochs:	117
# ------Run 10
# ---Fold 1	AUROC:	0.4109	Epochs:	366
# ---Fold 2	AUROC:	0.4286	Epochs:	347
# ---Fold 3	AUROC:	0.5092	Epochs:	399
# ---Fold 4	AUROC:	0.5599	Epochs:	383
# ---Fold 5	AUROC:	0.5747	Epochs:	310
# ------Run 11
# ---Fold 1	AUROC:	0.5433	Epochs:	120
# ---Fold 2	AUROC:	0.2427	Epochs:	116
# ---Fold 3	AUROC:	0.3547	Epochs:	107
# ---Fold 4	AUROC:	0.4013	Epochs:	118
# ---Fold 5	AUROC:	0.3459	Epochs:	115
# ------Run 12
# ---Fold 1	AUROC:	0.7366	Epochs:	100
# ---Fold 2	AUROC:	0.3109	Epochs:	100
# ---Fold 3	AUROC:	0.5000	Epochs:	100
# ---Fold 4	AUROC:	0.3232	Epochs:	100
# ---Fold 5	AUROC:	0.6667	Epochs:	100
# ------Run 13
# ---Fold 1	AUROC:	0.5170	Epochs:	118
# ---Fold 2	AUROC:	0.4223	Epochs:	190
# ---Fold 3	AUROC:	0.6118	Epochs:	119
# ---Fold 4	AUROC:	0.5299	Epochs:	120
# ---Fold 5	AUROC:	0.3229	Epochs:	196
# ------Run 14
# ---Fold 1	AUROC:	0.4000	Epochs:	107
# ---Fold 2	AUROC:	0.3434	Epochs:	110
# ---Fold 3	AUROC:	0.4701	Epochs:	109
# ---Fold 4	AUROC:	0.6884	Epochs:	100
# ---Fold 5	AUROC:	0.2787	Epochs:	106
# ------Run 15
# ---Fold 1	AUROC:	0.6997	Epochs:	280
# ---Fold 2	AUROC:	0.5407	Epochs:	420
# ---Fold 3	AUROC:	0.7000	Epochs:	283
# ---Fold 4	AUROC:	0.5426	Epochs:	352
# ---Fold 5	AUROC:	0.3775	Epochs:	440
# ------Run 16
# ---Fold 1	AUROC:	0.5719	Epochs:	149
# ---Fold 2	AUROC:	0.7656	Epochs:	115
# ---Fold 3	AUROC:	0.2988	Epochs:	161
# ---Fold 4	AUROC:	0.5250	Epochs:	136
# ---Fold 5	AUROC:	0.4923	Epochs:	130
# ------Run 17
# ---Fold 1	AUROC:	0.5049	Epochs:	219
# ---Fold 2	AUROC:	0.3004	Epochs:	288
# ---Fold 3	AUROC:	0.4615	Epochs:	281
# ---Fold 4	AUROC:	0.4167	Epochs:	317
# ---Fold 5	AUROC:	0.5918	Epochs:	358
# ------Run 18
# ---Fold 1	AUROC:	0.7363	Epochs:	123
# ---Fold 2	AUROC:	0.3049	Epochs:	125
# ---Fold 3	AUROC:	0.3200	Epochs:	101
# ---Fold 4	AUROC:	0.4200	Epochs:	146
# ---Fold 5	AUROC:	0.2428	Epochs:	158
# ------Run 19
# ---Fold 1	AUROC:	0.6622	Epochs:	113
# ---Fold 2	AUROC:	0.4122	Epochs:	155
# ---Fold 3	AUROC:	0.7907	Epochs:	129
# ---Fold 4	AUROC:	0.3774	Epochs:	161
# ---Fold 5	AUROC:	0.7500	Epochs:	109
# ------Run 20
# ---Fold 1	AUROC:	0.6889	Epochs:	458
# ---Fold 2	AUROC:	0.4121	Epochs:	352
# ---Fold 3	AUROC:	0.5694	Epochs:	381
# ---Fold 4	AUROC:	0.4601	Epochs:	252
# ---Fold 5	AUROC:	0.8220	Epochs:	253
# ---------OPC
# ------Run 1
# ---Fold 1	AUROC:	0.5248	Epochs:	181
# ---Fold 2	AUROC:	0.4283	Epochs:	164
# ---Fold 3	AUROC:	0.5370	Epochs:	178
# ---Fold 4	AUROC:	0.4857	Epochs:	202
# ---Fold 5	AUROC:	0.3151	Epochs:	162
# ------Run 2
# ---Fold 1	AUROC:	0.5162	Epochs:	100
# ---Fold 2	AUROC:	0.6926	Epochs:	100
# ---Fold 3	AUROC:	0.0973	Epochs:	100
# ---Fold 4	AUROC:	0.3322	Epochs:	100
# ---Fold 5	AUROC:	0.5929	Epochs:	100
# ------Run 3
# ---Fold 1	AUROC:	0.3604	Epochs:	100
# ---Fold 2	AUROC:	0.6810	Epochs:	100
# ---Fold 3	AUROC:	0.2258	Epochs:	100
# ---Fold 4	AUROC:	0.4524	Epochs:	100
# ---Fold 5	AUROC:	0.4904	Epochs:	100
# ------Run 4
# ---Fold 1	AUROC:	0.5863	Epochs:	332
# ---Fold 2	AUROC:	0.2812	Epochs:	444
# ---Fold 3	AUROC:	0.4613	Epochs:	293
# ---Fold 4	AUROC:	0.3966	Epochs:	300
# ---Fold 5	AUROC:	0.3439	Epochs:	409
# ------Run 5
# ---Fold 1	AUROC:	0.4674	Epochs:	195
# ---Fold 2	AUROC:	0.3032	Epochs:	104
# ---Fold 3	AUROC:	0.5128	Epochs:	104
# ---Fold 4	AUROC:	0.5785	Epochs:	103
# ---Fold 5	AUROC:	0.5701	Epochs:	102
# ------Run 6
# ---Fold 1	AUROC:	0.6302	Epochs:	382
# ---Fold 2	AUROC:	0.3109	Epochs:	375
# ---Fold 3	AUROC:	0.3948	Epochs:	308
# ---Fold 4	AUROC:	0.5216	Epochs:	347
# ---Fold 5	AUROC:	0.2589	Epochs:	369
# ------Run 7
# ---Fold 1	AUROC:	0.4845	Epochs:	100
# ---Fold 2	AUROC:	0.1863	Epochs:	100
# ---Fold 3	AUROC:	0.5327	Epochs:	100
# ---Fold 4	AUROC:	0.4737	Epochs:	100
# ---Fold 5	AUROC:	0.4104	Epochs:	100
# ------Run 8
# ---Fold 1	AUROC:	0.4643	Epochs:	124
# ---Fold 2	AUROC:	0.2972	Epochs:	128
# ---Fold 3	AUROC:	0.7336	Epochs:	122
# ---Fold 4	AUROC:	0.4924	Epochs:	120
# ---Fold 5	AUROC:	0.2818	Epochs:	108
# ------Run 9
# ---Fold 1	AUROC:	0.4083	Epochs:	133
# ---Fold 2	AUROC:	0.5379	Epochs:	115
# ---Fold 3	AUROC:	0.4948	Epochs:	115
# ---Fold 4	AUROC:	0.4720	Epochs:	116
# ---Fold 5	AUROC:	0.5030	Epochs:	119
# ------Run 10
# ---Fold 1	AUROC:	0.6859	Epochs:	379
# ---Fold 2	AUROC:	0.4322	Epochs:	347
# ---Fold 3	AUROC:	0.4915	Epochs:	366
# ---Fold 4	AUROC:	0.6464	Epochs:	261
# ---Fold 5	AUROC:	0.1778	Epochs:	272
# ------Run 11
# ---Fold 1	AUROC:	0.3305	Epochs:	110
# ---Fold 2	AUROC:	0.4646	Epochs:	111
# ---Fold 3	AUROC:	0.4912	Epochs:	119
# ---Fold 4	AUROC:	0.3961	Epochs:	117
# ---Fold 5	AUROC:	0.3410	Epochs:	116
# ------Run 12
# ---Fold 1	AUROC:	0.6068	Epochs:	100
# ---Fold 2	AUROC:	0.6620	Epochs:	100
# ---Fold 3	AUROC:	0.6818	Epochs:	100
# ---Fold 4	AUROC:	0.6042	Epochs:	100
# ---Fold 5	AUROC:	0.6570	Epochs:	100
# ------Run 13
# ---Fold 1	AUROC:	0.3812	Epochs:	114
# ---Fold 2	AUROC:	0.4155	Epochs:	118
# ---Fold 3	AUROC:	0.3249	Epochs:	119
# ---Fold 4	AUROC:	0.5504	Epochs:	114
# ---Fold 5	AUROC:	0.2730	Epochs:	125
# ------Run 14
# ---Fold 1	AUROC:	0.3818	Epochs:	107
# ---Fold 2	AUROC:	0.6009	Epochs:	117
# ---Fold 3	AUROC:	0.5880	Epochs:	107
# ---Fold 4	AUROC:	0.5426	Epochs:	105
# ---Fold 5	AUROC:	0.4509	Epochs:	106
# ------Run 15
# ---Fold 1	AUROC:	0.3850	Epochs:	347
# ---Fold 2	AUROC:	0.7453	Epochs:	315
# ---Fold 3	AUROC:	0.5660	Epochs:	400
# ---Fold 4	AUROC:	0.3217	Epochs:	420
# ---Fold 5	AUROC:	0.3274	Epochs:	366
# ------Run 16
# ---Fold 1	AUROC:	0.5413	Epochs:	161
# ---Fold 2
# C:\Users\nck\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_ranking.py:1029: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# AUROC:	nan	Epochs:	101
# ---Fold 3	AUROC:	0.6043	Epochs:	114
# ---Fold 4	AUROC:	0.6139	Epochs:	101
# ---Fold 5	AUROC:	0.4714	Epochs:	110
# ------Run 17
# ---Fold 1	AUROC:	0.4497	Epochs:	306
# ---Fold 2	AUROC:	0.6836	Epochs:	331
# ---Fold 3	AUROC:	0.4116	Epochs:	295
# ---Fold 4	AUROC:	0.4878	Epochs:	295
# ---Fold 5	AUROC:	0.7168	Epochs:	398
# ------Run 18
# ---Fold 1	AUROC:	0.2508	Epochs:	127
# ---Fold 2	AUROC:	0.4873	Epochs:	127
# ---Fold 3	AUROC:	0.4050	Epochs:	125
# ---Fold 4	AUROC:	0.4504	Epochs:	102
# ---Fold 5	AUROC:	0.7778	Epochs:	133
# ------Run 19
# ---Fold 1	AUROC:	0.2284	Epochs:	107
# ---Fold 2	AUROC:	0.3377	Epochs:	153
# ---Fold 3	AUROC:	0.4405	Epochs:	118
# ---Fold 4	AUROC:	0.6683	Epochs:	104
# ---Fold 5	AUROC:	0.2149	Epochs:	193
# ------Run 20
# ---Fold 1	AUROC:	0.4420	Epochs:	387
# ---Fold 2	AUROC:	0.2571	Epochs:	367
# ---Fold 3	AUROC:	0.5083	Epochs:	451
# ---Fold 4	AUROC:	0.4046	Epochs:	289
# ---Fold 5	AUROC:	0.1081	Epochs:	278

# %%
# Save performance
np.save(f'{results_dir}/auroc-{runs}-{folds}.npy', auroc_list)

# %% [markdown]
# # Results

# %%
# Load performances
diseases = [
    d for d in np.intersect1d(os.listdir(get_dirs('')[0]), os.listdir(get_dirs('')[1]))
    if np.array([bad_text not in d for bad_text in ('old', 'enrichment', 'ipynb')]).all()]
# diseases.sort(key=lambda d: ('-' in d))
auroc_lists = [np.load(f'{get_dirs(d)[1]}/auroc-{runs}-{folds}.npy') for d in diseases]

# Convert to pandas df
df = pd.DataFrame(data={
    'disease': np.concatenate([
        folds*[d]
        for d in diseases
        for cts in [[s.split('.')[0] for s in os.listdir(f'./data/psychAD_merged_GRN_0.2_0.2/{d.split("-")[0]}') if s[0] != '_']]
        for ct in cts
    ]),
    'cell_type': np.concatenate([
        folds*[ct]
        for d in diseases
        for cts in [[s.split('.')[0] for s in os.listdir(f'./data/psychAD_merged_GRN_0.2_0.2/{d.split("-")[0]}') if s[0] != '_']]
        for ct in cts
    ]),
    'fold': np.concatenate([
        list(range(folds))
        for d in diseases
        for cts in [[s.split('.')[0] for s in os.listdir(f'./data/psychAD_merged_GRN_0.2_0.2/{d.split("-")[0]}') if s[0] != '_']]
        for ct in cts
    ]),
    'auroc': np.concatenate([np.concatenate(al[list(range(al.shape[0])), np.array(al).mean(axis=-1).argmax(axis=-1), :]) for al in auroc_lists]),
}).sort_values(['cell_type', 'disease', 'fold'])  # Sorting required for patches with missing runs
# Replace hyphens with arrows
df['disease'] = [s.replace('-', '$\\rightarrow$') for s in df['disease']]
# Cherry-pick
# df = df.iloc[[e not in np.array(cell_types)[[4, 7, 9, 10]] for e in df['cell_type']]]  # Remove cell types

# %%
# Style
sns.set_palette('husl', len(diseases))
style = {
    'boxprops': {'edgecolor': None},
    'medianprops': {'color': 'red', 'linewidth': 1},
    'whiskerprops': {'color': 'black', 'linewidth': 1},
    # 'capprops': {'alpha': 0},
}

# Create Figure
fig, axs = plt.subplots(1, 1, figsize=(4+2*len(diseases), 8), sharey=True)
axs = [axs]

# Barplot
sns.boxplot(ax=axs[0], data=df, y='auroc', x='cell_type', hue='disease', **style)
sns.move_legend(axs[0], 'upper right')
sns.despine(ax=axs[0], left=True, bottom=True)

# Labels
axs[0].set_ylabel(f'AUROC ({int(np.max(df["fold"])+1)}CV)')
axs[0].set_xlabel(None)
plt.xticks(rotation=20, ha='right')

# Markers
axs[0].axhline(y=.5, color='black', linestyle='--', linewidth=.5)
axs[0].set_ylim([.4, 1. if np.max(df['auroc']) > .8 else .8])

# Fade out alt runs
box_patches = [patch for patch in axs[0].patches if type(patch) == mpl.patches.PathPatch]
lines_per_boxplot = len(axs[0].lines) // len(box_patches)
for i, patch in enumerate(box_patches):
    # disease = diseases[i % len(diseases)]
    disease = df.sort_values(['cell_type', 'disease']).iloc[::folds].iloc[i]['disease']
    if '$\\rightarrow$' in disease:
        # Change patch
        patch.set_alpha(.2)
        
        # Change lines
        for line in axs[0].lines[i * lines_per_boxplot: (i + 1) * lines_per_boxplot]:
            line.set_alpha(.2)
            
# Save figure
plt.tight_layout()
plt.savefig(f'{get_dirs("")[1][:-1]}/fig_performance_box-{runs}-{folds}.svg', format='svg', bbox_inches='tight')

# %%
# Create Figure
fig, axs = plt.subplots(1, 1, figsize=(2*len(diseases), len(np.unique(df['cell_type']))))
axs = [axs]

# Plot
df_averages = (
    df
    .groupby(['cell_type', 'disease'])
    .mean()
    .drop(columns='fold')
    .reset_index()
    .pivot(index='cell_type', columns='disease', values='auroc')
)
ax = sns.heatmap(df_averages, vmin=.4, cmap='mako')

# Highlight max per row (https://stackoverflow.com/questions/62696868/highlighting-maximum-value-in-a-column-on-a-seaborn-heatmap)
from matplotlib.patches import Circle, Rectangle
row_max = df_averages.idxmax(axis=1)

for row, index in enumerate(df_averages.index):
    positions = np.argsort(np.nan_to_num(np.array(df_averages.iloc[row])))[::-1][:2]
    # position = df_averages.columns.get_loc(row_max[index])
    for position in positions:
        # ax.add_patch(Rectangle((position, row), 1, 1, fill=False, edgecolor='#FF0000', lw=2))
        ax.add_patch(Circle((position+.5, row+.5), radius=1/32, color='#FF0000', lw=2))

# Save figure
plt.tight_layout()
plt.savefig(f'{get_dirs("")[1][:-1]}/fig_performance_heat-{runs}-{folds}.svg', format='svg', bbox_inches='tight')

# %%
# Load data
auroc_list = np.load(f'{results_dir}/auroc-{runs}-{folds}.npy')

# Predict per cell type
predictions = []
for i, (cell_type, cell_fname) in enumerate(zip(cell_types, cell_fnames)):
    print(f'Running {cell_type} predictions', end='\t')
    # Get best avg auroc for cell type
    run = np.nanmean(auroc_list[i], axis=-1).argmax()
    # Print hparams
    print('(', end='')
    for j, (hp_name, hp_val) in enumerate(zip(*np.loadtxt(f'{model_dir}/{model_str}-{cell_type}-{run}.txt', dtype=str))):
        if j == 0:
            print(f'{hp_name}: {hp_val}', end='')
        else:
            print(f', {hp_name}: {hp_val}', end='')
    print(')')
    
    # Get validation predictions from each fold (TODO: Train on all data, one prediction)
    for fold in range(folds):
        # Predict
        tg_genes = get_data(cell_fname, directed=directed)
        reg_threshold = filter_elist(percentile)
        dim, num_walks, walk_length = dim_list[run], num_walks_list[run], walk_length_list[run]
        dropout, lr, gamma = dropout_list[run], lr_list[run], gamma_list[run]
        genes, labels, emb_pp = get_embeddings_from_elist(model_dir, cell_type, tg_genes, dim, num_walks, walk_length, percentile, run)
        dataset = generate_dataset(genes, labels, emb_pp, fold, folds, run)
        model = generate_model(model_class, dataset, model_dir, model_str, cell_type, dim, num_walks, walk_length, dropout, lr, gamma, percentile, fold, folds, run)
        auroc, pred_raw = evaluate_predictions(model, dataset, labels)
        
        # Record predictions
        if fold == 0:
            predictions_cell = np.zeros_like(pred_raw[:, 1])
        assert np.sum(np.abs(predictions_cell[dataset.val_mask])) == 0
        predictions_cell[dataset.val_mask] += pred_raw[dataset.val_mask][:, 1].numpy()
        
    # Format predictions
    predictions_cell = np.array([[g, float(p)] for g, p in zip(genes, pred_raw[:, 1])])
    predictions_cell = predictions_cell[np.argsort(predictions_cell[:, 1].astype(float))[::-1]]
        
    # Save predictions
    fname = f'{results_dir}/{model_str}-{cell_type}-{runs}-{folds}-Predictions.txt'
    np.savetxt(fname, predictions_cell, fmt='%s %s')
        
    predictions.append(predictions_cell)
    
# Concatenate
# np.array(predictions)  # Sometimes ragged
# Out:
# Running Astrocyte predictions	(percentile: 90, dim: 128, num_walks: 100, walk_length: 10, dropout: 0.6, lr: 0.001, gamma: 0.96)
# Running Endothelial predictions	(percentile: 90, dim: 128, num_walks: 40, walk_length: 10, dropout: 0.4, lr: 0.1, gamma: 0.99)
# Running GABAergic neuron predictions	(percentile: 90, dim: 248, num_walks: 40, walk_length: 10, dropout: 0.6, lr: 0.0001, gamma: 0.99)
# Running GABAergic PVALB interneuron predictions	(percentile: 90, dim: 512, num_walks: 80, walk_length: 10, dropout: 0.4, lr: 0.1, gamma: 0.96)
# Running GABAergic SST interneuron predictions	(percentile: 90, dim: 248, num_walks: 60, walk_length: 10, dropout: 0.0, lr: 0.01, gamma: 0.995)
# Running GABAergic VIP interneuron predictions	(percentile: 90, dim: 64, num_walks: 80, walk_length: 10, dropout: 0.0, lr: 0.0001, gamma: 0.99)
# Running Glutamatergic neuron predictions	(percentile: 90, dim: 512, num_walks: 80, walk_length: 10, dropout: 0.4, lr: 0.1, gamma: 0.96)
# Running Microglia predictions	(percentile: 90, dim: 128, num_walks: 80, walk_length: 10, dropout: 0.8, lr: 0.1, gamma: 0.99)
# Running Mural predictions	(percentile: 90, dim: 128, num_walks: 100, walk_length: 10, dropout: 0.6, lr: 0.001, gamma: 0.96)
# Running Oligodendrocyte predictions	(percentile: 90, dim: 32, num_walks: 100, walk_length: 10, dropout: 0.8, lr: 0.1, gamma: 0.99)
# Running OPC predictions	(percentile: 90, dim: 64, num_walks: 80, walk_length: 10, dropout: 0.0, lr: 0.0001, gamma: 0.99)

# %%
# Get best cell type
best_cell = (
    np.nanmean(
        auroc_list,
        axis=-1,
    )  # Average fold
    .max(axis=-1)  # Max run
    .argmax()  # Best cell idx
)

print(f'{cell_types[best_cell]} ({np.nanmean(auroc_list[best_cell], axis=-1).max():.3f}):')
for g in predictions[best_cell][:100, 0]:
    print(g)
# Out:
# GABAergic PVALB interneuron (0.688):
# HNF1A
# PID1
# ABR
# STX3
# SOX6
# DBP
# CPNE4
# SRF
# GRHL2
# MYCN
# MAMLD1
# NECAB1
# ITPR1
# ZNF740
# PKP4
# NTNG1
# TLN2
# NMNAT2
# BDH1
# GLIS1
# DIRC3
# CD276
# DGKB
# NAV2
# ACTB
# SPEN
# ETV6
# SLC38A2
# KLF9
# FOSB
# PRDM1
# BBX
# CLVS1
# KIAA1217
# MYO1D
# LHX6
# KCNQ1
# MEIS2
# KIAA0319L
# SLC22A23
# HSD17B7P2
# EGR4
# RARA
# ELK1
# POMZP3
# SLC37A1
# PTPRE
# CDKL5
# SPIN2B
# SP1
# HEY1
# FMN1
# SCMH1
# UNC5D
# ZNF84
# RUNX2
# TLK1
# ARID5B
# KLHL12
# GRID2
# GABRA1
# DIAPH2
# PIK3CB
# HIBCH
# SDHAP1
# DPP6
# GK
# CNOT10
# RBPJ
# TRPS1
# BHLHE41
# ST3GAL5
# MITF
# ZNF384
# PCSK6
# SRGAP1
# DDX3X
# SYN3
# TEF
# SLIT3
# ENPP2
# EPHB2
# KIFC3
# PNOC
# CREB3
# SOX9
# INSR
# EIF2AK3
# TRPC4
# NAV1
# KLF5
# DAB2IP
# C1D
# FILIP1
# ZNF883
# LONRF1
# PDPR
# SPECC1
# POLR2J4
# FMN2

# %% [markdown]
# # Visualization

# %%
# Set colors
sns.set_palette('husl', 3)

# Maps
name_map = {'pos': 'Disease', 'neg': 'Not Disease', 'unk': 'Unknown'}
color_map = {'pos': np.array((1, .2, .2)), 'neg': np.array((.2, .2, 1)), 'unk': np.array((0, 0, 0))}
z_map = {'pos': 2, 'neg': 1, 'unk': 0}
s_map = {'pos': 10., 'neg': 1., 'unk': .5}

# Translation
trans = {'pos': 1, 'neg': 0, 'unk': 2}
trans_inv = {v: k for k, v in trans.items()}

# %%
# %%capture
from matplotlib.lines import Line2D

# Legend
legend = [
    Line2D([], [], color=(1, 1, 1, 0), markerfacecolor=color_map[l], marker='o', markersize=10)
    for l in name_map]
legend_names = [name_map[l] for l in name_map]

# Plot legend
fig, ax = plt.subplots()
legend = ax.legend(legend, legend_names, loc='center', frameon=False, ncol=len(legend)//1)
legend.figure.canvas.draw()
bbox = legend.get_window_extent().transformed(fig.dpi_scale_trans.inverted())
plt.axis('off')
plt.tight_layout()
plt.savefig(f'{results_dir}/fig_legend.svg', format='svg', bbox_inches=bbox)

# %%
from IPython.display import display, Image
display( Image(filename=f'{results_dir}/fig_legend.png', width=800) )

# %%
### Get best model
auroc_list = np.load(f'{results_dir}/auroc-{runs}-{folds}.npy')
ct, run, fold = np.unravel_index(np.nanargmax(auroc_list), auroc_list.shape)
cell_type, cell_fname = cell_types[ct], cell_fnames[ct]

### Load best model
tg_genes = get_data(cell_fname, directed=directed)
reg_threshold = filter_elist(percentile)
dim, num_walks, walk_length = dim_list[run], num_walks_list[run], walk_length_list[run]
dropout, lr, gamma = dropout_list[run], lr_list[run], gamma_list[run]
genes, labels, emb_pp = get_embeddings_from_elist(model_dir, cell_type, tg_genes, dim, num_walks, walk_length, percentile, run)
dataset = generate_dataset(genes, labels, emb_pp, fold, folds, run)
model = generate_model(model_class, dataset, model_dir, model_str, cell_type, dim, num_walks, walk_length, dropout, lr, gamma, percentile, fold, folds, run)
auroc, pred_raw = evaluate_predictions(model, dataset, labels)

# %%
np.random.seed(42)
# submask = torch.tensor((np.random.rand(dataset.x.shape[0]) > .7), dtype=bool)
submask = dataset.val_mask
G = tg.utils.to_networkx(dataset.subgraph(np.argwhere(submask).flatten()), node_attrs=['x'], edge_attrs=['edge_weight'], to_undirected=not directed)
edge_color = [(0, 0, 0, .1*G[u][v]['edge_weight'] / float(dataset.subgraph(np.argwhere(submask).flatten()).edge_weight.max())) for u, v in G.edges]
pos = nx.spring_layout(G, weight='edge_weight', k=.5)

# Original Data
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
node_color = [color_map[trans_inv[int(v)]] for v in dataset.y[submask]]
nx.draw(
    G,
    node_color=node_color,
    edge_color=edge_color,
    node_size=10,
    pos=pos,
)
plt.title('Gene Coregulation')
plt.savefig(f'{results_dir}/fig_data-{runs}-{folds}.svg', format='svg')

# Computed Data
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
# pred = model(dataset).detach().argmax(dim=1)
threshold = pred_raw[dataset.train_mask, 1].flatten().quantile(1 - (sum(labels=='pos') / (sum(labels=='pos') + sum(labels=='neg'))))
pred = 1*(model(dataset).detach()[:, 1] > threshold)
# Show known
# node_color = [color_map[trans_inv[int(v)]] if v != 2 else color_map[trans_inv[int(w)]] for v, w in zip(dataset.y[submask], pred[submask])]
# Do not show known
# node_color = [color_map[trans_inv[int(v)]] for v in pred[submask]]
# Show spectrum
strong_range = np.std(pred_raw[submask, 1].exp().numpy())
center = np.percentile(pred_raw[submask, 1].exp().numpy(), 90)
min_range, max_range = center - strong_range, center + strong_range
node_color = [
    np.array(
        (1-((max(min(v[1], max_range), min_range) - min_range)/(2*strong_range)))*color_map['neg']
        + ((max(min(v[1], max_range), min_range) - min_range)/(2*strong_range))*color_map['pos']
    )
        for v in pred_raw[submask].exp().numpy()]
node_color = [[max(min(cv, 1), 0) for cv in c] for c in node_color]
nx.draw(
    G,
    node_color=node_color,
    edge_color=edge_color,
    node_size=10,
    pos=pos,
)
plt.title('Predicted Disease')
plt.savefig(f'{results_dir}/fig_prediction-{runs}-{folds}.svg', format='svg')
