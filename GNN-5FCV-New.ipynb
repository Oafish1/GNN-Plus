# %%
import os

import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import pandas as pd
import scipy
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.metrics import auc, precision_recall_curve, roc_curve
import torch
import torch.nn as nn
import torch_geometric as pyg
import torch_geometric.nn as gnn

# %%
np.random.seed(42)

# %% [markdown]
# # Functions

# %% [markdown]
# ## Dataset

# %%
loaded_data = {}
def get_data(cell_type):
    # Get graph
    data_folder = './data/training_matrices_DGL/'
    if cell_type in loaded_data:
        mat = loaded_data[cell_type]
    else:
        mat = pd.read_csv(data_folder + f'{cell_type}.feat.mat', index_col=0, sep='\t')
        loaded_data[cell_type] = mat
    genes = np.array(mat.columns)
    assert (genes == np.array(mat.index)).all()

    # Get labels
    meta = pd.read_csv(data_folder + 'training_labels.txt', index_col=0, sep='\t')
    labels = meta.values[:, 0]
    labels = np.array([str(meta.loc[g]['label']) if g in meta.index else 'unknown' for g in genes])

    return mat.to_numpy(), labels, genes

# %% [markdown]
# ## Model

# %%
# Create model
def no_transform(x):
    return x

class ADModel(nn.Module):
    def __init__(self, node_feats, pca_dim=None, embedding_dim=16, output_dim=2, num_walks_per_node=2, walk_len=20):
        super().__init__()
        
        if pca_dim is None:
            self.input_dim = node_feats.shape[1]
        else:
            self.input_dim = pca_dim
        # self.num_nodes = num_nodes
        self.embedding_dim = embedding_dim
        self.output_dim = output_dim
        self.num_walks_per_node = num_walks_per_node
        self.walk_len = walk_len
        
        self.embedding = nn.Sequential(
            nn.Linear(self.input_dim, 2*embedding_dim),
            nn.LeakyReLU(),
            nn.Linear(2*embedding_dim, 2*embedding_dim),
            nn.LeakyReLU(),
            nn.Linear(2*embedding_dim, embedding_dim),
        )
        self.predict = nn.Sequential(
            nn.Linear(embedding_dim, 2*embedding_dim),
            nn.LeakyReLU(),
            # nn.Dropout(.8),
            nn.Linear(2*embedding_dim, output_dim),
            nn.Softmax(dim=-1),
        )
        
        if pca_dim is not None:
            self.pca = PCA(n_components=pca_dim).fit(node_feats).transform
        else:
            self.pca = no_transform
    
    def pos_walk(self, adj_mat):
        walks = []
        for node in range(adj_mat.shape[0]):
            for walk_num in range(self.num_walks_per_node):
                walks.append([node])
                for walk_node_num in range(self.walk_len):
                    p = adj_mat[walks[-1][-1]]
                    p[walks[-1][-1]] = 0
                    p = np.array(p).astype('float64')
                    if p.sum() != 0:
                        next_node = np.random.choice(adj_mat.shape[1], 1, p=p/p.sum())[0]
                    else:
                        next_node = walks[-1][-1]
                    walks[-1].append(next_node)
        return walks
    
    def neg_walk(self, adj_mat):
        # TODO: Implement p,q
        return self.pos_walk(1.*(adj_mat==0))
        
    def forward(self, node_feats):
        if node_feats.shape[1] != self.input_dim:
            node_feats = torch.Tensor(self.pca(node_feats))
        emb = self.embedding(node_feats)
        out = self.predict(emb)
        return emb, out
    
    def loss_embedding(self, node_feats, adj_mat):
        # Get logits
        emb, _ = self(node_feats)
        # emb = torch.zeros_like(emb)
        
        # Positive walks
        pw_loss = 0
        pw = self.pos_walk(adj_mat)
        for walk in pw:
            origin = emb[walk[0]].unsqueeze(dim=0)
            neighbors = emb[walk[1:]]
            similarity = (origin * neighbors).sum(dim=1)
            pw_loss = pw_loss + -torch.log(torch.sigmoid(similarity) + 1e-8).mean()  # Sigmoid for bounding
        pw_loss = pw_loss / len(pw)
        
        # Negative walks
        nw_loss = 0
        nw = self.neg_walk(adj_mat)
        for walk in nw:
            origin = emb[walk[0]].unsqueeze(dim=0)
            neighbors = emb[walk[1:]]
            similarity = (origin * neighbors).sum(dim=1)
            nw_loss = nw_loss + -torch.log(1 - torch.sigmoid(similarity) + 1e-8).mean()
        nw_loss = nw_loss / len(nw)
        
        return pw_loss + nw_loss

    def loss_predict(self, node_feats, true):
        _, out = self(node_feats)
        
        # NLL
        return nn.NLLLoss()(out, true)
        
        # MSE
        # true_out = torch.zeros_like(out)
        # true_out[list(range(true_out.shape[0])), true] = 1
        # return nn.MSELoss()(out, true_out)

# %%
# Train model
def train_batch(node_feats, adj_mat, labels, model, optimizer, batch_size=128, loss_type=None):
    batches = node_feats.shape[0] // batch_size
    epoch_loss = 0
    for batch in range(batches):
        # Choose batch
        batch_idx = np.array([])
        for l in np.unique(labels):
            idx = np.random.choice(np.argwhere(labels == l).flatten(), int(batch_size / len(np.unique(labels))))
            batch_idx = np.concatenate([batch_idx, idx])
        
        # Loss
        if loss_type == 'emb':
            loss = model.loss_embedding(node_feats[batch_idx], adj_mat[batch_idx, :][:, batch_idx])
        elif loss_type == 'pre':
            loss = model.loss_predict(node_feats[batch_idx], labels[batch_idx])
        elif loss_type == 'both':
            loss = (
                model.loss_embedding(node_feats[batch_idx], adj_mat[batch_idx, :][:, batch_idx])
                + model.loss_predict(node_feats[batch_idx], labels[batch_idx]))
        else:
            raise Exception(f'No loss "{loss_type}" found.')
        loss.backward()
        optimizer.step()
        epoch_loss += loss.detach()
    epoch_loss /= batches
    
    return epoch_loss

def train(node_feats, adj_mat, labels, model, optimizer, epochs=None, epoch_cli=None, **kwargs):
    model.train()
    for epoch in range(epochs):
        epoch_loss = train_batch(node_feats, adj_mat, labels, model, optimizer, **kwargs)
        if epoch % epoch_cli == 0:
            print(f'Epoch {epoch} Loss: {epoch_loss:.3f}')
    model.eval()

def generate_model(node_feats, adj_mat, labels, epochs=51, epochs_p=1001, epoch_cli=10, epoch_p_cli=500, simultaneous_training=False, **kwargs):
    model = ADModel(node_feats)
    pca_node_feats = torch.Tensor(model.pca(node_feats))
    
    if simultaneous_training:
        # Both
        print('Training combined model...')
        optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
        train(pca_node_feats, adj_mat, labels, model, optimizer, loss_type='both', epochs=epochs, epoch_cli=epoch_cli, **kwargs)
        
    else:
        # Embedding
        print('Training embedding model...')
        optimizer = torch.optim.Adam(model.embedding.parameters(), lr=1e-3)
        train(pca_node_feats, adj_mat, labels, model, optimizer, loss_type='emb', epochs=epochs, epoch_cli=epoch_cli, batch_size=node_feats.shape[0], **kwargs)

        # AD
        print('Training prediction model...')
        optimizer = torch.optim.Adam(model.predict.parameters(), lr=1e-3)
        train(pca_node_feats, adj_mat, labels, model, optimizer, loss_type='pre', epochs=epochs_p, epoch_cli=epoch_p_cli, **kwargs)
    
    return model

# %% [markdown]
# ## Training

# %%
# Preload data
# cell_types = np.array([f[:-9] for f in os.listdir('./data/training_matrices_DGL') if '.mat' in f])
# for i, cell_type in enumerate(cell_types):
#     print(cell_type)
#     data, labels, genes = get_data(cell_type)

# Hyperparameters
folds = 5

# %%
# Clear results
# if os.path.exists('./results/'):
#     import shutil
#     shutil.rmtree('./results/')

# Make models
cell_types = np.array([f[:-9] for f in os.listdir('./data/training_matrices_DGL') if '.mat' in f])
auroc_list, auprc_list, acc_list = [], [], []
for i, cell_type in enumerate(cell_types):
    auroc_list.append([])
    auprc_list.append([])
    acc_list.append([])

    # Get data
    print(f'Loading {cell_type} data...')
    data, labels, genes = get_data(cell_type)
    data = torch.Tensor(data)
    # data[np.eye(data.shape[0] ,dtype=bool)] = 0  # Remove diagonal
    data = 1.*(data > .3)  # Binarize
    true = torch.Tensor([1 if l == 'AD' else (0 if l == 'notAD' else 2) for l in labels]).long()
    
    for k in range(folds):
        # Set up directory
        if not os.path.exists('./results/'):
            os.mkdir('./results/')
        if not os.path.exists(f'./results/{cell_type}'):
            os.mkdir(f'./results/{cell_type}')
        if not os.path.exists(f'./results/{cell_type}/fold{k}'):
            os.mkdir(f'./results/{cell_type}/fold{k}')
        wd = f'./results/{cell_type}/fold{k}/'
        
        # Split data
        np.random.seed(42+folds*i+k)
        train_frac = .8
        train_idx = np.random.choice(data.shape[0], int(train_frac * data.shape[0]), replace=False)
        # Take all AD and balance negatives
        train_idx_AD = train_idx[labels[train_idx] == 'AD']
        train_idx_notAD = np.random.choice(train_idx[labels[train_idx] == 'notAD'], train_idx_AD.shape[0], replace=False)
        train_idx = np.concatenate([train_idx_AD, train_idx_notAD])
        # All others as eval
        eval_idx = np.array(list(set(range(data.shape[0])) - set(train_idx)))
        
        # Graph features
        node_feats = data[train_idx]
        adj_mat = data[train_idx, :][:, train_idx]

        # Train models
        if os.path.exists(wd + 'model.h5'):
            print('Loading pre-trained model...')
            model = torch.load(wd + 'model.h5')
        else:
            model = generate_model(node_feats, adj_mat, true[train_idx])  # , epochs=1
            torch.save(model, wd + 'model.h5')
        emb, logits = model(data)
        emb, logits = emb.detach(), logits.detach()
        
        ###
        # from sklearn.neural_network import MLPClassifier
        # mlp = (
        #     MLPClassifier(max_iter=1000)
        #     .fit(
        #         emb[train_idx].detach(),
        #         true[train_idx].detach().flatten())
        # )
        # logits = mlp.predict_proba(emb)
        ###
        
        known_train_idx = np.intersect1d(train_idx, np.argwhere(labels != 'unknown'))
        known_eval_idx = np.intersect1d(eval_idx, np.argwhere(labels != 'unknown'))
        # AUROC
        def get_auroc(subset_idx):
            fpr, tpr, thresholds = roc_curve(
                1.*(labels[subset_idx] == 'AD'),
                logits[subset_idx, 1])
            return auc(fpr, tpr)
        auroc_list[-1].append(get_auroc(known_eval_idx))
        
        # AUPRC
        def get_auprc(subset_idx, balanced=True):
            prec, rec, thresholds = precision_recall_curve(
                1.*(labels[subset_idx] == 'AD'),
                logits[subset_idx, 1])
            if balanced:
                return np.log( auc(rec, prec) / ((labels[subset_idx] == 'AD').sum() / len(subset_idx)) )
            return auc(rec, prec)
        auprc_list[-1].append(get_auprc(known_eval_idx))
        
        # ACC
        def get_acc(subset_idx):
            ad_acc = (1.*(logits[subset_idx[np.argwhere(labels[subset_idx] == 'AD')], 1] > .5)).mean()
            notad_acc = (1.*(logits[subset_idx[np.argwhere(labels[subset_idx] == 'notAD')], 1] <= .5)).mean()
            return (ad_acc + notad_acc) / 2
        acc_list[-1].append(get_acc(known_eval_idx))

        # Write predictions on unknown genes
        pred = np.array(['AD' if logit > .5 else 'notAD' for logit in logits[:, 1]])
        ad_enrichment_idx = np.intersect1d(np.argwhere(pred == 'AD'), np.argwhere(labels == 'unknown'))
        ad_enrichment = genes[ad_enrichment_idx][np.argsort(-logits[:, 1][ad_enrichment_idx])]
        notad_enrichment_idx = np.intersect1d(np.argwhere(pred == 'notAD'), np.argwhere(labels == 'unknown'))
        notad_enrichment = genes[notad_enrichment_idx][np.argsort(-logits[:, 0][notad_enrichment_idx])]
        np.savetxt(wd + 'AD.txt', ad_enrichment, fmt='%s')
        np.savetxt(wd + 'notAD.txt', notad_enrichment, fmt='%s')
        ad_enrichment_idx = np.intersect1d(np.argwhere(pred == 'AD'), known_eval_idx)
        ad_enrichment = genes[ad_enrichment_idx][np.argsort(-logits[:, 1][ad_enrichment_idx])]
        notad_enrichment_idx = np.intersect1d(np.argwhere(pred == 'notAD'), known_eval_idx)
        notad_enrichment = genes[notad_enrichment_idx][np.argsort(-logits[:, 0][notad_enrichment_idx])]
        np.savetxt(wd + 'eval_AD.txt', ad_enrichment, fmt='%s')
        np.savetxt(wd + 'eval_notAD.txt', notad_enrichment, fmt='%s')
        
        # Record and CLI
        print(f'{cell_type} (fold {k}):')
        with open(wd + 'perf.txt', 'w') as f:
            f.write(f'AUROC: {auroc_list[-1][-1]:.3f}\nAUPRC: {auprc_list[-1][-1]:.3f}\nACC: {acc_list[-1][-1]:.3f}\n')
        print(f'Train:\tAUROC: {get_auroc(known_train_idx):.3f}\tAUPRC: {get_auprc(known_train_idx):.3f}\tACC: {get_acc(known_train_idx):.3f}')
        print(f'Eval: \tAUROC: {auroc_list[-1][-1]:.3f}\tAUPRC: {auprc_list[-1][-1]:.3f}\tACC: {acc_list[-1][-1]:.3f}')
        print(20 * '-')
    print(20 * '-')
auroc_list = np.array(auroc_list)
auprc_list = np.array(auprc_list)
acc_list = np.array(acc_list)
# Out:
# Loading Astrocyte data...
# Loading pre-trained model...
# Astrocyte (fold 0):
# Train:	AUROC: 0.558	AUPRC: 0.123	ACC: 0.557
# Eval: 	AUROC: 0.585	AUPRC: 0.951	ACC: 0.565
# --------------------
# Loading pre-trained model...
# Astrocyte (fold 1):
# Train:	AUROC: 0.531	AUPRC: 0.034	ACC: 0.489
# Eval: 	AUROC: 0.586	AUPRC: 0.207	ACC: 0.565
# --------------------
# Loading pre-trained model...
# Astrocyte (fold 2):
# Train:	AUROC: 0.573	AUPRC: 0.113	ACC: 0.579
# Eval: 	AUROC: 0.554	AUPRC: 1.550	ACC: 0.510
# --------------------
# Loading pre-trained model...
# Astrocyte (fold 3):
# Train:	AUROC: 0.589	AUPRC: 0.071	ACC: 0.607
# Eval: 	AUROC: 0.558	AUPRC: 1.797	ACC: 0.565
# --------------------
# Loading pre-trained model...
# Astrocyte (fold 4):
# Train:	AUROC: 0.540	AUPRC: 0.096	ACC: 0.558
# Eval: 	AUROC: 0.500	AUPRC: 1.272	ACC: 0.514
# --------------------
# --------------------
# Loading Endothelial data...
# Loading pre-trained model...
# Endothelial (fold 0):
# Train:	AUROC: 0.552	AUPRC: 0.091	ACC: 0.547
# Eval: 	AUROC: 0.554	AUPRC: 0.154	ACC: 0.500
# --------------------
# Loading pre-trained model...
# Endothelial (fold 1):
# Train:	AUROC: 0.482	AUPRC: -0.027	ACC: 0.479
# Eval: 	AUROC: 0.510	AUPRC: 0.208	ACC: 0.532
# --------------------
# Loading pre-trained model...
# Endothelial (fold 2):
# Train:	AUROC: 0.618	AUPRC: 0.182	ACC: 0.588
# Eval: 	AUROC: 0.570	AUPRC: 0.190	ACC: 0.563
# --------------------
# Loading pre-trained model...
# Endothelial (fold 3):
# Train:	AUROC: 0.519	AUPRC: -0.007	ACC: 0.525
# Eval: 	AUROC: 0.505	AUPRC: -0.015	ACC: 0.513
# --------------------
# Loading pre-trained model...
# Endothelial (fold 4):
# Train:	AUROC: 0.575	AUPRC: 0.098	ACC: 0.571
# Eval: 	AUROC: 0.627	AUPRC: 0.826	ACC: 0.522
# --------------------
# --------------------
# Loading GABAergic_neuron data...
# Loading pre-trained model...
# GABAergic_neuron (fold 0):
# Train:	AUROC: 0.570	AUPRC: 0.163	ACC: 0.564
# Eval: 	AUROC: 0.536	AUPRC: -0.025	ACC: 0.533
# --------------------
# Loading pre-trained model...
# GABAergic_neuron (fold 1):
# Train:	AUROC: 0.605	AUPRC: 0.185	ACC: 0.582
# Eval: 	AUROC: 0.551	AUPRC: 2.045	ACC: 0.520
# --------------------
# Loading pre-trained model...
# GABAergic_neuron (fold 2):
# Train:	AUROC: 0.567	AUPRC: 0.143	ACC: 0.551
# Eval: 	AUROC: 0.515	AUPRC: 0.069	ACC: 0.486
# --------------------
# Loading pre-trained model...
# GABAergic_neuron (fold 3):
# Train:	AUROC: 0.550	AUPRC: 0.123	ACC: 0.522
# Eval: 	AUROC: 0.564	AUPRC: 0.292	ACC: 0.510
# --------------------
# Loading pre-trained model...
# GABAergic_neuron (fold 4):
# Train:	AUROC: 0.591	AUPRC: 0.121	ACC: 0.585
# Eval: 	AUROC: 0.594	AUPRC: 1.776	ACC: 0.550
# --------------------
# --------------------
# Loading GABAergic_PVALB_interneuron data...
# Loading pre-trained model...
# GABAergic_PVALB_interneuron (fold 0):
# Train:	AUROC: 0.563	AUPRC: 0.105	ACC: 0.560
# Eval: 	AUROC: 0.692	AUPRC: 1.660	ACC: 0.625
# --------------------
# Loading pre-trained model...
# GABAergic_PVALB_interneuron (fold 1):
# Train:	AUROC: 0.473	AUPRC: -0.008	ACC: 0.469
# Eval: 	AUROC: 0.486	AUPRC: -0.119	ACC: 0.442
# --------------------
# Loading pre-trained model...
# GABAergic_PVALB_interneuron (fold 2):
# Train:	AUROC: 0.529	AUPRC: 0.050	ACC: 0.522
# Eval: 	AUROC: 0.617	AUPRC: 0.406	ACC: 0.556
# --------------------
# Loading pre-trained model...
# GABAergic_PVALB_interneuron (fold 3):
# Train:	AUROC: 0.521	AUPRC: 0.122	ACC: 0.511
# Eval: 	AUROC: 0.508	AUPRC: -0.063	ACC: 0.495
# --------------------
# Loading pre-trained model...
# GABAergic_PVALB_interneuron (fold 4):
# Train:	AUROC: 0.522	AUPRC: 0.097	ACC: 0.531
# Eval: 	AUROC: 0.571	AUPRC: 0.140	ACC: 0.606
# --------------------
# --------------------
# Loading GABAergic_SST_interneuron data...
# Loading pre-trained model...
# GABAergic_SST_interneuron (fold 0):
# Train:	AUROC: 0.543	AUPRC: 0.105	ACC: 0.557
# Eval: 	AUROC: 0.609	AUPRC: 0.281	ACC: 0.531
# --------------------
# Loading pre-trained model...
# GABAergic_SST_interneuron (fold 1):
# Train:	AUROC: 0.634	AUPRC: 0.235	ACC: 0.593
# Eval: 	AUROC: 0.548	AUPRC: 0.134	ACC: 0.522
# --------------------
# Loading pre-trained model...
# GABAergic_SST_interneuron (fold 2):
# Train:	AUROC: 0.541	AUPRC: 0.089	ACC: 0.500
# Eval: 	AUROC: 0.541	AUPRC: 0.160	ACC: 0.540
# --------------------
# Loading pre-trained model...
# GABAergic_SST_interneuron (fold 3):
# Train:	AUROC: 0.511	AUPRC: 0.017	ACC: 0.489
# Eval: 	AUROC: 0.542	AUPRC: 0.095	ACC: 0.537
# --------------------
# Loading pre-trained model...
# GABAergic_SST_interneuron (fold 4):
# Train:	AUROC: 0.618	AUPRC: 0.192	ACC: 0.578
# Eval: 	AUROC: 0.522	AUPRC: -0.026	ACC: 0.506
# --------------------
# --------------------
# Loading GABAergic_VIP_interneuron data...
# Loading pre-trained model...
# GABAergic_VIP_interneuron (fold 0):
# Train:	AUROC: 0.469	AUPRC: -0.063	ACC: 0.473
# Eval: 	AUROC: 0.570	AUPRC: 1.893	ACC: 0.548
# --------------------
# Loading pre-trained model...
# GABAergic_VIP_interneuron (fold 1):
# Train:	AUROC: 0.544	AUPRC: 0.111	ACC: 0.500
# Eval: 	AUROC: 0.624	AUPRC: 1.207	ACC: 0.604
# --------------------
# Loading pre-trained model...
# GABAergic_VIP_interneuron (fold 2):
# Train:	AUROC: 0.551	AUPRC: 0.106	ACC: 0.538
# Eval: 	AUROC: 0.523	AUPRC: -0.001	ACC: 0.537
# --------------------
# Loading pre-trained model...
# GABAergic_VIP_interneuron (fold 3):
# Train:	AUROC: 0.529	AUPRC: 0.078	ACC: 0.522
# Eval: 	AUROC: 0.582	AUPRC: 0.368	ACC: 0.480
# --------------------
# Loading pre-trained model...
# GABAergic_VIP_interneuron (fold 4):
# Train:	AUROC: 0.523	AUPRC: 0.029	ACC: 0.526
# Eval: 	AUROC: 0.615	AUPRC: 1.790	ACC: 0.540
# --------------------
# --------------------
# Loading Glutamatergic_neuron data...
# Loading pre-trained model...
# Glutamatergic_neuron (fold 0):
# Train:	AUROC: 0.527	AUPRC: 0.084	ACC: 0.521
# Eval: 	AUROC: 0.514	AUPRC: 0.011	ACC: 0.499
# --------------------
# Loading pre-trained model...
# Glutamatergic_neuron (fold 1):
# Train:	AUROC: 0.509	AUPRC: 0.073	ACC: 0.500
# Eval: 	AUROC: 0.505	AUPRC: 0.253	ACC: 0.510
# --------------------
# Loading pre-trained model...
# Glutamatergic_neuron (fold 2):
# Train:	AUROC: 0.457	AUPRC: -0.061	ACC: 0.481
# Eval: 	AUROC: 0.682	AUPRC: 1.596	ACC: 0.628
# --------------------
# Loading pre-trained model...
# Glutamatergic_neuron (fold 3):
# Train:	AUROC: 0.560	AUPRC: 0.134	ACC: 0.556
# Eval: 	AUROC: 0.413	AUPRC: -0.243	ACC: 0.480
# --------------------
# Loading pre-trained model...
# Glutamatergic_neuron (fold 4):
# Train:	AUROC: 0.561	AUPRC: 0.107	ACC: 0.561
# Eval: 	AUROC: 0.390	AUPRC: -0.289	ACC: 0.458
# --------------------
# --------------------
# Loading Microglia data...
# Loading pre-trained model...
# Microglia (fold 0):
# Train:	AUROC: 0.503	AUPRC: 0.113	ACC: 0.465
# Eval: 	AUROC: 0.566	AUPRC: 1.340	ACC: 0.496
# --------------------
# Loading pre-trained model...
# Microglia (fold 1):
# Train:	AUROC: 0.563	AUPRC: 0.125	ACC: 0.520
# Eval: 	AUROC: 0.548	AUPRC: 0.362	ACC: 0.521
# --------------------
# Loading pre-trained model...
# Microglia (fold 2):
# Train:	AUROC: 0.502	AUPRC: 0.018	ACC: 0.520
# Eval: 	AUROC: 0.535	AUPRC: 0.173	ACC: 0.562
# --------------------
# Loading pre-trained model...
# Microglia (fold 3):
# Train:	AUROC: 0.605	AUPRC: 0.153	ACC: 0.587
# Eval: 	AUROC: 0.557	AUPRC: 0.467	ACC: 0.522
# --------------------
# Loading pre-trained model...
# Microglia (fold 4):
# Train:	AUROC: 0.616	AUPRC: 0.203	ACC: 0.565
# Eval: 	AUROC: 0.550	AUPRC: 0.255	ACC: 0.538
# --------------------
# --------------------
# Loading Mural data...
# Loading pre-trained model...
# Mural (fold 0):
# Train:	AUROC: 0.531	AUPRC: 0.008	ACC: 0.541
# Eval: 	AUROC: 0.508	AUPRC: -0.004	ACC: 0.544
# --------------------
# Loading pre-trained model...
# Mural (fold 1):
# Train:	AUROC: 0.434	AUPRC: -0.086	ACC: 0.470
# Eval: 	AUROC: 0.601	AUPRC: 0.213	ACC: 0.607
# --------------------
# Loading pre-trained model...
# Mural (fold 2):
# Train:	AUROC: 0.577	AUPRC: 0.128	ACC: 0.574
# Eval: 	AUROC: 0.491	AUPRC: -0.107	ACC: 0.504
# --------------------
# Loading pre-trained model...
# Mural (fold 3):
# Train:	AUROC: 0.529	AUPRC: -0.016	ACC: 0.549
# Eval: 	AUROC: 0.470	AUPRC: -0.099	ACC: 0.517
# --------------------
# Loading pre-trained model...
# Mural (fold 4):
# Train:	AUROC: 0.486	AUPRC: -0.009	ACC: 0.526
# Eval: 	AUROC: 0.562	AUPRC: 0.082	ACC: 0.519
# --------------------
# --------------------
# Loading Oligodendrocyte data...
# Loading pre-trained model...
# Oligodendrocyte (fold 0):
# Train:	AUROC: 0.519	AUPRC: 0.053	ACC: 0.514
# Eval: 	AUROC: 0.523	AUPRC: 0.240	ACC: 0.579
# --------------------
# Loading pre-trained model...
# Oligodendrocyte (fold 1):
# Train:	AUROC: 0.510	AUPRC: 0.069	ACC: 0.515
# Eval: 	AUROC: 0.521	AUPRC: 0.112	ACC: 0.576
# --------------------
# Loading pre-trained model...
# Oligodendrocyte (fold 2):
# Train:	AUROC: 0.620	AUPRC: 0.249	ACC: 0.597
# Eval: 	AUROC: 0.492	AUPRC: 0.180	ACC: 0.480
# --------------------
# Loading pre-trained model...
# Oligodendrocyte (fold 3):
# Train:	AUROC: 0.524	AUPRC: 0.041	ACC: 0.500
# Eval: 	AUROC: 0.404	AUPRC: -0.219	ACC: 0.459
# --------------------
# Loading pre-trained model...
# Oligodendrocyte (fold 4):
# Train:	AUROC: 0.498	AUPRC: 0.046	ACC: 0.520
# Eval: 	AUROC: 0.510	AUPRC: 0.144	ACC: 0.532
# --------------------
# --------------------
# Loading OPC data...
# Loading pre-trained model...
# OPC (fold 0):
# Train:	AUROC: 0.532	AUPRC: -0.003	ACC: 0.526
# Eval: 	AUROC: 0.518	AUPRC: 1.265	ACC: 0.493
# --------------------
# Loading pre-trained model...
# OPC (fold 1):
# Train:	AUROC: 0.553	AUPRC: 0.113	ACC: 0.547
# Eval: 	AUROC: 0.447	AUPRC: -0.204	ACC: 0.449
# --------------------
# Loading pre-trained model...
# OPC (fold 2):
# Train:	AUROC: 0.577	AUPRC: 0.083	ACC: 0.550
# Eval: 	AUROC: 0.532	AUPRC: 0.145	ACC: 0.504
# --------------------
# Loading pre-trained model...
# OPC (fold 3):
# Train:	AUROC: 0.524	AUPRC: 0.126	ACC: 0.516
# Eval: 	AUROC: 0.503	AUPRC: -0.039	ACC: 0.488
# --------------------
# Loading pre-trained model...
# OPC (fold 4):
# Train:	AUROC: 0.519	AUPRC: -0.009	ACC: 0.505
# Eval: 	AUROC: 0.528	AUPRC: 0.045	ACC: 0.534
# --------------------
# --------------------

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Performance Metrics

# %%
# Convert to pandas df
df = pd.DataFrame(data={
    'cell_type': np.concatenate([folds*[ct] for ct in cell_types]),
    'fold': np.concatenate([list(range(folds)) for i in cell_types]),
    'auroc': np.concatenate(auroc_list),
    'auprc': np.concatenate(auprc_list),
})
sns.set_style('white')
# https://stackoverflow.com/a/65529178
style = {
    'boxprops':{'facecolor':'none', 'edgecolor':'black'},
    'medianprops':{'color':'black'},
    'whiskerprops':{'color':'black'},
    'capprops':{'color':'black'}}

# %%
fig, axs = plt.subplots(1, 1, figsize=(8, 6), sharey=True)
axs = [axs]
# Barplot
sns.boxplot(ax=axs[0], data=df, x='auroc', y='cell_type', **style)
sns.despine(ax=axs[0], left=True, bottom=True)
# sns.boxplot(ax=axs[1], data=df, x='auprc', y='cell_type', **style)
# sns.despine(ax=axs[1], left=False, bottom=True)
# Labels
axs[0].set_xlabel('AUROC')
axs[0].set_ylabel('Cell Type')
axs[0].axvline(x=.5, color='black', linestyle='--')
# axs[1].set_xlabel('AUPRC')
# axs[1].set_ylabel(None)
plt.tight_layout()
# Save figure
plt.savefig('results/fig_performance.png', dpi=300, bbox_inches='tight')

# %%
import hiveplotlib as hpl
from hiveplotlib import Axis, Node, HivePlot
from hiveplotlib.converters import networkx_to_nodes_edges
from hiveplotlib.viz import axes_viz_mpl, node_viz_mpl, edge_viz_mpl

# Get best model
best_performing_model = np.argmax(np.concatenate(auroc_list))
print(f'Best performing model: {cell_types[best_performing_model // folds]} ({best_performing_model % folds}) ({auroc_list[best_performing_model // folds][best_performing_model % folds]:.3f})')
cell_type = cell_types[best_performing_model // folds]
wd = f'results/{cell_type}/fold{best_performing_model % folds}/'
# Out:
# Best performing model: GABAergic_PVALB_interneuron (0) (0.692)

# %%
# Get data
print('Loading data...')
data, labels, genes = get_data(cell_type)
subset_idx = np.concatenate([
    np.argwhere(labels=='AD').flatten(),
    # np.argwhere(labels=='notAD').flatten(),
    np.random.choice(np.argwhere(labels=='notAD').flatten(), len(np.argwhere(labels=='AD')), replace=False),
    # np.argwhere(labels=='unknown').flatten(),
    np.random.choice(np.argwhere(labels=='unknown').flatten(), 512, replace=False),
])
data = data.copy()[subset_idx]
labels = labels[subset_idx]
genes = genes[subset_idx]
ad_true = genes[np.argwhere(labels == 'AD').flatten()]
notad_true = genes[np.argwhere(labels == 'notAD').flatten()]
ad_pred = np.intersect1d(np.loadtxt(wd + 'AD.txt', dtype=str), genes)
notad_pred = np.intersect1d(np.loadtxt(wd + 'notAD.txt', dtype=str), genes)

# Get logits
model = torch.load(wd + 'model.h5')
_, logits = model(torch.Tensor(data))
logits = logits[:, 1].detach()
print(f'Min logit: {min(logits)}\tMax logit: {max(logits)}')

# Create graph
print('Creating graph...')
# Format sparse
print('\tMaking sparse...')
sparse_data = data.copy()[:, subset_idx]
sparse_data[np.eye(sparse_data.shape[0] ,dtype=bool)] = 0  # Remove diagonal
sparse_data = 1.*(sparse_data > .3)  # Threshold
sparse_data = scipy.sparse.coo_matrix(sparse_data)
edge_indices = np.stack([sparse_data.row, sparse_data.col])
edge_indices = np.concatenate([edge_indices, edge_indices[::-1]], axis=1)  # Make undirected
edge_weights = np.concatenate([sparse_data.data, sparse_data.data])
# Construct pyg dataset
print('\tConstructing pyg...')
graph = pyg.data.Data(
    num_nodes=len(labels),
    node_name=genes,
    y=labels,
    edge_index=torch.tensor(edge_indices).to(torch.int64),
    edge_weight=torch.tensor(edge_weights).to(torch.float64))
# To networkx
print('\tConverting networkx...')
graph = pyg.utils.convert.to_networkx(graph, node_attrs=['node_name'], edge_attrs=['edge_weight'], to_undirected=True)
graph = nx.relabel_nodes(graph, lambda x: graph.nodes(data=True)[x]['node_name'], copy=False)
# Hiveplot format
print('\tConverting hp...')
nodes, edges = hpl.converters.networkx_to_nodes_edges(graph)

# Add node information
print('Computing features...')
deg_cen = nx.degree_centrality(graph)
# eig_cen = nx.eigenvector_centrality(graph)
clo_cen = nx.closeness_centrality(graph)
bet_cen = nx.betweenness_centrality(graph)
for node in nodes:
    new_data = {}
    new_data['deg'] = deg_cen[node.data['node_name']]
    # new_data['eig'] = eig_cen[node.data['node_name']]
    new_data['clo'] = clo_cen[node.data['node_name']]
    new_data['bet'] = bet_cen[node.data['node_name']]
    new_data['pad'] = float(logits[np.argwhere(genes==node.data['node_name'])[0][0]].flatten())
    new_data['pnad'] = float(1-logits[np.argwhere(genes==node.data['node_name'])[0][0]].flatten())
    node.add_data(data=new_data)

# Add node information
# print('Getting weights...')
# edge_str = np.array([' '.join(g) for g in genes[edge_indices.T]])
# weights = np.array([edge_weights[np.argwhere(edge_str == ' '.join(e))[0][0]] for e in edges])
# Out:
# Loading data...
# Min logit: 0.17871609330177307	Max logit: 0.9945483803749084
# Creating graph...
# 	Making sparse...
# 	Constructing pyg...
# 	Converting networkx...
# 	Converting hp...
# Computing features...

# %% [markdown]
# ## Preview

# %%
# Get data
adj_matrix = data[:, subset_idx]
block_list = [np.argwhere(labels=='AD'), np.argwhere(labels=='notAD'), np.argwhere(labels=='unknown')]
block_colors = ['red', 'teal', 'black']

# Sort data
idx_list = list(range(len(subset_idx)))
order_ad = [0 if labels[idx]=='AD' else (1 if labels[idx]=='notAD' else 2) for idx in idx_list]
order_sum = -adj_matrix.sum(axis=1)
order_sum = [os if order_ad[idx]%2==0 else -os for idx, os in enumerate(order_sum)]  # Smooth visual
order = list(np.stack([idx_list, order_ad, order_sum]).T)
import operator
order.sort(key=operator.itemgetter(1,2))
order = np.array(order)[:, 0].astype(int)

# Plot data
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
plt.imshow(adj_matrix[order, :][:, order], cmap='Greys', interpolation='none')

# Plot boxes
# http://sociograph.blogspot.com/2012/11/visualizing-adjacency-matrices-in-python.html
from matplotlib import patches
current_idx = 0
for block, color in zip(block_list, block_colors):
    ax.add_patch(patches.Rectangle((current_idx, current_idx),
                                   block.shape[0],
                                   block.shape[0],
                                   facecolor='none',
                                   edgecolor=color,
                                   linewidth=1.5))
    current_idx += block.shape[0]
ax.set_xticks([])
ax.set_yticks([])
plt.savefig('results/fig_data.png', dpi=300)

# %% [markdown]
# ## Hive

# %%
# %%capture
from matplotlib.lines import Line2D

# Legend
legend = [
    Line2D([], [], markerfacecolor='red', markeredgecolor='red', marker=(2, 0, 20), linestyle='None', markersize=10),
    Line2D([], [], markerfacecolor='teal', markeredgecolor='teal', marker=(2, 0, 20), linestyle='None', markersize=10),
    Line2D([], [], markerfacecolor='teal', markeredgecolor='black', marker=(2, 0, 20), linestyle='None', markersize=10),
    Line2D([], [], color=f'black', lw=1, linestyle='-')]
legend_names = ['AD Genes', 'Non-AD Genes', 'Unknown Genes', 'Coregulation']

# Plot legend
fig, ax = plt.subplots()
legend = ax.legend(legend, legend_names, loc='center', frameon=False, ncol=len(legend)//1)
legend.figure.canvas.draw()
bbox = legend.get_window_extent().transformed(fig.dpi_scale_trans.inverted())
plt.axis('off')
plt.tight_layout()
plt.savefig('results/fig_legend.png', bbox_inches=bbox, dpi=300)

# %%
# Preview
from IPython.display import display, Image
display( Image(filename='results/fig_legend.png', width=800) )

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 12))

# Create Hive Plot
print('Creating Hive Plot...')
hp = HivePlot()
hp.add_nodes(nodes)

# Axes
def get_id():
    count = 0
    while True:
        yield count
        count += 1
id_inst = get_id()
default_sort = 'deg'
axes, unique_idss, sorting_feature_to_uses = [], [], []
axes.append(Axis(axis_id=next(id_inst), start=1, end=5, angle=-10, long_name=f'Predicted Non-AD ({len(notad_pred)})'))
unique_idss.append(notad_pred)
sorting_feature_to_uses.append('pnad')
axes.append(Axis(axis_id=next(id_inst), start=1, end=5, angle=10, long_name=f'Predicted Non-AD ({len(notad_pred)})'))
unique_idss.append(notad_pred)
sorting_feature_to_uses.append('pnad')
axes.append(Axis(axis_id=next(id_inst), start=1, end=5, angle=80, long_name=f'Non-AD ({len(notad_true)})'))
unique_idss.append(notad_true)
sorting_feature_to_uses.append(default_sort)
axes.append(Axis(axis_id=next(id_inst), start=1, end=5, angle=100, long_name=f'AD ({len(ad_true)})'))
unique_idss.append(ad_true)
sorting_feature_to_uses.append(default_sort)
axes.append(Axis(axis_id=next(id_inst), start=1, end=5, angle=170, long_name=f'Predicted AD ({len(ad_pred)})'))
unique_idss.append(ad_pred)
sorting_feature_to_uses.append('pad')
axes.append(Axis(axis_id=next(id_inst), start=1, end=5, angle=190, long_name=f'Predicted AD ({len(ad_pred)})'))
unique_idss.append(ad_pred)
sorting_feature_to_uses.append('pad')
axes.append(Axis(axis_id=next(id_inst), start=1, end=5, angle=260, long_name=f'Non-AD ({len(notad_true)})'))
unique_idss.append(notad_true)
sorting_feature_to_uses.append(default_sort)
axes.append(Axis(axis_id=next(id_inst), start=1, end=5, angle=280, long_name=f'AD ({len(ad_true)})'))
unique_idss.append(ad_true)
sorting_feature_to_uses.append(default_sort)
hp.add_axes(axes)

# Nodes
for axis, unique_ids, sorting_feature_to_use in zip(axes, unique_idss, sorting_feature_to_uses):
    kwargs = {}
    # if sorting_feature_to_use != default_sort:
    #     kwargs['vmin'] = .5
    #     kwargs['vmax'] = 1
    hp.place_nodes_on_axis(axis_id=axis.axis_id, unique_ids=unique_ids, sorting_feature_to_use=sorting_feature_to_use, **kwargs)

# Edges
for i in range(len(axes)):
    hp.connect_axes(edges=edges, axis_id_1=axes[i].axis_id, axis_id_2=axes[(i+1)%len(axes)].axis_id, color='black')

# Plot
axes_viz_mpl(hp, fig=fig, ax=ax)
edge_viz_mpl(hp, fig=fig, ax=ax, alpha=.01, zorder=-1, linewidth=1.)

# Mark Nodes
for hp_ax in hp.axes.values():
    locations = hp_ax.node_placements
    ad_locations_mask = np.array([g in ad_true for g in locations.loc[:, 'unique_id']])
    notad_locations_mask = np.array([g in notad_true for g in locations.loc[:, 'unique_id']])
    for x, y in list(locations.loc[ad_locations_mask, ['x', 'y']].values):
        ax.scatter(x, y, color='red', marker=(2, 0, hp_ax.angle), s=50, lw=1, alpha=1., zorder=4)
    for x, y in list(locations.loc[notad_locations_mask, ['x', 'y']].values):
        ax.scatter(x, y, color='teal', marker=(2, 0, hp_ax.angle), s=50, lw=1, alpha=1., zorder=3)
    for x, y in list(locations.loc[~(ad_locations_mask + notad_locations_mask), ['x', 'y']].values):
        ax.scatter(x, y, color='black', marker=(2, 0, hp_ax.angle), s=50, lw=1, alpha=1., zorder=2)

plt.savefig('results/fig_prediction.png', dpi=300, bbox_inches='tight')
# Out:
# Creating Hive Plot...

# %% [markdown]
# ## Common AD

# %%
import itertools

# Find common AD genes
gene_counts = {}
folder_num = 0
for i, (cell_type, k) in enumerate(itertools.product(cell_types, range(folds))):
    # Only use best fold
    if auroc_list[i // folds][i % folds] != max(auroc_list[i // folds]):
        continue
    folder_num += 1
    results_dir = f'results/{cell_type}/fold{k}/'
    
    num_top_genes = 100
    # Add AD genes
    ad_genes = list(np.loadtxt(results_dir + 'AD.txt', dtype=str))
    for g in ad_genes[:num_top_genes]:
        if g not in gene_counts:
            gene_counts[g] = 0
        gene_counts[g] += 1
    # Add notAD genes
    notad_genes = list(np.loadtxt(results_dir + 'notAD.txt', dtype=str))
    for g in ad_genes[num_top_genes:] + notad_genes:
        if g not in gene_counts:
            gene_counts[g] = 0
filtered_ad_genes = [g for g, v in gene_counts.items() if v > 1]
filtered_strongad_genes = [g for g, v in gene_counts.items() if v > int(.4*folder_num)]
np.savetxt('results/commonAD.txt', filtered_ad_genes, fmt='%s')
np.savetxt('results/commonstrongAD.txt', filtered_strongad_genes, fmt='%s')
