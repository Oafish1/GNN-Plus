# %%
from collections import defaultdict
from itertools import product
import os
import re

import matplotlib
from matplotlib.colors import LogNorm
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import pandas as pd
import pecanpy as pp
import seaborn as sns
import sklearn.metrics
import sklearn.svm
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch_geometric
import torch_geometric.nn as gnn

# Style
sns.set_theme(context='talk', style='white', palette='Set2')
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %% [markdown]
# # Preparation

# %%
# Get files for contrast
# contrast = 'c02x'
dir = '../../data/scenic_outs/'
# fnames = [fname for fname in os.listdir(dir) if fname.startswith(f'{contrast}_')]
fnames = os.listdir(dir)

# Get groups and cell-type based on fname
# TODO: Doesn't work for groups like 'AD_resilient'
m1 = re.compile('^([cr]\d+x(_\d+)?)_([a-zA-Z]+(_(resilient|strict))?)_((?!resilient|strict)\w+)_regulon_list.csv$')
get_contrast = lambda fname: m1.match(fname).group(1)
get_group = lambda fname: m1.match(fname).group(3)
get_cell_type = lambda fname: m1.match(fname).group(6)

# Get labels
gene_dir = '../../data/new_labels/'
gene_fnames = [fname for fname in os.listdir(gene_dir) if fname.endswith('.txt')]
gene_lists = {'.'.join(fname.split('.')[:-1]): np.loadtxt(os.path.join(gene_dir, fname), dtype=str) for fname in gene_fnames}

# %%
### Custom files (overwrites previous)
# From DisGeNet.org, C0497327::C0020179::C0030567::C0236642 are negatives, C0002395 is positive
# C0002395::C0497327::C0020179::C0030567::C0236642 all together
# List choices from https://www.biorxiv.org/content/10.1101/2023.11.04.565636v1.full
disgenet = pd.read_csv('../../data/disgenet/ad_pos_neg.csv')
positive_label = 'Alzheimer\'s Disease'

# Determine positive or negative linkage
disgenet['Positive'] = disgenet['Disease'] == positive_label
disgenet['Negative'] = disgenet['Disease'] != positive_label
annotations = disgenet[['Gene', 'Positive', 'Negative']].groupby('Gene').prod().astype(bool)
disgenet = disgenet.drop(columns=['Positive', 'Negative']).set_index('Gene').join(annotations, how='left').reset_index()

# Remove inconclusive linkages
disgenet = disgenet.loc[(disgenet['Positive'] + disgenet['Negative'])]

# Threshold by score
gda_score_threshold = 0  # TODO
disgenet = disgenet.loc[disgenet['Score gda'] > gda_score_threshold]

# Finish annotation
disgenet = disgenet[['Gene', 'Positive', 'Negative']].groupby('Gene').first()
positive_genes = disgenet.index.to_numpy()[disgenet['Positive'].to_numpy()]
negative_genes = disgenet.index.to_numpy()[disgenet['Negative'].to_numpy()]

# CLI
print(f'{positive_genes.shape[0]} positive and {negative_genes.shape[0]} negative genes found.')

# Write
gene_lists['AD'] = positive_genes
gene_lists['Control_AD'] = negative_genes
# Out:
# 1774 positive and 1302 negative genes found.

# %%
# Special cases
gene_lists['scz'] = gene_lists['SCZ']
gene_lists['AD_resilient'] = gene_lists['AD_strict'] = gene_lists['AD']
if 'Control_AD' in gene_lists: gene_lists['Control_AD_resilient'] = gene_lists['Control_AD_strict'] = gene_lists['Control_AD']

# %% [markdown]
# # Helper Functions

# %%
def pd_to_tg_data(df, *, group):
    "Convert pd edgelist into torch_geometric data"
    # Format
    df = df.rename(columns={'coex': 'weight', 'coreg': 'weight'})
    unique = np.unique(list(df['TF'])+list(df['TG']))
    x = np.eye(unique.shape[0])
    node_dict = {k: v for v, k in enumerate(unique)}
    node_dict_rev = {v: k for k, v in node_dict.items()}
    from_edges = df['TF'].apply(lambda x: node_dict[x]).to_numpy()
    to_edges = df['TG'].apply(lambda x: node_dict[x]).to_numpy()
    edge_index = np.stack((from_edges, to_edges), axis=0)
    edge_weight = df['weight'].to_numpy()
    if 'Cell Type' in df:
        unique = np.unique(df['Cell Type'])
        edge_ct_dict = {k: v for v, k in enumerate(unique)}
        edge_ct = df['Cell Type'].apply(lambda x: edge_ct_dict[x]).to_numpy()
        edge_attr = np.expand_dims(edge_ct, axis=-1)

    # Get y data
    # -1 is unknown, 0 is no disease, 1 is disease
    # Assign genes as unknown
    y = np.zeros(x.shape[0])-1
    # Annotate positive genes
    y[[node_dict_rev[i] in gene_lists[group] for i in range(x.shape[0])]] = 1
    if f'Control_{group}' in gene_lists:  # Negative list provided
        # Annotate negative genes
        y[[node_dict_rev[i] in gene_lists[f'Control_{group}'] for i in range(x.shape[0])]] = 0
    else:  # No negative list provided
        # Assign all others to negatives
        y[np.argwhere(y!=1).flatten()] = 0

        # Randomly assign negatives for now
        # TODO: Replace this once more data comes in
        # y[np.random.choice(np.argwhere(y!=1).flatten(), 100, replace=False)] = 0

    # Cast to tensors
    x = torch.tensor(x).float()
    edge_index = torch.tensor(edge_index).long()
    edge_weight = torch.tensor(edge_weight).float()
    if 'Cell Type' in df: edge_attr = torch.tensor(edge_attr).float()
    y = torch.tensor(y).long()

    # Torch data
    data = torch_geometric.data.Data(
        x=x,
        edge_index=edge_index,
        edge_weight=edge_weight,
        edge_attr=edge_attr if 'Cell Type' in df else None,
        y=y)

    # Additional attributes
    data.known_mask = y!=-1

    ret = (data, node_dict)
    if 'Cell Type' in df: ret += (edge_ct_dict,)
    return ret


def pd_to_jaccard(df):
    # Calculate matrix
    graph_matrix = df.pivot(index='TG', columns='TF', values='coex').fillna(0)
    labels = graph_matrix.index.to_numpy()
    graph_matrix = graph_matrix.to_numpy()
    binarized_graph_matrix = 1. * (graph_matrix > 0)
    # Calculate intersection
    intersection = binarized_graph_matrix @ binarized_graph_matrix.T
    # Calculate union (takes long time)
    union = np.zeros_like(intersection)
    for i, j in product(range(graph_matrix.shape[0]), range(graph_matrix.shape[0])):
        union[i][j] = ((binarized_graph_matrix[i] + binarized_graph_matrix[j]) > 0).sum()
    # Calculate jaccard
    jaccard = intersection / union
    # Remove diagonal
    jaccard -= np.eye(jaccard.shape[0])
    # Format into df
    # NOTE: TF and TG are used for compatibility, more like TG1 and TG2
    df = pd.DataFrame(jaccard, index=labels, columns=labels).reset_index(names='_TF').melt(id_vars='_TF', value_name='coreg', var_name='TG')  # _TF for TF gene
    df = df.rename(columns={'_TF': 'TF'})
    df = df.loc[df['coreg'] != 0]
    df = pd.concat([df, df.rename({'TF': 'TG', 'TG': 'TF'})]).reset_index(drop=True)

    return df


def aggregate_graph_fnames(fnames):
    "Aggregate dfs from file list into one graph"
    df = pd.DataFrame()
    for fname in fnames:
        # Get list
        graph_list = pd.read_csv(os.path.join(dir, fname), index_col=0)
        graph_list = graph_list.rename(columns={'gene': 'TG', 'CoexWeight': 'coex'})
        graph_list['Cell Type'] = get_cell_type(fname)

        # Normalize
        graph_list['coex'] /= graph_list['coex'].max()  # Maybe do over whole?

        # Concat
        df = pd.concat((df, graph_list), axis=0)

    return df.reset_index(drop=True)


def pd_normalize_weights(g, *, source, target, weight, strength=16):
    source_totals = g[[source, weight]].groupby(source).sum().rename(columns={weight: f'{weight}_total'})
    g[weight] *= strength / source_totals.loc[g[source], f'{weight}_total'].to_numpy()
    return g

# %% [markdown]
# ### Visualization

# %%
# # Load file
# fname = fnames[0]
# group = get_group(fname)
# graph_list = pd.read_csv(os.path.join(dir, fname), index_col=0)
# graph_list = graph_list.rename(columns={'gene': 'TG', 'CoexWeight': 'coex'})

# # Jaccard
# # graph_list = pd_to_jaccard(graph_list)

# # Filtering
# graph_list = graph_list.loc[graph_list['coex'] > np.percentile(graph_list['coex'], 90)]

# # Normalization
# graph_list = pd_normalize_weights(graph_list, source='TF', target='TG', weight='coex')

# # Convert
# data, node_dict = pd_to_tg_data(graph_list, group=group)

# g = torch_geometric.utils.to_networkx(data)
# c = [{-1: 'green', 0: 'blue', 1: 'red'}[v.item()] for v in data.y]
# nx.draw(g, node_size=3, width=.01, arrowsize=.1, node_color=c)

# %% [markdown]
# # Analyses

# %% [markdown]
# ## TG Dot Analysis

# %%
# for fname in fnames:
#     ### Reading
#     # Choose graph
#     contrast = get_contrast(fname)
#     group = get_group(fname)
#     cell_type = get_cell_type(fname)
#     print(' - '.join([fname, group, cell_type]))

#     # Escape if not compatible
#     if group not in gene_lists:
#         print()
#         continue

#     # Get TF-TG linkages
#     graph_list = pd.read_csv(os.path.join(dir, fname), index_col=0)
#     graph_list = graph_list.rename(columns={'gene': 'TG', 'CoexWeight': 'coex'})

#     # Get matrix
#     graph_matrix = graph_list.pivot(index='TF', columns='TG', values='coex').fillna(0)

#     # Get tf matrix
#     # tf_matrix = pd.DataFrame(graph_matrix.to_numpy() @ graph_matrix.to_numpy().T, index=graph_matrix.index, columns=graph_matrix.index)  # TF
#     tf_matrix = pd.DataFrame(graph_matrix.to_numpy().T @ graph_matrix.to_numpy(), index=graph_matrix.columns, columns=graph_matrix.columns)  # TG

#     # Annotate
#     gene_list = gene_lists[group]
#     annotation = tf_matrix.index.map(lambda g: g in gene_list).to_numpy()

#     # Sort based on annotation
#     # annotation_sort_idx = list(annotation.argsort())[::-1]
#     # tf_matrix = tf_matrix.iloc[annotation_sort_idx, annotation_sort_idx]
#     # annotation = annotation[annotation_sort_idx]

#     ### Processing
#     # Sort genes based on dot with known TFs
#     score = (tf_matrix.to_numpy() - np.diag(tf_matrix.to_numpy().diagonal()))[:, annotation].sum(axis=1)
#     score[annotation] *= float(len(annotation)) / (len(annotation) - 1)
#     sorted_idx = score.argsort()[::-1]

#     ### Analysis
#     # Evaluate performance
#     if annotation[sorted_idx].sum() != 0:
#         average_positive_percentile = np.linspace(1, 0, num=tf_matrix.shape[0])[annotation[sorted_idx]].mean()
#     else:
#         average_positive_percentile = np.nan
#     print(f'Average positive percentile of {average_positive_percentile:.3f}')
#     positive_unknown_genes = tf_matrix.index.to_numpy()[(score >= np.percentile(score, 100 - 100*float(annotation.sum()) / score.shape[0])) * ~annotation]
#     print(f'Positive unknown genes: {positive_unknown_genes}')
#     negative_positive_genes = tf_matrix.index.to_numpy()[(score < np.percentile(score, 100 - 100*float(annotation.sum()) / score.shape[0])) * annotation]
#     print(f'Negative positive genes: {negative_positive_genes}')
#     df = pd.DataFrame({
#         # 'TF': tf_matrix.index.to_numpy()[sorted_idx],  # TF
#         'TG': tf_matrix.index.to_numpy()[sorted_idx],  # TG
#         'score': score[sorted_idx],
#         'percentile': np.linspace(1, 0, num=tf_matrix.shape[0]),
#         'annotation': annotation[sorted_idx],
#     })

#     ### Visualization
#     # Sort based on score
#     score_sort_idx = list(score.argsort())[::-1]
#     tf_matrix_sort_score = tf_matrix.iloc[score_sort_idx, score_sort_idx]
#     annotation_sort_score = annotation[score_sort_idx]
#     # Sample for visualization size
#     idx = np.random.choice(tf_matrix_sort_score.shape[0], min(tf_matrix_sort_score.shape[0], 100), replace=False)
#     idx.sort()
#     tf_matrix_sort_score = tf_matrix_sort_score.iloc[idx, idx]
#     annotation_sort_score = annotation[idx]
#     # Plot
#     fig, ax = plt.subplots(1, 1, figsize=(9, 9))
#     plt.title(f'{group}_{cell_type} - APP {average_positive_percentile:.3f}')
#     sns.heatmap(tf_matrix_sort_score, norm=LogNorm(), cmap='mako_r', ax=ax)
#     for i in np.argwhere(annotation_sort_score): plt.axhline(y=i, color='red', linewidth=1)
#     fig.savefig(f'./plots/tf_matrix_{contrast}_{group}_{cell_type}.pdf', format='pdf', transparent=True)
#     plt.tight_layout()
#     plt.close()

#     print()

# %% [markdown]
# ## Node2Vec Analysis

# %%
class MLP(torch.nn.Module):
    def __init__(self, input_size, dropout=.6):
        super().__init__()
        self.mlp = nn.Sequential(
            # Multiple layer
            # nn.Linear(input_size, input_size//2),
            # nn.Dropout(dropout),
            # nn.BatchNorm1d(input_size//2),
            # nn.LeakyReLU(),

            # nn.Linear(input_size//2, input_size//4),
            # nn.Dropout(dropout),
            # nn.BatchNorm1d(input_size//4),
            # nn.LeakyReLU(),

            # nn.Linear(input_size//4, 2),
            # nn.Dropout(dropout),
            # nn.BatchNorm1d(2),
            # nn.Softmax(1),

            # Single hidden layer
            # nn.Linear(input_size, 64),
            # nn.Dropout(dropout),
            # nn.BatchNorm1d(64),
            # nn.LeakyReLU(),

            # nn.Linear(64, 2),
            # nn.Dropout(dropout),
            # nn.BatchNorm1d(2),
            # nn.Softmax(1),

            # Single layer
            nn.Linear(input_size, 2),
            nn.BatchNorm1d(2),
            nn.Softmax(1),
        )

    def forward(self, X):
        return self.mlp(X)

# %%
# # Parameters
# dim = 64  # Automatic if `features``=='coex'
# lr = 1e-1
# gamma = .96
# features = ('embeddings', 'coex')[0]

# replications = 3
# folds = 5  # 1 indicates 80-20 validation, 0 indicates no validation
# max_epochs = 1_001
# batch_size = 64
# max_lapses = 20

# # Books
# graph_type = []
# app_list = []
# auprc_list = []
# auroc_list = []

# # Loop
# for fname in fnames:
#     ### Reading
#     # Choose graph
#     contrast = get_contrast(fname)
#     group = get_group(fname)
#     cell_type = get_cell_type(fname)
#     print(' - '.join([fname, group, cell_type]))

#     # Escape if not compatible
#     if group not in gene_lists:
#         print()
#         continue

#     # Get TF-TG linkages
#     graph_list = pd.read_csv(os.path.join(dir, fname), index_col=0)
#     graph_list = graph_list.rename(columns={'gene': 'TG', 'CoexWeight': 'coex'})

#     # Get matrix
#     graph_matrix = graph_list.pivot(index='TF', columns='TG', values='coex').fillna(0)
#     # Make square
#     all_genes = np.unique(list(graph_matrix.index) + list(graph_matrix.columns))
#     for gene in all_genes:
#         if gene not in graph_matrix.index: graph_matrix.loc[gene] = 0
#         if gene not in graph_matrix.columns: graph_matrix[gene] = 0


#     ### Processing
#     for replication in range(replications):
#         print(f'Replication {replication:02d}')
#         # Reproducibility
#         replication_seed = 42+replication
#         np.random.seed(replication_seed)

#         # Split into folds
#         if folds > 1:
#             folds_idx = np.array_split(np.array(range(np.unique(np.concatenate([np.unique(graph_list['TF']), np.unique(graph_list['TG'])])).shape[0])), folds)
#         elif folds == 1:
#             folds_idx = np.array(list(range(np.unique(np.concatenate([np.unique(graph_list['TF']), np.unique(graph_list['TG'])])).shape[0])))
#             np.random.shuffle(folds_idx)
#             split_idx = int(.8 * folds_idx.shape[0])
#             folds_idx = [folds_idx[:split_idx], folds_idx[split_idx:]]
#         else:
#             folds = 1
#             folds_idx = [np.array(list(range(np.unique(np.concatenate([np.unique(graph_list['TF']), np.unique(graph_list['TG'])])).shape[0])))] * 2

#         # Run folds
#         for fold in range(folds):
#             print(f'Fold {fold:02d}')

#             # Reproducibility
#             fold_seed = 42+replication*folds+fold
#             np.random.seed(fold_seed)
#             torch.manual_seed(fold_seed)

#             # Testing
#             # graph_type.append(f'{contrast}_{group}_{cell_type}_{replication}_{fold}')
#             # performance.append(np.random.rand())
#             # continue

#             # Convenience
#             fold_idx = np.concatenate([idx for i, idx in enumerate(folds_idx) if i != fold])
#             val_idx = folds_idx[fold]

#             # Generate embeddings
#             if features == 'embeddings':
#                 graph_list[['TF', 'TG', 'coex']].to_csv('_elist.edg', sep='\t', header=None, index=None)
#                 g = pp.pecanpy.SparseOTF(p=1, q=1, workers=8, verbose=False, random_state=fold_seed)
#                 g.read_edg('_elist.edg', weighted=True, directed=True)  # False if coexpression
#                 embeddings = g.embed(dim=dim, num_walks=10, walk_length=80, window_size=10, epochs=1)
#                 labels = np.array(g._node_ids)  # As long as no removing, `_node_idmap` isn't needed
#             elif features == 'coex':
#                 labels = graph_matrix.index.to_numpy()
#                 embeddings_from = graph_matrix.loc[labels].to_numpy()
#                 embeddings_to = graph_matrix[labels].to_numpy().T
#                 embeddings = np.concatenate((embeddings_from, embeddings_to), axis=1)
#                 dim = embeddings.shape[1]

#             # Annotate
#             gene_list = gene_lists[group]
#             annotation = np.array([g in gene_list for g in labels])

#             # Predict relevancy
#             X = torch.Tensor(embeddings)
#             unique, inverse = np.unique(annotation, return_inverse=True)
#             y = np.zeros((annotation.shape[0], unique.shape[0]))
#             y[np.arange(y.shape[0]), inverse] = 1
#             y = torch.Tensor(y)

#             # Make model
#             model = MLP(dim)
#             optimizer = torch.optim.Adam(model.parameters(), lr=lr)
#             scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer=optimizer, gamma=gamma)

#             # Train model
#             model.train()
#             lapses = 0; best_loss = np.inf
#             for epoch in range(max_epochs):
#                 epoch_loss = []
#                 epoch_val_loss = []
#                 for batch in range(fold_idx.shape[0] // batch_size):
#                     # Sample

#                     # Training
#                     batch_idx = np.random.choice(fold_idx, batch_size)
#                     batch_X = X[batch_idx]
#                     batch_y = y[batch_idx]
#                     logits = model(batch_X)
#                     loss = ((logits - batch_y)**2).mean()
#                     epoch_loss.append(loss.detach())

#                     # Validation
#                     val_X = X[val_idx]
#                     val_y = y[val_idx]
#                     logits = model(val_X)
#                     val_loss = ((logits - val_y)**2).mean()
#                     epoch_val_loss.append(val_loss.detach())

#                     # Iterate
#                     optimizer.zero_grad()
#                     loss.backward()
#                     optimizer.step()
#                     scheduler.step()
#                 epoch_loss = torch.Tensor(epoch_loss).mean()
#                 epoch_val_loss = torch.Tensor(epoch_val_loss).mean()

#                 # Early stopping
#                 if epoch_val_loss < best_loss:
#                     best_loss = epoch_val_loss
#                     lapses = 0
#                 else:
#                     lapses += 1
#                 if epoch % (max_epochs // 5) == 0 or lapses >= max_lapses: print(f'Epoch: {epoch:03d}\tLoss: {epoch_loss:.4f}\tValidation Loss: {epoch_val_loss:.4f}')
#                 if lapses >= max_lapses:
#                     break

#             model.eval()

#             ### Analysis
#             # Processing
#             logits = model(X[val_idx]).detach()
#             probability = logits[:, 1]
#             sorted_idx = torch.argsort(probability).flip(dims=(0,))
#             true = annotation[val_idx][sorted_idx]

#             # Outcomes
#             if true.sum() != 0:
#                 average_positive_percentile = np.linspace(1, 0, num=val_idx.shape[0])[true].mean()
#             else:
#                 average_positive_percentile = np.nan
#             print(f'Average positive percentile of {average_positive_percentile:.3f}')
#             if np.unique(true).shape[0] != 1:
#                 auprc = sklearn.metrics.average_precision_score(true, probability)
#             else:
#                 auprc = np.nan
#             print(f'AUPRC of {auprc:.3f}')
#             if np.unique(true).shape[0] != 1:
#                 auroc = sklearn.metrics.roc_auc_score(true, probability)
#             else:
#                 auroc = np.nan
#             print(f'AUROC of {auroc:.3f}')

#             ### Books
#             graph_type.append(f'{contrast}_{group}_{cell_type}_{replication}_{fold}')
#             app_list.append(average_positive_percentile)
#             auprc_list.append(auprc)
#             auroc_list.append(auroc)

#             print()
#         print()
#     print()

# ### Format
# graph_type = np.array(graph_type).reshape((-1, replications, folds))
# app_list = np.array(app_list).reshape((-1, replications, folds))
# auprc_list = np.array(auprc_list).reshape((-1, replications, folds))
# auroc_list = np.array(auroc_list).reshape((-1, replications, folds))

# %%
# # Format
# m2 = re.compile('^([cr]\d+x(_\d+)?)_([a-zA-Z]+(_(resilient|strict))?)_((?!resilient|strict)\w+)_(\d+)_(\d+)$')
# df_get_contrast = lambda s: m2.match(s).group(1)
# df_get_group = lambda s: m2.match(s).group(3)
# df_get_cell_type = lambda s: m2.match(s).group(6)
# df_get_replication = lambda s: m2.match(s).group(7)
# df_get_fold = lambda s: m2.match(s).group(8)
# df = pd.DataFrame({
#     'Contrast': np.vectorize(df_get_contrast)(graph_type.flatten()),
#     'Group': np.vectorize(df_get_group)(graph_type.flatten()),
#     'Cell Type': np.vectorize(df_get_cell_type)(graph_type.flatten()),
#     'Replication': np.vectorize(df_get_replication)(graph_type.flatten()),
#     'Fold': np.vectorize(df_get_fold)(graph_type.flatten()),
#     'Average Positive Percentile': app_list.flatten(),
#     'AUPRC': auprc_list.flatten(),
#     'AUROC': auroc_list.flatten(),
# })
# df.to_csv('../results/results.csv')

# # Parameters
# statistic = 'AUROC'
# statistic_minimum = .5

# # Collapse folds
# df = df.groupby(['Contrast', 'Group', 'Cell Type', 'Replication']).mean().reset_index()

# # Collapse all
# df_summary = df.groupby(['Contrast', 'Group', 'Cell Type']).mean().reset_index()

# # Filter
# df_avg = df.groupby(['Contrast', 'Group', 'Cell Type']).mean().reset_index()
# df_avg.index = df_avg.apply(lambda r: '_'.join([r['Contrast'], r['Group'], r['Cell Type']]), axis=1)
# df.index = df.apply(lambda r: '_'.join([r['Contrast'], r['Group'], r['Cell Type']]), axis=1)
# df = df.loc[df_avg.index[df_avg[statistic] > statistic_minimum].to_numpy()]
# df = df.reset_index(drop=True)

# # Sort
# df = df.sort_values('Cell Type')
# df_summary = df_summary.sort_values('Cell Type')

# # Visualize boxplot
# fig, ax = plt.subplots(1, 1, figsize=(18, 9))
# sns.boxplot(df, x='Cell Type', y=statistic, hue='Group', ax=ax)
# plt.axhline(.5, color='black', linestyle='--')
# plt.xticks(rotation=90)
# plt.tight_layout()
# fig.savefig(f'../plots/grn_performance.pdf', format='pdf', transparent=True)
# plt.close()

# # Visualize line plot
# # fig, ax = plt.subplots(1, 1, figsize=(9, 9))
# # sns.lineplot(df_summary.sort_values('Cell Type'), x='Cell Type', y=statistic, hue='Group', ax=ax)
# # plt.axhline(.5, color='black', linestyle='--')
# # plt.xticks(rotation=90)
# # plt.tight_layout()
# # fig.savefig(f'../plots/grn_performance.pdf', format='pdf', transparent=True)
# # plt.close()

# %% [markdown]
# ## SVM Classification

# %%
for fname in fnames:
    # Load file
    group = get_group(fname)
    if group not in gene_lists: continue
    graph_list = pd.read_csv(os.path.join(dir, fname), index_col=0)
    graph_list = graph_list.rename(columns={'gene': 'TG', 'CoexWeight': 'coex'})

    # Jaccard
    # graph_list = pd_to_jaccard(graph_list)

    # Filtering
    graph_list = graph_list.loc[graph_list['coex'] > 1]

    # Normalization
    graph_list = pd_normalize_weights(graph_list, source='TF', target='TG', weight='coex')

    # Convert
    data, node_dict = pd_to_tg_data(graph_list, group=group)

    # Create adjacency
    adj = np.zeros(2*[data.x.shape[0]])
    for e, w in zip(data.edge_index.T, data.edge_weight):
        adj[*e] = w

    # Classify
    clf = sklearn.svm.SVC()
    clf.fit(adj[data.known_mask], data.y[data.known_mask])
    pred = clf.predict(adj)
    auroc = sklearn.metrics.roc_auc_score(data.y[data.known_mask], pred[data.known_mask])
    print(f'{fname} - {auroc:.3f}')
# Out:
# c02x_AD_Astro_regulon_list.csv - 0.535
# c02x_AD_Endo_regulon_list.csv - 0.531
# c02x_AD_EN_L3_5_IT_1_regulon_list.csv - 0.533
# c02x_AD_EN_L3_5_IT_3_regulon_list.csv - 0.524
# c02x_AD_EN_L5_ET_regulon_list.csv - 0.530
# c02x_AD_EN_L6B_regulon_list.csv - 0.528
# c02x_AD_EN_L6_CT_regulon_list.csv - 0.529
# c02x_AD_EN_L6_IT_1_regulon_list.csv - 0.530
# c02x_AD_EN_L6_IT_2_regulon_list.csv - 0.533
# c02x_AD_EN_NF_regulon_list.csv - 0.562
# c02x_AD_Immune_regulon_list.csv - 0.536
# c02x_AD_IN_LAMP5_LHX6_regulon_list.csv - 0.524
# c02x_AD_IN_LAMP5_RELN_regulon_list.csv - 0.526
# c02x_AD_IN_PVALB_CHC_regulon_list.csv - 0.534
# c02x_AD_IN_PVALB_regulon_list.csv - 0.532
# c02x_AD_IN_SST_regulon_list.csv - 0.537
# c02x_AD_IN_VIP_regulon_list.csv - 0.539
# c02x_AD_Micro_regulon_list.csv - 0.529
# c02x_AD_Oligo_regulon_list.csv - 0.542
# c02x_AD_OPC_regulon_list.csv - 0.538
# c02x_AD_PC_regulon_list.csv - 0.543
# c02x_AD_PVM_regulon_list.csv - 0.539
# c02x_AD_SMC_regulon_list.csv - 0.524
# c02x_AD_VLMC_regulon_list.csv - 0.532
# c07x_scz_EN_L2_3_IT_regulon_list.csv - 0.500
# c07x_scz_EN_L3_5_IT_1_regulon_list.csv - 0.500
# c07x_scz_EN_L3_5_IT_2_regulon_list.csv - 0.519
# c07x_scz_EN_L3_5_IT_3_regulon_list.csv - 0.500
# c07x_scz_EN_L5_6_NP_regulon_list.csv - 0.536
# c07x_scz_EN_L5_ET_regulon_list.csv - 0.500
# c07x_scz_EN_L6B_regulon_list.csv - 0.583
# c07x_scz_EN_L6_CT_regulon_list.csv - 0.522
# c07x_scz_EN_L6_IT_1_regulon_list.csv - 0.500
# c07x_scz_EN_L6_IT_2_regulon_list.csv - 0.519
# c07x_scz_EN_NF_regulon_list.csv - 0.500
# c07x_scz_IN_ADARB2_regulon_list.csv - 0.500
# c07x_scz_IN_LAMP5_LHX6_regulon_list.csv - 0.525
# c07x_scz_IN_LAMP5_RELN_regulon_list.csv - 0.526
# c07x_scz_IN_PVALB_CHC_regulon_list.csv - 0.500
# c07x_scz_IN_PVALB_regulon_list.csv - 0.500
# c07x_scz_IN_SST_regulon_list.csv - 0.600
# c07x_scz_IN_VIP_regulon_list.csv - 0.529
# c28x_AD_resilient_Astro_regulon_list.csv - 0.518
# c28x_AD_resilient_Endo_regulon_list.csv - 0.522
# c28x_AD_resilient_EN_L2_3_IT_regulon_list.csv - 0.533
# c28x_AD_resilient_EN_L3_5_IT_1_regulon_list.csv - 0.536
# c28x_AD_resilient_EN_L3_5_IT_2_regulon_list.csv - 0.543
# c28x_AD_resilient_EN_L3_5_IT_3_regulon_list.csv - 0.537
# c28x_AD_resilient_EN_L5_6_NP_regulon_list.csv - 0.538
# c28x_AD_resilient_EN_L5_ET_regulon_list.csv - 0.500
# c28x_AD_resilient_EN_L6B_regulon_list.csv - 0.519
# c28x_AD_resilient_EN_L6_CT_regulon_list.csv - 0.518
# c28x_AD_resilient_EN_L6_IT_1_regulon_list.csv - 0.521
# c28x_AD_resilient_EN_L6_IT_2_regulon_list.csv - 0.520
# c28x_AD_resilient_EN_NF_regulon_list.csv - 0.540
# c28x_AD_resilient_Immune_regulon_list.csv - 0.553
# c28x_AD_resilient_IN_ADARB2_regulon_list.csv - 0.509
# c28x_AD_resilient_IN_LAMP5_LHX6_regulon_list.csv - 0.509
# c28x_AD_resilient_IN_LAMP5_RELN_regulon_list.csv - 0.523
# c28x_AD_resilient_IN_PVALB_CHC_regulon_list.csv - 0.515
# c28x_AD_resilient_IN_PVALB_regulon_list.csv - 0.518
# c28x_AD_resilient_IN_SST_regulon_list.csv - 0.526
# c28x_AD_resilient_IN_VIP_regulon_list.csv - 0.515
# c28x_AD_resilient_Micro_regulon_list.csv - 0.530
# c28x_AD_resilient_OPC_regulon_list.csv - 0.527
# c28x_AD_resilient_PC_regulon_list.csv - 0.550
# c28x_AD_resilient_PVM_regulon_list.csv - 0.536
# c28x_AD_resilient_SMC_regulon_list.csv - 0.536
# c28x_AD_resilient_VLMC_regulon_list.csv - 0.517
# c28x_AD_strict_Endo_regulon_list.csv - 0.531
# c28x_AD_strict_EN_L2_3_IT_regulon_list.csv - 0.518
# c28x_AD_strict_EN_L3_5_IT_1_regulon_list.csv - 0.526
# c28x_AD_strict_EN_L3_5_IT_2_regulon_list.csv - 0.523
# c28x_AD_strict_EN_L3_5_IT_3_regulon_list.csv - 0.538
# c28x_AD_strict_EN_L5_6_NP_regulon_list.csv - 0.530
# c28x_AD_strict_EN_L5_ET_regulon_list.csv - 0.577
# c28x_AD_strict_EN_L6B_regulon_list.csv - 0.534
# c28x_AD_strict_EN_L6_CT_regulon_list.csv - 0.525
# c28x_AD_strict_EN_L6_IT_1_regulon_list.csv - 0.524
# c28x_AD_strict_EN_L6_IT_2_regulon_list.csv - 0.541
# c28x_AD_strict_EN_NF_regulon_list.csv - 0.522
# c28x_AD_strict_Immune_regulon_list.csv - 0.527
# c28x_AD_strict_IN_ADARB2_regulon_list.csv - 0.536
# c28x_AD_strict_IN_LAMP5_LHX6_regulon_list.csv - 0.525
# c28x_AD_strict_IN_LAMP5_RELN_regulon_list.csv - 0.533
# c28x_AD_strict_IN_PVALB_CHC_regulon_list.csv - 0.528
# c28x_AD_strict_IN_PVALB_regulon_list.csv - 0.527
# c28x_AD_strict_IN_SST_regulon_list.csv - 0.525
# c28x_AD_strict_IN_VIP_regulon_list.csv - 0.527
# c28x_AD_strict_Micro_regulon_list.csv - 0.522
# c28x_AD_strict_OPC_regulon_list.csv - 0.514
# c28x_AD_strict_PC_regulon_list.csv - 0.544
# c28x_AD_strict_PVM_regulon_list.csv - 0.524
# c28x_AD_strict_SMC_regulon_list.csv - 0.530
# c28x_AD_strict_VLMC_regulon_list.csv - 0.512

# %% [markdown]
# ## GCN Analysis

# %% [markdown]
# ### Model

# %%
class GCN(torch.nn.Module):
    # NOTES:
    # Edge weights drastically increase performance
    # Right now, very prone to overfitting if initial embedding dimension is too high
    # RESOURCES:
    # Layer cheatsheet: https://pytorch-geometric.readthedocs.io/en/laval/notes/cheatsheet.html
    def __init__(self, input_dim):
        super().__init__()

        self.input_dim = input_dim

        self.net = gnn.Sequential('x, edge_index, edge_weight', [
            # Pure weighted GCN
            (gnn.GCNConv(self.input_dim, 8), 'x, edge_index, edge_weight -> x'),
            nn.BatchNorm1d(8),
            nn.LeakyReLU(),
            # nn.Dropout(.5),

            (gnn.GCNConv(-1, 4), 'x, edge_index, edge_weight -> x'),
            nn.BatchNorm1d(4),
            nn.LeakyReLU(),
            # nn.Dropout(.5),

            (gnn.GCNConv(-1, 2), 'x, edge_index, edge_weight -> x'),
        ])

    def forward(self, x, edge_index, edge_weight):
        return self.net(x, edge_index, edge_weight)

# %% [markdown]
# ### Runtime

# %%
# Parameters
run_type = ['Cell Type', 'Group'][0]
jaccard = False
epochs = 1_001
epoch_cli = 100
max_lapses = 100
percentile_filter = 90
num_folds = 5
use_test = False

# Seed
np.random.seed(42)
torch.manual_seed(42)

# Aggregate fnames by contrast+group
if run_type in ['Cell Type']:
    group_iterable = fnames
elif run_type in ['Group']:
    contrast_group_fnames = defaultdict(lambda: [])
    for fname in fnames:
        # Get data
        contrast = get_contrast(fname)
        group = get_group(fname)
        contrast_group_fnames[(contrast, group)].append(fname)
    contrast_group_fnames = dict(contrast_group_fnames)

    group_iterable = contrast_group_fnames.items()

# Main loop
stats = defaultdict(lambda: [])
for item in group_iterable:
    if run_type in ['Cell Type']:
        # Parse
        fname = item

        # Choose graph
        contrast = get_contrast(fname)
        group = get_group(fname)
        cell_type = get_cell_type(fname)
        graph_name = ' - '.join([contrast, group, cell_type])
        print(graph_name)

        # Escape if not compatible
        if group not in gene_lists: print(); continue

        # valing escapes
        # if group != 'AD_resilient': print(); continue

        # Get TF-TG linkages
        graph_list = pd.read_csv(os.path.join(dir, fname), index_col=0)
        graph_list = graph_list.rename(columns={'gene': 'TG', 'CoexWeight': 'coex'})

    elif run_type in ['Group']:
        # Parse
        (contrast, group), cg_fnames = item

        # CLI
        graph_name = ' - '.join([contrast, group])
        print(graph_name)

        # Escape if not compatible
        if group not in gene_lists: print(); continue

        # valing escapes
        # if group != 'AD_resilient': print(); continue

        # Get list
        graph_list = aggregate_graph_fnames(cg_fnames)

        # Jaccard
        # Currently, Jaccard destroys CT inheritance
        if jaccard: graph_list = graph_list[['TF', 'TG', 'coex']].groupby(['TF', 'TG']).sum().reset_index()

    # Filtering
    graph_list = graph_list.loc[graph_list['coex'] >= np.percentile(graph_list['coex'], percentile_filter)]

    # Jaccard
    if jaccard: graph_list = pd_to_jaccard(graph_list)

    # Normalization
    if not jaccard: graph_list = pd_normalize_weights(graph_list, source='TF', target='TG', weight='coex')

    # Skip if no edges
    if graph_list.shape[0] == 0: print(); continue

    # Convert to pyg
    out = pd_to_tg_data(graph_list, group=group)
    if run_type in ['Group'] and not jaccard: data, node_dict, edge_ct_dict = out
    else:  data, node_dict = out

    ## Running
    # CLI
    unique, weight = torch.unique(data.y, return_counts=True)
    print(f'Graph has unique members {list(unique.numpy())} with counts {list(weight.numpy())}')

    # Create folds
    folds = torch.randperm(data.x.shape[0]).split(int(np.ceil(data.x.shape[0]/num_folds)))

    # Run folds
    for fold_idx in range(num_folds):
        print(f'Fold {fold_idx:02}')

        # Split data
        val_fold = fold_idx
        test_fold = ((fold_idx + 1) % num_folds) if use_test else fold_idx
        train_folds = [i for i in range(num_folds) if i not in (val_fold, test_fold)]
        data.train_idx, data.val_idx, data.test_idx = torch.concat([folds[i] for i in train_folds]), folds[val_fold], folds[test_fold]
        data.train_mask = torch.zeros(data.x.shape[0], dtype=torch.bool); data.train_mask[data.train_idx] = True
        data.val_mask = torch.zeros(data.x.shape[0], dtype=torch.bool); data.val_mask[data.val_idx] = True
        data.test_mask = torch.zeros(data.x.shape[0], dtype=torch.bool); data.test_mask[data.test_idx] = True
        data.train_mask *= data.known_mask; data.val_mask *= data.known_mask; data.test_mask *= data.known_mask

        # Make model
        model = GCN(data.x.shape[1])
        # Determine weight based on population
        unique, weight = torch.unique(data.y[data.train_mask], return_counts=True)
        # Skip if not enough
        if not np.array([x in torch.unique(data.y[data.train_mask]) for x in (0, 1)]).all():
            print('Not enough class samples in the training dataset.', end='\n\n')
            continue
        if not np.array([x in torch.unique(data.y[data.val_mask]) for x in (0, 1)]).all():
            print('Not enough class samples in the validation dataset.', end='\n\n')
            continue
        if not np.array([x in torch.unique(data.y[data.test_mask]) for x in (0, 1)]).all():
            print('Not enough class samples in the validation dataset.', end='\n\n')
            continue
        # Calculate weights
        weight = weight[[torch.argwhere(unique==i)[0][0].item() for i in range(2)]].float()
        weight = weight.norm() / weight
        weight = weight / weight.norm()
        # Define model helpers
        criterion = nn.CrossEntropyLoss(weight=weight)  # , label_smoothing=.01
        optimizer = torch.optim.Adam(model.parameters(), lr=1e-2, weight_decay=5e-4)
        scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer=optimizer, gamma=.96)

        # Run through data
        model.train()
        best_loss = np.inf; lapses = 0; break_next = False
        for epoch in range(epochs):
            # Reset
            optimizer.zero_grad()

            # Forward
            z = model(data.x, data.edge_index, data.edge_weight)
            # Subset by cell type
            # edge_idx = sum([data.edge_attr[:, 0] == ct for ct in np.random.choice(int(data.edge_attr[:, 0].max().item()), 10, replace=False)]).bool()
            # z = model(data.x, data.edge_index[:, edge_idx], data.edge_weight[edge_idx])

            # Get positives and negatives
            positives = (data.y==1).argwhere().flatten()
            negatives = (data.y==0).argwhere().flatten()
            # Sample even positive and negatives
            # num_per_class = min(positives.shape[0], negatives.shape[0])
            # positives = positives[torch.randperm(positives.shape[0])[:num_per_class]]
            # negatives = negatives[torch.randperm(negatives.shape[0])[:num_per_class]]
            # Generate mask
            idx = torch.concat((positives, negatives))
            mask = torch.zeros(data.x.shape[0], dtype=torch.bool); mask[idx] = True
            # Calculate loss
            loss = criterion(z[data.train_mask*mask], data.y[data.train_mask*mask])

            # Backward
            loss.backward()
            optimizer.step()
            scheduler.step()

            # Get new logits
            model.eval()
            z = model(data.x, data.edge_index, data.edge_weight).detach()
            model.train()

            # Train and validation loss
            loss = criterion(z[data.train_mask], data.y[data.train_mask]).item()
            val_loss = criterion(z[data.val_mask], data.y[data.val_mask]).item()
            if use_test: test_loss = criterion(z[data.test_mask], data.y[data.test_mask]).item()

            # Early stopping
            es_loss = val_loss
            if es_loss < best_loss:
                best_loss = es_loss
                lapses = 0
            else: lapses += 1

            if lapses >= max_lapses:
                break_next = True

            # Reporting
            if epoch % epoch_cli == 0 or break_next:
                # Statistics
                pred = z.argmax(dim=1).detach(); true = data.y
                pred_prob = F.softmax(z, dim=1)[:, 1]
                # Acc
                acc = ((z.argmax(dim=1) == data.y)[data.train_mask].sum() / true[data.train_mask].shape[0]).item()
                val_acc = ((z.argmax(dim=1) == data.y)[data.val_mask].sum() / data.y[data.val_mask].shape[0]).item()
                if use_test: test_acc = ((z.argmax(dim=1) == data.y)[data.test_mask].sum() / data.y[data.test_mask].shape[0]).item()
                # Bacc
                bal_acc = sklearn.metrics.balanced_accuracy_score(true[data.train_mask], pred[data.train_mask])
                val_bal_acc = sklearn.metrics.balanced_accuracy_score(true[data.val_mask], pred[data.val_mask])
                if use_test: test_bal_acc = sklearn.metrics.balanced_accuracy_score(true[data.test_mask], pred[data.test_mask])
                # AUPRC
                auprc = sklearn.metrics.average_precision_score(true[data.train_mask], pred_prob[data.train_mask])
                val_auprc = sklearn.metrics.average_precision_score(true[data.val_mask], pred_prob[data.val_mask])
                if use_test: test_auprc = sklearn.metrics.average_precision_score(true[data.test_mask], pred_prob[data.test_mask])
                # AUROC
                auroc = sklearn.metrics.roc_auc_score(true[data.train_mask], pred_prob[data.train_mask])
                val_auroc = sklearn.metrics.roc_auc_score(true[data.val_mask], pred_prob[data.val_mask])
                if use_test: test_auroc = sklearn.metrics.roc_auc_score(true[data.test_mask], pred_prob[data.test_mask])

                # CLI
                print(
                    ' - '.join([
                        f'Epoch: {epoch:03d}',
                        # f'Loss: {loss:.3f}',
                        # f'Balanced Acc: {bal_acc:.3f}',
                        f'AUROC: {auroc:.3f}',
                        # f'Val Loss: {val_loss:.3f}',
                        # f'Val Balanced Acc: {val_bal_acc:.3f}',
                        f'Val AUROC: {val_auroc:.3f}']
                    + ([
                        # f'Test Loss: {test_loss:.3f}',
                        # f'Test Balanced Acc: {test_bal_acc:.3f}',
                        f'Test AUROC: {test_auroc:.3f}',
                    ] if use_test else [])
                ))

            # Escape on early stop
            if break_next: break
        model.eval()

        # Save statistics
        stats['fname'].append(graph_name)
        stats['fold'].append(fold_idx)
        stats['epochs'].append(epoch)
        stats['loss'].append(loss)
        stats['acc'].append(acc)
        stats['bal_acc'].append(bal_acc)
        stats['auprc'].append(auprc)
        stats['auroc'].append(auroc)
        stats['val_loss'].append(val_loss)
        stats['val_acc'].append(val_acc)
        stats['val_bal_acc'].append(val_bal_acc)
        stats['val_auprc'].append(val_auprc)
        stats['val_auroc'].append(val_auroc)
        if use_test:
            stats['test_loss'].append(test_loss)
            stats['test_acc'].append(test_acc)
            stats['test_bal_acc'].append(test_bal_acc)
            stats['test_auprc'].append(test_auprc)
            stats['test_auroc'].append(test_auroc)

        # Save
        if run_type in ['Cell Type']:
            fname = f'../results/{contrast}_{group}_{cell_type}_{fold_idx}_prioritized_genes.csv'
        elif run_type in ['Group']:
            fname = f'../results/{contrast}_{group}_{fold_idx}_prioritized_genes.csv'

        # Save predictions
        z = model(data.x, data.edge_index, data.edge_weight).detach()
        pred = F.softmax(z, dim=1)[:, 1]
        node_dict_rev = {v: k for k, v in node_dict.items()}
        node_labels = [node_dict_rev[i] for i in range(len(node_dict))]
        df = pd.DataFrame({'gene': node_labels, 'score': pred.numpy(), 'validation': data.val_mask.numpy(), 'label': data.y.numpy()})
        df.to_csv(fname, index=False)

        # CLI
        print()

    print()

# Save statistics
stats = pd.DataFrame(stats)
if run_type in ['Cell Type']:
    fname = f'../results/stats_cell_type.csv'
elif run_type in ['Group']:
    fname = f'../results/stats_group.csv'
stats.to_csv(fname, index=None)
# Out:
# c02x - AD - Astro
# Graph has unique members [-1, 0, 1] with counts [717, 62, 125]
# Fold 00
# Epoch: 000 - AUROC: 0.670 - Val AUROC: 0.333
# Epoch: 100 - AUROC: 0.999 - Val AUROC: 0.250
# Epoch: 129 - AUROC: 0.999 - Val AUROC: 0.250
#
# Fold 01
# Epoch: 000 - AUROC: 0.764 - Val AUROC: 0.505
# Epoch: 100 - AUROC: 0.999 - Val AUROC: 0.361
#
# Fold 02
# Epoch: 000 - AUROC: 0.664 - Val AUROC: 0.417
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.500
# Epoch: 101 - AUROC: 1.000 - Val AUROC: 0.500
#
# Fold 03
# Epoch: 000 - AUROC: 0.655 - Val AUROC: 0.462
# Epoch: 100 - AUROC: 0.999 - Val AUROC: 0.447
# Epoch: 105 - AUROC: 0.999 - Val AUROC: 0.444
#
# Fold 04
# Epoch: 000 - AUROC: 0.672 - Val AUROC: 0.676
# Epoch: 100 - AUROC: 0.998 - Val AUROC: 0.612
# Epoch: 103 - AUROC: 0.998 - Val AUROC: 0.612
#
#
# c02x - AD - Endo
# Graph has unique members [-1, 0, 1] with counts [618, 64, 112]
# Fold 00
# Epoch: 000 - AUROC: 0.646 - Val AUROC: 0.584
# Epoch: 100 - AUROC: 0.998 - Val AUROC: 0.554
# Epoch: 146 - AUROC: 0.999 - Val AUROC: 0.550
#
# Fold 01
# Epoch: 000 - AUROC: 0.655 - Val AUROC: 0.452
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.429
# Epoch: 102 - AUROC: 1.000 - Val AUROC: 0.429
#
# Fold 02
# Epoch: 000 - AUROC: 0.675 - Val AUROC: 0.522
# Epoch: 100 - AUROC: 0.997 - Val AUROC: 0.434
# Epoch: 111 - AUROC: 0.998 - Val AUROC: 0.429
#
# Fold 03
# Epoch: 000 - AUROC: 0.751 - Val AUROC: 0.403
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.525
#
# Fold 04
# Epoch: 000 - AUROC: 0.668 - Val AUROC: 0.513
# Epoch: 100 - AUROC: 0.999 - Val AUROC: 0.465
# Epoch: 102 - AUROC: 0.999 - Val AUROC: 0.465
#
#
# c02x - AD - EN_L3_5_IT_1
# Graph has unique members [-1, 0, 1] with counts [749, 74, 151]
# Fold 00
# Epoch: 000 - AUROC: 0.668 - Val AUROC: 0.618
# Epoch: 100 - AUROC: 0.996 - Val AUROC: 0.661
# Epoch: 149 - AUROC: 0.997 - Val AUROC: 0.658
#
# Fold 01
# Epoch: 000 - AUROC: 0.687 - Val AUROC: 0.400
# Epoch: 100 - AUROC: 0.998 - Val AUROC: 0.534
# Epoch: 106 - AUROC: 0.998 - Val AUROC: 0.532
#
# Fold 02
# Epoch: 000 - AUROC: 0.727 - Val AUROC: 0.380
# Epoch: 100 - AUROC: 0.997 - Val AUROC: 0.658
# Epoch: 109 - AUROC: 0.997 - Val AUROC: 0.653
#
# Fold 03
# Epoch: 000 - AUROC: 0.712 - Val AUROC: 0.326
# Epoch: 100 - AUROC: 0.996 - Val AUROC: 0.414
# Epoch: 109 - AUROC: 0.996 - Val AUROC: 0.414
#
# Fold 04
# Epoch: 000 - AUROC: 0.669 - Val AUROC: 0.431
# Epoch: 100 - AUROC: 0.998 - Val AUROC: 0.364
# Epoch: 103 - AUROC: 0.999 - Val AUROC: 0.364
#
#
# c02x - AD - EN_L3_5_IT_3
# Graph has unique members [-1, 0, 1] with counts [781, 79, 140]
# Fold 00
# Epoch: 000 - AUROC: 0.622 - Val AUROC: 0.449
# Epoch: 100 - AUROC: 0.992 - Val AUROC: 0.366
# Epoch: 102 - AUROC: 0.992 - Val AUROC: 0.366
#
# Fold 01
# Epoch: 000 - AUROC: 0.728 - Val AUROC: 0.543
# Epoch: 100 - AUROC: 0.998 - Val AUROC: 0.449
# Epoch: 116 - AUROC: 0.999 - Val AUROC: 0.449
#
# Fold 02
# Epoch: 000 - AUROC: 0.629 - Val AUROC: 0.449
# Epoch: 100 - AUROC: 0.998 - Val AUROC: 0.332
# Epoch: 117 - AUROC: 0.998 - Val AUROC: 0.323
#
# Fold 03
# Epoch: 000 - AUROC: 0.713 - Val AUROC: 0.463
# Epoch: 100 - AUROC: 0.998 - Val AUROC: 0.501
# Epoch: 101 - AUROC: 0.998 - Val AUROC: 0.501
#
# Fold 04
# Epoch: 000 - AUROC: 0.667 - Val AUROC: 0.439
# Epoch: 100 - AUROC: 0.998 - Val AUROC: 0.382
# Epoch: 105 - AUROC: 0.998 - Val AUROC: 0.382
#
#
# c02x - AD - EN_L5_ET
# Graph has unique members [-1, 0, 1] with counts [452, 49, 78]
# Fold 00
# Epoch: 000 - AUROC: 0.656 - Val AUROC: 0.471
# Epoch: 100 - AUROC: 0.997 - Val AUROC: 0.600
# Epoch: 117 - AUROC: 0.997 - Val AUROC: 0.600
#
# Fold 01
# Epoch: 000 - AUROC: 0.672 - Val AUROC: 0.460
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.476
# Epoch: 112 - AUROC: 1.000 - Val AUROC: 0.468
#
# Fold 02
# Epoch: 000 - AUROC: 0.559 - Val AUROC: 0.618
# Epoch: 100 - AUROC: 0.996 - Val AUROC: 0.667
# Epoch: 103 - AUROC: 0.996 - Val AUROC: 0.667
#
# Fold 03
# Epoch: 000 - AUROC: 0.705 - Val AUROC: 0.542
# Epoch: 100 - AUROC: 0.991 - Val AUROC: 0.600
# Epoch: 101 - AUROC: 0.991 - Val AUROC: 0.600
#
# Fold 04
# Epoch: 000 - AUROC: 0.678 - Val AUROC: 0.688
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.536
# Epoch: 103 - AUROC: 1.000 - Val AUROC: 0.536
#
#
# c02x - AD - EN_L6B
# Graph has unique members [-1, 0, 1] with counts [612, 54, 98]
# Fold 00
# Epoch: 000 - AUROC: 0.606 - Val AUROC: 0.831
# Epoch: 100 - AUROC: 0.996 - Val AUROC: 0.429
#
# Fold 01
# Epoch: 000 - AUROC: 0.642 - Val AUROC: 0.385
# Epoch: 100 - AUROC: 0.996 - Val AUROC: 0.550
# Epoch: 107 - AUROC: 0.996 - Val AUROC: 0.547
#
# Fold 02
# Epoch: 000 - AUROC: 0.708 - Val AUROC: 0.534
# Epoch: 100 - AUROC: 0.997 - Val AUROC: 0.471
# Epoch: 103 - AUROC: 0.997 - Val AUROC: 0.471
#
# Fold 03
# Epoch: 000 - AUROC: 0.652 - Val AUROC: 0.504
# Epoch: 100 - AUROC: 0.984 - Val AUROC: 0.564
# Epoch: 134 - AUROC: 0.985 - Val AUROC: 0.568
#
# Fold 04
# Epoch: 000 - AUROC: 0.681 - Val AUROC: 0.583
# Epoch: 100 - AUROC: 0.998 - Val AUROC: 0.537
# Epoch: 119 - AUROC: 0.998 - Val AUROC: 0.537
#
#
# c02x - AD - EN_L6_CT
# Graph has unique members [-1, 0, 1] with counts [648, 66, 109]
# Fold 00
# Epoch: 000 - AUROC: 0.672 - Val AUROC: 0.537
# Epoch: 100 - AUROC: 0.992 - Val AUROC: 0.503
#
# Fold 01
# Epoch: 000 - AUROC: 0.663 - Val AUROC: 0.408
# Epoch: 100 - AUROC: 0.998 - Val AUROC: 0.568
#
# Fold 02
# Epoch: 000 - AUROC: 0.675 - Val AUROC: 0.436
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.604
#
# Fold 03
# Epoch: 000 - AUROC: 0.764 - Val AUROC: 0.560
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.574
# Epoch: 130 - AUROC: 1.000 - Val AUROC: 0.577
#
# Fold 04
# Epoch: 000 - AUROC: 0.634 - Val AUROC: 0.372
# Epoch: 100 - AUROC: 0.999 - Val AUROC: 0.350
#
#
# c02x - AD - EN_L6_IT_1
# Graph has unique members [-1, 0, 1] with counts [719, 68, 123]
# Fold 00
# Epoch: 000 - AUROC: 0.604 - Val AUROC: 0.494
# Epoch: 100 - AUROC: 0.998 - Val AUROC: 0.389
#
# Fold 01
# Epoch: 000 - AUROC: 0.604 - Val AUROC: 0.434
# Epoch: 100 - AUROC: 0.997 - Val AUROC: 0.596
# Epoch: 101 - AUROC: 0.997 - Val AUROC: 0.596
#
# Fold 02
# Epoch: 000 - AUROC: 0.674 - Val AUROC: 0.393
# Epoch: 100 - AUROC: 0.998 - Val AUROC: 0.558
# Epoch: 102 - AUROC: 0.998 - Val AUROC: 0.558
#
# Fold 03
# Epoch: 000 - AUROC: 0.621 - Val AUROC: 0.570
# Epoch: 100 - AUROC: 0.998 - Val AUROC: 0.572
# Epoch: 116 - AUROC: 0.998 - Val AUROC: 0.576
#
# Fold 04
# Epoch: 000 - AUROC: 0.636 - Val AUROC: 0.587
# Epoch: 100 - AUROC: 0.996 - Val AUROC: 0.463
# Epoch: 101 - AUROC: 0.996 - Val AUROC: 0.463
#
#
# c02x - AD - EN_L6_IT_2
# Graph has unique members [-1, 0, 1] with counts [667, 63, 137]
# Fold 00
# Epoch: 000 - AUROC: 0.701 - Val AUROC: 0.536
# Epoch: 100 - AUROC: 0.999 - Val AUROC: 0.683
# Epoch: 124 - AUROC: 0.999 - Val AUROC: 0.683
#
# Fold 01
# Epoch: 000 - AUROC: 0.664 - Val AUROC: 0.520
# Epoch: 100 - AUROC: 0.998 - Val AUROC: 0.462
#
# Fold 02
# Epoch: 000 - AUROC: 0.634 - Val AUROC: 0.517
# Epoch: 100 - AUROC: 0.998 - Val AUROC: 0.467
# Epoch: 102 - AUROC: 0.998 - Val AUROC: 0.471
#
# Fold 03
# Epoch: 000 - AUROC: 0.636 - Val AUROC: 0.506
# Epoch: 100 - AUROC: 0.999 - Val AUROC: 0.534
#
# Fold 04
# Epoch: 000 - AUROC: 0.597 - Val AUROC: 0.590
# Epoch: 100 - AUROC: 0.994 - Val AUROC: 0.681
# Epoch: 162 - AUROC: 0.994 - Val AUROC: 0.688
#
#
# c02x - AD - EN_NF
# Graph has unique members [-1, 0, 1] with counts [144, 17, 24]
# Fold 00
# Epoch: 000 - AUROC: 0.706 - Val AUROC: 0.750
# Epoch: 100 - AUROC: 0.972 - Val AUROC: 0.500
#
# Fold 01
# Epoch: 000 - AUROC: 0.642 - Val AUROC: 0.812
# Epoch: 100 - AUROC: 0.988 - Val AUROC: 0.562
#
# Fold 02
# Epoch: 000 - AUROC: 0.584 - Val AUROC: 0.257
# Epoch: 100 - AUROC: 0.942 - Val AUROC: 0.571
#
# Fold 03
# Epoch: 000 - AUROC: 0.761 - Val AUROC: 0.500
# Epoch: 100 - AUROC: 0.982 - Val AUROC: 0.500
# Epoch: 110 - AUROC: 0.982 - Val AUROC: 0.500
#
# Fold 04
# Epoch: 000 - AUROC: 0.722 - Val AUROC: 0.611
# Epoch: 100 - AUROC: 0.968 - Val AUROC: 0.667
# Epoch: 126 - AUROC: 0.968 - Val AUROC: 0.667
#
#
# c02x - AD - Immune
# Graph has unique members [-1, 0, 1] with counts [536, 42, 85]
# Fold 00
# Epoch: 000 - AUROC: 0.592 - Val AUROC: 0.317
# Epoch: 100 - AUROC: 0.998 - Val AUROC: 0.627
#
# Fold 01
# Epoch: 000 - AUROC: 0.689 - Val AUROC: 0.775
# Epoch: 100 - AUROC: 0.998 - Val AUROC: 0.775
# Epoch: 116 - AUROC: 0.998 - Val AUROC: 0.775
#
# Fold 02
# Epoch: 000 - AUROC: 0.596 - Val AUROC: 0.376
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.419
#
# Fold 03
# Epoch: 000 - AUROC: 0.682 - Val AUROC: 0.417
# Epoch: 100 - AUROC: 0.999 - Val AUROC: 0.576
# Epoch: 101 - AUROC: 0.999 - Val AUROC: 0.576
#
# Fold 04
# Epoch: 000 - AUROC: 0.669 - Val AUROC: 0.470
# Epoch: 100 - AUROC: 0.999 - Val AUROC: 0.220
# Epoch: 108 - AUROC: 0.999 - Val AUROC: 0.220
#
#
# c02x - AD - IN_LAMP5_LHX6
# Graph has unique members [-1, 0, 1] with counts [680, 75, 124]
# Fold 00
# Epoch: 000 - AUROC: 0.724 - Val AUROC: 0.527
# Epoch: 100 - AUROC: 0.999 - Val AUROC: 0.431
# Epoch: 105 - AUROC: 0.999 - Val AUROC: 0.431
#
# Fold 01
# Epoch: 000 - AUROC: 0.639 - Val AUROC: 0.555
# Epoch: 100 - AUROC: 0.985 - Val AUROC: 0.477
#
# Fold 02
# Epoch: 000 - AUROC: 0.677 - Val AUROC: 0.546
# Epoch: 100 - AUROC: 0.993 - Val AUROC: 0.514
#
# Fold 03
# Epoch: 000 - AUROC: 0.634 - Val AUROC: 0.630
# Epoch: 100 - AUROC: 0.994 - Val AUROC: 0.480
# Epoch: 118 - AUROC: 0.994 - Val AUROC: 0.480
#
# Fold 04
# Epoch: 000 - AUROC: 0.646 - Val AUROC: 0.464
# Epoch: 100 - AUROC: 0.996 - Val AUROC: 0.547
#
#
# c02x - AD - IN_LAMP5_RELN
# Graph has unique members [-1, 0, 1] with counts [685, 57, 125]
# Fold 00
# Epoch: 000 - AUROC: 0.632 - Val AUROC: 0.458
# Epoch: 100 - AUROC: 0.999 - Val AUROC: 0.483
#
# Fold 01
# Epoch: 000 - AUROC: 0.648 - Val AUROC: 0.321
# Epoch: 100 - AUROC: 0.993 - Val AUROC: 0.515
#
# Fold 02
# Epoch: 000 - AUROC: 0.561 - Val AUROC: 0.520
# Epoch: 100 - AUROC: 0.993 - Val AUROC: 0.607
#
# Fold 03
# Epoch: 000 - AUROC: 0.657 - Val AUROC: 0.483
# Epoch: 100 - AUROC: 0.992 - Val AUROC: 0.601
# Epoch: 145 - AUROC: 0.992 - Val AUROC: 0.594
#
# Fold 04
# Epoch: 000 - AUROC: 0.694 - Val AUROC: 0.437
# Epoch: 100 - AUROC: 0.991 - Val AUROC: 0.594
#
#
# c02x - AD - IN_PVALB_CHC
# Graph has unique members [-1, 0, 1] with counts [532, 45, 88]
# Fold 00
# Epoch: 000 - AUROC: 0.695 - Val AUROC: 0.593
# Epoch: 100 - AUROC: 0.998 - Val AUROC: 0.457
# Epoch: 105 - AUROC: 0.999 - Val AUROC: 0.457
#
# Fold 01
# Epoch: 000 - AUROC: 0.691 - Val AUROC: 0.580
# Epoch: 100 - AUROC: 0.999 - Val AUROC: 0.251
#
# Fold 02
# Epoch: 000 - AUROC: 0.668 - Val AUROC: 0.500
# Epoch: 100 - AUROC: 0.996 - Val AUROC: 0.484
#
# Fold 03
# Epoch: 000 - AUROC: 0.641 - Val AUROC: 0.402
# Epoch: 100 - AUROC: 0.989 - Val AUROC: 0.223
#
# Fold 04
# Epoch: 000 - AUROC: 0.659 - Val AUROC: 0.547
# Epoch: 100 - AUROC: 0.996 - Val AUROC: 0.406
#
#
# c02x - AD - IN_PVALB
# Graph has unique members [-1, 0, 1] with counts [764, 72, 138]
# Fold 00
# Epoch: 000 - AUROC: 0.606 - Val AUROC: 0.395
# Epoch: 100 - AUROC: 0.999 - Val AUROC: 0.369
#
# Fold 01
# Epoch: 000 - AUROC: 0.656 - Val AUROC: 0.522
# Epoch: 100 - AUROC: 0.999 - Val AUROC: 0.533
# Epoch: 101 - AUROC: 0.999 - Val AUROC: 0.533
#
# Fold 02
# Epoch: 000 - AUROC: 0.665 - Val AUROC: 0.444
# Epoch: 100 - AUROC: 0.999 - Val AUROC: 0.413
# Epoch: 119 - AUROC: 0.999 - Val AUROC: 0.413
#
# Fold 03
# Epoch: 000 - AUROC: 0.718 - Val AUROC: 0.528
# Epoch: 100 - AUROC: 0.995 - Val AUROC: 0.422
# Epoch: 101 - AUROC: 0.995 - Val AUROC: 0.422
#
# Fold 04
# Epoch: 000 - AUROC: 0.705 - Val AUROC: 0.464
# Epoch: 100 - AUROC: 0.997 - Val AUROC: 0.497
# Epoch: 112 - AUROC: 0.997 - Val AUROC: 0.499
#
#
# c02x - AD - IN_SST
# Graph has unique members [-1, 0, 1] with counts [655, 63, 119]
# Fold 00
# Epoch: 000 - AUROC: 0.654 - Val AUROC: 0.595
# Epoch: 100 - AUROC: 0.997 - Val AUROC: 0.655
# Epoch: 109 - AUROC: 0.997 - Val AUROC: 0.658
#
# Fold 01
# Epoch: 000 - AUROC: 0.686 - Val AUROC: 0.333
# Epoch: 100 - AUROC: 0.997 - Val AUROC: 0.396
# Epoch: 101 - AUROC: 0.997 - Val AUROC: 0.396
#
# Fold 02
# Epoch: 000 - AUROC: 0.691 - Val AUROC: 0.315
# Epoch: 100 - AUROC: 0.999 - Val AUROC: 0.308
# Epoch: 102 - AUROC: 0.999 - Val AUROC: 0.308
#
# Fold 03
# Epoch: 000 - AUROC: 0.597 - Val AUROC: 0.549
# Epoch: 100 - AUROC: 0.997 - Val AUROC: 0.337
# Epoch: 108 - AUROC: 0.997 - Val AUROC: 0.342
#
# Fold 04
# Epoch: 000 - AUROC: 0.620 - Val AUROC: 0.581
# Epoch: 100 - AUROC: 0.998 - Val AUROC: 0.513
# Epoch: 123 - AUROC: 0.998 - Val AUROC: 0.506
#
#
# c02x - AD - IN_VIP
# Graph has unique members [-1, 0, 1] with counts [720, 61, 114]
# Fold 00
# Epoch: 000 - AUROC: 0.668 - Val AUROC: 0.700
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.467
#
# Fold 01
# Epoch: 000 - AUROC: 0.677 - Val AUROC: 0.535
# Epoch: 100 - AUROC: 0.997 - Val AUROC: 0.526
# Epoch: 116 - AUROC: 0.997 - Val AUROC: 0.518
#
# Fold 02
# Epoch: 000 - AUROC: 0.653 - Val AUROC: 0.449
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.582
# Epoch: 103 - AUROC: 1.000 - Val AUROC: 0.579
#
# Fold 03
# Epoch: 000 - AUROC: 0.616 - Val AUROC: 0.606
# Epoch: 100 - AUROC: 0.997 - Val AUROC: 0.425
# Epoch: 104 - AUROC: 0.997 - Val AUROC: 0.425
#
# Fold 04
# Epoch: 000 - AUROC: 0.784 - Val AUROC: 0.524
# Epoch: 100 - AUROC: 0.999 - Val AUROC: 0.403
#
#
# c02x - AD - Micro
# Graph has unique members [-1, 0, 1] with counts [933, 66, 172]
# Fold 00
# Epoch: 000 - AUROC: 0.644 - Val AUROC: 0.480
# Epoch: 100 - AUROC: 0.996 - Val AUROC: 0.410
#
# Fold 01
# Epoch: 000 - AUROC: 0.667 - Val AUROC: 0.361
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.532
#
# Fold 02
# Epoch: 000 - AUROC: 0.594 - Val AUROC: 0.587
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.465
# Epoch: 102 - AUROC: 1.000 - Val AUROC: 0.469
#
# Fold 03
# Epoch: 000 - AUROC: 0.694 - Val AUROC: 0.488
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.537
#
# Fold 04
# Epoch: 000 - AUROC: 0.625 - Val AUROC: 0.426
# Epoch: 100 - AUROC: 0.999 - Val AUROC: 0.566
# Epoch: 155 - AUROC: 0.999 - Val AUROC: 0.571
#
#
# c02x - AD - Oligo
# Graph has unique members [-1, 0, 1] with counts [542, 49, 98]
# Fold 00
# Epoch: 000 - AUROC: 0.702 - Val AUROC: 0.515
# Epoch: 100 - AUROC: 0.997 - Val AUROC: 0.460
# Epoch: 115 - AUROC: 0.997 - Val AUROC: 0.465
#
# Fold 01
# Epoch: 000 - AUROC: 0.567 - Val AUROC: 0.433
# Epoch: 100 - AUROC: 0.998 - Val AUROC: 0.718
# Epoch: 200 - AUROC: 0.998 - Val AUROC: 0.714
# Epoch: 224 - AUROC: 0.998 - Val AUROC: 0.714
#
# Fold 02
# Epoch: 000 - AUROC: 0.721 - Val AUROC: 0.550
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.537
#
# Fold 03
# Epoch: 000 - AUROC: 0.757 - Val AUROC: 0.514
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.611
# Epoch: 115 - AUROC: 1.000 - Val AUROC: 0.611
#
# Fold 04
# Epoch: 000 - AUROC: 0.674 - Val AUROC: 0.540
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.540
# Epoch: 124 - AUROC: 1.000 - Val AUROC: 0.540
#
#
# c02x - AD - OPC
# Graph has unique members [-1, 0, 1] with counts [728, 74, 139]
# Fold 00
# Epoch: 000 - AUROC: 0.586 - Val AUROC: 0.573
# Epoch: 100 - AUROC: 0.999 - Val AUROC: 0.473
#
# Fold 01
# Epoch: 000 - AUROC: 0.645 - Val AUROC: 0.529
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.500
#
# Fold 02
# Epoch: 000 - AUROC: 0.746 - Val AUROC: 0.539
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.370
#
# Fold 03
# Epoch: 000 - AUROC: 0.666 - Val AUROC: 0.573
# Epoch: 100 - AUROC: 0.998 - Val AUROC: 0.543
# Epoch: 171 - AUROC: 0.998 - Val AUROC: 0.550
#
# Fold 04
# Epoch: 000 - AUROC: 0.584 - Val AUROC: 0.417
# Epoch: 100 - AUROC: 0.999 - Val AUROC: 0.518
#
#
# c02x - AD - PC
# Graph has unique members [-1, 0, 1] with counts [498, 44, 106]
# Fold 00
# Epoch: 000 - AUROC: 0.722 - Val AUROC: 0.495
# Epoch: 100 - AUROC: 0.994 - Val AUROC: 0.425
#
# Fold 01
# Epoch: 000 - AUROC: 0.708 - Val AUROC: 0.436
# Epoch: 100 - AUROC: 0.994 - Val AUROC: 0.532
# Epoch: 109 - AUROC: 0.994 - Val AUROC: 0.532
#
# Fold 02
# Epoch: 000 - AUROC: 0.680 - Val AUROC: 0.440
# Epoch: 100 - AUROC: 0.990 - Val AUROC: 0.510
#
# Fold 03
# Epoch: 000 - AUROC: 0.664 - Val AUROC: 0.625
# Epoch: 100 - AUROC: 0.992 - Val AUROC: 0.375
# Epoch: 130 - AUROC: 0.993 - Val AUROC: 0.375
#
# Fold 04
# Epoch: 000 - AUROC: 0.591 - Val AUROC: 0.508
# Epoch: 100 - AUROC: 0.998 - Val AUROC: 0.483
# Epoch: 105 - AUROC: 0.998 - Val AUROC: 0.475
#
#
# c02x - AD - PVM
# Graph has unique members [-1, 0, 1] with counts [698, 52, 115]
# Fold 00
# Epoch: 000 - AUROC: 0.690 - Val AUROC: 0.565
# Epoch: 100 - AUROC: 0.997 - Val AUROC: 0.425
#
# Fold 01
# Epoch: 000 - AUROC: 0.603 - Val AUROC: 0.451
# Epoch: 100 - AUROC: 0.999 - Val AUROC: 0.448
#
# Fold 02
# Epoch: 000 - AUROC: 0.609 - Val AUROC: 0.601
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.498
# Epoch: 101 - AUROC: 1.000 - Val AUROC: 0.498
#
# Fold 03
# Epoch: 000 - AUROC: 0.679 - Val AUROC: 0.656
# Epoch: 100 - AUROC: 0.999 - Val AUROC: 0.500
# Epoch: 139 - AUROC: 0.999 - Val AUROC: 0.487
#
# Fold 04
# Epoch: 000 - AUROC: 0.580 - Val AUROC: 0.537
# Epoch: 100 - AUROC: 0.981 - Val AUROC: 0.606
# Epoch: 132 - AUROC: 0.981 - Val AUROC: 0.600
#
#
# c02x - AD - SMC
# Graph has unique members [-1, 0, 1] with counts [449, 39, 101]
# Fold 00
# Epoch: 000 - AUROC: 0.646 - Val AUROC: 0.407
# Epoch: 100 - AUROC: 0.996 - Val AUROC: 0.386
#
# Fold 01
# Epoch: 000 - AUROC: 0.625 - Val AUROC: 0.447
# Epoch: 100 - AUROC: 0.993 - Val AUROC: 0.363
# Epoch: 107 - AUROC: 0.993 - Val AUROC: 0.359
#
# Fold 02
# Epoch: 000 - AUROC: 0.549 - Val AUROC: 0.242
# Epoch: 100 - AUROC: 0.988 - Val AUROC: 0.417
# Epoch: 102 - AUROC: 0.988 - Val AUROC: 0.417
#
# Fold 03
# Epoch: 000 - AUROC: 0.536 - Val AUROC: 0.364
# Epoch: 100 - AUROC: 0.997 - Val AUROC: 0.386
# Epoch: 103 - AUROC: 0.997 - Val AUROC: 0.386
#
# Fold 04
# Epoch: 000 - AUROC: 0.493 - Val AUROC: 0.555
# Epoch: 100 - AUROC: 0.970 - Val AUROC: 0.473
# Epoch: 123 - AUROC: 0.971 - Val AUROC: 0.482
#
#
# c02x - AD - VLMC
# Graph has unique members [-1, 0, 1] with counts [757, 65, 139]
# Fold 00
# Epoch: 000 - AUROC: 0.650 - Val AUROC: 0.482
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.478
# Epoch: 102 - AUROC: 1.000 - Val AUROC: 0.475
#
# Fold 01
# Epoch: 000 - AUROC: 0.587 - Val AUROC: 0.549
# Epoch: 100 - AUROC: 0.991 - Val AUROC: 0.574
# Epoch: 176 - AUROC: 0.991 - Val AUROC: 0.580
#
# Fold 02
# Epoch: 000 - AUROC: 0.722 - Val AUROC: 0.466
# Epoch: 100 - AUROC: 0.996 - Val AUROC: 0.649
#
# Fold 03
# Epoch: 000 - AUROC: 0.636 - Val AUROC: 0.694
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.525
#
# Fold 04
# Epoch: 000 - AUROC: 0.637 - Val AUROC: 0.300
# Epoch: 100 - AUROC: 0.998 - Val AUROC: 0.508
#
#
# c02x - ctl - Astro
#
# c02x - ctl - Endo
#
# c02x - ctl - EN_L2_3_IT
#
# c02x - ctl - EN_L3_5_IT_1
#
# c02x - ctl - EN_L3_5_IT_2
#
# c02x - ctl - EN_L3_5_IT_3
#
# c02x - ctl - EN_L5_6_NP
#
# c02x - ctl - EN_L5_ET
#
# c02x - ctl - EN_L6B
#
# c02x - ctl - EN_L6_CT
#
# c02x - ctl - EN_L6_IT_1
#
# c02x - ctl - EN_L6_IT_2
#
# c02x - ctl - EN_NF
#
# c02x - ctl - Immune
#
# c02x - ctl - IN_ADARB2
#
# c02x - ctl - IN_LAMP5_LHX6
#
# c02x - ctl - IN_LAMP5_RELN
#
# c02x - ctl - IN_PVALB_CHC
#
# c02x - ctl - IN_PVALB
#
# c02x - ctl - IN_SST
#
# c02x - ctl - IN_VIP
#
# c02x - ctl - Micro
#
# c02x - ctl - oligo
#
# c02x - ctl - OPC
#
# c02x - ctl - PC
#
# c02x - ctl - PVM
#
# c02x - ctl - SMC
#
# c02x - ctl - VLMC
#
# c07x - scz - EN_L2_3_IT
# Graph has unique members [0, 1] with counts [149, 2]
# Fold 00
# Not enough class samples in the validation dataset.
#
# Fold 01
# Epoch: 000 - AUROC: 0.429 - Val AUROC: 0.067
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.233
#
# Fold 02
# Not enough class samples in the validation dataset.
#
# Fold 03
# Epoch: 000 - AUROC: 0.933 - Val AUROC: 0.833
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.900
# Epoch: 200 - AUROC: 1.000 - Val AUROC: 0.967
# Epoch: 300 - AUROC: 1.000 - Val AUROC: 0.967
# Epoch: 400 - AUROC: 1.000 - Val AUROC: 0.967
# Epoch: 478 - AUROC: 1.000 - Val AUROC: 0.967
#
# Fold 04
# Not enough class samples in the validation dataset.
#
#
# c07x - scz - EN_L3_5_IT_1
# Graph has unique members [0, 1] with counts [74, 1]
# Fold 00
# Not enough class samples in the training dataset.
#
# Fold 01
# Not enough class samples in the validation dataset.
#
# Fold 02
# Not enough class samples in the validation dataset.
#
# Fold 03
# Not enough class samples in the validation dataset.
#
# Fold 04
# Not enough class samples in the validation dataset.
#
#
# c07x - scz - EN_L3_5_IT_2
# Graph has unique members [0, 1] with counts [167, 6]
# Fold 00
# Epoch: 000 - AUROC: 0.405 - Val AUROC: 0.647
# Epoch: 100 - AUROC: 0.985 - Val AUROC: 0.971
# Epoch: 196 - AUROC: 0.985 - Val AUROC: 0.971
#
# Fold 01
# Not enough class samples in the validation dataset.
#
# Fold 02
# Epoch: 000 - AUROC: 0.160 - Val AUROC: 0.115
# Epoch: 100 - AUROC: 0.906 - Val AUROC: 0.667
# Epoch: 155 - AUROC: 0.914 - Val AUROC: 0.667
#
# Fold 03
# Epoch: 000 - AUROC: 0.698 - Val AUROC: 0.364
# Epoch: 100 - AUROC: 0.976 - Val AUROC: 0.879
# Epoch: 200 - AUROC: 0.976 - Val AUROC: 0.879
# Epoch: 300 - AUROC: 0.976 - Val AUROC: 0.879
# Epoch: 400 - AUROC: 0.976 - Val AUROC: 0.879
# Epoch: 456 - AUROC: 0.976 - Val AUROC: 0.879
#
# Fold 04
# Not enough class samples in the validation dataset.
#
#
# c07x - scz - EN_L3_5_IT_3
# Graph has unique members [0, 1] with counts [114, 2]
# Fold 00
# Not enough class samples in the validation dataset.
#
# Fold 01
# Not enough class samples in the training dataset.
#
# Fold 02
# Not enough class samples in the validation dataset.
#
# Fold 03
# Not enough class samples in the validation dataset.
#
# Fold 04
# Not enough class samples in the validation dataset.
#
#
# c07x - scz - EN_L5_6_NP
# Graph has unique members [0, 1] with counts [72, 1]
# Fold 00
# Not enough class samples in the validation dataset.
#
# Fold 01
# Not enough class samples in the training dataset.
#
# Fold 02
# Not enough class samples in the validation dataset.
#
# Fold 03
# Not enough class samples in the validation dataset.
#
# Fold 04
# Not enough class samples in the validation dataset.
#
#
# c07x - scz - EN_L5_ET
# Graph has unique members [0, 1] with counts [36, 3]
# Fold 00
# Not enough class samples in the validation dataset.
#
# Fold 01
# Epoch: 000 - AUROC: 0.483 - Val AUROC: 0.143
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 1.000
# Epoch: 200 - AUROC: 1.000 - Val AUROC: 1.000
# Epoch: 300 - AUROC: 1.000 - Val AUROC: 1.000
# Epoch: 400 - AUROC: 1.000 - Val AUROC: 1.000
# Epoch: 436 - AUROC: 1.000 - Val AUROC: 1.000
#
# Fold 02
# Not enough class samples in the validation dataset.
#
# Fold 03
# Epoch: 000 - AUROC: 0.828 - Val AUROC: 0.286
# Epoch: 100 - AUROC: 0.983 - Val AUROC: 0.714
# Epoch: 200 - AUROC: 0.983 - Val AUROC: 0.714
# Epoch: 300 - AUROC: 0.983 - Val AUROC: 0.714
# Epoch: 400 - AUROC: 0.983 - Val AUROC: 0.714
# Epoch: 459 - AUROC: 0.983 - Val AUROC: 0.714
#
# Fold 04
# Epoch: 000 - AUROC: 0.417 - Val AUROC: 0.500
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.667
# Epoch: 125 - AUROC: 1.000 - Val AUROC: 0.667
#
#
# c07x - scz - EN_L6B
# Graph has unique members [0] with counts [63]
# Fold 00
# Not enough class samples in the training dataset.
#
# Fold 01
# Not enough class samples in the training dataset.
#
# Fold 02
# Not enough class samples in the training dataset.
#
# Fold 03
# Not enough class samples in the training dataset.
#
# Fold 04
# Not enough class samples in the training dataset.
#
#
# c07x - scz - EN_L6_CT
# Graph has unique members [0] with counts [155]
# Fold 00
# Not enough class samples in the training dataset.
#
# Fold 01
# Not enough class samples in the training dataset.
#
# Fold 02
# Not enough class samples in the training dataset.
#
# Fold 03
# Not enough class samples in the training dataset.
#
# Fold 04
# Not enough class samples in the training dataset.
#
#
# c07x - scz - EN_L6_IT_1
# Graph has unique members [0, 1] with counts [161, 4]
# Fold 00
# Epoch: 000 - AUROC: 0.884 - Val AUROC: 0.219
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.781
# Epoch: 101 - AUROC: 1.000 - Val AUROC: 0.781
#
# Fold 01
# Epoch: 000 - AUROC: 0.846 - Val AUROC: 0.565
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.452
#
# Fold 02
# Not enough class samples in the validation dataset.
#
# Fold 03
# Epoch: 000 - AUROC: 0.736 - Val AUROC: 0.125
# Epoch: 100 - AUROC: 0.964 - Val AUROC: 0.250
#
# Fold 04
# Not enough class samples in the validation dataset.
#
#
# c07x - scz - EN_L6_IT_2
# Graph has unique members [0, 1] with counts [121, 2]
# Fold 00
# Not enough class samples in the validation dataset.
#
# Fold 01
# Epoch: 000 - AUROC: 0.866 - Val AUROC: 0.750
# Epoch: 100 - AUROC: 0.969 - Val AUROC: 0.792
# Epoch: 200 - AUROC: 0.969 - Val AUROC: 0.792
# Epoch: 300 - AUROC: 0.969 - Val AUROC: 0.792
# Epoch: 400 - AUROC: 0.969 - Val AUROC: 0.792
# Epoch: 406 - AUROC: 0.969 - Val AUROC: 0.792
#
# Fold 02
# Not enough class samples in the validation dataset.
#
# Fold 03
# Not enough class samples in the validation dataset.
#
# Fold 04
# Epoch: 000 - AUROC: 0.626 - Val AUROC: 0.545
# Epoch: 100 - AUROC: 0.949 - Val AUROC: 0.955
# Epoch: 200 - AUROC: 0.960 - Val AUROC: 0.955
# Epoch: 300 - AUROC: 0.960 - Val AUROC: 0.955
# Epoch: 400 - AUROC: 0.960 - Val AUROC: 0.955
# Epoch: 440 - AUROC: 0.960 - Val AUROC: 0.955
#
#
# c07x - scz - EN_NF
# Graph has unique members [0, 1] with counts [40, 2]
# Fold 00
# Epoch: 000 - AUROC: 0.062 - Val AUROC: 0.125
# Epoch: 100 - AUROC: 0.969 - Val AUROC: 0.125
#
# Fold 01
# Not enough class samples in the validation dataset.
#
# Fold 02
# Not enough class samples in the validation dataset.
#
# Fold 03
# Not enough class samples in the validation dataset.
#
# Fold 04
# Epoch: 000 - AUROC: 0.314 - Val AUROC: 1.000
# Epoch: 100 - AUROC: 0.971 - Val AUROC: 0.000
# Epoch: 102 - AUROC: 0.971 - Val AUROC: 0.000
#
#
# c07x - scz - IN_ADARB2
# Graph has unique members [0, 1] with counts [105, 1]
# Fold 00
# Not enough class samples in the validation dataset.
#
# Fold 01
# Not enough class samples in the validation dataset.
#
# Fold 02
# Not enough class samples in the validation dataset.
#
# Fold 03
# Not enough class samples in the training dataset.
#
# Fold 04
# Not enough class samples in the validation dataset.
#
#
# c07x - scz - IN_LAMP5_LHX6
# Graph has unique members [0, 1] with counts [165, 3]
# Fold 00
# Epoch: 000 - AUROC: 0.792 - Val AUROC: 0.364
# Epoch: 100 - AUROC: 0.985 - Val AUROC: 0.212
# Epoch: 109 - AUROC: 0.985 - Val AUROC: 0.212
#
# Fold 01
# Not enough class samples in the validation dataset.
#
# Fold 02
# Epoch: 000 - AUROC: 0.693 - Val AUROC: 0.455
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.485
# Epoch: 101 - AUROC: 1.000 - Val AUROC: 0.485
#
# Fold 03
# Not enough class samples in the validation dataset.
#
# Fold 04
# Epoch: 000 - AUROC: 0.784 - Val AUROC: 0.581
# Epoch: 100 - AUROC: 0.985 - Val AUROC: 0.516
#
#
# c07x - scz - IN_LAMP5_RELN
# Graph has unique members [0, 1] with counts [151, 3]
# Fold 00
# Not enough class samples in the validation dataset.
#
# Fold 01
# Epoch: 000 - AUROC: 0.721 - Val AUROC: 0.207
# Epoch: 100 - AUROC: 0.967 - Val AUROC: 0.328
#
# Fold 02
# Epoch: 000 - AUROC: 0.488 - Val AUROC: 0.900
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.200
#
# Fold 03
# Not enough class samples in the validation dataset.
#
# Fold 04
# Not enough class samples in the validation dataset.
#
#
# c07x - scz - IN_PVALB_CHC
# Graph has unique members [0] with counts [105]
# Fold 00
# Not enough class samples in the training dataset.
#
# Fold 01
# Not enough class samples in the training dataset.
#
# Fold 02
# Not enough class samples in the training dataset.
#
# Fold 03
# Not enough class samples in the training dataset.
#
# Fold 04
# Not enough class samples in the training dataset.
#
#
# c07x - scz - IN_PVALB
# Graph has unique members [0, 1] with counts [178, 2]
# Fold 00
# Epoch: 000 - AUROC: 0.357 - Val AUROC: 0.743
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.114
#
# Fold 01
# Not enough class samples in the validation dataset.
#
# Fold 02
# Not enough class samples in the validation dataset.
#
# Fold 03
# Epoch: 000 - AUROC: 0.629 - Val AUROC: 0.314
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.314
#
# Fold 04
# Not enough class samples in the validation dataset.
#
#
# c07x - scz - IN_SST
# Graph has unique members [0] with counts [82]
# Fold 00
# Not enough class samples in the training dataset.
#
# Fold 01
# Not enough class samples in the training dataset.
#
# Fold 02
# Not enough class samples in the training dataset.
#
# Fold 03
# Not enough class samples in the training dataset.
#
# Fold 04
# Not enough class samples in the training dataset.
#
#
# c07x - scz - IN_VIP
# Graph has unique members [0, 1] with counts [144, 1]
# Fold 00
# Not enough class samples in the validation dataset.
#
# Fold 01
# Not enough class samples in the validation dataset.
#
# Fold 02
# Not enough class samples in the validation dataset.
#
# Fold 03
# Not enough class samples in the validation dataset.
#
# Fold 04
# Not enough class samples in the training dataset.
#
#
# c28x - AD_resilient - Astro
# Graph has unique members [-1, 0, 1] with counts [138, 15, 25]
# Fold 00
# Epoch: 000 - AUROC: 0.696 - Val AUROC: 1.000
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.800
# Epoch: 151 - AUROC: 1.000 - Val AUROC: 0.800
#
# Fold 01
# Epoch: 000 - AUROC: 0.655 - Val AUROC: 0.150
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.450
#
# Fold 02
# Epoch: 000 - AUROC: 0.781 - Val AUROC: 0.594
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.688
# Epoch: 200 - AUROC: 1.000 - Val AUROC: 0.688
# Epoch: 300 - AUROC: 1.000 - Val AUROC: 0.688
# Epoch: 400 - AUROC: 1.000 - Val AUROC: 0.688
# Epoch: 476 - AUROC: 1.000 - Val AUROC: 0.688
#
# Fold 03
# Epoch: 000 - AUROC: 0.727 - Val AUROC: 0.500
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.500
# Epoch: 120 - AUROC: 1.000 - Val AUROC: 0.500
#
# Fold 04
# Epoch: 000 - AUROC: 0.787 - Val AUROC: 1.000
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 1.000
# Epoch: 193 - AUROC: 1.000 - Val AUROC: 0.875
#
#
# c28x - AD_resilient - Endo
# Graph has unique members [-1, 0, 1] with counts [274, 26, 46]
# Fold 00
# Epoch: 000 - AUROC: 0.594 - Val AUROC: 0.500
# Epoch: 100 - AUROC: 0.974 - Val AUROC: 0.636
#
# Fold 01
# Epoch: 000 - AUROC: 0.788 - Val AUROC: 0.762
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.274
# Epoch: 101 - AUROC: 1.000 - Val AUROC: 0.274
#
# Fold 02
# Epoch: 000 - AUROC: 0.625 - Val AUROC: 0.556
# Epoch: 100 - AUROC: 0.957 - Val AUROC: 0.667
# Epoch: 200 - AUROC: 0.957 - Val AUROC: 0.694
# Epoch: 300 - AUROC: 0.957 - Val AUROC: 0.694
# Epoch: 400 - AUROC: 0.957 - Val AUROC: 0.694
# Epoch: 467 - AUROC: 0.957 - Val AUROC: 0.694
#
# Fold 03
# Epoch: 000 - AUROC: 0.580 - Val AUROC: 0.600
# Epoch: 100 - AUROC: 0.940 - Val AUROC: 0.560
# Epoch: 113 - AUROC: 0.940 - Val AUROC: 0.560
#
# Fold 04
# Epoch: 000 - AUROC: 0.576 - Val AUROC: 0.567
# Epoch: 100 - AUROC: 0.974 - Val AUROC: 0.400
#
#
# c28x - AD_resilient - EN_L2_3_IT
# Graph has unique members [-1, 0, 1] with counts [133, 14, 33]
# Fold 00
# Not enough class samples in the validation dataset.
#
# Fold 01
# Epoch: 000 - AUROC: 0.645 - Val AUROC: 0.375
# Epoch: 100 - AUROC: 0.993 - Val AUROC: 0.812
# Epoch: 141 - AUROC: 0.993 - Val AUROC: 0.812
#
# Fold 02
# Epoch: 000 - AUROC: 0.587 - Val AUROC: 0.630
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.630
# Epoch: 120 - AUROC: 1.000 - Val AUROC: 0.630
#
# Fold 03
# Epoch: 000 - AUROC: 0.756 - Val AUROC: 0.250
# Epoch: 100 - AUROC: 0.997 - Val AUROC: 0.583
# Epoch: 145 - AUROC: 0.997 - Val AUROC: 0.583
#
# Fold 04
# Epoch: 000 - AUROC: 0.647 - Val AUROC: 0.240
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.560
# Epoch: 120 - AUROC: 1.000 - Val AUROC: 0.560
#
#
# c28x - AD_resilient - EN_L3_5_IT_1
# Graph has unique members [-1, 0, 1] with counts [71, 3, 15]
# Fold 00
# Epoch: 000 - AUROC: 0.536 - Val AUROC: 0.000
# Epoch: 100 - AUROC: 0.964 - Val AUROC: 1.000
# Epoch: 200 - AUROC: 0.964 - Val AUROC: 1.000
# Epoch: 300 - AUROC: 0.964 - Val AUROC: 1.000
# Epoch: 400 - AUROC: 0.964 - Val AUROC: 1.000
# Epoch: 473 - AUROC: 0.964 - Val AUROC: 1.000
#
# Fold 01
# Not enough class samples in the validation dataset.
#
# Fold 02
# Epoch: 000 - AUROC: 0.393 - Val AUROC: 0.000
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.000
# Epoch: 103 - AUROC: 1.000 - Val AUROC: 0.000
#
# Fold 03
# Not enough class samples in the validation dataset.
#
# Fold 04
# Epoch: 000 - AUROC: 0.542 - Val AUROC: 0.667
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.333
#
#
# c28x - AD_resilient - EN_L3_5_IT_2
# Graph has unique members [-1, 0, 1] with counts [111, 14, 31]
# Fold 00
# Epoch: 000 - AUROC: 0.670 - Val AUROC: 0.562
# Epoch: 100 - AUROC: 0.978 - Val AUROC: 0.219
#
# Fold 01
# Epoch: 000 - AUROC: 0.535 - Val AUROC: 0.600
# Epoch: 100 - AUROC: 0.949 - Val AUROC: 0.100
#
# Fold 02
# Epoch: 000 - AUROC: 0.531 - Val AUROC: 0.400
# Epoch: 100 - AUROC: 0.983 - Val AUROC: 0.533
# Epoch: 105 - AUROC: 0.983 - Val AUROC: 0.533
#
# Fold 03
# Epoch: 000 - AUROC: 0.738 - Val AUROC: 0.444
# Epoch: 100 - AUROC: 0.996 - Val AUROC: 0.333
#
# Fold 04
# Epoch: 000 - AUROC: 0.604 - Val AUROC: 0.214
# Epoch: 100 - AUROC: 0.997 - Val AUROC: 0.286
# Epoch: 104 - AUROC: 0.997 - Val AUROC: 0.286
#
#
# c28x - AD_resilient - EN_L3_5_IT_3
# Graph has unique members [-1, 0, 1] with counts [65, 5, 15]
# Fold 00
# Not enough class samples in the validation dataset.
#
# Fold 01
# Not enough class samples in the validation dataset.
#
# Fold 02
# Not enough class samples in the validation dataset.
#
# Fold 03
# Epoch: 000 - AUROC: 0.667 - Val AUROC: 0.889
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.444
#
# Fold 04
# Not enough class samples in the validation dataset.
#
#
# c28x - AD_resilient - EN_L5_6_NP
# Graph has unique members [-1, 0, 1] with counts [42, 2, 10]
# Fold 00
# Not enough class samples in the validation dataset.
#
# Fold 01
# Not enough class samples in the validation dataset.
#
# Fold 02
# Not enough class samples in the validation dataset.
#
# Fold 03
# Not enough class samples in the training dataset.
#
# Fold 04
# Not enough class samples in the validation dataset.
#
#
# c28x - AD_resilient - EN_L5_ET
# Graph has unique members [-1, 0, 1] with counts [24, 1, 7]
# Fold 00
# Not enough class samples in the training dataset.
#
# Fold 01
# Not enough class samples in the validation dataset.
#
# Fold 02
# Not enough class samples in the validation dataset.
#
# Fold 03
# Not enough class samples in the validation dataset.
#
# Fold 04
# Not enough class samples in the validation dataset.
#
#
# c28x - AD_resilient - EN_L6B
# Graph has unique members [-1, 0, 1] with counts [69, 5, 9]
# Fold 00
# Epoch: 000 - AUROC: 0.267 - Val AUROC: 0.875
# Epoch: 100 - AUROC: 0.933 - Val AUROC: 0.500
#
# Fold 01
# Epoch: 000 - AUROC: 0.750 - Val AUROC: 1.000
# Epoch: 100 - AUROC: 0.929 - Val AUROC: 0.000
#
# Fold 02
# Not enough class samples in the validation dataset.
#
# Fold 03
# Epoch: 000 - AUROC: 0.750 - Val AUROC: 0.000
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.000
#
# Fold 04
# Not enough class samples in the validation dataset.
#
#
# c28x - AD_resilient - EN_L6_CT
# Graph has unique members [-1, 0, 1] with counts [82, 12, 22]
# Fold 00
# Epoch: 000 - AUROC: 0.483 - Val AUROC: 0.500
# Epoch: 100 - AUROC: 0.967 - Val AUROC: 0.500
# Epoch: 101 - AUROC: 0.967 - Val AUROC: 0.500
#
# Fold 01
# Epoch: 000 - AUROC: 0.617 - Val AUROC: 0.708
# Epoch: 100 - AUROC: 0.977 - Val AUROC: 0.292
#
# Fold 02
# Epoch: 000 - AUROC: 0.531 - Val AUROC: 0.500
# Epoch: 100 - AUROC: 0.912 - Val AUROC: 0.500
# Epoch: 110 - AUROC: 0.912 - Val AUROC: 0.500
#
# Fold 03
# Epoch: 000 - AUROC: 0.382 - Val AUROC: 0.300
# Epoch: 100 - AUROC: 0.853 - Val AUROC: 0.600
# Epoch: 123 - AUROC: 0.859 - Val AUROC: 0.600
#
# Fold 04
# Epoch: 000 - AUROC: 0.638 - Val AUROC: 1.000
# Epoch: 100 - AUROC: 0.971 - Val AUROC: 0.500
# Epoch: 114 - AUROC: 0.971 - Val AUROC: 0.500
#
#
# c28x - AD_resilient - EN_L6_IT_1
# Graph has unique members [-1, 0, 1] with counts [65, 6, 22]
# Fold 00
# Not enough class samples in the validation dataset.
#
# Fold 01
# Epoch: 000 - AUROC: 0.622 - Val AUROC: 0.250
# Epoch: 100 - AUROC: 0.989 - Val AUROC: 0.250
# Epoch: 129 - AUROC: 0.989 - Val AUROC: 0.250
#
# Fold 02
# Epoch: 000 - AUROC: 0.550 - Val AUROC: 1.000
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.500
# Epoch: 150 - AUROC: 1.000 - Val AUROC: 0.500
#
# Fold 03
# Epoch: 000 - AUROC: 0.624 - Val AUROC: 0.200
# Epoch: 100 - AUROC: 0.988 - Val AUROC: 0.200
# Epoch: 103 - AUROC: 0.988 - Val AUROC: 0.200
#
# Fold 04
# Epoch: 000 - AUROC: 0.483 - Val AUROC: 0.000
# Epoch: 100 - AUROC: 0.933 - Val AUROC: 0.429
# Epoch: 102 - AUROC: 0.933 - Val AUROC: 0.429
#
#
# c28x - AD_resilient - EN_L6_IT_2
# Graph has unique members [-1, 0, 1] with counts [80, 5, 13]
# Fold 00
# Not enough class samples in the validation dataset.
#
# Fold 01
# Epoch: 000 - AUROC: 0.697 - Val AUROC: 0.250
# Epoch: 100 - AUROC: 0.970 - Val AUROC: 0.250
# Epoch: 104 - AUROC: 0.970 - Val AUROC: 0.250
#
# Fold 02
# Epoch: 000 - AUROC: 0.389 - Val AUROC: 1.000
# Epoch: 100 - AUROC: 0.889 - Val AUROC: 1.000
# Epoch: 124 - AUROC: 0.889 - Val AUROC: 1.000
#
# Fold 03
# Epoch: 000 - AUROC: 0.139 - Val AUROC: 1.000
# Epoch: 100 - AUROC: 0.944 - Val AUROC: 0.000
#
# Fold 04
# Epoch: 000 - AUROC: 0.477 - Val AUROC: 0.500
# Epoch: 100 - AUROC: 0.977 - Val AUROC: 1.000
# Epoch: 124 - AUROC: 0.977 - Val AUROC: 1.000
#
#
# c28x - AD_resilient - EN_NF
# Graph has unique members [-1, 0, 1] with counts [68, 6, 17]
# Fold 00
# Not enough class samples in the validation dataset.
#
# Fold 01
# Not enough class samples in the validation dataset.
#
# Fold 02
# Epoch: 000 - AUROC: 0.467 - Val AUROC: 0.810
# Epoch: 100 - AUROC: 0.900 - Val AUROC: 0.952
# Epoch: 200 - AUROC: 0.900 - Val AUROC: 0.952
# Epoch: 300 - AUROC: 0.900 - Val AUROC: 0.952
# Epoch: 400 - AUROC: 0.900 - Val AUROC: 0.952
# Epoch: 436 - AUROC: 0.900 - Val AUROC: 0.952
#
# Fold 03
# Epoch: 000 - AUROC: 0.308 - Val AUROC: 0.625
# Epoch: 100 - AUROC: 0.962 - Val AUROC: 0.375
# Epoch: 128 - AUROC: 0.962 - Val AUROC: 0.375
#
# Fold 04
# Epoch: 000 - AUROC: 0.720 - Val AUROC: 0.500
# Epoch: 100 - AUROC: 0.947 - Val AUROC: 0.500
# Epoch: 125 - AUROC: 0.947 - Val AUROC: 0.500
#
#
# c28x - AD_resilient - Immune
# Graph has unique members [-1, 0, 1] with counts [177, 12, 35]
# Fold 00
# Epoch: 000 - AUROC: 0.782 - Val AUROC: 0.111
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.278
# Epoch: 105 - AUROC: 1.000 - Val AUROC: 0.278
#
# Fold 01
# Epoch: 000 - AUROC: 0.684 - Val AUROC: 0.375
# Epoch: 100 - AUROC: 0.987 - Val AUROC: 0.250
#
# Fold 02
# Epoch: 000 - AUROC: 0.399 - Val AUROC: 0.375
# Epoch: 100 - AUROC: 0.988 - Val AUROC: 0.625
# Epoch: 112 - AUROC: 0.988 - Val AUROC: 0.625
#
# Fold 03
# Epoch: 000 - AUROC: 0.409 - Val AUROC: 0.667
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.633
# Epoch: 124 - AUROC: 1.000 - Val AUROC: 0.633
#
# Fold 04
# Epoch: 000 - AUROC: 0.679 - Val AUROC: 0.429
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.286
# Epoch: 108 - AUROC: 1.000 - Val AUROC: 0.286
#
#
# c28x - AD_resilient - IN_ADARB2
# Graph has unique members [-1, 0, 1] with counts [68, 4, 12]
# Fold 00
# Epoch: 000 - AUROC: 0.682 - Val AUROC: 0.500
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.500
#
# Fold 01
# Not enough class samples in the validation dataset.
#
# Fold 02
# Epoch: 000 - AUROC: 0.593 - Val AUROC: 0.333
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.333
#
# Fold 03
# Not enough class samples in the validation dataset.
#
# Fold 04
# Not enough class samples in the validation dataset.
#
#
# c28x - AD_resilient - IN_LAMP5_LHX6
# Graph has unique members [-1, 0, 1] with counts [90, 8, 16]
# Fold 00
# Not enough class samples in the validation dataset.
#
# Fold 01
# Epoch: 000 - AUROC: 0.531 - Val AUROC: 0.000
# Epoch: 100 - AUROC: 0.929 - Val AUROC: 0.500
#
# Fold 02
# Epoch: 000 - AUROC: 0.800 - Val AUROC: 0.500
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 1.000
# Epoch: 179 - AUROC: 1.000 - Val AUROC: 1.000
#
# Fold 03
# Not enough class samples in the validation dataset.
#
# Fold 04
# Epoch: 000 - AUROC: 0.654 - Val AUROC: 0.333
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.583
# Epoch: 126 - AUROC: 1.000 - Val AUROC: 0.500
#
#
# c28x - AD_resilient - IN_LAMP5_RELN
# Graph has unique members [-1, 0, 1] with counts [79, 12, 20]
# Fold 00
# Epoch: 000 - AUROC: 0.503 - Val AUROC: 0.444
# Epoch: 100 - AUROC: 0.993 - Val AUROC: 0.667
# Epoch: 142 - AUROC: 0.987 - Val AUROC: 0.556
#
# Fold 01
# Epoch: 000 - AUROC: 0.379 - Val AUROC: 0.417
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.500
#
# Fold 02
# Epoch: 000 - AUROC: 0.706 - Val AUROC: 0.333
# Epoch: 100 - AUROC: 0.988 - Val AUROC: 0.333
#
# Fold 03
# Epoch: 000 - AUROC: 0.690 - Val AUROC: 0.500
# Epoch: 100 - AUROC: 0.968 - Val AUROC: 0.333
# Epoch: 106 - AUROC: 0.968 - Val AUROC: 0.333
#
# Fold 04
# Epoch: 000 - AUROC: 0.511 - Val AUROC: 0.250
# Epoch: 100 - AUROC: 0.967 - Val AUROC: 0.750
# Epoch: 138 - AUROC: 0.967 - Val AUROC: 0.750
#
#
# c28x - AD_resilient - IN_PVALB_CHC
# Graph has unique members [-1, 0, 1] with counts [66, 6, 13]
# Fold 00
# Not enough class samples in the validation dataset.
#
# Fold 01
# Epoch: 000 - AUROC: 0.667 - Val AUROC: 0.250
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 1.000
# Epoch: 200 - AUROC: 1.000 - Val AUROC: 1.000
# Epoch: 300 - AUROC: 1.000 - Val AUROC: 1.000
# Epoch: 400 - AUROC: 1.000 - Val AUROC: 1.000
# Epoch: 445 - AUROC: 1.000 - Val AUROC: 1.000
#
# Fold 02
# Epoch: 000 - AUROC: 0.519 - Val AUROC: 0.333
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.250
# Epoch: 103 - AUROC: 1.000 - Val AUROC: 0.250
#
# Fold 03
# Epoch: 000 - AUROC: 0.655 - Val AUROC: 0.500
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.500
# Epoch: 141 - AUROC: 1.000 - Val AUROC: 0.500
#
# Fold 04
# Epoch: 000 - AUROC: 0.417 - Val AUROC: 0.000
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 1.000
# Epoch: 102 - AUROC: 1.000 - Val AUROC: 1.000
#
#
# c28x - AD_resilient - IN_PVALB
# Graph has unique members [-1, 0, 1] with counts [144, 12, 31]
# Fold 00
# Epoch: 000 - AUROC: 0.650 - Val AUROC: 0.500
# Epoch: 100 - AUROC: 0.996 - Val AUROC: 0.167
#
# Fold 01
# Epoch: 000 - AUROC: 0.512 - Val AUROC: 0.083
# Epoch: 100 - AUROC: 0.968 - Val AUROC: 0.500
# Epoch: 105 - AUROC: 0.968 - Val AUROC: 0.500
#
# Fold 02
# Epoch: 000 - AUROC: 0.620 - Val AUROC: 0.583
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.833
# Epoch: 200 - AUROC: 1.000 - Val AUROC: 0.833
# Epoch: 300 - AUROC: 1.000 - Val AUROC: 0.833
# Epoch: 400 - AUROC: 1.000 - Val AUROC: 0.833
# Epoch: 500 - AUROC: 1.000 - Val AUROC: 0.833
# Epoch: 514 - AUROC: 1.000 - Val AUROC: 0.833
#
# Fold 03
# Not enough class samples in the validation dataset.
#
# Fold 04
# Epoch: 000 - AUROC: 0.745 - Val AUROC: 0.225
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.600
# Epoch: 127 - AUROC: 1.000 - Val AUROC: 0.575
#
#
# c28x - AD_resilient - IN_SST
# Graph has unique members [-1, 0, 1] with counts [127, 13, 24]
# Fold 00
# Epoch: 000 - AUROC: 0.744 - Val AUROC: 0.875
# Epoch: 100 - AUROC: 0.994 - Val AUROC: 1.000
#
# Fold 01
# Epoch: 000 - AUROC: 0.588 - Val AUROC: 0.905
# Epoch: 100 - AUROC: 0.988 - Val AUROC: 0.762
# Epoch: 137 - AUROC: 0.988 - Val AUROC: 0.762
#
# Fold 02
# Epoch: 000 - AUROC: 0.417 - Val AUROC: 0.438
# Epoch: 100 - AUROC: 0.978 - Val AUROC: 0.562
#
# Fold 03
# Epoch: 000 - AUROC: 0.535 - Val AUROC: 0.214
# Epoch: 100 - AUROC: 0.957 - Val AUROC: 0.929
# Epoch: 167 - AUROC: 0.957 - Val AUROC: 0.929
#
# Fold 04
# Not enough class samples in the validation dataset.
#
#
# c28x - AD_resilient - IN_VIP
# Graph has unique members [-1, 0, 1] with counts [80, 12, 19]
# Fold 00
# Epoch: 000 - AUROC: 0.540 - Val AUROC: 0.500
# Epoch: 100 - AUROC: 0.973 - Val AUROC: 0.250
# Epoch: 102 - AUROC: 0.973 - Val AUROC: 0.250
#
# Fold 01
# Epoch: 000 - AUROC: 0.551 - Val AUROC: 1.000
# Epoch: 100 - AUROC: 0.947 - Val AUROC: 1.000
# Epoch: 152 - AUROC: 0.952 - Val AUROC: 1.000
#
# Fold 02
# Epoch: 000 - AUROC: 0.442 - Val AUROC: 0.250
# Epoch: 100 - AUROC: 0.952 - Val AUROC: 0.250
# Epoch: 109 - AUROC: 0.952 - Val AUROC: 0.250
#
# Fold 03
# Epoch: 000 - AUROC: 0.456 - Val AUROC: 0.296
# Epoch: 100 - AUROC: 0.978 - Val AUROC: 0.296
#
# Fold 04
# Not enough class samples in the validation dataset.
#
#
# c28x - AD_resilient - Micro
# Graph has unique members [-1, 0, 1] with counts [507, 48, 100]
# Fold 00
# Epoch: 000 - AUROC: 0.596 - Val AUROC: 0.476
# Epoch: 100 - AUROC: 0.979 - Val AUROC: 0.519
# Epoch: 200 - AUROC: 0.979 - Val AUROC: 0.529
# Epoch: 300 - AUROC: 0.979 - Val AUROC: 0.529
# Epoch: 400 - AUROC: 0.979 - Val AUROC: 0.529
# Epoch: 468 - AUROC: 0.979 - Val AUROC: 0.529
#
# Fold 01
# Epoch: 000 - AUROC: 0.665 - Val AUROC: 0.476
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.648
# Epoch: 103 - AUROC: 1.000 - Val AUROC: 0.648
#
# Fold 02
# Epoch: 000 - AUROC: 0.694 - Val AUROC: 0.540
# Epoch: 100 - AUROC: 0.997 - Val AUROC: 0.509
# Epoch: 120 - AUROC: 0.997 - Val AUROC: 0.516
#
# Fold 03
# Epoch: 000 - AUROC: 0.636 - Val AUROC: 0.425
# Epoch: 100 - AUROC: 0.998 - Val AUROC: 0.256
#
# Fold 04
# Epoch: 000 - AUROC: 0.658 - Val AUROC: 0.486
# Epoch: 100 - AUROC: 0.999 - Val AUROC: 0.476
#
#
# c28x - AD_resilient - OPC
# Graph has unique members [-1, 0, 1] with counts [176, 16, 46]
# Fold 00
# Epoch: 000 - AUROC: 0.742 - Val AUROC: 0.714
# Epoch: 100 - AUROC: 0.985 - Val AUROC: 0.857
# Epoch: 166 - AUROC: 0.985 - Val AUROC: 0.857
#
# Fold 01
# Epoch: 000 - AUROC: 0.650 - Val AUROC: 0.455
# Epoch: 100 - AUROC: 0.998 - Val AUROC: 0.182
# Epoch: 120 - AUROC: 0.998 - Val AUROC: 0.182
#
# Fold 02
# Epoch: 000 - AUROC: 0.717 - Val AUROC: 0.727
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.500
# Epoch: 101 - AUROC: 1.000 - Val AUROC: 0.500
#
# Fold 03
# Epoch: 000 - AUROC: 0.684 - Val AUROC: 0.694
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.571
#
# Fold 04
# Epoch: 000 - AUROC: 0.679 - Val AUROC: 0.400
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.650
#
#
# c28x - AD_resilient - PC
# Graph has unique members [-1, 0, 1] with counts [102, 16, 24]
# Fold 00
# Epoch: 000 - AUROC: 0.533 - Val AUROC: 1.000
# Epoch: 100 - AUROC: 0.977 - Val AUROC: 0.000
#
# Fold 01
# Epoch: 000 - AUROC: 0.618 - Val AUROC: 0.350
# Epoch: 100 - AUROC: 0.959 - Val AUROC: 0.600
# Epoch: 114 - AUROC: 0.959 - Val AUROC: 0.600
#
# Fold 02
# Epoch: 000 - AUROC: 0.361 - Val AUROC: 0.286
# Epoch: 100 - AUROC: 0.832 - Val AUROC: 0.571
# Epoch: 112 - AUROC: 0.836 - Val AUROC: 0.571
#
# Fold 03
# Epoch: 000 - AUROC: 0.450 - Val AUROC: 0.250
# Epoch: 100 - AUROC: 0.946 - Val AUROC: 0.438
#
# Fold 04
# Epoch: 000 - AUROC: 0.439 - Val AUROC: 0.400
# Epoch: 100 - AUROC: 0.838 - Val AUROC: 0.450
# Epoch: 200 - AUROC: 0.842 - Val AUROC: 0.450
# Epoch: 300 - AUROC: 0.842 - Val AUROC: 0.450
# Epoch: 400 - AUROC: 0.842 - Val AUROC: 0.450
# Epoch: 453 - AUROC: 0.842 - Val AUROC: 0.450
#
#
# c28x - AD_resilient - PVM
# Graph has unique members [-1, 0, 1] with counts [223, 22, 40]
# Fold 00
# Epoch: 000 - AUROC: 0.662 - Val AUROC: 0.727
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.636
# Epoch: 103 - AUROC: 1.000 - Val AUROC: 0.636
#
# Fold 01
# Epoch: 000 - AUROC: 0.553 - Val AUROC: 0.050
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.300
# Epoch: 130 - AUROC: 1.000 - Val AUROC: 0.300
#
# Fold 02
# Epoch: 000 - AUROC: 0.710 - Val AUROC: 0.405
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.762
# Epoch: 148 - AUROC: 1.000 - Val AUROC: 0.762
#
# Fold 03
# Epoch: 000 - AUROC: 0.472 - Val AUROC: 0.639
# Epoch: 100 - AUROC: 0.998 - Val AUROC: 0.694
# Epoch: 158 - AUROC: 0.998 - Val AUROC: 0.778
#
# Fold 04
# Epoch: 000 - AUROC: 0.549 - Val AUROC: 0.657
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.629
#
#
# c28x - AD_resilient - SMC
# Graph has unique members [-1, 0, 1] with counts [181, 13, 41]
# Fold 00
# Epoch: 000 - AUROC: 0.523 - Val AUROC: 0.444
# Epoch: 100 - AUROC: 0.960 - Val AUROC: 0.444
# Epoch: 126 - AUROC: 0.960 - Val AUROC: 0.444
#
# Fold 01
# Epoch: 000 - AUROC: 0.486 - Val AUROC: 0.389
# Epoch: 100 - AUROC: 0.931 - Val AUROC: 0.639
# Epoch: 158 - AUROC: 0.934 - Val AUROC: 0.611
#
# Fold 02
# Epoch: 000 - AUROC: 0.667 - Val AUROC: 0.458
# Epoch: 100 - AUROC: 0.979 - Val AUROC: 0.250
#
# Fold 03
# Epoch: 000 - AUROC: 0.621 - Val AUROC: 0.792
# Epoch: 100 - AUROC: 0.985 - Val AUROC: 0.625
# Epoch: 111 - AUROC: 0.985 - Val AUROC: 0.625
#
# Fold 04
# Epoch: 000 - AUROC: 0.668 - Val AUROC: 0.750
# Epoch: 100 - AUROC: 0.980 - Val AUROC: 0.750
# Epoch: 133 - AUROC: 0.980 - Val AUROC: 0.750
#
#
# c28x - AD_resilient - VLMC
# Graph has unique members [-1, 0, 1] with counts [225, 18, 52]
# Fold 00
# Epoch: 000 - AUROC: 0.642 - Val AUROC: 0.650
# Epoch: 100 - AUROC: 0.974 - Val AUROC: 0.575
#
# Fold 01
# Epoch: 000 - AUROC: 0.618 - Val AUROC: 0.432
# Epoch: 100 - AUROC: 0.934 - Val AUROC: 0.477
# Epoch: 103 - AUROC: 0.934 - Val AUROC: 0.477
#
# Fold 02
# Epoch: 000 - AUROC: 0.749 - Val AUROC: 0.520
# Epoch: 100 - AUROC: 0.991 - Val AUROC: 0.380
#
# Fold 03
# Epoch: 000 - AUROC: 0.552 - Val AUROC: 1.000
# Epoch: 100 - AUROC: 0.996 - Val AUROC: 0.000
#
# Fold 04
# Epoch: 000 - AUROC: 0.636 - Val AUROC: 0.533
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.644
# Epoch: 112 - AUROC: 1.000 - Val AUROC: 0.644
#
#
# c28x - AD_strict - Endo
# Graph has unique members [-1, 0, 1] with counts [389, 36, 65]
# Fold 00
# Epoch: 000 - AUROC: 0.626 - Val AUROC: 0.692
# Epoch: 100 - AUROC: 0.983 - Val AUROC: 0.429
#
# Fold 01
# Epoch: 000 - AUROC: 0.643 - Val AUROC: 0.292
# Epoch: 100 - AUROC: 0.980 - Val AUROC: 0.375
#
# Fold 02
# Epoch: 000 - AUROC: 0.673 - Val AUROC: 0.247
# Epoch: 100 - AUROC: 0.965 - Val AUROC: 0.294
# Epoch: 135 - AUROC: 0.968 - Val AUROC: 0.306
#
# Fold 03
# Epoch: 000 - AUROC: 0.680 - Val AUROC: 0.454
# Epoch: 100 - AUROC: 0.979 - Val AUROC: 0.292
# Epoch: 119 - AUROC: 0.981 - Val AUROC: 0.308
#
# Fold 04
# Epoch: 000 - AUROC: 0.602 - Val AUROC: 0.616
# Epoch: 100 - AUROC: 0.980 - Val AUROC: 0.562
# Epoch: 134 - AUROC: 0.980 - Val AUROC: 0.554
#
#
# c28x - AD_strict - EN_L2_3_IT
# Graph has unique members [-1, 0, 1] with counts [136, 16, 32]
# Fold 00
# Epoch: 000 - AUROC: 0.455 - Val AUROC: 0.625
# Epoch: 100 - AUROC: 0.973 - Val AUROC: 0.562
#
# Fold 01
# Epoch: 000 - AUROC: 0.656 - Val AUROC: 0.700
# Epoch: 100 - AUROC: 0.976 - Val AUROC: 0.300
# Epoch: 109 - AUROC: 0.976 - Val AUROC: 0.300
#
# Fold 02
# Epoch: 000 - AUROC: 0.533 - Val AUROC: 0.000
# Epoch: 100 - AUROC: 0.970 - Val AUROC: 0.167
# Epoch: 101 - AUROC: 0.970 - Val AUROC: 0.167
#
# Fold 03
# Epoch: 000 - AUROC: 0.549 - Val AUROC: 0.333
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.533
#
# Fold 04
# Epoch: 000 - AUROC: 0.545 - Val AUROC: 0.486
# Epoch: 100 - AUROC: 0.989 - Val AUROC: 0.257
# Epoch: 107 - AUROC: 0.989 - Val AUROC: 0.257
#
#
# c28x - AD_strict - EN_L3_5_IT_1
# Graph has unique members [-1, 0, 1] with counts [56, 5, 14]
# Fold 00
# Not enough class samples in the validation dataset.
#
# Fold 01
# Epoch: 000 - AUROC: 0.364 - Val AUROC: 1.000
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 1.000
# Epoch: 200 - AUROC: 1.000 - Val AUROC: 1.000
# Epoch: 300 - AUROC: 1.000 - Val AUROC: 1.000
# Epoch: 400 - AUROC: 1.000 - Val AUROC: 1.000
# Epoch: 450 - AUROC: 1.000 - Val AUROC: 1.000
#
# Fold 02
# Epoch: 000 - AUROC: 0.364 - Val AUROC: 0.000
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.000
#
# Fold 03
# Not enough class samples in the validation dataset.
#
# Fold 04
# Epoch: 000 - AUROC: 0.278 - Val AUROC: 0.500
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.250
# ...
# Epoch: 102 - AUROC: 0.971 - Val AUROC: 0.583
#
# Fold 01
# Epoch: 000 - AUROC: 0.857 - Val AUROC: 0.875
# Epoch: 100 - AUROC: 0.986 - Val AUROC: 0.500
# Epoch: 105 - AUROC: 0.986 - Val AUROC: 0.500
#
# Fold 02
# Epoch: 000 - AUROC: 0.512 - Val AUROC: 0.500
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.125
# Epoch: 104 - AUROC: 1.000 - Val AUROC: 0.125
#
# Fold 03
# Not enough class samples in the validation dataset.
#
# Fold 04
# Epoch: 000 - AUROC: 0.573 - Val AUROC: 0.000
# Epoch: 100 - AUROC: 0.958 - Val AUROC: 0.000
# Epoch: 118 - AUROC: 0.958 - Val AUROC: 0.000
#
#
# c28x - AD_strict - Immune
# Graph has unique members [-1, 0, 1] with counts [238, 21, 41]
# Fold 00
# Epoch: 000 - AUROC: 0.828 - Val AUROC: 0.400
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.523
# Epoch: 108 - AUROC: 1.000 - Val AUROC: 0.508
#
# Fold 01
# Epoch: 000 - AUROC: 0.580 - Val AUROC: 0.167
# Epoch: 100 - AUROC: 0.954 - Val AUROC: 0.417
# Epoch: 101 - AUROC: 0.954 - Val AUROC: 0.417
#
# Fold 02
# Epoch: 000 - AUROC: 0.652 - Val AUROC: 0.661
# Epoch: 100 - AUROC: 0.985 - Val AUROC: 0.589
# Epoch: 101 - AUROC: 0.985 - Val AUROC: 0.589
#
# Fold 03
# Epoch: 000 - AUROC: 0.595 - Val AUROC: 0.500
# Epoch: 100 - AUROC: 0.984 - Val AUROC: 0.500
# Epoch: 111 - AUROC: 0.984 - Val AUROC: 0.500
#
# Fold 04
# Epoch: 000 - AUROC: 0.646 - Val AUROC: 0.083
# Epoch: 100 - AUROC: 0.990 - Val AUROC: 0.333
# Epoch: 103 - AUROC: 0.990 - Val AUROC: 0.333
#
#
# c28x - AD_strict - IN_ADARB2
# Graph has unique members [-1, 0, 1] with counts [81, 4, 16]
# Fold 00
# Epoch: 000 - AUROC: 1.000 - Val AUROC: 0.500
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.667
#
# Fold 01
# Not enough class samples in the validation dataset.
#
# Fold 02
# Epoch: 000 - AUROC: 0.821 - Val AUROC: 0.333
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 1.000
# Epoch: 166 - AUROC: 1.000 - Val AUROC: 1.000
#
# Fold 03
# Epoch: 000 - AUROC: 0.844 - Val AUROC: 1.000
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.000
#
# Fold 04
# Not enough class samples in the validation dataset.
#
#
# c28x - AD_strict - IN_LAMP5_LHX6
# Graph has unique members [-1, 0, 1] with counts [77, 13, 23]
# Fold 00
# Epoch: 000 - AUROC: 0.579 - Val AUROC: 0.167
# Epoch: 100 - AUROC: 0.957 - Val AUROC: 0.556
#
# Fold 01
# Epoch: 000 - AUROC: 0.767 - Val AUROC: 0.929
# Epoch: 100 - AUROC: 0.960 - Val AUROC: 0.929
# Epoch: 200 - AUROC: 0.960 - Val AUROC: 0.929
# Epoch: 300 - AUROC: 0.960 - Val AUROC: 0.929
# Epoch: 400 - AUROC: 0.960 - Val AUROC: 0.929
# Epoch: 471 - AUROC: 0.960 - Val AUROC: 0.929
#
# Fold 02
# Epoch: 000 - AUROC: 0.569 - Val AUROC: 0.500
# Epoch: 100 - AUROC: 0.941 - Val AUROC: 0.333
# Epoch: 137 - AUROC: 0.941 - Val AUROC: 0.333
#
# Fold 03
# Epoch: 000 - AUROC: 0.287 - Val AUROC: 0.000
# Epoch: 100 - AUROC: 0.876 - Val AUROC: 0.250
# Epoch: 103 - AUROC: 0.876 - Val AUROC: 0.250
#
# Fold 04
# Epoch: 000 - AUROC: 0.623 - Val AUROC: 0.667
# Epoch: 100 - AUROC: 0.977 - Val AUROC: 0.500
# Epoch: 104 - AUROC: 0.977 - Val AUROC: 0.500
#
#
# c28x - AD_strict - IN_LAMP5_RELN
# Graph has unique members [-1, 0, 1] with counts [100, 7, 22]
# Fold 00
# Epoch: 000 - AUROC: 0.535 - Val AUROC: 0.333
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.333
#
# Fold 01
# Epoch: 000 - AUROC: 0.763 - Val AUROC: 0.556
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.444
# Epoch: 128 - AUROC: 1.000 - Val AUROC: 0.444
#
# Fold 02
# Not enough class samples in the validation dataset.
#
# Fold 03
# Epoch: 000 - AUROC: 0.611 - Val AUROC: 0.500
# Epoch: 100 - AUROC: 0.991 - Val AUROC: 0.750
# Epoch: 200 - AUROC: 0.991 - Val AUROC: 0.750
# Epoch: 300 - AUROC: 0.991 - Val AUROC: 0.750
# Epoch: 400 - AUROC: 0.991 - Val AUROC: 0.750
# Epoch: 438 - AUROC: 0.991 - Val AUROC: 0.750
#
# Fold 04
# Epoch: 000 - AUROC: 0.713 - Val AUROC: 0.667
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.333
# Epoch: 103 - AUROC: 1.000 - Val AUROC: 0.250
#
#
# c28x - AD_strict - IN_PVALB_CHC
# Graph has unique members [-1, 0, 1] with counts [92, 10, 15]
# Fold 00
# Epoch: 000 - AUROC: 0.457 - Val AUROC: 0.600
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.200
# Epoch: 115 - AUROC: 1.000 - Val AUROC: 0.200
#
# Fold 01
# Epoch: 000 - AUROC: 0.750 - Val AUROC: 0.500
# Epoch: 100 - AUROC: 0.990 - Val AUROC: 0.500
#
# Fold 02
# Epoch: 000 - AUROC: 0.636 - Val AUROC: 0.000
# Epoch: 100 - AUROC: 0.939 - Val AUROC: 0.250
# Epoch: 153 - AUROC: 0.960 - Val AUROC: 0.250
#
# Fold 03
# Epoch: 000 - AUROC: 0.635 - Val AUROC: 0.500
# Epoch: 100 - AUROC: 0.990 - Val AUROC: 0.500
# Epoch: 140 - AUROC: 1.000 - Val AUROC: 0.500
#
# Fold 04
# Epoch: 000 - AUROC: 0.788 - Val AUROC: 0.000
# Epoch: 100 - AUROC: 0.990 - Val AUROC: 0.000
#
#
# c28x - AD_strict - IN_PVALB
# Graph has unique members [-1, 0, 1] with counts [101, 5, 30]
# Fold 00
# Epoch: 000 - AUROC: 0.850 - Val AUROC: 0.400
# Epoch: 100 - AUROC: 0.990 - Val AUROC: 0.400
# Epoch: 104 - AUROC: 0.990 - Val AUROC: 0.400
#
# Fold 01
# Not enough class samples in the validation dataset.
#
# Fold 02
# Epoch: 000 - AUROC: 0.520 - Val AUROC: 0.600
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.600
#
# Fold 03
# Epoch: 000 - AUROC: 0.562 - Val AUROC: 0.444
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.556
# Epoch: 103 - AUROC: 1.000 - Val AUROC: 0.556
#
# Fold 04
# Not enough class samples in the validation dataset.
#
#
# c28x - AD_strict - IN_SST
# Graph has unique members [-1, 0, 1] with counts [95, 10, 24]
# Fold 00
# Epoch: 000 - AUROC: 0.676 - Val AUROC: 0.500
# Epoch: 100 - AUROC: 0.993 - Val AUROC: 0.286
#
# Fold 01
# Epoch: 000 - AUROC: 0.608 - Val AUROC: 0.562
# Epoch: 100 - AUROC: 0.992 - Val AUROC: 0.312
# Epoch: 139 - AUROC: 0.992 - Val AUROC: 0.312
#
# Fold 02
# Epoch: 000 - AUROC: 0.457 - Val AUROC: 0.000
# Epoch: 100 - AUROC: 0.989 - Val AUROC: 0.000
#
# Fold 03
# Epoch: 000 - AUROC: 0.611 - Val AUROC: 1.000
# Epoch: 100 - AUROC: 0.994 - Val AUROC: 0.167
# Epoch: 200 - AUROC: 0.994 - Val AUROC: 0.167
# Epoch: 300 - AUROC: 0.994 - Val AUROC: 0.167
# Epoch: 400 - AUROC: 0.994 - Val AUROC: 0.167
# Epoch: 500 - AUROC: 0.994 - Val AUROC: 0.167
# Epoch: 524 - AUROC: 0.994 - Val AUROC: 0.167
#
# Fold 04
# Epoch: 000 - AUROC: 0.562 - Val AUROC: 0.000
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.000
#
#
# c28x - AD_strict - IN_VIP
# Graph has unique members [-1, 0, 1] with counts [65, 10, 14]
# Fold 00
# Epoch: 000 - AUROC: 0.726 - Val AUROC: 0.000
# Epoch: 100 - AUROC: 0.991 - Val AUROC: 0.000
#
# Fold 01
# Epoch: 000 - AUROC: 0.650 - Val AUROC: 0.250
# Epoch: 100 - AUROC: 0.912 - Val AUROC: 0.375
#
# Fold 02
# Epoch: 000 - AUROC: 0.494 - Val AUROC: 0.556
# Epoch: 100 - AUROC: 0.909 - Val AUROC: 0.111
#
# Fold 03
# Not enough class samples in the validation dataset.
#
# Fold 04
# Epoch: 000 - AUROC: 0.236 - Val AUROC: 0.500
# Epoch: 100 - AUROC: 0.931 - Val AUROC: 0.500
#
#
# c28x - AD_strict - Micro
# Graph has unique members [-1, 0, 1] with counts [567, 43, 123]
# Fold 00
# Epoch: 000 - AUROC: 0.731 - Val AUROC: 0.419
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.494
#
# Fold 01
# Epoch: 000 - AUROC: 0.630 - Val AUROC: 0.284
# Epoch: 100 - AUROC: 0.999 - Val AUROC: 0.475
# Epoch: 104 - AUROC: 0.999 - Val AUROC: 0.475
#
# Fold 02
# Epoch: 000 - AUROC: 0.564 - Val AUROC: 0.477
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.386
#
# Fold 03
# Epoch: 000 - AUROC: 0.634 - Val AUROC: 0.583
# Epoch: 100 - AUROC: 0.998 - Val AUROC: 0.367
# Epoch: 102 - AUROC: 0.998 - Val AUROC: 0.367
#
# Fold 04
# Epoch: 000 - AUROC: 0.617 - Val AUROC: 0.428
# Epoch: 100 - AUROC: 0.993 - Val AUROC: 0.717
# Epoch: 194 - AUROC: 0.993 - Val AUROC: 0.717
#
#
# c28x - AD_strict - OPC
# Graph has unique members [-1, 0, 1] with counts [222, 27, 59]
# Fold 00
# Epoch: 000 - AUROC: 0.685 - Val AUROC: 0.250
# Epoch: 100 - AUROC: 0.998 - Val AUROC: 0.367
# Epoch: 132 - AUROC: 0.998 - Val AUROC: 0.367
#
# Fold 01
# Epoch: 000 - AUROC: 0.472 - Val AUROC: 0.467
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.429
# Epoch: 102 - AUROC: 1.000 - Val AUROC: 0.429
#
# Fold 02
# Epoch: 000 - AUROC: 0.730 - Val AUROC: 0.574
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.296
#
# Fold 03
# Epoch: 000 - AUROC: 0.456 - Val AUROC: 0.415
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.538
# Epoch: 134 - AUROC: 1.000 - Val AUROC: 0.538
#
# Fold 04
# Epoch: 000 - AUROC: 0.488 - Val AUROC: 0.472
# Epoch: 100 - AUROC: 0.988 - Val AUROC: 0.361
# Epoch: 158 - AUROC: 0.989 - Val AUROC: 0.361
#
#
# c28x - AD_strict - PC
# Graph has unique members [-1, 0, 1] with counts [194, 23, 45]
# Fold 00
# Epoch: 000 - AUROC: 0.679 - Val AUROC: 0.698
# Epoch: 100 - AUROC: 0.995 - Val AUROC: 0.508
# Epoch: 110 - AUROC: 0.995 - Val AUROC: 0.508
#
# Fold 01
# Epoch: 000 - AUROC: 0.601 - Val AUROC: 0.800
# Epoch: 100 - AUROC: 0.998 - Val AUROC: 0.600
# Epoch: 109 - AUROC: 0.998 - Val AUROC: 0.600
#
# Fold 02
# Epoch: 000 - AUROC: 0.521 - Val AUROC: 0.495
# Epoch: 100 - AUROC: 0.990 - Val AUROC: 0.637
#
# Fold 03
# Epoch: 000 - AUROC: 0.574 - Val AUROC: 0.542
# Epoch: 100 - AUROC: 0.980 - Val AUROC: 0.625
#
# Fold 04
# Epoch: 000 - AUROC: 0.705 - Val AUROC: 0.611
# Epoch: 100 - AUROC: 0.994 - Val AUROC: 0.500
# Epoch: 117 - AUROC: 0.994 - Val AUROC: 0.500
#
#
# c28x - AD_strict - PVM
# Graph has unique members [-1, 0, 1] with counts [447, 39, 83]
# Fold 00
# Epoch: 000 - AUROC: 0.569 - Val AUROC: 0.960
# Epoch: 100 - AUROC: 0.988 - Val AUROC: 0.507
# Epoch: 131 - AUROC: 0.989 - Val AUROC: 0.507
#
# Fold 01
# Epoch: 000 - AUROC: 0.633 - Val AUROC: 0.481
# Epoch: 100 - AUROC: 0.992 - Val AUROC: 0.506
# Epoch: 106 - AUROC: 0.992 - Val AUROC: 0.506
#
# Fold 02
# Epoch: 000 - AUROC: 0.558 - Val AUROC: 0.722
# Epoch: 100 - AUROC: 0.997 - Val AUROC: 0.444
#
# Fold 03
# Epoch: 000 - AUROC: 0.688 - Val AUROC: 0.462
# Epoch: 100 - AUROC: 0.998 - Val AUROC: 0.443
#
# Fold 04
# Epoch: 000 - AUROC: 0.515 - Val AUROC: 0.420
# Epoch: 100 - AUROC: 0.957 - Val AUROC: 0.304
# Epoch: 127 - AUROC: 0.958 - Val AUROC: 0.304
#
#
# c28x - AD_strict - SMC
# Graph has unique members [-1, 0, 1] with counts [148, 13, 39]
# Fold 00
# Epoch: 000 - AUROC: 0.554 - Val AUROC: 0.500
# Epoch: 100 - AUROC: 0.963 - Val AUROC: 0.429
# Epoch: 119 - AUROC: 0.966 - Val AUROC: 0.429
#
# Fold 01
# Epoch: 000 - AUROC: 0.594 - Val AUROC: 0.167
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.611
# Epoch: 135 - AUROC: 1.000 - Val AUROC: 0.611
#
# Fold 02
# Epoch: 000 - AUROC: 0.630 - Val AUROC: 0.167
# Epoch: 100 - AUROC: 0.800 - Val AUROC: 0.000
# Epoch: 109 - AUROC: 0.822 - Val AUROC: 0.000
#
# Fold 03
# Epoch: 000 - AUROC: 0.636 - Val AUROC: 0.688
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.562
# Epoch: 103 - AUROC: 1.000 - Val AUROC: 0.562
#
# Fold 04
# Epoch: 000 - AUROC: 0.703 - Val AUROC: 0.611
# Epoch: 100 - AUROC: 1.000 - Val AUROC: 0.500
# Epoch: 103 - AUROC: 1.000 - Val AUROC: 0.500
#
#
# c28x - AD_strict - VLMC
# Graph has unique members [-1, 0, 1] with counts [318, 30, 75]
# Fold 00
# Epoch: 000 - AUROC: 0.578 - Val AUROC: 0.838
# Epoch: 100 - AUROC: 0.995 - Val AUROC: 0.456
# Epoch: 127 - AUROC: 0.995 - Val AUROC: 0.426
#
# Fold 01
# Epoch: 000 - AUROC: 0.568 - Val AUROC: 0.288
# Epoch: 100 - AUROC: 0.989 - Val AUROC: 0.365
#
# Fold 02
# Epoch: 000 - AUROC: 0.688 - Val AUROC: 0.626
# Epoch: 100 - AUROC: 0.998 - Val AUROC: 0.556
#
# Fold 03
# Epoch: 000 - AUROC: 0.674 - Val AUROC: 0.488
# Epoch: 100 - AUROC: 0.999 - Val AUROC: 0.250
#
# Fold 04
# Epoch: 000 - AUROC: 0.646 - Val AUROC: 0.311
# Epoch: 100 - AUROC: 0.998 - Val AUROC: 0.530
# Epoch: 102 - AUROC: 0.998 - Val AUROC: 0.530
#
#
# c28x - ctl - Astro
#
# c28x - ctl - Endo
#
# c28x - ctl - EN_L2_3_IT
#
# c28x - ctl - EN_L3_5_IT_1
#
# c28x - ctl - EN_L3_5_IT_2
#
# c28x - ctl - EN_L3_5_IT_3
#
# c28x - ctl - EN_L5_6_NP
#
# c28x - ctl - EN_L5_ET
#
# c28x - ctl - EN_L6B
#
# c28x - ctl - EN_L6_CT
#
# c28x - ctl - EN_L6_IT_1
#
# c28x - ctl - EN_L6_IT_2
#
# c28x - ctl - EN_NF
#
# c28x - ctl - Immune
#
# c28x - ctl - IN_ADARB2
#
# c28x - ctl - IN_LAMP5_LHX6
#
# c28x - ctl - IN_LAMP5_RELN
#
# c28x - ctl - IN_PVALB_CHC
#
# c28x - ctl - IN_PVALB
#
# c28x - ctl - IN_SST
#
# c28x - ctl - IN_VIP
#
# c28x - ctl - Micro
#
# c28x - ctl - OPC
#
# c28x - ctl - PC
#
# c28x - ctl - PVM
#
# c28x - ctl - SMC
#
# c28x - ctl - VLMC
#
# r01x_0 - ctl - Astro
#
# r01x_0 - ctl - Endo
#
# r01x_0 - ctl - EN_L2_3_IT
#
# r01x_0 - ctl - EN_L3_5_IT_1
#
# r01x_0 - ctl - EN_L3_5_IT_2
#
# r01x_0 - ctl - EN_L3_5_IT_3
#
# r01x_0 - ctl - EN_L5_6_NP
#
# r01x_0 - ctl - EN_L5_ET
#
# r01x_0 - ctl - EN_L6B
#
# r01x_0 - ctl - EN_L6_CT
#
# r01x_0 - ctl - EN_L6_IT_1
#
# r01x_0 - ctl - EN_L6_IT_2
#
# r01x_0 - ctl - EN_NF
#
# r01x_0 - ctl - Immune
#
# r01x_0 - ctl - IN_ADARB2
#
# r01x_0 - ctl - IN_LAMP5_LHX6
#
# r01x_0 - ctl - IN_LAMP5_RELN
#
# r01x_0 - ctl - IN_PVALB_CHC
#
# r01x_0 - ctl - IN_PVALB
#
# r01x_0 - ctl - IN_SST
#
# r01x_0 - ctl - IN_VIP
#
# r01x_0 - ctl - Micro
#
# r01x_0 - ctl - Oligo
#
# r01x_0 - ctl - OPC
#
# r01x_0 - ctl - PC
#
# r01x_0 - ctl - PVM
#
# r01x_0 - ctl - SMC
#
# r01x_0 - ctl - VLMC
#
# r01x_1 - ctl - Astro
#
# r01x_1 - ctl - Endo
#
# r01x_1 - ctl - EN_L2_3_IT
#
# r01x_1 - ctl - EN_L3_5_IT_1
#
# r01x_1 - ctl - EN_L3_5_IT_2
#
# r01x_1 - ctl - EN_L3_5_IT_3
#
# r01x_1 - ctl - EN_L5_6_NP
#
# r01x_1 - ctl - EN_L5_ET
#
# r01x_1 - ctl - EN_L6B
#
# r01x_1 - ctl - EN_L6_CT
#
# r01x_1 - ctl - EN_L6_IT_1
#
# r01x_1 - ctl - EN_L6_IT_2
#
# r01x_1 - ctl - EN_NF
#
# r01x_1 - ctl - Immune
#
# r01x_1 - ctl - IN_ADARB2
#
# r01x_1 - ctl - IN_LAMP5_LHX6
#
# r01x_1 - ctl - IN_LAMP5_RELN
#
# r01x_1 - ctl - IN_PVALB_CHC
#
# r01x_1 - ctl - IN_PVALB
#
# r01x_1 - ctl - IN_SST
#
# r01x_1 - ctl - IN_VIP
#
# r01x_1 - ctl - Micro
#
# r01x_1 - ctl - Oligo
#
# r01x_1 - ctl - OPC
#
# r01x_1 - ctl - PC
#
# r01x_1 - ctl - PVM
#
# r01x_1 - ctl - SMC
#
# r01x_1 - ctl - VLMC
#
# r01x_2 - ctl - Astro
#
# r01x_2 - ctl - Endo
#
# r01x_2 - ctl - EN_L2_3_IT
#
# r01x_2 - ctl - EN_L3_5_IT_1
#
# r01x_2 - ctl - EN_L3_5_IT_2
#
# r01x_2 - ctl - EN_L3_5_IT_3
#
# r01x_2 - ctl - EN_L5_6_NP
#
# r01x_2 - ctl - EN_L5_ET
#
# r01x_2 - ctl - EN_L6B
#
# r01x_2 - ctl - EN_L6_CT
#
# r01x_2 - ctl - EN_L6_IT_1
#
# r01x_2 - ctl - EN_L6_IT_2
#
# r01x_2 - ctl - EN_NF
#
# r01x_2 - ctl - Immune
#
# r01x_2 - ctl - IN_ADARB2
#
# r01x_2 - ctl - IN_LAMP5_LHX6
#
# r01x_2 - ctl - IN_LAMP5_RELN
#
# r01x_2 - ctl - IN_PVALB_CHC
#
# r01x_2 - ctl - IN_PVALB
#
# r01x_2 - ctl - IN_SST
#
# r01x_2 - ctl - IN_VIP
#
# r01x_2 - ctl - Micro
#
# r01x_2 - ctl - Oligo
#
# r01x_2 - ctl - OPC
#
# r01x_2 - ctl - PC
#
# r01x_2 - ctl - PVM
#
# r01x_2 - ctl - SMC
#
# r01x_2 - ctl - VLMC
#
# r01x_3 - ctl - Astro
#
# r01x_3 - ctl - Endo
#
# r01x_3 - ctl - EN_L2_3_IT
#
# r01x_3 - ctl - EN_L3_5_IT_1
#
# r01x_3 - ctl - EN_L3_5_IT_2
#
# r01x_3 - ctl - EN_L3_5_IT_3
#
# r01x_3 - ctl - EN_L5_6_NP
#
# r01x_3 - ctl - EN_L5_ET
#
# r01x_3 - ctl - EN_L6B
#
# r01x_3 - ctl - EN_L6_CT
#
# r01x_3 - ctl - EN_L6_IT_1
#
# r01x_3 - ctl - EN_L6_IT_2
#
# r01x_3 - ctl - EN_NF
#
# r01x_3 - ctl - Immune
#
# r01x_3 - ctl - IN_ADARB2
#
# r01x_3 - ctl - IN_LAMP5_LHX6
#
# r01x_3 - ctl - IN_LAMP5_RELN
#
# r01x_3 - ctl - IN_PVALB_CHC
#
# r01x_3 - ctl - IN_PVALB
#
# r01x_3 - ctl - IN_SST
#
# r01x_3 - ctl - IN_VIP
#
# r01x_3 - ctl - Micro
#
# r01x_3 - ctl - Oligo
#
# r01x_3 - ctl - OPC
#
# r01x_3 - ctl - PC
#
# r01x_3 - ctl - PVM
#
# r01x_3 - ctl - SMC
#
# r01x_3 - ctl - VLMC
#
# r01x_4 - ctl - Astro
#
# r01x_4 - ctl - Endo
#
# r01x_4 - ctl - EN_L2_3_IT
#
# r01x_4 - ctl - EN_L3_5_IT_1
#
# r01x_4 - ctl - EN_L3_5_IT_2
#
# r01x_4 - ctl - EN_L3_5_IT_3
#
# r01x_4 - ctl - EN_L5_6_NP
#
# r01x_4 - ctl - EN_L5_ET
#
# r01x_4 - ctl - EN_L6B
#
# r01x_4 - ctl - EN_L6_CT
#
# r01x_4 - ctl - EN_L6_IT_1
#
# r01x_4 - ctl - EN_L6_IT_2
#
# r01x_4 - ctl - EN_NF
#
# r01x_4 - ctl - Immune
#
# r01x_4 - ctl - IN_ADARB2
#
# r01x_4 - ctl - IN_LAMP5_LHX6
#
# r01x_4 - ctl - IN_LAMP5_RELN
#
# r01x_4 - ctl - IN_PVALB_CHC
#
# r01x_4 - ctl - IN_PVALB
#
# r01x_4 - ctl - IN_SST
#
# r01x_4 - ctl - IN_VIP
#
# r01x_4 - ctl - Micro
#
# r01x_4 - ctl - Oligo
#
# r01x_4 - ctl - OPC
#
# r01x_4 - ctl - PC
#
# r01x_4 - ctl - PVM
#
# r01x_4 - ctl - SMC
#
# r01x_4 - ctl - VLMC
#
# r01x_5 - ctl - Astro
#
# r01x_5 - ctl - Endo
#
# r01x_5 - ctl - EN_L2_3_IT
#
# r01x_5 - ctl - EN_L3_5_IT_1
#
# r01x_5 - ctl - EN_L3_5_IT_2
#
# r01x_5 - ctl - EN_L3_5_IT_3
#
# r01x_5 - ctl - EN_L5_6_NP
#
# r01x_5 - ctl - EN_L5_ET
#
# r01x_5 - ctl - EN_L6B
#
# r01x_5 - ctl - EN_L6_CT
#
# r01x_5 - ctl - EN_L6_IT_1
#
# r01x_5 - ctl - EN_L6_IT_2
#
# r01x_5 - ctl - EN_NF
#
# r01x_5 - ctl - Immune
#
# r01x_5 - ctl - IN_ADARB2
#
# r01x_5 - ctl - IN_LAMP5_LHX6
#
# r01x_5 - ctl - IN_LAMP5_RELN
#
# r01x_5 - ctl - IN_PVALB_CHC
#
# r01x_5 - ctl - IN_PVALB
#
# r01x_5 - ctl - IN_SST
#
# r01x_5 - ctl - IN_VIP
#
# r01x_5 - ctl - Micro
#
# r01x_5 - ctl - Oligo
#
# r01x_5 - ctl - OPC
#
# r01x_5 - ctl - PC
#
# r01x_5 - ctl - PVM
#
# r01x_5 - ctl - SMC
#
# r01x_5 - ctl - VLMC
#
# r01x_6 - ctl - Endo
#
# r01x_6 - ctl - EN_L3_5_IT_1
#
# r01x_6 - ctl - EN_L3_5_IT_2
#
# r01x_6 - ctl - EN_L3_5_IT_3
#
# r01x_6 - ctl - EN_L5_6_NP
#
# r01x_6 - ctl - EN_L5_ET
#
# r01x_6 - ctl - EN_L6B
#
# r01x_6 - ctl - EN_L6_CT
#
# r01x_6 - ctl - EN_L6_IT_1
#
# r01x_6 - ctl - EN_L6_IT_2
#
# r01x_6 - ctl - EN_NF
#
# r01x_6 - ctl - Immune
#
# r01x_6 - ctl - IN_ADARB2
#
# r01x_6 - ctl - IN_LAMP5_LHX6
#
# r01x_6 - ctl - IN_LAMP5_RELN
#
# r01x_6 - ctl - IN_PVALB_CHC
#
# r01x_6 - ctl - IN_PVALB
#
# r01x_6 - ctl - IN_VIP
#
# r01x_6 - ctl - Micro
#
# r01x_6 - ctl - OPC

# %% [markdown]
# ### Performance

# %%
# Load statistics
if run_type in ['Cell Type']:
    fname = f'../results/stats_cell_type.csv'
elif run_type in ['Group']:
    fname = f'../results/stats_group.csv'
stats = pd.read_csv(fname)

# Show possible arguments
print(f'Possible stats:\t\t{list(stats.keys())}')
print(f'Possible groups:\t{list(np.unique([fname.split(" - ")[1] for fname in stats["fname"]]))}')
# Out:
# Possible stats:		['fname', 'fold', 'epochs', 'loss', 'acc', 'bal_acc', 'auprc', 'auroc', 'val_loss', 'val_acc', 'val_bal_acc', 'val_auprc', 'val_auroc']
# Possible groups:	['AD', 'AD_resilient', 'AD_strict', 'scz']

# %%
# Params
stat = 'auroc'
group = 'AD_resilient' if len(stats['fname'].iloc[0].split(' - ')) == 3 else None  # None if no filtering needed

# Format stats
df = stats.copy()
# Check if test was used
use_test = 'test_loss' in df.columns
# Filter to desired groups
if group is not None: df = df.loc[df['fname'].map(lambda s: s.split(' - ')[1] == group)]
# Filter by epoch (experimental, very important)
# NOTE: Only evaluates models which hadn't converged by epoch 20
# TODO: Try early stopping based on training acc
min_convergence_epoch = 20
df = df.loc[df['epochs'] >= max_lapses + min_convergence_epoch]
# Filter to desired statistics
val_stat = f'val_{stat}'
test_stat = f'test_{stat}'
eval_stat = test_stat if use_test else val_stat
cols = ['fname', stat, val_stat] + ([test_stat] if use_test else [])
df = df[cols]
# Sort by median validation stat
df = df.set_index('fname').loc[ df[['fname', eval_stat]].groupby('fname').median().sort_values(eval_stat).iloc[::-1].index.to_numpy() ].reset_index()
# Format
df = df.melt(id_vars=[cols[0]], var_name='stat')
# Plot
fig, ax = plt.subplots(1, 1, figsize=(10, 6))
sns.boxplot(data=df, x=cols[0], y='value', hue='stat', ax=ax)
plt.axhline(y=.5, color='black', ls='--')
plt.ylim(0, 1)
plt.xticks(rotation=90)
# Annotate
au_stat = df.loc[df['stat']==stat, 'value'].to_numpy().mean()
au_val_stat = df.loc[df['stat']==val_stat, 'value'].to_numpy().mean()
if use_test: au_test_stat = df.loc[df['stat']==test_stat, 'value'].to_numpy().mean()
if use_test:
    plt.title(f'Average train ({au_stat:.3f}), val ({au_val_stat:.3f}), and test ({au_test_stat:.3f})')
else:
    plt.title(f'Average train ({au_stat:.3f}) and val ({au_val_stat:.3f})')
fig.savefig(f'../plots/gcn_performance_{group if group is not None else "group"}_{stat}.pdf', transparent=True, bbox_inches='tight')

# %%
df.loc[df['stat'] == eval_stat, ['fname', 'value']].groupby('fname').count().rename(columns={'value': 'eval_count'})
# Out:
#                                      eval_count
# fname
# c28x - AD_resilient - Astro                   4
# c28x - AD_resilient - EN_L2_3_IT              4
# c28x - AD_resilient - EN_L3_5_IT_1            1
# c28x - AD_resilient - EN_L6_CT                1
# c28x - AD_resilient - EN_L6_IT_1              2
# c28x - AD_resilient - EN_L6_IT_2              2
# c28x - AD_resilient - EN_NF                   3
# c28x - AD_resilient - Endo                    1
# c28x - AD_resilient - IN_LAMP5_LHX6           2
# c28x - AD_resilient - IN_LAMP5_RELN           2
# c28x - AD_resilient - IN_PVALB                2
# c28x - AD_resilient - IN_PVALB_CHC            2
# c28x - AD_resilient - IN_SST                  2
# c28x - AD_resilient - IN_VIP                  1
# c28x - AD_resilient - Immune                  1
# c28x - AD_resilient - Micro                   2
# c28x - AD_resilient - OPC                     2
# c28x - AD_resilient - PC                      1
# c28x - AD_resilient - PVM                     3
# c28x - AD_resilient - SMC                     3

# %% [markdown]
# ### Module Analysis

# %%
# Params
target_contrast = 'c02x'
percentile_filter = 90

# Read files
df = pd.DataFrame(columns=['cell_type', 'regulon', 'score'])
for fname in fnames:
    # Get meta
    contrast = get_contrast(fname)
    group = get_group(fname)
    cell_type = get_cell_type(fname)

    # Filter to contrast
    # TODO: Filter to group as well
    if group not in gene_lists: continue
    if contrast != target_contrast: continue

    # Get TF-TG linkages
    graph_list = pd.read_csv(os.path.join(dir, fname), index_col=0)
    graph_list = graph_list.rename(columns={'gene': 'TG', 'CoexWeight': 'coex'})

    # Filtering
    graph_list = graph_list.loc[graph_list['coex'] >= np.percentile(graph_list['coex'], percentile_filter)]

    # Open results
    # TODO: Choose a fold more wisely
    scores = pd.read_csv(f'../results/{contrast}_{group}_{cell_type}_0_prioritized_genes.csv').set_index('gene')[['score']]

    # Record
    df_ct = graph_list.set_index('TF').join(scores).reset_index()[['TF', 'score']].groupby('TF').sum().reset_index().rename(columns={'TF': 'regulon'})
    df_ct['cell_type'] = cell_type
    df = pd.concat((df, df_ct))

# Format
df = df.rename(columns={'cell_type': 'Cell Type', 'regulon': 'TF (+)'}).pivot(index='Cell Type', columns='TF (+)')
df.columns = df.columns.droplevel()

# Get first appearing cell type and sort (for heatmap)
# first_ct = df.apply(lambda r: (np.arange(len(r)) * ~r.isna())[~r.isna()].min())
# first_ct = first_ct.sort_values().index.to_numpy()
# df = df[first_ct]

fig = sns.clustermap(df.fillna(0), mask=df.isna(), cmap=sns.color_palette('light:crimson', as_cmap=True), cbar_kws={'label': 'Module Score'}, figsize=(20, 14))
fig.savefig(f'../plots/module_analysis_{target_contrast}.pdf', transparent=True, bbox_inches='tight')
