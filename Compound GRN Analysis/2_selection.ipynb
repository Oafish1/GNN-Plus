# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
style='white'
sns.set(style=style)
plt.rcParams.update({'font.weight': 'normal',
                     'font.size': 18,
                     'axes.titlesize': 'large',
                     'axes.labelsize': 'large',
                     'xtick.labelsize': 'small',
                     'ytick.labelsize': 'small'})

# %%
# In AD-AD not AD-SCZ
# Load data
results_folder = './results/'
genes_suffix = '/mlp-Microglia-20-5-Predictions.txt'
ad_ad = pd.read_csv(results_folder + 'AD' + genes_suffix, delimiter=' ').to_numpy()
ad_scz = pd.read_csv(results_folder + 'AD-SCZ' + genes_suffix, delimiter=' ').to_numpy()

# Get significant genes
ad_ad_significant = ad_ad[:100, 0]
ad_scz_significant = ad_scz[:500, 0]
ad_not_scz = list(set(ad_ad_significant) - set(ad_scz_significant))

# Print significant genes
for s in ad_not_scz:
    print(s)
# Out:
# GCLC
# CSGALNACT1
# APBB1
# MYBL2
# POU3F2
# MLX
# MZF1
# PPARG
# RAB7A
# MAPT
# TAOK3
# ZNF384
# IRF3
# NFIC
# TCERG1
# PTPRE
# MX1
# NAV3
# CABLES1
# MAGI2
# ANK2
# HESX1
# ATF7
# ESR2
# PTK2B
# TGIF1
# GRB10
# LRRK2
# TLR3
# CASS4
# FHOD3
# PPIL4
# EBF1
# IRF5
# MTUS2
# ZBTB7B
# PHC2
# FRS2
# ARID1A
# ETV5
# FHIT
# PRUNE2

# %%
# # In SCZ-SCZ not SCZ-AD
# # Load data
# results_folder = './results/'
# genes_suffix = '/mlp-Glutamatergic neuron-20-5-Predictions.txt'
# scz_scz = pd.read_csv(results_folder + 'SCZ' + genes_suffix, delimiter=' ').to_numpy()
# scz_ad = pd.read_csv(results_folder + 'SCZ-AD' + genes_suffix, delimiter=' ').to_numpy()

# # Get significant genes
# scz_scz_significant = scz_scz[:100, 0]
# scz_ad_significant = scz_ad[:500, 0]
# scz_not_ad = list(set(scz_scz_significant) - set(scz_ad_significant))

# # Print significant genes
# for s in scz_not_ad:
#     print(s)

# %%
# In AD-SCZ
# Load data
results_folder = './results/'
genes_suffix = '/mlp-GABAergic VIP interneuron-20-5-Predictions.txt'
ad_scz = pd.read_csv(results_folder + 'AD-SCZ' + genes_suffix, delimiter=' ').to_numpy()

# Get significant genes
ad_scz_significant = ad_scz[:100, 0]

# Print significant genes
for s in ad_scz_significant:
    print(s)
# Out:
# PCP4L1
# PLCH1
# NFYA
# PRKCZ
# TPK1
# ZNF84
# TWIST1
# CCDC82
# NR4A1
# PLS1
# FOLH1
# LAS1L
# TFEB
# SGIP1
# STXBP6
# PIK3CB
# ST6GAL1
# ANKS1B
# GATAD2A
# EGR2
# RASGRF1
# TMEM108
# ABCB7
# INSM1
# MYBL2
# PDC
# GRM7
# TLN2
# UTP23
# EPS8
# GNAI1
# SMARCAD1
# TCF3
# NRG1
# UNC5D
# MAP2
# MAST2
# POU1F1
# MYSM1
# TNIP1
# UBE3A
# E2F7
# COX6B1
# ATP2B1
# CRHR2
# CREB5
# ETV5
# NHLH1
# ZNF362
# SCUBE2
# BCAR3
# CDH9
# NCAM2
# TRAK1
# STARD8
# IRF3
# ATP9B
# FCHSD2
# MYCN
# SH3GL3
# SCN9A
# CHRNA7
# KALRN
# SORBS2
# PLCL1
# AMY2B
# MAPK8
# KCTD16
# JUNB
# PPP1R1C
# SYNPO2
# GAS2
# TBX1
# TCEAL2
# ARHGEF12
# DOCK10
# FMN2
# PDE10A
# GABRG2
# MCTP2
# EOMES
# IRF1
# ARHGEF10L
# CTBP2
# CTCF
# NECAB1
# MTUS1
# HSF1
# GLRA2
# JDP2
# STS
# RREB1
# AP1S2
# TSPAN7
# ASPH
# PRKX
# LTBP1
# ARPP19
# MAFG
# LPIN1

# %%
# In AD-SCZ
# Load data
results_folder = './results/'
genes_suffix = '/mlp-Endothelial-20-5-Predictions.txt'
scz_ad = pd.read_csv(results_folder + 'SCZ-AD' + genes_suffix, delimiter=' ').to_numpy()

# Get significant genes
scz_ad_significant = scz_ad[:100, 0]

# Print significant genes
for s in scz_ad_significant:
    print(s)
# Out:
# GAB2
# NRXN3
# PECR
# CFH
# GBP2
# GSTO2
# LRRTM3
# POU2F1
# PLA2G4A
# MX1
# PON2
# MEF2C
# PRUNE2
# PPP2R2B
# CELF2
# OGFRL1
# RAB7A
# CAMK2D
# EIF2AK2
# CELF1
# IL33
# NCAM2
# ABCG2
# MAGI2
# SEMA4D
# ANK2
# IDE
# ESR1
# RBFOX1
# PPARG
# SORL1
# RPS6KA6
# ALDH1A1
# REL
# MSX1
# ESR2
# OLIG1
# EFNA5
# STXBP5L
# FGF1
# ZNF248
# SOX8
# RUNX1
# MAOA
# REST
# CACHD1
# CEBPB
# DBP
# ZNF282
# HSF1
# RXRB
# RNF19A
# AR
# FGD4
# PCLO
# FOXK1
# NFKB2
# TFE3
# E2F1
# ZEB1
# IRF3
# MNT
# ITGB1
# ANKRD36BP2
# SYNPO2
# OXR1
# KLF5
# WDR17
# GRB10
# GLIS2
# TEK
# CUX2
# GATA6
# MEOX2
# CENPB
# DPP10
# ERG
# HESX1
# RBPJ
# TRAK1
# MEIS3
# BARD1
# TCF3
# IRF2
# IRF8
# DISP1
# ALPK1
# KSR1
# RFX2
# IRF7
# TRIM59
# FGF14
# POU6F1
# HLF
# ZNF407
# JUNB
# ARHGEF3
# FHL1
# APBA2
# HSF4

# %%
# In AD-SCZ
# Load data
results_folder = './results/'
genes_suffix = '/mlp-GABAergic neuron-20-5-Predictions.txt'
scz_ad = pd.read_csv(results_folder + 'SCZ-AD' + genes_suffix, delimiter=' ').to_numpy()

# Get significant genes
scz_ad_significant = scz_ad[:100, 0]

# Print significant genes
for s in scz_ad_significant:
    print(s)
# Out:
# CYFIP2
# TAC1
# FRMPD1
# RUNX1T1
# IDH1
# ASPH
# UBE2H
# ZNF740
# SYT14
# MYH14
# PJA2
# CDKL5
# NR2F2
# CDYL
# CDON
# HUWE1
# PPARGC1B
# CAST
# ASCL1
# KIAA0895
# CNOT10
# PRRX1
# ENKUR
# WDR17
# WSB2
# PID1
# FLI1
# PTCH1
# ARHGEF3
# OXR1
# KIF6
# STOX2
# PTPRE
# SH3GL3
# PPP2R3A
# AFF2
# FOLH1
# APBA1
# PLS1
# ESR1
# ETS1
# CPLX2
# PURA
# PDC
# SOX4
# PER1
# ZNF24
# STAT1
# RORB
# NDST4
# PRKAG2
# KCNK12
# FOXO3
# CTNNBL1
# PLCH1
# MIPOL1
# MEG8
# ATF4
# GRHL1
# OSBPL5
# CREB5
# ARHGEF6
# HK1
# NFXL1
# ZNF282
# ACVR1
# PBX1
# RFX4
# TYW3
# GRHL2
# JUND
# MGST1
# JAKMIP3
# MTPAP
# MRPL45P2
# CEBPD
# AP1G1
# SCN8A
# DCX
# KIRREL3
# PTPRD
# MEOX2
# RPS6KA2
# ELK1
# SVIL
# FAT4
# DRAM2
# RASSF8
# GPD2
# CHORDC1
# COLQ
# EBF1
# MRPL48
# PRMT8
# PLEKHB2
# ATP10B
# HPS4
# RFTN1
# CNIH3
# NUMB

# %%
# In AD-SCZ
# Load data
results_folder = './results/'
genes_suffix = '/mlp-GABAergic SST interneuron-20-5-Predictions.txt'
scz_ad = pd.read_csv(results_folder + 'SCZ-AD' + genes_suffix, delimiter=' ').to_numpy()

# Get significant genes
scz_ad_significant = scz_ad[:100, 0]

# Print significant genes
for s in scz_ad_significant:
    print(s)

# Enrichment barplot
fig, axs = plt.subplots(1, 1, figsize=(12, 6))
pathway_enrichment = pd.read_csv(results_folder + 'enrichment/sst_scz-ad.csv')
sns.barplot(data=pathway_enrichment, x='Log10(P)', y='Description')
plt.ylabel(None)
plt.tight_layout()
plt.savefig(results_folder + f'enrichment/sst_scz-ad.png', dpi=300, bbox_inches='tight')
# Out:
# PIK3R1
# KCNIP4
# AP4S1
# KDM6A
# RASSF3
# RAB3GAP1
# SLC7A8
# BCL9
# LHX6
# FGF12
# CTNNA3
# HP1BP3
# GPR83
# ATP10B
# HDAC7
# MAP3K13
# GPR173
# TBC1D5
# GRM8
# SMYD3
# SETD2
# PDE7B
# ITPR1
# DGKK
# ADARB2
# CNKSR2
# ZFYVE26
# FOXJ3
# ZHX3
# SLC35F1
# FOXK1
# CEP57L1
# WIPF3
# DOCK10
# STAT2
# ELMOD2
# TEAD2
# SP1
# ADCYAP1R1
# ARHGAP6
# VAC14
# RARB
# ATP8B4
# CSMD3
# TPD52
# BBX
# STOX2
# SYT17
# EFHD2
# KIAA0319L
# REST
# SLC25A46
# NFIA
# CNTNAP2
# KTN1
# NXN
# CCDC149
# GLRA2
# ANKS1B
# POU6F1
# CLIP4
# CIZ1
# ATXN7L1
# FAM133A
# CEBPG
# LTBP1
# RREB1
# RHOXF1
# SCN5A
# DSE
# SP8
# ANXA4
# DDX20
# SLC22A23
# EGR3
# MAPK9
# PRICKLE2
# EFHD1
# PDE10A
# CHRNA6
# KCNIP3
# RORB
# NRG1
# RAPGEF5
# DPP6
# SEMA5B
# MLX
# PKNOX2
# VPS41
# NFYA
# CHD7
# SCRT1
# SLC1A2
# PBX3
# MTF1
# PJA2
# EPB41L2
# ZNF215
# WDR44
# LRRC7
