# %%
from collections import defaultdict
import os
import re

import matplotlib
from matplotlib.colors import LogNorm
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pecanpy as pp
import seaborn as sns
import sklearn.metrics
import torch
import torch.nn as nn
import torch_geometric
import torch_geometric.nn as gnn

# Style
sns.set_theme(context='talk', style='white', palette='Set2')
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %% [markdown]
# # Preparation

# %%
# Get files for contrast
# contrast = 'c02x'
dir = '../data/scenic_outs/'
# fnames = [fname for fname in os.listdir(dir) if fname.startswith(f'{contrast}_')]
fnames = os.listdir(dir)

# Get groups and cell-type based on fname
# TODO: Doesn't work for groups like 'AD_resilient'
m1 = re.compile('^([cr]\d+x(_\d+)?)_([a-zA-Z]+(_(resilient|strict))?)_((?!resilient|strict)\w+)_regulon_list.csv$')
get_contrast = lambda fname: m1.match(fname).group(1)
get_group = lambda fname: m1.match(fname).group(3)
get_cell_type = lambda fname: m1.match(fname).group(6)

# Get labels
gene_dir = '../data/new_labels/'
gene_fnames = [fname for fname in os.listdir(gene_dir) if fname.endswith('.txt')]
gene_lists = {'.'.join(fname.split('.')[:-1]): np.loadtxt(os.path.join(gene_dir, fname), dtype=str) for fname in gene_fnames}

# Special cases
gene_lists['scz'] = gene_lists['SCZ']
gene_lists['AD_resilient'] = gene_lists['AD_strict'] = gene_lists['AD']

# %% [markdown]
# # Analyses

# %% [markdown]
# ### TG Dot Analysis

# %%
for fname in fnames:
    ### Reading
    # Choose graph
    contrast = get_contrast(fname)
    group = get_group(fname)
    cell_type = get_cell_type(fname)
    print(' - '.join([fname, group, cell_type]))

    # Escape if not compatible
    if group not in gene_lists:
        print()
        continue

    # Get TF-TG linkages
    graph_list = pd.read_csv(os.path.join(dir, fname), index_col=0)
    graph_list = graph_list.rename(columns={'gene': 'TG', 'CoexWeight': 'coex'})

    # Get matrix
    graph_matrix = graph_list.pivot(index='TF', columns='TG', values='coex').fillna(0)

    # Get tf matrix
    # tf_matrix = pd.DataFrame(graph_matrix.to_numpy() @ graph_matrix.to_numpy().T, index=graph_matrix.index, columns=graph_matrix.index)  # TF
    tf_matrix = pd.DataFrame(graph_matrix.to_numpy().T @ graph_matrix.to_numpy(), index=graph_matrix.columns, columns=graph_matrix.columns)  # TG

    # Annotate
    gene_list = gene_lists[group]
    annotation = tf_matrix.index.map(lambda g: g in gene_list).to_numpy()

    # Sort based on annotation
    # annotation_sort_idx = list(annotation.argsort())[::-1]
    # tf_matrix = tf_matrix.iloc[annotation_sort_idx, annotation_sort_idx]
    # annotation = annotation[annotation_sort_idx]

    ### Processing
    # Sort genes based on dot with known TFs
    score = (tf_matrix.to_numpy() - np.diag(tf_matrix.to_numpy().diagonal()))[:, annotation].sum(axis=1)
    score[annotation] *= float(len(annotation)) / (len(annotation) - 1)
    sorted_idx = score.argsort()[::-1]

    ### Analysis
    # Evaluate performance
    if annotation[sorted_idx].sum() != 0:
        average_positive_percentile = np.linspace(1, 0, num=tf_matrix.shape[0])[annotation[sorted_idx]].mean()
    else:
        average_positive_percentile = np.nan
    print(f'Average positive percentile of {average_positive_percentile:.3f}')
    positive_unknown_genes = tf_matrix.index.to_numpy()[(score >= np.percentile(score, 100 - 100*float(annotation.sum()) / score.shape[0])) * ~annotation]
    print(f'Positive unknown genes: {positive_unknown_genes}')
    negative_positive_genes = tf_matrix.index.to_numpy()[(score < np.percentile(score, 100 - 100*float(annotation.sum()) / score.shape[0])) * annotation]
    print(f'Negative positive genes: {negative_positive_genes}')
    df = pd.DataFrame({
        # 'TF': tf_matrix.index.to_numpy()[sorted_idx],  # TF
        'TG': tf_matrix.index.to_numpy()[sorted_idx],  # TG
        'score': score[sorted_idx],
        'percentile': np.linspace(1, 0, num=tf_matrix.shape[0]),
        'annotation': annotation[sorted_idx],
    })

    ### Visualization
    # Sort based on score
    score_sort_idx = list(score.argsort())[::-1]
    tf_matrix_sort_score = tf_matrix.iloc[score_sort_idx, score_sort_idx]
    annotation_sort_score = annotation[score_sort_idx]
    # Sample for visualization size
    idx = np.random.choice(tf_matrix_sort_score.shape[0], min(tf_matrix_sort_score.shape[0], 100), replace=False)
    idx.sort()
    tf_matrix_sort_score = tf_matrix_sort_score.iloc[idx, idx]
    annotation_sort_score = annotation[idx]
    # Plot
    fig, ax = plt.subplots(1, 1, figsize=(9, 9))
    plt.title(f'{group}_{cell_type} - APP {average_positive_percentile:.3f}')
    sns.heatmap(tf_matrix_sort_score, norm=LogNorm(), cmap='mako_r', ax=ax)
    for i in np.argwhere(annotation_sort_score): plt.axhline(y=i, color='red', linewidth=1)
    fig.savefig(f'./plots/tf_matrix_{contrast}_{group}_{cell_type}.pdf', format='pdf', transparent=True)
    plt.tight_layout()
    plt.close()

    print()
# Out:
# c02x_AD_Astro_regulon_list.csv - AD - Astro
# Average positive percentile of 0.469
# Positive unknown genes: ['AEBP1' 'ANGPTL4' 'ANOS1' 'APLNR' 'ARID5A' 'ATF3' 'BAG3' 'BARD1' 'BCL6'
#  'BHLHE40' 'BTG2' 'C1R' 'C1RL' 'C4orf19' 'CACHD1' 'CDKN1A' 'CEBPB' 'CEBPD'
#  'CLIC4' 'CNN3' 'CRISPLD1' 'CRYAB' 'CSRNP1' 'CYCS' 'DBI' 'DDIT4' 'DTNA'
#  'DUSP1' 'ELL2' 'EMP1' 'EPAS1' 'ETV6' 'FGF2' 'FOS' 'FOSL2' 'GADD45A'
#  'GADD45B' 'GEM' 'GFAP' 'GHR' 'GPCPD1' 'GRIA1' 'HELB' 'HES1' 'HMGCS1'
#  'HSP90AA1' 'HSPA1A' 'HSPB1' 'HSPB8' 'HSPD1' 'HSPH1' 'ID2' 'ID3' 'IDI1'
#  'IER2' 'IGFBP7' 'IL13RA1' 'IL1R1' 'ITPKB' 'JUN' 'JUNB' 'KIAA0040' 'KLF6'
#  'LAMA1' 'LIMK2' 'LMO2' 'LTBP1' 'MAP3K14' 'MATN2' 'MIDN' 'MSN' 'NAMPT'
#  'NFIL3' 'NR4A1' 'NRP1' 'NRP2' 'OSMR' 'P2RY6' 'PAM' 'PARP9' 'PDPN'
#  'PFKFB2' 'PLSCR1' 'PMP2' 'RASD1' 'RELL1' 'RFX4' 'RGS16' 'RND3' 'RNF122'
#  'SAMD4A' 'SBNO2' 'SCARA3' 'SH3GL2' 'SLC38A1' 'SLC38A2' 'SMAD3' 'SOCS3'
#  'STOM' 'SULF1' 'TANC1' 'TEAD3' 'TEAD4' 'TIPARP' 'TNFRSF1A' 'TOB1'
#  'TRIP10' 'TXNIP' 'UBASH3B' 'UBC' 'WIPF1' 'WWTR1' 'YBX3' 'YOD1' 'ZBTB7C'
#  'ZCCHC24' 'ZFP36' 'ZFP36L1' 'ZFP36L2' 'ZIC1']
# Negative positive genes: ['A2M' 'ABCA1' 'ABCA2' 'ABCG2' 'ACAN' 'ADRB2' 'AGER' 'ALOX5' 'APOC1'
#  'APOD' 'APOE' 'AR' 'ARSJ' 'ATP7B' 'BCHE' 'BDNF' 'CADPS2' 'CARD8' 'CASS4'
#  'CAV1' 'CCL3' 'CD14' 'CD36' 'CDKN2A' 'CFH' 'CH25H' 'CHRNA7' 'CLSTN2'
#  'CLU' 'COL11A1' 'COL25A1' 'CST3' 'CTSS' 'DCHS2' 'DGKB' 'DHCR24' 'EFNA5'
#  'ESR1' 'ESR2' 'F13A1' 'FAS' 'FCER1G' 'FGF1' 'FRMD6' 'FSHR' 'GBP2' 'GPX1'
#  'GREM2' 'GRIN3A' 'GRN' 'GSTP1' 'HACD1' 'HCRTR2' 'HFE' 'HHEX' 'HLA-A'
#  'HLA-DQB1' 'HLA-DRA' 'HLA-DRB1' 'HMOX1' 'HSD11B1' 'HSPA5' 'HSPG2' 'IGF1'
#  'IL18' 'IL1B' 'IL33' 'IL6R' 'INPP5D' 'LIPC' 'LMNA' 'LPL' 'LRRK2' 'MAOA'
#  'MEF2A' 'MME' 'MTHFD1L' 'MX1' 'NEDD9' 'NGB' 'NGF' 'NGFR' 'NINJ2' 'NLRP1'
#  'NOS1' 'NOS3' 'NPC2' 'NXPH1' 'OGFRL1' 'OLR1' 'PCDH11X' 'PCED1B' 'PLA2G4A'
#  'PLXNA4' 'PON2' 'PON3' 'PPARG' 'PPP1R3B' 'PTGS2' 'RELN' 'RUNX1' 'SAMSN1'
#  'SDC2' 'SLC2A9' 'SNTG1' 'SOAT1' 'SORCS1' 'SORCS3' 'SORL1' 'SST' 'TBX3'
#  'TF' 'TGFB1' 'TLR2' 'TP53' 'TP63' 'VEGFA' 'WWC1' 'XBP1' 'ZCWPW1']
#
# c02x_AD_Endo_regulon_list.csv - AD - Endo
# Average positive percentile of 0.486
# Positive unknown genes: ['ACER2' 'ACSL5' 'ADAMTS9' 'AKAP12' 'ANGPT2' 'APOLD1' 'ARHGEF28' 'ARID5A'
#  'ARRDC3' 'ATP10A' 'B2M' 'BCL6' 'BHLHE40' 'C4orf19' 'CASP4' 'CDKN1A'
#  'CEBPD' 'CHST15' 'CLDN5' 'CLEC1A' 'CLEC2B' 'CLIC1' 'CLIC5' 'COL4A2' 'CP'
#  'CREM' 'CSRNP1' 'DUSP1' 'DUSP16' 'DUSP5' 'DUSP6' 'EFNA1' 'EGR1' 'ELL2'
#  'EMP2' 'ERG' 'ETS2' 'FLT1' 'FOS' 'FOSL2' 'GADD45B' 'GALNT18' 'GJA1'
#  'GNA13' 'GNB4' 'GRAMD1A' 'HES1' 'ID1' 'IER2' 'IFI16' 'IFITM3' 'IL4R'
#  'IL6ST' 'ITGA6' 'JUN' 'JUNB' 'KLF2' 'KLF4' 'KLF6' 'LDLRAD3' 'LIMS2'
#  'LRRC32' 'MAFF' 'MAP3K8' 'MCL1' 'MCTP1' 'MID1' 'MT1E' 'MT2A' 'MYO1E'
#  'NAMPT' 'NDRG1' 'NFKBIA' 'NFKBIZ' 'NR4A1' 'OSMR' 'P4HA1' 'PAPSS2'
#  'PITPNC1' 'PLA1A' 'PLEKHG1' 'PLOD2' 'PLSCR1' 'PLSCR4' 'PODXL' 'PTMA'
#  'PXN' 'RBMS2' 'RELL1' 'RGCC' 'RHOJ' 'RIMKLB' 'RNF19A' 'RPS23' 'S1PR1'
#  'SAMD4A' 'SCARB1' 'SDCBP' 'SEMA6A' 'SERPINH1' 'SLC16A1' 'SLC19A3'
#  'SLC26A2' 'SLC2A3' 'SLC38A2' 'SLC4A7' 'SLC6A6' 'SLCO4A1' 'SMAD6' 'SMAD7'
#  'SOCS3' 'SOX7' 'SRGN' 'STARD8' 'SVIL' 'TAGLN2' 'TGFBR2' 'TIPARP' 'TMSB10'
#  'TNS1' 'TPT1' 'TSHZ2' 'UBC' 'YBX3' 'ZFP36']
# Negative positive genes: ['A2M' 'ABCA1' 'ABCA2' 'ABCG2' 'ACAN' 'ADAM12' 'ADRB2' 'AGER' 'ALOX5'
#  'APOC1' 'APOD' 'APOE' 'AR' 'ARSJ' 'ATP7B' 'BCHE' 'BDNF' 'CADPS2' 'CARD8'
#  'CASS4' 'CAV1' 'CCL2' 'CCL3' 'CD14' 'CD33' 'CD36' 'CD44' 'CDKN2A' 'CH25H'
#  'CHRNA7' 'CLSTN2' 'CLU' 'COL11A1' 'COL25A1' 'CST3' 'CTSS' 'DCHS2' 'DGKB'
#  'DHCR24' 'EFNA5' 'ESR1' 'ESR2' 'F13A1' 'FAS' 'FCER1G' 'FGF1' 'FRMD6'
#  'FSHR' 'GBP2' 'GPX1' 'GREM2' 'GRIN3A' 'GRN' 'HACD1' 'HCRTR2' 'HHEX'
#  'HLA-A' 'HLA-DRA' 'HLA-DRB1' 'HLA-DRB5' 'HMOX1' 'HSD11B1' 'HSPG2' 'ICAM1'
#  'IGF1' 'IL18' 'IL1B' 'IL33' 'INPP5D' 'LDLR' 'LIPC' 'LMNA' 'LPL' 'LRP2'
#  'LRRK2' 'MAOA' 'MEF2A' 'MME' 'MS4A4A' 'MX1' 'NEDD9' 'NGB' 'NGF' 'NGFR'
#  'NINJ2' 'NLRP1' 'NLRP3' 'NOS1' 'NOS3' 'NPC2' 'NXPH1' 'OGFRL1' 'OLR1'
#  'PCDH11X' 'PCED1B' 'PLA2G4A' 'PLXNA4' 'PON3' 'PPARG' 'PPP1R3B' 'PTGS2'
#  'RELN' 'RUNX1' 'S100B' 'SAMSN1' 'SDC2' 'SLC19A1' 'SLC2A9' 'SNTG1' 'SOAT1'
#  'SORCS1' 'SORCS3' 'SORL1' 'SST' 'TBX3' 'TF' 'TGFB1' 'TLR2' 'TP53' 'TP63'
#  'TREM2' 'VEGFA' 'WWC1' 'XBP1' 'ZCWPW1']
#
# c02x_AD_EN_L3_5_IT_1_regulon_list.csv - AD - EN_L3_5_IT_1
# Average positive percentile of 0.511
# Positive unknown genes: ['ABCB1' 'ADGRL2' 'AFAP1L2' 'ANKUB1' 'ANTXR2' 'ARHGAP15' 'ATP8B1' 'B3GNT5'
#  'BCL2L14' 'CCDC168' 'CCK' 'CCND3' 'CDH19' 'CDH7' 'CEMIP' 'CHODL' 'CHRDL1'
#  'CHRM2' 'CHST9' 'CLMP' 'CNR1' 'COBLL1' 'COL12A1' 'COL5A2' 'COL8A1'
#  'CREB5' 'CSGALNACT1' 'CTNNA2' 'CUX2' 'DCC' 'ENPP1' 'EPHA7' 'FGFR1'
#  'FILIP1L' 'FMO5' 'FN1' 'FOXO1' 'FOXP2' 'GLIPR1L1' 'GNG4' 'GPR149'
#  'GPRIN3' 'GRM8' 'HGF' 'HS3ST2' 'HSPA1A' 'HTR1F' 'HTR2B' 'ID2' 'IER5'
#  'IFIT3' 'IL12RB2' 'IL1RAP' 'ITGA11' 'KCNH5' 'KCNK2' 'KCNQ5' 'KCTD8'
#  'LAMA2' 'LDLRAD3' 'LRTM1' 'MAMDC2' 'MAN1A1' 'MAN2A1' 'MCMDC2' 'MEGF11'
#  'MGST1' 'MLIP' 'MMP16' 'MPPED2' 'MYOCD' 'NFE2L3' 'NPAS4' 'NRP2' 'OPRM1'
#  'P2RY12' 'P2RY14' 'PDE1C' 'PDZRN4' 'PHLDB2' 'PLCH1' 'PLCXD3' 'PLEKHG1'
#  'PLOD2' 'PLSCR4' 'PLXDC2' 'PNRC1' 'POU6F2' 'PPFIBP1' 'PRELID2' 'PROX1'
#  'PTCHD4' 'PTMA' 'RALYL' 'RASD1' 'RIN3' 'RORB' 'RSPO2' 'RUNX2' 'SEMA3E'
#  'SEMA5A' 'SFMBT2' 'SGK1' 'SLA' 'SLC35F1' 'SNCAIP' 'SOX5' 'SPARC' 'SPATA1'
#  'ST8SIA4' 'STX19' 'STXBP6' 'SULF2' 'SYT17' 'TBL1X' 'THSD7B' 'TMSB4X'
#  'TMTC2' 'TOX' 'TRPM3' 'TSHZ2' 'TTN' 'UBC' 'UNC5D' 'VWC2L' 'ZFHX3' 'ZFPM2'
#  'ZNF213' 'ZNF385B']
# Negative positive genes: ['A2M' 'ABCA1' 'ABCA2' 'ABCG2' 'ACAN' 'ADAM12' 'ADRB2' 'AGER' 'ALOX5'
#  'APOC1' 'APOD' 'APOE' 'AR' 'ARSJ' 'ATP7B' 'BACE2' 'BCHE' 'BDNF' 'CADPS2'
#  'CARD8' 'CASS4' 'CAV1' 'CCL2' 'CD14' 'CD33' 'CD36' 'CD44' 'CDKN2A'
#  'CH25H' 'CHRNA7' 'CLSTN2' 'CLU' 'COL11A1' 'COL25A1' 'CR1' 'CST3' 'CTSS'
#  'DCHS2' 'DGKB' 'DHCR24' 'EFNA5' 'ESR2' 'F13A1' 'FAS' 'FCER1G' 'FGF1'
#  'FRMD6' 'FSHR' 'GBP2' 'GPX1' 'GRIN3A' 'GRN' 'GSTP1' 'HACD1' 'HCRTR2'
#  'HHEX' 'HLA-A' 'HLA-DQB1' 'HLA-DRB1' 'HLA-DRB5' 'HMOX1' 'HSD11B1' 'HSPA5'
#  'HSPG2' 'ICAM1' 'IGF1' 'IL18' 'IL1B' 'IL33' 'IL6R' 'INPP5D' 'LDLR' 'LIPC'
#  'LMNA' 'LPL' 'LRP2' 'LRRK2' 'MALRD1' 'MAOA' 'MS4A4A' 'MS4A6A' 'MTHFD1L'
#  'MX1' 'NEDD9' 'NGB' 'NGF' 'NGFR' 'NINJ2' 'NLRP1' 'NLRP3' 'NOS1' 'NOS3'
#  'NPC2' 'NXPH1' 'OGFRL1' 'OLR1' 'PCED1B' 'PLA2G4A' 'PLXNA4' 'PON2' 'PON3'
#  'PPARG' 'PPP1R3B' 'PTGS2' 'RELN' 'RUNX1' 'S100B' 'SAMSN1' 'SDC2'
#  'SLC19A1' 'SLC2A9' 'SNTG1' 'SOAT1' 'SORCS1' 'SORCS2' 'SORCS3' 'SORL1'
#  'SST' 'TBX3' 'TF' 'TGFB1' 'TLR2' 'TP53' 'TP63' 'TREM2' 'VEGFA' 'WWC1'
#  'XBP1' 'ZCWPW1']
#
# c02x_AD_EN_L3_5_IT_3_regulon_list.csv - AD - EN_L3_5_IT_3
# Average positive percentile of 0.507
# Positive unknown genes: ['ABCB1' 'ACTA2' 'ADGRG2' 'AMZ1' 'ANGPT2' 'ANKUB1' 'ARHGAP15' 'ARHGAP9'
#  'ASB14' 'ASPN' 'B3GNT5' 'BCL2L14' 'C11orf65' 'C4orf45' 'CABLES1' 'CAV3'
#  'CCDC60' 'CCK' 'CDH13' 'CEACAM1' 'CEMIP' 'CHST9' 'CLMP' 'CPB2' 'CRLF1'
#  'CUX2' 'CYP3A5' 'DCC' 'DOCK6' 'DUSP16' 'ECM2' 'EGR1' 'ENPP2' 'EPHA3'
#  'ETV6' 'EYS' 'FILIP1L' 'FLRT2' 'FMO5' 'FN1' 'FOXP2' 'FPR3' 'FSIP2' 'FTH1'
#  'GCNT1' 'GLRA2' 'GLRX' 'GPC6' 'GRIP1' 'HHIP' 'HSP90AA1' 'HTR2B' 'ID2'
#  'IFIT2' 'IFIT3' 'IGSF6' 'ITGBL1' 'KAZN' 'KHDRBS3' 'KIAA1217' 'LENG9'
#  'LINGO2' 'LPAR6' 'LRTM1' 'MEGF11' 'MFSD4B' 'MGST1' 'MROH9' 'MYOT'
#  'NFE2L3' 'NHS' 'NPAS4' 'NPNT' 'NTNG1' 'OGN' 'OMD' 'OPRM1' 'OSMR' 'P2RY12'
#  'P2RY14' 'PALLD' 'PAPPA' 'PGM5' 'PIGC' 'PLCB4' 'PLCXD3' 'POU6F2' 'PRSS23'
#  'PTMA' 'PTPRO' 'PYGL' 'RALYL' 'RARB' 'RFX4' 'RHD' 'RPL35A' 'RPS27'
#  'RPS4X' 'RPS7' 'RUNX2' 'SCG2' 'SEMA3E' 'SEMA6D' 'SFRP4' 'SLC22A24'
#  'SLC22A25' 'SLC26A5' 'SLC38A2' 'SPATA1' 'STX19' 'SVIL' 'TBL1X' 'TCF7L2'
#  'TIMP3' 'TMSB10' 'TP53TG5' 'TRPC3' 'TSHR' 'TTN' 'UBC' 'USP13' 'UTRN'
#  'WNT5B' 'ZFHX3' 'ZNF213']
# Negative positive genes: ['ABCA1' 'ABCA2' 'ABCG2' 'ACAN' 'ADAM12' 'ADRB2' 'AGER' 'ALOX5' 'APOC1'
#  'APOD' 'APOE' 'AR' 'ARSJ' 'ATP7B' 'BACE2' 'BCHE' 'BDNF' 'CADPS2' 'CARD8'
#  'CASS4' 'CAV1' 'CCL2' 'CCL3' 'CD14' 'CD33' 'CD36' 'CD44' 'CDKN2A' 'CFH'
#  'CH25H' 'CHRNA7' 'CLU' 'COL11A1' 'COL25A1' 'CR1' 'CST3' 'CTSS' 'DCHS2'
#  'DHCR24' 'EFNA5' 'ESR1' 'ESR2' 'F13A1' 'FAS' 'FCER1G' 'FRMD6' 'FSHR'
#  'GBP2' 'GPX1' 'GREM2' 'GRIN3A' 'GSTP1' 'HACD1' 'HCRTR2' 'HFE' 'HHEX'
#  'HLA-A' 'HLA-DRA' 'HLA-DRB1' 'HLA-DRB5' 'HMOX1' 'HSD11B1' 'HSPA5' 'HSPG2'
#  'ICAM1' 'IGF1' 'IL1B' 'IL33' 'IL6R' 'INPP5D' 'LDLR' 'LIPC' 'LMNA' 'LPL'
#  'LRP2' 'LRRK2' 'MALRD1' 'MAOA' 'MEF2A' 'MME' 'MS4A4A' 'MTHFD1L' 'MX1'
#  'NEDD9' 'NGB' 'NGF' 'NGFR' 'NINJ2' 'NLRP1' 'NLRP3' 'NOS1' 'NOS3' 'NPC2'
#  'NXPH1' 'OGFRL1' 'OLR1' 'PCDH11X' 'PCED1B' 'PLA2G4A' 'PLXNA4' 'PON2'
#  'PON3' 'PPARG' 'PPP1R3B' 'PTGS2' 'RELN' 'RUNX1' 'S100B' 'SAMSN1' 'SDC2'
#  'SLC19A1' 'SLC2A9' 'SOAT1' 'SORCS1' 'SORCS3' 'SORL1' 'SST' 'TBX3' 'TLR2'
#  'TP53' 'TP63' 'VEGFA' 'WWC1' 'XBP1' 'ZCWPW1']
#
# c02x_AD_EN_L5_ET_regulon_list.csv - AD - EN_L5_ET
# Average positive percentile of 0.533
# Positive unknown genes: ['ABCB1' 'ACTA2' 'ADAM28' 'ADAMTS1' 'ALK' 'ANGPT2' 'ANKUB1' 'ANO4'
#  'ARHGAP15' 'B3GNT5' 'BCL2L14' 'BMX' 'C11orf65' 'C4orf45' 'CACNB2' 'CAV3'
#  'CFTR' 'CHST9' 'CNR1' 'COL10A1' 'COL12A1' 'CPS1' 'CREB5' 'CREM' 'CYP1B1'
#  'DNAJB1' 'DUSP16' 'ECM2' 'EFCAB13' 'ENO4' 'EYS' 'FILIP1L' 'FMO5' 'FN1'
#  'FSIP2' 'GABRA2' 'GCNT1' 'GLIPR1L1' 'GRM1' 'HHIP' 'HTR2B' 'IFIT2' 'IFIT3'
#  'IGSF6' 'KCNMB4' 'KCNQ1' 'LAMC1' 'LENG9' 'LPAR6' 'LRTM1' 'MFSD4B' 'MGST1'
#  'MROH9' 'NDST3' 'NETO1' 'NFE2L3' 'NPNT' 'OGN' 'OPRM1' 'OSMR' 'P2RY12'
#  'P2RY14' 'P4HA3' 'PHEX' 'PIPOX' 'PRSS23' 'PRSS48' 'PTPRE' 'PYGL' 'PZP'
#  'RARRES1' 'RUNX2' 'SCN9A' 'SERPINE2' 'SFRP4' 'SGMS2' 'SHISA6' 'SHROOM3'
#  'SLC26A5' 'SMIM4' 'SPI1' 'STX19' 'SVIL' 'TIMP3' 'TMEM132D' 'TMSB4X'
#  'TNFRSF11A' 'TRIM5' 'TRPS1' 'TTN' 'USP13' 'WNT5B' 'ZNF213' 'ZNF565']
# Negative positive genes: ['A2M' 'ABCA1' 'ABCG2' 'ACAN' 'ADAM12' 'ALOX5' 'APOD' 'APOE' 'AR' 'ARSJ'
#  'ATP7B' 'BACE2' 'BCHE' 'BDNF' 'CADPS2' 'CARD8' 'CASS4' 'CAV1' 'CD36'
#  'CD44' 'CDKN2A' 'CFH' 'CHRNA7' 'CLSTN2' 'CLU' 'COL11A1' 'COL25A1' 'CTSS'
#  'DCHS2' 'DGKB' 'DHCR24' 'EFNA5' 'ESR2' 'F13A1' 'FAS' 'FGF1' 'FRMD6'
#  'FSHR' 'GBP2' 'GREM2' 'GRIN3A' 'HACD1' 'HCRTR2' 'HLA-DRA' 'HLA-DRB1'
#  'HSPA5' 'HSPG2' 'ICAM1' 'IGF1' 'IL18' 'IL33' 'IL6R' 'INPP5D' 'LDLR'
#  'LIPC' 'LMNA' 'LPL' 'LRP2' 'MALRD1' 'MAOA' 'MEF2A' 'MME' 'MS4A4A' 'MX1'
#  'NEDD9' 'NGF' 'NINJ2' 'NLRP1' 'NOS1' 'NPC2' 'NXPH1' 'OGFRL1' 'PCED1B'
#  'PLA2G4A' 'PLXNA4' 'PPARG' 'PPP1R3B' 'PTGS2' 'RELN' 'RUNX1' 'SAMSN1'
#  'SDC2' 'SNTG1' 'SOAT1' 'SORL1' 'SST' 'TF' 'TLR2' 'TP53' 'TP63' 'VEGFA'
#  'WWC1' 'XBP1' 'ZCWPW1']
#
# c02x_AD_EN_L6B_regulon_list.csv - AD - EN_L6B
# Average positive percentile of 0.466
# Positive unknown genes: ['ABCB1' 'ACSL5' 'ACSM3' 'ACTA2' 'ADGRG2' 'ALK' 'AMZ1' 'ANGPT2' 'ANKUB1'
#  'ARHGAP15' 'ASB14' 'B3GNT5' 'BCL2L14' 'BHLHE40' 'C11orf65' 'C1QTNF7'
#  'C4orf45' 'CA1' 'CASP8' 'CAV3' 'CCDC141' 'CEACAM1' 'CHST9' 'CNR1' 'CNTN5'
#  'COL10A1' 'COL6A6' 'CYP3A5' 'DUSP16' 'DUSP6' 'ECM2' 'EDNRA' 'EGR1' 'EGR3'
#  'ENO4' 'ENPP2' 'ETS2' 'EYS' 'FAM217A' 'FILIP1L' 'FMO5' 'FN1' 'FSIP2'
#  'FTH1' 'GABRA2' 'GCNT1' 'GLRX' 'GPR183' 'HHIP' 'HS3ST2' 'HTR1F' 'HTR2B'
#  'ID2' 'IGSF6' 'ITGA1' 'JUNB' 'KCNQ1' 'KCNQ5' 'LRTM1' 'MCMDC2' 'MDFIC'
#  'MFSD4B' 'MGST1' 'MROH9' 'NDST3' 'NFE2L3' 'NPAS4' 'NR4A1' 'OMD' 'OSMR'
#  'P2RY12' 'P2RY14' 'P4HA3' 'PAM' 'PAPPA' 'PCDH7' 'PGM5' 'PHEX' 'PIGC'
#  'PLCB4' 'PLCH1' 'POU6F2' 'PPP1R1C' 'PRSS23' 'PRSS48' 'PZP' 'RARB' 'RBMS1'
#  'RERG' 'RFX4' 'RHD' 'RIN3' 'RPL19' 'RPL35A' 'RPS12' 'RPS4X' 'SDK1'
#  'SEMA3D' 'SGMS2' 'SLC22A25' 'SLC7A5' 'SORBS2' 'SPATA1' 'ST6GALNAC5'
#  'STX19' 'STXBP6' 'SVIL' 'SYT2' 'TACR1' 'TIMP3' 'TM6SF1' 'TP53TG5' 'TRIM5'
#  'TSHR' 'TTC29' 'TTN' 'TUBA1A' 'UBASH3B' 'USP13' 'WNT5B' 'WWTR1' 'ZNF213'
#  'ZNF565']
# Negative positive genes: ['ABCA1' 'ABCA2' 'ABCG2' 'ACAN' 'ADAM12' 'ADRB2' 'AGER' 'ALOX5' 'APOC1'
#  'APOD' 'APOE' 'AR' 'ARSJ' 'BACE2' 'BCHE' 'BDNF' 'CADPS2' 'CARD8' 'CAV1'
#  'CCL2' 'CCL3' 'CD14' 'CD33' 'CD36' 'CD44' 'CDKN2A' 'CFH' 'CH25H' 'CHRNA7'
#  'CLSTN2' 'CLU' 'COL11A1' 'COL25A1' 'CR1' 'CTSS' 'DCHS2' 'DHCR24' 'EFNA5'
#  'ESR1' 'ESR2' 'F13A1' 'FAS' 'FCER1G' 'FRMD6' 'FSHR' 'GBP2' 'GPX1' 'GREM2'
#  'GRIN3A' 'GRN' 'HACD1' 'HCRTR2' 'HFE' 'HHEX' 'HLA-A' 'HLA-DQB1' 'HLA-DRA'
#  'HLA-DRB1' 'HLA-DRB5' 'HMOX1' 'HSD11B1' 'HSPA5' 'HSPG2' 'ICAM1' 'IGF1'
#  'IL18' 'IL1B' 'IL33' 'IL6R' 'INPP5D' 'LDLR' 'LIPC' 'LMNA' 'LPL' 'LRP2'
#  'LRRK2' 'MAOA' 'MEF2A' 'MME' 'MS4A4A' 'MS4A6A' 'MX1' 'NEDD9' 'NGB' 'NGF'
#  'NGFR' 'NINJ2' 'NLRP1' 'NLRP3' 'NOS1' 'NOS3' 'NPC2' 'NXPH1' 'OGFRL1'
#  'PCED1B' 'PLA2G4A' 'PLXNA4' 'PPARG' 'PPP1R3B' 'PTGS2' 'RELN' 'RUNX1'
#  'S100B' 'SAMSN1' 'SDC2' 'SLC19A1' 'SLC2A9' 'SNTG1' 'SOAT1' 'SORCS1'
#  'SORCS3' 'SORL1' 'TBX3' 'TF' 'TGFB1' 'TLR2' 'TP53' 'TP63' 'TREM2' 'VEGFA'
#  'WWC1' 'XBP1' 'ZCWPW1']
#
# c02x_AD_EN_L6_CT_regulon_list.csv - AD - EN_L6_CT
# Average positive percentile of 0.481
# Positive unknown genes: ['ADAMTS3' 'ALDH1A2' 'ANGPT2' 'ANKUB1' 'ARHGAP15' 'ARHGAP6' 'ASB14' 'ASPN'
#  'B3GNT5' 'BCL2L14' 'BTG2' 'C11orf65' 'C1QTNF7' 'C4orf45' 'CAV3' 'CDH18'
#  'CEACAM1' 'CFTR' 'CHST9' 'COL10A1' 'COL5A2' 'CPB2' 'CRLF1' 'CSRNP1'
#  'CYP3A5' 'DACH1' 'DOK6' 'DUSP16' 'DUSP5' 'DUSP6' 'ECM2' 'EGR1' 'EGR3'
#  'ELOVL5' 'ENO4' 'EYS' 'FILIP1L' 'FMO5' 'FN1' 'FOS' 'FOSB' 'FSIP2' 'FTL'
#  'GADD45A' 'GADD45B' 'GCNT1' 'GPM6A' 'GRM1' 'GRM3' 'GRM8' 'HHIP' 'HTR2B'
#  'ID2' 'IGSF6' 'ITGBL1' 'JUNB' 'KCNH5' 'KCTD8' 'LENG9' 'LPAR6' 'LRRC4C'
#  'LRRTM4' 'LRTM1' 'MFSD4B' 'MGST1' 'MROH9' 'NFE2L3' 'NPAS4' 'NR4A1'
#  'NR4A3' 'OMD' 'P2RY12' 'P2RY14' 'P4HA3' 'PCSK5' 'PHEX' 'PLPPR1' 'POU6F2'
#  'PRKG1' 'PRSS23' 'PRSS48' 'PTMA' 'PYGL' 'RALYL' 'RFX4' 'ROBO1' 'RPL18A'
#  'RPL41' 'RPS12' 'RPS21' 'RPS27' 'RPS4X' 'RUNX2' 'SEMA3E' 'SFRP4' 'SGK1'
#  'SHISA6' 'SLC13A4' 'SLC16A3' 'SLC22A24' 'SLC22A25' 'SLC26A5' 'SLC2A3'
#  'SLC4A4' 'SLC7A5' 'SOX5' 'SPATA1' 'STX19' 'SVIL' 'SYT1' 'SYT2' 'TACR1'
#  'TENM1' 'TIMP3' 'TMSB10' 'TRIM5' 'TRPM3' 'TSHR' 'TTN' 'TUBA1A' 'UBASH3B'
#  'USP13' 'ZNF213' 'ZNF565' 'ZNF804A']
# Negative positive genes: ['ABCA1' 'ABCA2' 'ABCG2' 'ACAN' 'ADAM12' 'ADRB2' 'AGER' 'ALOX5' 'APOC1'
#  'APOD' 'APOE' 'AR' 'ARSJ' 'ATP7B' 'BACE2' 'BCHE' 'BDNF' 'CARD8' 'CASS4'
#  'CAV1' 'CCL2' 'CCL3' 'CD14' 'CD33' 'CD36' 'CD44' 'CDKN2A' 'CFH' 'CHRNA7'
#  'CLU' 'COL11A1' 'COL25A1' 'CST3' 'CTSS' 'DCHS2' 'DGKB' 'DHCR24' 'EFNA5'
#  'ESR1' 'ESR2' 'F13A1' 'FAS' 'FCER1G' 'FGF1' 'FRMD6' 'FSHR' 'GBP2' 'GPX1'
#  'GREM2' 'GRIN3A' 'GRN' 'HACD1' 'HCRTR2' 'HFE' 'HLA-A' 'HLA-DQB1'
#  'HLA-DRA' 'HLA-DRB1' 'HLA-DRB5' 'HMOX1' 'HSD11B1' 'HSPA5' 'HSPG2' 'ICAM1'
#  'IGF1' 'IL18' 'IL1B' 'IL33' 'IL6R' 'INPP5D' 'LDLR' 'LIPC' 'LMNA' 'LPL'
#  'LRP2' 'LRRK2' 'MALRD1' 'MAOA' 'MEF2A' 'MS4A4A' 'MS4A6A' 'MX1' 'NEDD9'
#  'NGB' 'NGF' 'NGFR' 'NINJ2' 'NLRP1' 'NLRP3' 'NOS1' 'NOS3' 'NXPH1' 'OGFRL1'
#  'OLR1' 'PCDH11X' 'PCED1B' 'PLA2G4A' 'PLXNA4' 'PON2' 'PPARG' 'PPP1R3B'
#  'PTGS2' 'RELN' 'RUNX1' 'S100B' 'SAMSN1' 'SDC2' 'SLC19A1' 'SLC2A9' 'SNTG1'
#  'SOAT1' 'SORCS1' 'SORCS2' 'SORCS3' 'SORL1' 'SST' 'TBX3' 'TF' 'TGFB1'
#  'TLR2' 'TP63' 'VEGFA' 'WWC1' 'XBP1' 'ZCWPW1']
#
# c02x_AD_EN_L6_IT_1_regulon_list.csv - AD - EN_L6_IT_1
# Average positive percentile of 0.532
# Positive unknown genes: ['ABCB1' 'ACSS3' 'ACTA2' 'ADAM28' 'ADGRG2' 'AHR' 'ANGPT2' 'ANKUB1' 'ANXA1'
#  'ARHGAP15' 'ARHGAP9' 'ASPN' 'ATP13A5' 'B3GAT2' 'B3GNT5' 'BCL2L14' 'BMX'
#  'C11orf65' 'C1QTNF7' 'C4orf45' 'CA1' 'CASP8' 'CAV3' 'CC2D2B' 'CCDC60'
#  'CD226' 'CEMIP' 'CFTR' 'CHRM5' 'CHST9' 'CNTN5' 'COL10A1' 'COL6A6' 'CP'
#  'CPVL' 'CRLF1' 'CYYR1' 'DACH1' 'DCC' 'DNAJB1' 'DOCK2' 'DOCK6' 'DUSP16'
#  'ECM2' 'EFCAB13' 'ELK3' 'ENO4' 'ENPP2' 'EYA1' 'EYS' 'FAU' 'FILIP1L'
#  'FMNL1' 'FN1' 'FTH1' 'FTL' 'GCNT1' 'GPR183' 'HHIP' 'HSPD1' 'HTR2B' 'ID2'
#  'ITGBL1' 'KCNQ1' 'KMO' 'LENG9' 'LPAR6' 'LRTM1' 'MEI4' 'MGST1' 'MROH9'
#  'MYO1F' 'MYOT' 'NEK5' 'NFE2L3' 'NPAS4' 'OMD' 'OPRM1' 'P2RY12' 'P2RY14'
#  'PALLD' 'PAPPA' 'PGM5' 'PHEX' 'PIGC' 'PPP1R1C' 'PRSS23' 'PRSS48' 'PTER'
#  'RARRES1' 'RASGRP3' 'RERG' 'RFX4' 'RHD' 'RIN3' 'RPL41' 'RPS4X' 'RPS7'
#  'SEMA3A' 'SFRP4' 'SGMS2' 'SH2D4A' 'SHISA6' 'SHROOM3' 'SKA2' 'SLC13A4'
#  'SLC16A3' 'SLC26A5' 'STX19' 'SVIL' 'SYT2' 'THSD4' 'TIMP3' 'TOX' 'TP53TG5'
#  'TTN' 'USP13' 'WNT5B' 'ZNF213' 'ZNF565']
# Negative positive genes: ['ABCA1' 'ABCA2' 'ABCG2' 'ACAN' 'ADAM12' 'ADRB2' 'AGER' 'ALOX5' 'APOC1'
#  'APOD' 'AR' 'ARSJ' 'ATP7B' 'BACE2' 'BCHE' 'BDNF' 'CADPS2' 'CARD8' 'CASS4'
#  'CAV1' 'CCL2' 'CCL3' 'CD14' 'CD33' 'CD36' 'CD44' 'CDKN2A' 'CFH' 'CH25H'
#  'CHRNA7' 'CLSTN2' 'CLU' 'COL11A1' 'COL25A1' 'CR1' 'CST3' 'CTSS' 'DCHS2'
#  'DHCR24' 'ESR2' 'F13A1' 'FAS' 'FCER1G' 'FRMD6' 'FSHR' 'GBP2' 'GPX1'
#  'GREM2' 'GRIN3A' 'GRN' 'GSTP1' 'HACD1' 'HCRTR2' 'HFE' 'HHEX' 'HLA-A'
#  'HLA-DQB1' 'HLA-DRA' 'HLA-DRB1' 'HMOX1' 'HSPA5' 'HSPG2' 'ICAM1' 'IGF1'
#  'IL1B' 'IL33' 'IL6R' 'INPP5D' 'LDLR' 'LIPC' 'LMNA' 'LPL' 'LRP2' 'LRRK2'
#  'MALRD1' 'MAOA' 'MEF2A' 'MME' 'MS4A4A' 'MTHFD1L' 'MX1' 'NGF' 'NGFR'
#  'NINJ2' 'NLRP3' 'NOS1' 'NOS3' 'NXPH1' 'OGFRL1' 'OLR1' 'PCDH11X' 'PCED1B'
#  'PLA2G4A' 'PLXNA4' 'PON2' 'PON3' 'PPARG' 'PPP1R3B' 'PTGS2' 'RELN' 'RUNX1'
#  'SAMSN1' 'SDC2' 'SLC19A1' 'SLC2A9' 'SNTG1' 'SOAT1' 'SORCS2' 'SORCS3'
#  'SST' 'TBX3' 'TF' 'TLR2' 'TP53' 'TP63' 'TREM2' 'VEGFA' 'WWC1' 'XBP1'
#  'ZCWPW1']
#
# c02x_AD_EN_L6_IT_2_regulon_list.csv - AD - EN_L6_IT_2
# Average positive percentile of 0.507
# Positive unknown genes: ['ACVR1C' 'ADAMTS6' 'ADCY8' 'AHR' 'ANGPT2' 'ANKUB1' 'ANTXR2' 'ARHGAP15'
#  'ARHGAP29' 'ARHGEF38' 'ASPN' 'ATP8B1' 'B3GAT2' 'B3GNT5' 'BCL2L14' 'CA1'
#  'CCDC141' 'CDH18' 'CDH6' 'CEMIP' 'CFTR' 'CHST9' 'CLMP' 'CNTN3' 'CNTN5'
#  'CREB5' 'CYSLTR1' 'EGR1' 'EGR3' 'ELK3' 'ENO4' 'ENPP2' 'EPHA3' 'EPHA6'
#  'FAP' 'FILIP1L' 'FMO5' 'FN1' 'FZD6' 'GCNT1' 'GLRA2' 'GRIK3' 'HHIP'
#  'HS3ST2' 'HTR2B' 'ID2' 'IGSF6' 'IL1RAPL2' 'INHBA' 'ITGBL1' 'ITPKB'
#  'ITPR2' 'JDP2' 'KCNH5' 'KCNH7' 'KCNIP1' 'LAMA2' 'LAMA4' 'LDB2' 'LHFPL3'
#  'LPAR6' 'LRRC4C' 'LRTM1' 'MAMDC2' 'MGAT4C' 'MGST1' 'MTSS1' 'MYOT' 'NCALD'
#  'NFE2L3' 'NPAS4' 'NPNT' 'NR4A2' 'NRG1' 'OMD' 'OPCML' 'OPRM1' 'OSMR'
#  'P2RY12' 'P2RY14' 'PAM' 'PCDH15' 'PDE10A' 'PHEX' 'PITPNC1' 'PLEKHH2'
#  'PLOD2' 'PPP1R1C' 'PRR16' 'PRRX1' 'PRSS23' 'PTPRT' 'RBM20' 'RFX4' 'SDK1'
#  'SEMA5A' 'SEMA6D' 'SGMS2' 'SHISA6' 'SHROOM3' 'SLC2A12' 'SLC38A4' 'SLIT2'
#  'SNTB1' 'SPON1' 'STK33' 'STX19' 'SVIL' 'TANC1' 'TBL1X' 'TEC' 'THSD7A'
#  'TIMP3' 'TLL1' 'TMTC2' 'TOX' 'TRPC3' 'TTN' 'TXK' 'VEGFC' 'VIPR2' 'ZFHX3'
#  'ZNF213']
# Negative positive genes: ['A2M' 'ABCA2' 'ABCG2' 'ACAN' 'ADAM12' 'ADRB2' 'ALOX5' 'APOD' 'APOE' 'AR'
#  'ARSJ' 'ATP7B' 'BACE2' 'BCHE' 'BDNF' 'CARD8' 'CASS4' 'CAV1' 'CCL2' 'CCL3'
#  'CD14' 'CD33' 'CD36' 'CD44' 'CDKN2A' 'CHRNA7' 'CLSTN2' 'CLU' 'COL11A1'
#  'COL25A1' 'CR1' 'CST3' 'CTSS' 'DCHS2' 'DGKB' 'DHCR24' 'EFNA5' 'ESR2'
#  'F13A1' 'FAS' 'FCER1G' 'FGF1' 'FRMD6' 'FSHR' 'GBP2' 'GPX1' 'GREM2'
#  'GRIN3A' 'GRN' 'HACD1' 'HCRTR2' 'HHEX' 'HLA-A' 'HLA-DRA' 'HLA-DRB1'
#  'HLA-DRB5' 'HMOX1' 'HSPA5' 'HSPG2' 'ICAM1' 'IGF1' 'IL1B' 'IL33' 'IL6R'
#  'INPP5D' 'LDLR' 'LIPC' 'LMNA' 'LPL' 'LRP2' 'LRRK2' 'MALRD1' 'MAOA'
#  'MEF2A' 'MME' 'MS4A4A' 'MS4A6A' 'MTHFD1L' 'MX1' 'NGB' 'NGF' 'NGFR'
#  'NINJ2' 'NLRP1' 'NLRP3' 'NOS1' 'NOS3' 'NPC2' 'NXPH1' 'OGFRL1' 'OLR1'
#  'PCDH11X' 'PCED1B' 'PLA2G4A' 'PLXNA4' 'PON2' 'PON3' 'PPP1R3B' 'PTGS2'
#  'RELN' 'RUNX1' 'S100B' 'SAMSN1' 'SDC2' 'SLC19A1' 'SLC2A9' 'SNTG1' 'SOAT1'
#  'SORCS1' 'SORCS2' 'SORCS3' 'SORL1' 'SST' 'TBX3' 'TF' 'TGFB1' 'TLR2'
#  'TP53' 'TP63' 'VEGFA' 'WWC1' 'XBP1' 'ZCWPW1']
#
# c02x_AD_EN_NF_regulon_list.csv - AD - EN_NF
# Average positive percentile of 0.476
# Positive unknown genes: ['AATK' 'ADAMTS17' 'ADIPOR2' 'ANK1' 'BHLHE41' 'BMPR1B' 'CERCAM' 'CHST8'
#  'CNTNAP5' 'CTNNA2' 'DGKH' 'EBF1' 'EFS' 'ELOVL5' 'FANCC' 'GALNTL6' 'GRK5'
#  'KLF3' 'LAMP2' 'MAML2' 'MTSS1' 'MYRIP' 'NAT8L' 'PCSK2' 'PDZRN4' 'PELI2'
#  'PLP1' 'PLS3' 'PRDM1' 'PRDM11' 'RGS6' 'RPS3A' 'SALL1' 'SEMA6D' 'SLC7A14'
#  'SMAD7' 'SRGAP2B' 'TBC1D14' 'TLL1' 'ZFY' 'ZIC4']
# Negative positive genes: ['ABCA1' 'APOE' 'BDNF' 'CADPS2' 'CHRNA7' 'CLU' 'COL25A1' 'DHCR24' 'EFNA5'
#  'ESR2' 'FRMD6' 'FSHR' 'GRIN3A' 'HLA-A' 'HSPA5' 'LDLR' 'LMNA' 'LRP2'
#  'LRRK2' 'MME' 'NEDD9' 'NINJ2' 'NXPH1' 'PCDH11X' 'PLXNA4' 'PPARG' 'PTGS2'
#  'RELN' 'SDC2' 'SLC19A1' 'SOAT1' 'SORCS1' 'SORCS2' 'SORCS3' 'SST' 'TF'
#  'TGFB1' 'TP53' 'VEGFA' 'WWC1' 'ZCWPW1']
#
# c02x_AD_Immune_regulon_list.csv - AD - Immune
# Average positive percentile of 0.507
# Positive unknown genes: ['ADAMTS17' 'AKNA' 'ANTXR2' 'ANXA1' 'AOAH' 'APMAP' 'ARRDC3' 'ATP1B3'
#  'B4GALT1' 'BAZ1A' 'BCAS2' 'BCL11B' 'BCL2' 'BTG1' 'BTG3' 'CBLB' 'CCL5'
#  'CD226' 'CD53' 'CD55' 'CD6' 'CD69' 'CD96' 'CDC14A' 'CFLAR' 'CLEC2B'
#  'CLIC5' 'CREB3L2' 'CREM' 'CXCR4' 'CYTIP' 'DISC1' 'DOCK8' 'DUSP16' 'DUSP2'
#  'ELF1' 'ELL2' 'EML4' 'ERN1' 'FKBP5' 'FOSL2' 'GPCPD1' 'GRAP2' 'GRK5'
#  'HERPUD1' 'HIF1A' 'HSP90AA1' 'HSPD1' 'HSPH1' 'ID2' 'IFI16' 'IFNGR1'
#  'IL18R1' 'IL6ST' 'ISG20' 'ITGA1' 'ITGA4' 'ITGA6' 'ITK' 'KIF13B' 'KLF3'
#  'KLF6' 'LCP1' 'LCP2' 'LDLRAD4' 'LEF1' 'LGR6' 'LITAF' 'LYN' 'MAML3'
#  'MAP3K8' 'MCC' 'MCL1' 'MDFIC' 'METRNL' 'MGAT4A' 'MYBL1' 'MYO1D' 'NAMPT'
#  'NFKBIZ' 'NR4A2' 'PARP8' 'PDE3B' 'PDGFD' 'PELI2' 'PIK3AP1' 'PIK3IP1'
#  'PLAC8' 'PLCG2' 'PPP1CB' 'PRDM1' 'PRR5L' 'PTPN22' 'PTPRC' 'PYHIN1'
#  'RAPGEF1' 'RBMS1' 'RCSD1' 'REL' 'RGS1' 'RNF19A' 'RUNX2' 'RUNX3' 'SAMHD1'
#  'SCML4' 'SLA' 'SLC16A10' 'SLC2A3' 'SLC38A1' 'SMAP2' 'SRGN' 'SYAP1'
#  'SYTL3' 'TBL1X' 'TC2N' 'THEMIS' 'TLE1' 'TNFAIP3' 'TNFRSF1B' 'TNFSF8'
#  'TSC22D3' 'UTY' 'YES1' 'ZFP36L2' 'ZNF331']
# Negative positive genes: ['ABCA1' 'ABCA2' 'ABCG2' 'ACAN' 'ADRB2' 'AGER' 'ALOX5' 'APOC1' 'APOD'
#  'APOE' 'AR' 'ARSJ' 'BACE2' 'BCHE' 'BDNF' 'CADPS2' 'CARD8' 'CASS4' 'CAV1'
#  'CCL2' 'CCL3' 'CD14' 'CD33' 'CD36' 'CD44' 'CDKN2A' 'CHRNA7' 'CLSTN2'
#  'CLU' 'COL11A1' 'COL25A1' 'CR1' 'CST3' 'CTSS' 'DCHS2' 'DGKB' 'DHCR24'
#  'EFNA5' 'ESR1' 'ESR2' 'F13A1' 'FAS' 'FCER1G' 'FGF1' 'FRMD6' 'FSHR' 'GPX1'
#  'GREM2' 'GRIN3A' 'GRN' 'HACD1' 'HCRTR2' 'HFE' 'HHEX' 'HLA-A' 'HLA-DQB1'
#  'HLA-DRA' 'HLA-DRB1' 'HLA-DRB5' 'HMOX1' 'HSD11B1' 'HSPA5' 'HSPG2' 'ICAM1'
#  'IGF1' 'IL18' 'IL33' 'IL6R' 'INPP5D' 'LDLR' 'LIPC' 'LMNA' 'LPL' 'LRP2'
#  'LRRK2' 'MAOA' 'MEF2A' 'MME' 'MS4A4A' 'MS4A6A' 'MTHFD1L' 'MX1' 'NEDD9'
#  'NGB' 'NGF' 'NGFR' 'NINJ2' 'NLRP1' 'NLRP3' 'NOS1' 'NOS3' 'NPC2' 'NXPH1'
#  'OGFRL1' 'OLR1' 'PCDH11X' 'PCED1B' 'PLA2G4A' 'PLXNA4' 'PON2' 'PON3'
#  'PPARG' 'PPP1R3B' 'PTGS2' 'RUNX1' 'S100B' 'SDC2' 'SLC19A1' 'SLC2A9'
#  'SNTG1' 'SOAT1' 'SORCS1' 'SORCS2' 'SORCS3' 'SORL1' 'SST' 'TF' 'TGFB1'
#  'TLR2' 'TP53' 'TP63' 'VEGFA' 'WWC1' 'XBP1' 'ZCWPW1']
#
# c02x_AD_IN_LAMP5_LHX6_regulon_list.csv - AD - IN_LAMP5_LHX6
# Average positive percentile of 0.505
# Positive unknown genes: ['ADARB2' 'ADGRL2' 'ATP8B1' 'ATRNL1' 'BCL2' 'BMPER' 'CA2' 'CA3' 'CDH13'
#  'CDH20' 'CDH4' 'CDH8' 'CHRM2' 'CHST11' 'CLIC4' 'CNR1' 'CNTN6' 'CNTNAP5'
#  'CTNNA2' 'DCC' 'DKK2' 'DLGAP1' 'DNAJA4' 'DOK6' 'DSCAM' 'EGR1' 'EGR3'
#  'ELOVL5' 'EPHA3' 'ETV1' 'EYA4' 'FGF14' 'FILIP1L' 'FLRT2' 'FOS' 'FOSB'
#  'FRMD4B' 'GABRA2' 'GAD1' 'GHR' 'GRK5' 'GULP1' 'HEG1' 'HS3ST2' 'HSPH1'
#  'ID2' 'IL1RAP' 'IL1RAPL2' 'ISM1' 'ITGA6' 'JUN' 'JUNB' 'KCNB2' 'KCNH5'
#  'KCNT2' 'KCTD12' 'KCTD8' 'KIAA1217' 'LBH' 'LRRC3B' 'LRRC4C' 'MAML3'
#  'MGAT4C' 'MID1' 'MIDN' 'MITF' 'MYO1B' 'NHS' 'NR4A1' 'NRG1' 'NTNG1' 'NWD2'
#  'OPHN1' 'PCDH7' 'PDE1C' 'PDE7B' 'PDZRN4' 'PHACTR1' 'PHACTR2' 'PITPNC1'
#  'PLCXD3' 'PLS3' 'PPFIBP1' 'PRELID2' 'PROX1' 'RALYL' 'RARB' 'RBMS1' 'RGS6'
#  'RND3' 'ROR1' 'RSPO2' 'SAMD4A' 'SCG2' 'SEMA6A' 'SEMA6D' 'SGCD' 'SGCZ'
#  'SLC35F4' 'SLC4A4' 'SLC7A5' 'SLC8A1' 'SULF1' 'SVIL' 'SYNPR' 'TENM2'
#  'THSD7A' 'THSD7B' 'TMSB4X' 'TNFRSF19' 'TNR' 'TPD52L1' 'TRPC3' 'TRPC4'
#  'TRPM3' 'TXK' 'USPL1' 'UST' 'UTRN' 'VCAN' 'ZBTB7C']
# Negative positive genes: ['A2M' 'ABCA1' 'ABCA2' 'ABCG2' 'ACAN' 'ADAM12' 'ADRB2' 'AGER' 'ALOX5'
#  'APOC1' 'APOD' 'APOE' 'AR' 'ARSJ' 'ATP7B' 'BACE2' 'BCHE' 'BDNF' 'CADPS2'
#  'CARD8' 'CASS4' 'CAV1' 'CCL2' 'CCL3' 'CD14' 'CD36' 'CD44' 'CDKN2A' 'CFH'
#  'CH25H' 'CHRNA7' 'CLSTN2' 'CLU' 'COL11A1' 'CR1' 'CST3' 'CTSS' 'DCHS2'
#  'DHCR24' 'EFNA5' 'ESR1' 'ESR2' 'F13A1' 'FAS' 'FGF1' 'FRMD6' 'FSHR' 'GPX1'
#  'GREM2' 'GRIN3A' 'GRN' 'GSTP1' 'HACD1' 'HFE' 'HHEX' 'HLA-A' 'HLA-DRB1'
#  'HLA-DRB5' 'HMOX1' 'HSD11B1' 'HSPA5' 'HSPG2' 'ICAM1' 'IGF1' 'IL18' 'IL1B'
#  'IL33' 'IL6R' 'INPP5D' 'LDLR' 'LIPC' 'LPL' 'LRP2' 'LRRK2' 'MALRD1' 'MAOA'
#  'MEF2A' 'MME' 'MS4A4A' 'MS4A6A' 'MX1' 'NEDD9' 'NGB' 'NGF' 'NGFR' 'NINJ2'
#  'NLRP1' 'NLRP3' 'NOS3' 'NXPH1' 'OGFRL1' 'OLR1' 'PCDH11X' 'PCED1B'
#  'PLA2G4A' 'PLXNA4' 'PON2' 'PON3' 'PPARG' 'PPP1R3B' 'PTGS2' 'RELN' 'RUNX1'
#  'SAMSN1' 'SDC2' 'SLC19A1' 'SLC2A9' 'SNTG1' 'SOAT1' 'SORCS1' 'SORL1' 'SST'
#  'TBX3' 'TGFB1' 'TLR2' 'TP53' 'TP63' 'VEGFA' 'WWC1' 'XBP1' 'ZCWPW1']
#
# c02x_AD_IN_LAMP5_RELN_regulon_list.csv - AD - IN_LAMP5_RELN
# Average positive percentile of 0.483
# Positive unknown genes: ['ABCA9' 'AKAP12' 'AMER2' 'ANK1' 'ANLN' 'ANO6' 'B3GAT2' 'BMP7' 'BTBD11'
#  'BTG1' 'BTG2' 'CA2' 'CCBE1' 'CCK' 'CDH13' 'CDH8' 'CDKN1B' 'CHRDL1'
#  'CLIC4' 'CNTN4' 'CPNE4' 'CRIM1' 'CTNNA2' 'DLGAP1' 'DNAJA4' 'DNAJB1'
#  'DOK6' 'DUSP5' 'EGR1' 'EGR3' 'ELAVL2' 'ELOVL5' 'EPHA7' 'EPN2' 'ETV1'
#  'FAM107A' 'FGF14' 'FGFR1' 'FIGN' 'FOS' 'FOSB' 'FRMD4B' 'GREB1L' 'GRIK1'
#  'GRIP1' 'GRM8' 'HMGCS1' 'HS3ST2' 'HSP90AA1' 'HSPA1A' 'HSPH1' 'ID2'
#  'IGFBP3' 'IL1RAP' 'IL1RAPL2' 'IL6ST' 'INSIG1' 'IQCJ-SCHIP1' 'JUN' 'JUNB'
#  'LGI1' 'LRRN1' 'LTBP1' 'MAFB' 'MARCKSL1' 'MYT1' 'NDRG1' 'NELL2' 'NR4A1'
#  'NR4A3' 'NRG1' 'NRIP3' 'NTNG1' 'PAM' 'PCSK2' 'PDGFRA' 'PELI1' 'PELI2'
#  'PER1' 'PIP5K1B' 'PLCB4' 'PLCXD3' 'PLEKHO1' 'PMEPA1' 'PNRC1' 'PPARD'
#  'PPP1R15A' 'PREX2' 'PROX1' 'PTMA' 'PTPRB' 'PTPRG' 'RAB3IP' 'RALYL'
#  'RASD1' 'RBMS1' 'ROBO1' 'RPS11' 'RYBP' 'SEC14L1' 'SFRP1' 'SGCZ' 'SLC35F4'
#  'SLC38A1' 'SLC38A2' 'SLC7A5' 'SLIT2' 'SLIT3' 'SMAD9' 'SYNDIG1' 'SYNPR'
#  'TENM2' 'TGFB2' 'TMSB4X' 'TPT1' 'TRPM3' 'TRPS1' 'TSC22D3' 'UBC' 'VCAN'
#  'ZNF385D' 'ZNF462']
# Negative positive genes: ['A2M' 'ABCA2' 'ABCG2' 'ACAN' 'ADAM12' 'ADRB2' 'AGER' 'ALOX5' 'APOC1'
#  'APOD' 'APOE' 'AR' 'ARSJ' 'ATP7B' 'BACE2' 'BCHE' 'BDNF' 'CADPS2' 'CARD8'
#  'CASS4' 'CAV1' 'CCL2' 'CCL3' 'CD33' 'CD36' 'CD44' 'CDKN2A' 'CFH' 'CHRNA7'
#  'CLSTN2' 'CLU' 'COL11A1' 'COL25A1' 'CR1' 'CST3' 'CTSS' 'DCHS2' 'DHCR24'
#  'EFNA5' 'ESR1' 'ESR2' 'F13A1' 'FAS' 'FCER1G' 'FGF1' 'FRMD6' 'FSHR' 'GBP2'
#  'GPX1' 'GREM2' 'GRIN3A' 'GRN' 'GSTP1' 'HACD1' 'HCRTR2' 'HFE' 'HHEX'
#  'HLA-A' 'HLA-DRA' 'HMOX1' 'HSD11B1' 'HSPA5' 'HSPG2' 'ICAM1' 'IL18' 'IL1B'
#  'IL33' 'IL6R' 'INPP5D' 'LDLR' 'LIPC' 'LMNA' 'LPL' 'LRP2' 'LRRK2' 'MAOA'
#  'MEF2A' 'MME' 'MS4A6A' 'MX1' 'NEDD9' 'NGB' 'NGF' 'NGFR' 'NINJ2' 'NLRP1'
#  'NLRP3' 'NOS1' 'NOS3' 'NPC2' 'OGFRL1' 'OLR1' 'PCDH11X' 'PCED1B' 'PLA2G4A'
#  'PLXNA4' 'PON2' 'PON3' 'PPARG' 'PPP1R3B' 'PTGS2' 'RELN' 'RUNX1' 'S100B'
#  'SAMSN1' 'SDC2' 'SLC19A1' 'SLC2A9' 'SOAT1' 'SORCS1' 'SORCS3' 'SORL1'
#  'SST' 'TBX3' 'TGFB1' 'TP53' 'TP63' 'TREM2' 'VEGFA' 'WWC1' 'XBP1' 'ZCWPW1']
#
# c02x_AD_IN_PVALB_CHC_regulon_list.csv - AD - IN_PVALB_CHC
# Average positive percentile of 0.496
# Positive unknown genes: ['ACSL1' 'ACTA2' 'AHR' 'ALDH1A2' 'AMOTL1' 'ANKRD44' 'ANKUB1' 'ARHGAP15'
#  'ATP1B3' 'ATP8B1' 'BACH1' 'BCL2L14' 'BCL6' 'BHLHE41' 'BTG1' 'C1QTNF7'
#  'CALD1' 'CAMK2G' 'CBLB' 'CCNG2' 'CDKN1B' 'CEMIP' 'CFTR' 'CNR1' 'COL10A1'
#  'CREB5' 'CRH' 'CRLF1' 'CUX2' 'CYCS' 'DCC' 'DPYSL5' 'DUSP16' 'EGR1'
#  'ELAVL2' 'ELK3' 'ELL2' 'ELOVL5' 'EML4' 'ENO4' 'ERRFI1' 'EZH2' 'FILIP1L'
#  'FN1' 'FOS' 'FOSB' 'FTL' 'GAD1' 'GK' 'GLRX' 'GNB4' 'GRB10' 'GRIN2A'
#  'GRM3' 'HERPUD1' 'HHIP' 'HS3ST2' 'HSP90AA1' 'HSPH1' 'IFRD1' 'IL6ST'
#  'JDP2' 'KITLG' 'LPGAT1' 'LRRN1' 'METAP1D' 'MFSD4B' 'MYL6' 'NAT8L' 'NTN4'
#  'OSMR' 'P2RY14' 'PALLD' 'PAPPA' 'PELI1' 'PHACTR2' 'PHLDB2' 'PIPOX'
#  'PLSCR1' 'PMEPA1' 'PRSS23' 'PTMA' 'RFX4' 'RUNDC3B' 'RYBP' 'SCN9A'
#  'SEC14L1' 'SERF2' 'SLC16A3' 'SLC2A3' 'SLC38A2' 'SLC7A14' 'SMAP2' 'SNED1'
#  'SRGAP2' 'SRGAP2B' 'SULF1' 'SULF2' 'SYT2' 'TENM2' 'TIMP3' 'TMEM196'
#  'TMSB4X' 'TPM1' 'TPT1' 'TTN' 'UBC' 'VCL' 'ZBTB7C' 'ZFAND4' 'ZFHX3'
#  'ZNF213' 'ZNF462' 'ZNF565' 'ZPBP']
# Negative positive genes: ['A2M' 'ABCA1' 'ABCG2' 'ACAN' 'ADAM12' 'ADRB2' 'AGER' 'ALOX5' 'APOD'
#  'APOE' 'AR' 'ARSJ' 'ATP7B' 'BACE2' 'BCHE' 'BDNF' 'CADPS2' 'CARD8' 'CASS4'
#  'CAV1' 'CCL2' 'CCL3' 'CD14' 'CD36' 'CDKN2A' 'CFH' 'CHRNA7' 'CLSTN2' 'CLU'
#  'COL11A1' 'COL25A1' 'CTSS' 'DCHS2' 'DGKB' 'DHCR24' 'EFNA5' 'ESR2' 'F13A1'
#  'FAS' 'FGF1' 'FRMD6' 'FSHR' 'GREM2' 'GRIN3A' 'GRN' 'GSTP1' 'HACD1'
#  'HCRTR2' 'HFE' 'HLA-A' 'HLA-DRB1' 'HMOX1' 'HSD11B1' 'HSPA5' 'HSPG2'
#  'ICAM1' 'IGF1' 'IL18' 'IL1B' 'IL33' 'IL6R' 'INPP5D' 'LDLR' 'LIPC' 'LMNA'
#  'LPL' 'LRP2' 'LRRK2' 'MALRD1' 'MS4A4A' 'MTHFD1L' 'MX1' 'NEDD9' 'NGB'
#  'NGF' 'NGFR' 'NINJ2' 'NLRP1' 'NLRP3' 'NOS1' 'NOS3' 'NPC2' 'NXPH1'
#  'OGFRL1' 'OLR1' 'PCDH11X' 'PCED1B' 'PLA2G4A' 'PLXNA4' 'PON2' 'PON3'
#  'PPARG' 'PPP1R3B' 'PTGS2' 'RELN' 'RUNX1' 'S100B' 'SAMSN1' 'SDC2'
#  'SLC19A1' 'SLC2A9' 'SNTG1' 'SOAT1' 'SORCS1' 'SORCS2' 'SORCS3' 'SORL1'
#  'SST' 'TBX3' 'TLR2' 'TP63' 'VEGFA' 'WWC1' 'XBP1' 'ZCWPW1']
#
# c02x_AD_IN_PVALB_regulon_list.csv - AD - IN_PVALB
# Average positive percentile of 0.518
# Positive unknown genes: ['ABCB1' 'ADAMTS17' 'ADGRL2' 'ADRA1A' 'AHR' 'AMOTL1' 'ANGPT2' 'ANKUB1'
#  'ARHGAP15' 'ASIC2' 'BAALC' 'BCL2L14' 'BCL6' 'C11orf65' 'CDH10' 'CDH12'
#  'CDH13' 'CDH18' 'CDH4' 'CEMIP' 'CNTN3' 'CNTN4' 'COBLL1' 'CRHBP'
#  'CSGALNACT1' 'CSRNP1' 'CUX2' 'DEPTOR' 'DLGAP2' 'DNAJA4' 'DUSP1' 'DUSP5'
#  'EGR1' 'EGR3' 'ELL2' 'ELOVL5' 'ENO4' 'EPHA6' 'EYS' 'FILIP1L' 'FOS' 'FOSB'
#  'FOSL2' 'FRAS1' 'FRMD4B' 'FSIP2' 'FSTL4' 'FSTL5' 'GADD45B' 'GADD45G'
#  'GALNT18' 'GEM' 'GHR' 'GLRX' 'GRM3' 'GRM8' 'HHIP' 'HS3ST2' 'HS6ST3'
#  'HTR4' 'JUNB' 'KAZN' 'KCNB2' 'KCNS3' 'KHDRBS2' 'KIAA1217' 'KIF26B' 'KIF6'
#  'LBH' 'LDB2' 'LGR5' 'LRFN5' 'LRRTM4' 'MFSD4B' 'MGST1' 'MITF' 'MTUS2'
#  'NFIL3' 'NOTCH2' 'NR4A1' 'NWD2' 'OLFM3' 'P2RY14' 'PAPPA' 'PCDH11Y'
#  'PCDH7' 'PCSK6' 'PDE7B' 'PDZRN3' 'PDZRN4' 'PHF21B' 'PIEZO2' 'PIM3'
#  'PITPNC1' 'PLCH1' 'PMEPA1' 'PPP1R15A' 'PRDM1' 'PRELID2' 'PTMA' 'PTPRM'
#  'PTPRZ1' 'RSPO2' 'RYBP' 'RYR2' 'SGCZ' 'SLC7A5' 'SLC8A1' 'SOX6' 'SPSB1'
#  'ST6GALNAC3' 'ST6GALNAC5' 'SULF1' 'SYNDIG1' 'TAC1' 'TENM2' 'TGFBR3'
#  'TIMP3' 'TMEM132C' 'TMSB4X' 'TOX3' 'TTN' 'UBASH3B' 'UBC' 'UBE2U' 'VWC2L'
#  'XKR4' 'ZNF213']
# Negative positive genes: ['A2M' 'ABCA1' 'ABCA2' 'ABCG2' 'ADAM12' 'ADRB2' 'ALOX5' 'APOC1' 'APOD'
#  'APOE' 'AR' 'ARSJ' 'ATP7B' 'BACE2' 'BCHE' 'BDNF' 'CADPS2' 'CARD8' 'CASS4'
#  'CAV1' 'CCL2' 'CCL3' 'CD14' 'CD33' 'CD36' 'CD44' 'CDKN2A' 'CFH' 'CH25H'
#  'CHRNA7' 'CLSTN2' 'CLU' 'COL11A1' 'COL25A1' 'CR1' 'CST3' 'CTSS' 'DCHS2'
#  'DGKB' 'DHCR24' 'ESR1' 'ESR2' 'F13A1' 'FAS' 'FCER1G' 'FGF1' 'FRMD6'
#  'FSHR' 'GBP2' 'GPX1' 'GREM2' 'GRIN3A' 'GRN' 'HACD1' 'HCRTR2' 'HFE' 'HHEX'
#  'HLA-A' 'HLA-DRA' 'HMOX1' 'HSD11B1' 'HSPA5' 'HSPG2' 'ICAM1' 'IGF1' 'IL18'
#  'IL1B' 'IL33' 'IL6R' 'INPP5D' 'LDLR' 'LIPC' 'LMNA' 'LPL' 'LRP2' 'LRRK2'
#  'MALRD1' 'MAOA' 'MEF2A' 'MME' 'MS4A4A' 'MS4A6A' 'MTHFD1L' 'MX1' 'NEDD9'
#  'NGB' 'NGF' 'NGFR' 'NINJ2' 'NLRP1' 'NLRP3' 'NOS1' 'NOS3' 'NPC2' 'NXPH1'
#  'OGFRL1' 'OLR1' 'PCDH11X' 'PCED1B' 'PLA2G4A' 'PLXNA4' 'PON2' 'PON3'
#  'PPARG' 'PPP1R3B' 'PTGS2' 'RELN' 'RUNX1' 'S100B' 'SAMSN1' 'SDC2'
#  'SLC19A1' 'SLC2A9' 'SNTG1' 'SOAT1' 'SORCS1' 'SST' 'TBX3' 'TF' 'TGFB1'
#  'TLR2' 'TP53' 'TP63' 'TREM2' 'VEGFA' 'WWC1' 'XBP1' 'ZCWPW1']
#
# c02x_AD_IN_SST_regulon_list.csv - AD - IN_SST
# Average positive percentile of 0.511
# Positive unknown genes: ['ABCB1' 'ADAMTS12' 'ADAMTS17' 'AHR' 'AKAP13' 'ALDH1A2' 'ALK' 'ANGPT2'
#  'ANKUB1' 'ARHGAP15' 'ARHGAP6' 'B3GNT5' 'BACH1' 'BMP6' 'BRINP3' 'C11orf65'
#  'CA1' 'CABLES1' 'CACHD1' 'CDH10' 'CDH12' 'CDH8' 'CDKN1B' 'CLMP' 'CNTN4'
#  'CRLF1' 'CRYBG3' 'DLC1' 'DOCK2' 'EGR1' 'EGR3' 'ENPP2' 'EPHA6' 'EPHA7'
#  'ETV1' 'EYA4' 'F8' 'FAM110B' 'FAT4' 'FGD4' 'FILIP1L' 'FMO5' 'FOS' 'FOSB'
#  'FSTL5' 'GALNTL6' 'GCNT1' 'GLRA2' 'GPC5' 'HDAC9' 'HECW1' 'HHIP'
#  'HSP90AA1' 'HTR1F' 'HTR2B' 'HTR4' 'ITGBL1' 'ITPR2' 'KAZN' 'KCTD12'
#  'KIF26B' 'LENG9' 'LINGO2' 'LRTM1' 'MAF' 'MAFB' 'MCC' 'MCTP1' 'METAP1D'
#  'MFSD4B' 'MGST1' 'MID1' 'MPPED2' 'MSR1' 'NET1' 'NMU' 'NOTCH2' 'NRG1'
#  'NXPH2' 'P3H2' 'P4HA3' 'PAPPA' 'PCDH15' 'PCDH7' 'PCSK2' 'PCSK5' 'PDE6B'
#  'PID1' 'PRKCQ' 'PRTG' 'PTMA' 'RFX4' 'RNF152' 'ROBO2' 'RSPO2' 'SAMD5'
#  'SDK1' 'SFMBT2' 'SGCZ' 'SLC24A3' 'SLC9A2' 'SNED1' 'ST8SIA4' 'TMEM132C'
#  'TMEM132D' 'TMEM241' 'TMSB4X' 'TOX' 'TRHDE' 'TTN' 'UBC' 'UST' 'UTRN'
#  'VWC2' 'ZNF213' 'ZNF385B' 'ZNF565' 'ZNF804A']
# Negative positive genes: ['A2M' 'ABCA1' 'ABCA2' 'ABCG2' 'ACAN' 'ADAM12' 'ADRB2' 'AGER' 'ALOX5'
#  'APOD' 'APOE' 'AR' 'ARSJ' 'BACE2' 'BCHE' 'BDNF' 'CADPS2' 'CARD8' 'CASS4'
#  'CAV1' 'CCL2' 'CCL3' 'CD14' 'CD36' 'CD44' 'CDKN2A' 'CFH' 'CHRNA7'
#  'CLSTN2' 'CLU' 'COL11A1' 'COL25A1' 'CR1' 'CST3' 'CTSS' 'DCHS2' 'DGKB'
#  'DHCR24' 'EFNA5' 'ESR1' 'ESR2' 'F13A1' 'FAS' 'FRMD6' 'FSHR' 'GBP2' 'GPX1'
#  'GREM2' 'GRIN3A' 'GRN' 'GSTP1' 'HCRTR2' 'HFE' 'HHEX' 'HLA-A' 'HLA-DRB1'
#  'HLA-DRB5' 'HMOX1' 'HSD11B1' 'HSPA5' 'HSPG2' 'ICAM1' 'IGF1' 'IL18' 'IL1B'
#  'IL33' 'IL6R' 'INPP5D' 'LDLR' 'LIPC' 'LMNA' 'LPL' 'LRP2' 'MAOA' 'MEF2A'
#  'MS4A6A' 'MTHFD1L' 'MX1' 'NEDD9' 'NGB' 'NGF' 'NGFR' 'NINJ2' 'NLRP1'
#  'NLRP3' 'NOS1' 'NOS3' 'NPC2' 'NXPH1' 'OGFRL1' 'PCDH11X' 'PCED1B'
#  'PLA2G4A' 'PON2' 'PPARG' 'PPP1R3B' 'PTGS2' 'RELN' 'RUNX1' 'S100B'
#  'SAMSN1' 'SDC2' 'SLC2A9' 'SNTG1' 'SOAT1' 'SORCS1' 'SORCS3' 'SORL1' 'TBX3'
#  'TF' 'TGFB1' 'TP53' 'TP63' 'TREM2' 'VEGFA' 'WWC1' 'XBP1' 'ZCWPW1']
#
# c02x_AD_IN_VIP_regulon_list.csv - AD - IN_VIP
# Average positive percentile of 0.512
# Positive unknown genes: ['ACSM3' 'ADGRG2' 'ADGRL2' 'ANGPT2' 'ANKUB1' 'ANO4' 'ARHGAP15' 'ARHGAP24'
#  'ARHGAP6' 'B3GNT5' 'BCL2L14' 'BRINP3' 'C1QTNF7' 'CALN1' 'CBLN2' 'CCDC60'
#  'CDH20' 'CDH7' 'CHD7' 'CHRM2' 'CHST11' 'CNTN6' 'COL10A1' 'COL6A6' 'CPB2'
#  'CRIM1' 'CRLF1' 'CYP3A5' 'DCN' 'DENND2A' 'DISC1' 'DNAJB1' 'DTNA' 'DUSP16'
#  'ECM2' 'EFCAB13' 'ENO4' 'EXPH5' 'EYA4' 'FAT3' 'FILIP1L' 'FKBP5' 'FMO5'
#  'FN1' 'FNDC3B' 'FSIP2' 'GCNT1' 'GLRX' 'GRM3' 'GRM7' 'GULP1' 'HEG1' 'HEPH'
#  'HHIP' 'HTR2B' 'HTR4' 'IFIT3' 'IGFBP5' 'ITGA8' 'ITGBL1' 'JUN' 'KCNC2'
#  'KCNIP1' 'KCNQ1' 'LCP2' 'LDB2' 'LDLRAD3' 'LDLRAD4' 'LIX1' 'LPAR6'
#  'LRRC3B' 'MAP3K1' 'MCC' 'MCTP2' 'METAP1D' 'MFSD4B' 'MYO16' 'NDST4' 'NRG1'
#  'NWD2' 'OLFM3' 'OPRM1' 'OSMR' 'P2RY12' 'P2RY14' 'P4HA3' 'PAPPA' 'PCDH15'
#  'PCDH7' 'PCP4' 'PDE10A' 'PDE3A' 'PDE7B' 'PIPOX' 'PKD2L2' 'PLCL1' 'PLCXD3'
#  'PRTG' 'ROBO2' 'RPS27' 'SALL1' 'SCML4' 'SEMA6D' 'SFRP4' 'SLC35F3' 'STX19'
#  'SULF2' 'SVEP1' 'TENM2' 'TENM4' 'TMCO4' 'TMEM132C' 'TNR' 'TRPC6' 'TRPM3'
#  'TSHZ2' 'TSPAN18' 'TTN' 'UNC13C' 'ZFPM2' 'ZNF213' 'ZNF385B' 'ZPBP']
# Negative positive genes: ['A2M' 'ABCA2' 'ABCG2' 'ACAN' 'ADAM12' 'ADRB2' 'AGER' 'ALOX5' 'APOD'
#  'APOE' 'AR' 'ARSJ' 'ATP7B' 'BACE2' 'BCHE' 'BDNF' 'CADPS2' 'CARD8' 'CASS4'
#  'CAV1' 'CCL2' 'CD14' 'CD33' 'CD36' 'CD44' 'CDKN2A' 'CFH' 'CHRNA7' 'CLU'
#  'COL11A1' 'COL25A1' 'CR1' 'CST3' 'CTSS' 'DCHS2' 'DGKB' 'DHCR24' 'EFNA5'
#  'ESR1' 'ESR2' 'F13A1' 'FAS' 'FGF1' 'FRMD6' 'FSHR' 'GBP2' 'GPX1' 'GREM2'
#  'GRIN3A' 'GRN' 'GSTP1' 'HCRTR2' 'HFE' 'HHEX' 'HLA-A' 'HLA-DQB1' 'HLA-DRA'
#  'HLA-DRB1' 'HLA-DRB5' 'HMOX1' 'HSD11B1' 'HSPA5' 'HSPG2' 'ICAM1' 'IGF1'
#  'IL18' 'IL1B' 'IL33' 'INPP5D' 'LDLR' 'LIPC' 'LMNA' 'LPL' 'LRP2' 'LRRK2'
#  'MALRD1' 'MAOA' 'MEF2A' 'MS4A4A' 'MS4A6A' 'MX1' 'NEDD9' 'NGB' 'NGF'
#  'NGFR' 'NINJ2' 'NLRP1' 'NLRP3' 'NOS1' 'NOS3' 'NPC2' 'NXPH1' 'OGFRL1'
#  'OLR1' 'PCDH11X' 'PCED1B' 'PLA2G4A' 'PON2' 'PON3' 'PPARG' 'PPP1R3B'
#  'PTGS2' 'RUNX1' 'S100B' 'SAMSN1' 'SDC2' 'SLC19A1' 'SLC2A9' 'SNTG1'
#  'SOAT1' 'SORCS2' 'SORCS3' 'SORL1' 'SST' 'TBX3' 'TF' 'TGFB1' 'TLR2' 'TP53'
#  'TP63' 'VEGFA' 'XBP1' 'ZCWPW1']
#
# c02x_AD_Micro_regulon_list.csv - AD - Micro
# Average positive percentile of 0.559
# Positive unknown genes: ['ACSL1' 'ADAM28' 'ADGRE2' 'AMZ2' 'B2M' 'BACH1' 'BCL2A1' 'BCL6' 'BHLHE41'
#  'BLNK' 'BROX' 'BTG1' 'BTG2' 'C12orf75' 'C1QA' 'C1QB' 'C1QC' 'C5AR1'
#  'CCND3' 'CD163' 'CD55' 'CD74' 'CD83' 'CD86' 'CDKN1A' 'CEBPD' 'CHSY1'
#  'CIITA' 'CMKLR1' 'CPED1' 'CREM' 'CSGALNACT1' 'CTSB' 'CXCR4' 'DDIT4'
#  'DENND3' 'DUSP1' 'ETS2' 'FAM110B' 'FAM177B' 'FCGR2A' 'FKBP5' 'FLVCR2'
#  'FOS' 'FTH1' 'GK' 'GLDN' 'GLUL' 'GNA13' 'GPR183' 'GRB2' 'GRID2' 'HAMP'
#  'HCLS1' 'HERPUD1' 'HIF1A' 'HLA-B' 'HS3ST4' 'HSPA1A' 'IGSF21' 'IKZF2'
#  'IL10RA' 'IL4R' 'JAK3' 'JDP2' 'JUNB' 'LAP3' 'LCP2' 'LIMK2' 'LMO2' 'LY96'
#  'MAN2A1' 'MAP3K8' 'MGAT1' 'MRC1' 'MSR1' 'NABP1' 'NAMPT' 'NFKBIZ'
#  'OLFML2B' 'P2RY12' 'PAPOLG' 'PARVG' 'PELI1' 'PFKFB3' 'PIK3AP1' 'PIK3IP1'
#  'PIM1' 'PIP5K1B' 'PLSCR1' 'PLTP' 'PNRC1' 'PPARD' 'PPP1CB' 'PRDM1'
#  'PRKAG2' 'RAB20' 'RAPGEF1' 'RASSF2' 'REL' 'RGS1' 'RGS2' 'RNF144B' 'SAT1'
#  'SDCBP' 'SEC14L1' 'SERPINE1' 'SH3TC1' 'SLA' 'SLC11A1' 'SLC15A2' 'SLC2A3'
#  'SLC2A5' 'SMAP2' 'SOCS6' 'SPP1' 'SPTLC3' 'SRGAP1' 'SRGN' 'SYTL3'
#  'TBC1D14' 'TGFBR1' 'THEMIS2' 'TMEM163' 'TMEM176B' 'TMEM71' 'TNFRSF1B'
#  'TSC22D3' 'TXNIP' 'UBC' 'ZFP36' 'ZFP36L2']
# Negative positive genes: ['A2M' 'ABCA2' 'ABCG2' 'ACAN' 'ADAM12' 'ADRB2' 'AGER' 'ALOX5' 'APOC1'
#  'APOD' 'APOE' 'AR' 'ARSJ' 'ATP7B' 'BACE2' 'BCHE' 'BDNF' 'CADPS2' 'CARD8'
#  'CASS4' 'CAV1' 'CCL2' 'CCL3' 'CD14' 'CD33' 'CD36' 'CD44' 'CDKN2A' 'CFH'
#  'CH25H' 'CHRNA7' 'CLSTN2' 'CLU' 'COL11A1' 'COL25A1' 'CR1' 'CST3' 'CTSS'
#  'DCHS2' 'DGKB' 'DHCR24' 'EFNA5' 'ESR1' 'ESR2' 'F13A1' 'FAS' 'FCER1G'
#  'FGF1' 'FRMD6' 'FSHR' 'GBP2' 'GPX1' 'GREM2' 'GRIN3A' 'GRN' 'GSTP1'
#  'HACD1' 'HCRTR2' 'HFE' 'HHEX' 'HLA-DQB1' 'HLA-DRB5' 'HMOX1' 'HSD11B1'
#  'HSPA5' 'HSPG2' 'ICAM1' 'IGF1' 'IL18' 'IL1B' 'IL33' 'IL6R' 'INPP5D'
#  'LDLR' 'LIPC' 'LMNA' 'LPL' 'LRP2' 'LRRK2' 'MALRD1' 'MAOA' 'MEF2A' 'MME'
#  'MS4A4A' 'MS4A6A' 'MTHFD1L' 'MX1' 'NEDD9' 'NGB' 'NGF' 'NGFR' 'NINJ2'
#  'NLRP1' 'NLRP3' 'NOS1' 'NOS3' 'NPC2' 'NXPH1' 'OGFRL1' 'OLR1' 'PCDH11X'
#  'PCED1B' 'PLA2G4A' 'PLXNA4' 'PON2' 'PON3' 'PPARG' 'PPP1R3B' 'PTGS2'
#  'RELN' 'S100B' 'SDC2' 'SLC19A1' 'SLC2A9' 'SNTG1' 'SOAT1' 'SORCS1'
#  'SORCS2' 'SORCS3' 'SORL1' 'SST' 'TBX3' 'TF' 'TGFB1' 'TLR2' 'TP53' 'TP63'
#  'TREM2' 'VEGFA' 'WWC1' 'XBP1' 'ZCWPW1']
#
# c02x_AD_Oligo_regulon_list.csv - AD - Oligo
# Average positive percentile of 0.488
# Positive unknown genes: ['ACSL1' 'ADAMTSL3' 'ANKRD44' 'ANLN' 'APOLD1' 'ATP1B3' 'BCL2' 'BOK'
#  'C21orf91' 'CA2' 'CALD1' 'CARNS1' 'CDK18' 'CHD7' 'CLIC4' 'CPM' 'CSRP1'
#  'DAAM2' 'DLC1' 'DPYSL5' 'DTNA' 'DYSF' 'EFHD1' 'ELOVL5' 'ENPP6' 'ERBB3'
#  'FIGN' 'FKBP5' 'GALNT6' 'GLDN' 'GRB10' 'GREB1L' 'GREM1' 'GSN' 'HEG1'
#  'IKZF2' 'INSIG1' 'ITPKB' 'JADE3' 'KAT2B' 'KCNMB4' 'KCTD8' 'KIF13B' 'LDB3'
#  'LDLRAP1' 'LGR5' 'LLGL2' 'LRP4' 'LRRC1' 'MARCKSL1' 'MID1IP1' 'MSI2'
#  'MYO1E' 'NDE1' 'NDRG1' 'NDRG2' 'NFKBIZ' 'NKX6-2' 'OLIG1' 'P4HA1' 'PBX3'
#  'PDE9A' 'PLEKHG1' 'PLEKHG3' 'PPFIBP1' 'PRELID2' 'PRIMA1' 'PROX1' 'PRR5L'
#  'PTMA' 'PTN' 'PTPRE' 'RAB3IP' 'RASSF2' 'RFTN2' 'RGCC' 'RHOBTB1' 'SEMA3B'
#  'SEMA3C' 'SFMBT2' 'SH3BP4' 'SLC12A2' 'SLC38A2' 'SLC45A3' 'SLC6A9' 'SMAD9'
#  'SMOC1' 'SPSB1' 'SRGAP2' 'SUN2' 'SYNDIG1' 'SYNJ2' 'TANC1' 'TBL1X' 'TFEB'
#  'TOX3' 'TRPS1' 'TTC7A' 'WIPF1' 'ZCCHC24' 'ZFAND6' 'ZHX2' 'ZNF462'
#  'ZNF521']
# Negative positive genes: ['A2M' 'ABCA1' 'ABCA2' 'ACAN' 'ADAM12' 'ADRB2' 'APOD' 'APOE' 'AR' 'ATP7B'
#  'BACE2' 'BCHE' 'BDNF' 'CADPS2' 'CARD8' 'CASS4' 'CAV1' 'CCL2' 'CD36'
#  'CD44' 'CDKN2A' 'CH25H' 'CLSTN2' 'CLU' 'COL11A1' 'COL25A1' 'CR1' 'DCHS2'
#  'DGKB' 'DHCR24' 'EFNA5' 'ESR1' 'ESR2' 'F13A1' 'FAS' 'FGF1' 'FRMD6' 'GPX1'
#  'GREM2' 'GRIN3A' 'GRN' 'HACD1' 'HCRTR2' 'HFE' 'HHEX' 'HLA-A' 'HMOX1'
#  'HSD11B1' 'HSPA5' 'HSPG2' 'ICAM1' 'IGF1' 'IL18' 'IL33' 'IL6R' 'INPP5D'
#  'LDLR' 'LIPC' 'LMNA' 'LPL' 'LRRK2' 'MALRD1' 'MEF2A' 'MME' 'MTHFD1L'
#  'NEDD9' 'NGB' 'NGF' 'NGFR' 'NINJ2' 'NLRP3' 'NOS1' 'NPC2' 'NXPH1' 'OGFRL1'
#  'PCDH11X' 'PLA2G4A' 'PLXNA4' 'PON2' 'PON3' 'PPP1R3B' 'PTGS2' 'RELN'
#  'RUNX1' 'S100B' 'SAMSN1' 'SDC2' 'SLC19A1' 'SLC2A9' 'SNTG1' 'SOAT1'
#  'SORCS1' 'SORCS2' 'SORCS3' 'SORL1' 'TBX3' 'TGFB1' 'TP53' 'TP63' 'TREM2'
#  'VEGFA' 'WWC1' 'XBP1' 'ZCWPW1']
#
# c02x_AD_OPC_regulon_list.csv - AD - OPC
# Average positive percentile of 0.480
# Positive unknown genes: ['ABR' 'ADAMTS9' 'AHCYL1' 'AKAP12' 'AKAP13' 'AMER2' 'APCDD1' 'ARHGAP15'
#  'ARHGEF10L' 'ARID5A' 'ARRDC3' 'ATF3' 'ATP1B3' 'B2M' 'BAALC' 'BARD1'
#  'BCL6' 'BEST3' 'BTG2' 'C1QL1' 'CDKN1A' 'CEBPD' 'CHSY1' 'CLIC4' 'CNN3'
#  'COL27A1' 'COL9A1' 'CREB5' 'CTSC' 'DPYSL3' 'DUSP16' 'ELL2' 'ETV6' 'F3'
#  'FILIP1L' 'FKBP5' 'FNDC3B' 'FOS' 'GADD45A' 'GADD45B' 'GALNT10' 'GLIS3'
#  'GLUL' 'GPR17' 'GRIK3' 'HAP1' 'HAS2' 'HMGCS1' 'HSP90AA1' 'HSPB1' 'HSPD1'
#  'ID2' 'IL1RAP' 'IL6ST' 'INHBA' 'ITPKC' 'JUN' 'JUNB' 'KCNMB4' 'KIAA0040'
#  'LDLRAD4' 'LMO2' 'LRIG1' 'MAP3K1' 'MATN2' 'MT2A' 'NEK6' 'NEURL1B'
#  'NFKBIZ' 'OLIG1' 'OLIG2' 'OSMR' 'P4HA1' 'PARP9' 'PDK4' 'PDPN' 'PFKFB3'
#  'PHF21B' 'PIP4K2A' 'PITPNC1' 'PLSCR4' 'PMP2' 'PMP22' 'PROM1' 'PROX1'
#  'PTMA' 'PTPRE' 'PYGL' 'RAB3IP' 'RDH10' 'RFTN2' 'RFX4' 'RGCC' 'RGMA'
#  'RHOBTB3' 'RHOU' 'RPGR' 'SAT1' 'SCARA3' 'SCG2' 'SLC38A2' 'SNED1' 'SNX22'
#  'SOCS3' 'SORBS1' 'SOX13' 'SPRY4' 'ST6GAL1' 'TACC1' 'TANC1' 'TBL1X'
#  'TGFBR3' 'TIMP3' 'TM4SF1' 'TMCC3' 'TNFRSF1A' 'TNFSF13B' 'TNS3' 'TUBA1A'
#  'TUBB2B' 'TXNIP' 'UBASH3B' 'WLS' 'YBX3' 'ZFP36' 'ZFP36L2']
# Negative positive genes: ['A2M' 'ABCA1' 'ABCA2' 'ABCG2' 'ADAM12' 'ADRB2' 'AGER' 'ALOX5' 'APOC1'
#  'APOD' 'APOE' 'AR' 'ARSJ' 'ATP7B' 'BACE2' 'BCHE' 'BDNF' 'CADPS2' 'CASS4'
#  'CAV1' 'CCL2' 'CCL3' 'CD14' 'CD36' 'CD44' 'CDKN2A' 'CFH' 'CHRNA7'
#  'CLSTN2' 'CLU' 'COL11A1' 'COL25A1' 'CR1' 'CST3' 'CTSS' 'DCHS2' 'DGKB'
#  'DHCR24' 'EFNA5' 'ESR1' 'ESR2' 'F13A1' 'FAS' 'FGF1' 'FRMD6' 'FSHR' 'GBP2'
#  'GPX1' 'GREM2' 'GRIN3A' 'GRN' 'GSTP1' 'HACD1' 'HCRTR2' 'HFE' 'HHEX'
#  'HLA-A' 'HLA-DQB1' 'HLA-DRA' 'HLA-DRB1' 'HLA-DRB5' 'HMOX1' 'HSD11B1'
#  'HSPA5' 'HSPG2' 'ICAM1' 'IGF1' 'IL18' 'IL1B' 'IL33' 'IL6R' 'INPP5D'
#  'LDLR' 'LIPC' 'LPL' 'LRP2' 'LRRK2' 'MALRD1' 'MAOA' 'MEF2A' 'MME' 'MS4A4A'
#  'MTHFD1L' 'MX1' 'NGB' 'NGF' 'NGFR' 'NINJ2' 'NLRP1' 'NLRP3' 'NOS3' 'NPC2'
#  'NXPH1' 'PCDH11X' 'PCED1B' 'PLA2G4A' 'PLXNA4' 'PON2' 'PON3' 'PPARG'
#  'PPP1R3B' 'PTGS2' 'RELN' 'RUNX1' 'S100B' 'SAMSN1' 'SDC2' 'SLC19A1'
#  'SLC2A9' 'SNTG1' 'SOAT1' 'SORCS1' 'SORCS2' 'SORCS3' 'SST' 'TBX3' 'TF'
#  'TGFB1' 'TLR2' 'TP53' 'TP63' 'TREM2' 'VEGFA' 'WWC1' 'XBP1' 'ZCWPW1']
#
# c02x_AD_PC_regulon_list.csv - AD - PC
# Average positive percentile of 0.480
# Positive unknown genes: ['ABCA6' 'ABCA9' 'ADAMTS1' 'ADAMTS4' 'ADAMTS9' 'ADARB2' 'ADGRD1' 'AKAP12'
#  'ANKRD37' 'ANTXR2' 'APOLD1' 'ATF3' 'ATP1B3' 'AXL' 'BCL6' 'BHLHE40'
#  'BICC1' 'BTG2' 'C1QTNF1' 'CCND3' 'CDC42EP4' 'CDKN1A' 'CEBPD' 'CEMIP'
#  'COL1A2' 'COL4A1' 'COL4A2' 'CREB3L2' 'CREM' 'CRIM1' 'CRISPLD2' 'CSRNP1'
#  'DDIT4' 'DENND3' 'DISC1' 'DUSP1' 'DUSP5' 'EDNRB' 'EFHD1' 'EGR1' 'ELL2'
#  'ENPEP' 'ESYT2' 'FGFR1' 'FLT1' 'FOS' 'FOSL2' 'GABRE' 'GADD45B' 'GADD45G'
#  'GEM' 'GNG11' 'HES4' 'HEYL' 'HIF1A' 'HSPD1' 'ID3' 'IFITM3' 'IGFBP4'
#  'IL18R1' 'IL1R1' 'ISM1' 'ITGA11' 'ITIH5' 'JAG1' 'JUNB' 'JUP' 'KCNE4'
#  'LAMB1' 'LDLRAD3' 'MAF' 'MAFF' 'MCC' 'MIDN' 'MT2A' 'MTSS1' 'NAMPT'
#  'NFIL3' 'NR4A1' 'NR4A2' 'NR4A3' 'NRP2' 'NXN' 'OSMR' 'PALD1' 'PDE10A'
#  'PDE3A' 'PDGFA' 'PDK1' 'PDK4' 'PDZRN3' 'PER1' 'PHLDA1' 'PHLDB2' 'PITPNC1'
#  'PLSCR1' 'PRELP' 'PRRX1' 'PTMA' 'RASSF1' 'RCSD1' 'RNF152' 'SBNO2'
#  'SCARB1' 'SDCBP' 'SLC2A3' 'SMAD7' 'SRGN' 'STXBP6' 'TBX15' 'TNFRSF1A'
#  'TRPC4' 'TSC22D3' 'TXNIP' 'YBX3' 'ZCCHC24' 'ZHX2' 'ZNF331' 'ZNF618']
# Negative positive genes: ['A2M' 'ABCA1' 'ABCG2' 'ACAN' 'ADAM12' 'AGER' 'ALOX5' 'APOC1' 'APOD'
#  'APOE' 'AR' 'ARSJ' 'ATP7B' 'BACE2' 'BCHE' 'BDNF' 'CADPS2' 'CARD8' 'CASS4'
#  'CAV1' 'CCL2' 'CCL3' 'CD14' 'CD44' 'CDKN2A' 'CFH' 'CH25H' 'CHRNA7'
#  'CLSTN2' 'CLU' 'COL11A1' 'COL25A1' 'CST3' 'CTSS' 'DCHS2' 'DGKB' 'DHCR24'
#  'EFNA5' 'ESR1' 'ESR2' 'F13A1' 'FAS' 'FCER1G' 'FGF1' 'FSHR' 'GBP2' 'GPX1'
#  'GREM2' 'GRIN3A' 'GRN' 'HACD1' 'HCRTR2' 'HHEX' 'HLA-A' 'HLA-DRA'
#  'HLA-DRB1' 'HLA-DRB5' 'HMOX1' 'HSD11B1' 'HSPA5' 'HSPG2' 'ICAM1' 'IGF1'
#  'IL18' 'IL33' 'IL6R' 'INPP5D' 'LDLR' 'LIPC' 'LMNA' 'LPL' 'LRP2' 'LRRK2'
#  'MAOA' 'MEF2A' 'MME' 'MS4A6A' 'MTHFD1L' 'MX1' 'NEDD9' 'NGB' 'NGF' 'NGFR'
#  'NINJ2' 'NLRP1' 'NLRP3' 'NOS1' 'NXPH1' 'PCDH11X' 'PCED1B' 'PLA2G4A'
#  'PLXNA4' 'PON2' 'PON3' 'PPARG' 'PPP1R3B' 'PTGS2' 'RELN' 'RUNX1' 'SAMSN1'
#  'SDC2' 'SLC19A1' 'SNTG1' 'SOAT1' 'SORCS1' 'SORCS2' 'SORCS3' 'SORL1' 'SST'
#  'TBX3' 'TF' 'TGFB1' 'TLR2' 'TP53' 'TP63' 'TREM2' 'WWC1' 'XBP1' 'ZCWPW1']
#
# c02x_AD_PVM_regulon_list.csv - AD - PVM
# Average positive percentile of 0.547
# Positive unknown genes: ['ACSL1' 'ADAM28' 'ADAP2' 'ADGRE2' 'ANXA1' 'APMAP' 'ARRDC3' 'ATF3'
#  'ATP1B3' 'B4GALT1' 'BCAS2' 'BCL6' 'BHLHE41' 'BTG1' 'C1QB' 'CD83' 'CDKN1A'
#  'CLEC2B' 'CLEC7A' 'CMKLR1' 'CPED1' 'CREM' 'CSF1R' 'CTSB' 'CTTNBP2NL'
#  'CYCS' 'CYTIP' 'DDIT4' 'DUSP1' 'DUSP10' 'EIF4A3' 'ELL2' 'ESYT2' 'ETS2'
#  'FAM110B' 'FLT1' 'FOS' 'FOSL2' 'FTH1' 'GADD45B' 'GLUL' 'GNA13' 'GPR183'
#  'GPRIN3' 'HERPUD1' 'HIF1A' 'HK2' 'HNMT' 'HPGDS' 'HRH1' 'HSPA1A' 'HSPB1'
#  'HSPD1' 'HSPH1' 'IER2' 'INSIG1' 'IRAK3' 'JUN' 'JUNB' 'KLF2' 'KLF4' 'KLF6'
#  'LIMK2' 'LYVE1' 'MAFB' 'MAP3K8' 'MCL1' 'MRC1' 'MSR1' 'NAMPT' 'NFATC2'
#  'NFIL3' 'NFKBIZ' 'NR4A1' 'NR4A2' 'NR4A3' 'NRP1' 'NRP2' 'OSBPL11' 'OTUD1'
#  'P4HA1' 'PAPOLG' 'PDK1' 'PELI1' 'PER1' 'PFKFB3' 'PLSCR1' 'PPARD' 'PPP1CB'
#  'PRDM1' 'PRKCH' 'RAB20' 'RAB31' 'RAPGEF1' 'RCSD1' 'REL' 'RGS1' 'RGS2'
#  'RIPK2' 'RNF144B' 'SAT1' 'SCN9A' 'SDCBP' 'SGK1' 'SH3TC1' 'SIGLEC1'
#  'SLC11A1' 'SLC16A3' 'SLC2A3' 'SLC2A5' 'SLC7A5' 'SPP1' 'SRGN' 'STK17B'
#  'SULF2' 'SYAP1' 'SYTL3' 'TBC1D4' 'TEX14' 'TFRC' 'TNFAIP3' 'TSC22D3'
#  'UBASH3B' 'UBC' 'USP53' 'WLS' 'ZFP36' 'ZFP36L2' 'ZNF331']
# Negative positive genes: ['A2M' 'ABCA1' 'ABCG2' 'ACAN' 'ADAM12' 'ADRB2' 'AGER' 'ALOX5' 'APOC1'
#  'APOD' 'APOE' 'AR' 'ARSJ' 'BACE2' 'BCHE' 'BDNF' 'CADPS2' 'CARD8' 'CASS4'
#  'CAV1' 'CCL2' 'CCL3' 'CD14' 'CD33' 'CD36' 'CD44' 'CDKN2A' 'CFH' 'CH25H'
#  'CHRNA7' 'CLSTN2' 'CLU' 'COL11A1' 'COL25A1' 'CR1' 'CST3' 'CTSS' 'DCHS2'
#  'DGKB' 'DHCR24' 'EFNA5' 'ESR1' 'ESR2' 'F13A1' 'FAS' 'FCER1G' 'FGF1'
#  'FRMD6' 'FSHR' 'GBP2' 'GPX1' 'GREM2' 'GRIN3A' 'GRN' 'HACD1' 'HCRTR2'
#  'HFE' 'HHEX' 'HLA-A' 'HLA-DQB1' 'HLA-DRA' 'HLA-DRB1' 'HLA-DRB5' 'HMOX1'
#  'HSD11B1' 'HSPG2' 'ICAM1' 'IGF1' 'IL18' 'IL1B' 'IL33' 'IL6R' 'INPP5D'
#  'LDLR' 'LIPC' 'LMNA' 'LPL' 'LRP2' 'LRRK2' 'MALRD1' 'MAOA' 'MEF2A' 'MME'
#  'MS4A4A' 'MTHFD1L' 'MX1' 'NEDD9' 'NGB' 'NGF' 'NGFR' 'NINJ2' 'NLRP1'
#  'NLRP3' 'NOS1' 'NOS3' 'NPC2' 'NXPH1' 'OGFRL1' 'OLR1' 'PCDH11X' 'PCED1B'
#  'PLA2G4A' 'PLXNA4' 'PON2' 'PON3' 'PPARG' 'PPP1R3B' 'PTGS2' 'RELN' 'RUNX1'
#  'S100B' 'SLC19A1' 'SLC2A9' 'SNTG1' 'SOAT1' 'SORCS1' 'SORCS3' 'SORL1'
#  'SST' 'TBX3' 'TF' 'TGFB1' 'TLR2' 'TP53' 'TP63' 'TREM2' 'WWC1' 'XBP1'
#  'ZCWPW1']
#
# c02x_AD_SMC_regulon_list.csv - AD - SMC
# Average positive percentile of 0.508
# Positive unknown genes: ['ABCA6' 'ABCA8' 'ABCA9' 'ABCC9' 'ABI3BP' 'ADAMTS1' 'ADCY2' 'ADGRF5'
#  'ADGRL2' 'APOLD1' 'ASPH' 'ATF3' 'BHLHE40' 'BICC1' 'BMPR1B' 'BNC2' 'BOC'
#  'BTG2' 'C7' 'CACHD1' 'CEBPD' 'CHSY3' 'CLMN' 'CNTN4' 'COL8A1' 'CPED1'
#  'CRISPLD2' 'CYP1B1' 'DACH1' 'DCN' 'DDR2' 'DUSP1' 'EGR1' 'ELL2' 'EPHA7'
#  'ERRFI1' 'FAM107B' 'FGD6' 'FLRT2' 'FN1' 'FOS' 'FOSB' 'GADD45B' 'GGT5'
#  'GLRX' 'GLUL' 'GPC5' 'HMCN1' 'HSPB1' 'ID4' 'IER2' 'IGFBP4' 'IGFBP5'
#  'INPP4B' 'ITGA5' 'JUN' 'JUNB' 'KAZN' 'KCNT2' 'KLF2' 'LAMA2' 'LDB2'
#  'LDLRAD3' 'MAN1A1' 'MCL1' 'MECOM' 'MID1' 'MYO1B' 'NAMPT' 'NFIL3' 'NFKBIZ'
#  'NR4A1' 'NRP1' 'OSMR' 'PCSK5' 'PDGFC' 'PDLIM5' 'PDZRN4' 'PID1' 'PLD1'
#  'PLSCR1' 'PLXDC2' 'PROS1' 'PRRX1' 'PTH1R' 'PTMA' 'PTPRM' 'RBMS3' 'SDK2'
#  'SEMA5A' 'SEMA6D' 'SLC2A3' 'SLC7A2' 'SMOC2' 'SNED1' 'SORBS2' 'SOX6'
#  'SVEP1' 'TAGLN' 'TBX15' 'TENM4' 'TMEM132C' 'TPM2' 'TXNIP' 'USP6NL' 'VIM'
#  'VIT' 'YBX3' 'ZFP36']
# Negative positive genes: ['A2M' 'ABCA1' 'ABCA2' 'ABCG2' 'ADAM12' 'AGER' 'ALOX5' 'APOC1' 'APOD'
#  'APOE' 'AR' 'ARSJ' 'BCHE' 'BDNF' 'CADPS2' 'CASS4' 'CAV1' 'CCL2' 'CCL3'
#  'CD14' 'CD36' 'CD44' 'CDKN2A' 'CH25H' 'CHRNA7' 'CLSTN2' 'CLU' 'COL25A1'
#  'CR1' 'CST3' 'DCHS2' 'EFNA5' 'ESR1' 'ESR2' 'F13A1' 'FAS' 'FGF1' 'FRMD6'
#  'FSHR' 'GPX1' 'GREM2' 'GRIN3A' 'GRN' 'GSTP1' 'HACD1' 'HCRTR2' 'HFE'
#  'HHEX' 'HLA-A' 'HMOX1' 'HSD11B1' 'HSPA5' 'ICAM1' 'IGF1' 'IL18' 'IL33'
#  'IL6R' 'INPP5D' 'LDLR' 'LMNA' 'LPL' 'LRP2' 'LRRK2' 'MALRD1' 'MAOA'
#  'MEF2A' 'MME' 'MS4A4A' 'MTHFD1L' 'MX1' 'NEDD9' 'NGB' 'NGF' 'NGFR' 'NINJ2'
#  'NLRP1' 'NOS1' 'NPC2' 'NXPH1' 'OGFRL1' 'OLR1' 'PCED1B' 'PLA2G4A' 'PLXNA4'
#  'PON2' 'PPARG' 'PPP1R3B' 'PTGS2' 'RELN' 'RUNX1' 'SAMSN1' 'SDC2' 'SLC19A1'
#  'SLC2A9' 'SNTG1' 'SOAT1' 'SORCS1' 'SORCS2' 'SORCS3' 'SORL1' 'SST' 'TBX3'
#  'TGFB1' 'TLR2' 'TP63' 'VEGFA' 'WWC1' 'XBP1' 'ZCWPW1']
#
# c02x_AD_VLMC_regulon_list.csv - AD - VLMC
# Average positive percentile of 0.461
# Positive unknown genes: ['ABCA6' 'ABLIM1' 'ALDH1A1' 'ALDH1A2' 'ALPL' 'ANTXR2' 'APCDD1' 'ARHGAP42'
#  'B4GALT1' 'BCL2' 'BCL6' 'BTG2' 'C1R' 'C1RL' 'C7' 'CACHD1' 'CD55' 'CFLAR'
#  'CGNL1' 'CNN3' 'COBLL1' 'COL12A1' 'COL13A1' 'COL27A1' 'COL6A3'
#  'CSGALNACT1' 'CXCL12' 'CYP1B1' 'DAAM2' 'DCN' 'DISC1' 'DLC1' 'EBF1' 'EBF2'
#  'EGR1' 'ELL2' 'ETS1' 'ETV6' 'FAM124A' 'FAM126A' 'FAM160A1' 'FAP' 'FBLN1'
#  'FBLN5' 'FLI1' 'FOS' 'FOSL2' 'GAS1' 'GGT5' 'GHR' 'GRK5' 'IFI16' 'IFI44L'
#  'IGFBP4' 'IGFBP5' 'IL16' 'IL1R1' 'IQGAP2' 'ITGA11' 'JUN' 'JUNB' 'LAMB1'
#  'LEF1' 'MITF' 'MTSS1' 'NAMPT' 'NEK6' 'OAF' 'PALD1' 'PAMR1' 'PARP14'
#  'PCDH18' 'PDE10A' 'PDE7B' 'PDGFRA' 'PDGFRB' 'PIEZO2' 'PITPNC1' 'PLEKHG1'
#  'PLXDC2' 'PRDM1' 'PREX2' 'PRRX1' 'PTPRE' 'RARB' 'RBMS3' 'RFTN2' 'RND3'
#  'RNF144B' 'RNF220' 'RUNX2' 'SAT1' 'SFMBT2' 'SLC1A1' 'SLC2A3' 'SLC38A2'
#  'SLC4A4' 'SLC6A13' 'SLCO1C1' 'SLIT2' 'SMOC1' 'SOX5' 'SPON1' 'SPRY4'
#  'SYNPO2' 'TBC1D16' 'TBX18' 'TGFBR2' 'THBS1' 'TLE1' 'TNFRSF19' 'TRPS1'
#  'TWIST2' 'UBASH3B' 'USH1C' 'VIT' 'WNT5B' 'WWTR1' 'YBX3' 'ZCCHC24' 'ZFHX3'
#  'ZHX2' 'ZNF521' 'ZNRF3']
# Negative positive genes: ['A2M' 'ABCA2' 'ABCG2' 'ADAM12' 'ADRB2' 'AGER' 'ALOX5' 'APOE' 'AR' 'ARSJ'
#  'ATP7B' 'BACE2' 'BCHE' 'BDNF' 'CADPS2' 'CARD8' 'CASS4' 'CAV1' 'CCL2'
# ...
#  'ICAM1' 'LDLR' 'LMNA' 'LPL' 'LRP2' 'LRRK2' 'MAOA' 'MEF2A' 'MTHFD1L' 'MX1'
#  'NEDD9' 'NGF' 'NOS1' 'PLA2G4A' 'PLXNA4' 'PON2' 'PPP1R3B' 'PTGS2' 'RELN'
#  'RUNX1' 'SDC2' 'SLC19A1' 'SORCS1' 'SORCS3' 'TBX3' 'TGFB1' 'TP63' 'VEGFA'
#  'WWC1' 'XBP1']
#
# c28x_AD_strict_PVM_regulon_list.csv - AD_strict - PVM
# Average positive percentile of 0.584
# Positive unknown genes: ['ACSL1' 'ADAM28' 'ANXA1' 'APMAP' 'ARRDC3' 'ATF3' 'ATP1B3' 'B4GALT1'
#  'BCAS2' 'BCL6' 'BHLHE41' 'BTG1' 'CD69' 'CD83' 'CDKN1A' 'CLEC2B' 'CREM'
#  'CSF1R' 'CTTNBP2NL' 'CYCS' 'CYTIP' 'DDIT4' 'DUSP1' 'DUSP10' 'EIF4A3'
#  'ELL2' 'ESYT2' 'ETS2' 'FOS' 'FOSB' 'FOSL2' 'FTH1' 'GADD45B' 'GLUL'
#  'GNA13' 'GPR183' 'HERPUD1' 'HIF1A' 'HK2' 'HSPA1A' 'HSPB1' 'HSPH1' 'IER2'
#  'INSIG1' 'JUN' 'JUNB' 'KLF2' 'KLF4' 'KLF6' 'LAPTM5' 'MAP3K8' 'MCL1'
#  'MSR1' 'NAMPT' 'NFIL3' 'NFKBID' 'NFKBIZ' 'NR4A1' 'NR4A2' 'NR4A3' 'P4HA1'
#  'PADI2' 'PAPOLG' 'PDGFB' 'PDK1' 'PELI1' 'PER1' 'PFKFB3' 'PPARD' 'PPP1CB'
#  'PRDM1' 'PRKCH' 'RAB20' 'RAPGEF1' 'REL' 'RGS1' 'RGS2' 'RIPK2' 'RNF144B'
#  'SAT1' 'SDCBP' 'SGK1' 'SLC11A1' 'SLC2A3' 'SPP1' 'SRGN' 'SYAP1' 'SYTL3'
#  'TEX14' 'TFRC' 'TNFAIP3' 'TNFRSF1B' 'UBASH3B' 'UBC' 'ZFP36' 'ZNF331']
# Negative positive genes: ['A2M' 'ABCA1' 'ABCA2' 'ADRB2' 'AGER' 'ALOX5' 'APOC1' 'APOE' 'AR' 'ARSJ'
#  'BACE2' 'BCHE' 'BDNF' 'CADPS2' 'CARD8' 'CASS4' 'CAV1' 'CCL2' 'CCL3'
#  'CD14' 'CD33' 'CD36' 'CD44' 'CDKN2A' 'CH25H' 'CHRNA7' 'CLSTN2' 'COL11A1'
#  'COL25A1' 'CR1' 'CST3' 'CTSS' 'DCHS2' 'DGKB' 'EFNA5' 'ESR1' 'ESR2'
#  'F13A1' 'FAS' 'FCER1G' 'FGF1' 'FRMD6' 'GBP2' 'GRN' 'HFE' 'HHEX' 'HLA-A'
#  'HLA-DQB1' 'HLA-DRA' 'HLA-DRB1' 'HLA-DRB5' 'HMOX1' 'HSPA5' 'ICAM1' 'IGF1'
#  'IL18' 'IL1B' 'IL6R' 'INPP5D' 'LDLR' 'LMNA' 'LPL' 'LRRK2' 'MAOA' 'MEF2A'
#  'MS4A4A' 'MS4A6A' 'MTHFD1L' 'MX1' 'NEDD9' 'NINJ2' 'NLRP1' 'NPC2' 'NXPH1'
#  'OGFRL1' 'PCED1B' 'PLA2G4A' 'PLXNA4' 'PPARG' 'PPP1R3B' 'PTGS2' 'RELN'
#  'RUNX1' 'S100B' 'SDC2' 'SLC19A1' 'SLC2A9' 'SOAT1' 'SORL1' 'SST' 'TF'
#  'TGFB1' 'TLR2' 'TREM2' 'XBP1' 'ZCWPW1']
#
# c28x_AD_strict_SMC_regulon_list.csv - AD_strict - SMC
# Average positive percentile of 0.509
# Positive unknown genes: ['ADAMTS1' 'ADAMTS4' 'ADIRF' 'APOLD1' 'ATF3' 'ATP1B3' 'AXL' 'B2M' 'BMPR1B'
#  'BNC2' 'BTG2' 'CEBPD' 'CRISPLD2' 'CYP1B1' 'DCN' 'DUSP1' 'EGR1' 'ELL2'
#  'EPAS1' 'EYA1' 'EYA2' 'FOS' 'FOSB' 'FOSL2' 'GADD45B' 'GPC5' 'HES4' 'HEYL'
#  'IGFBP4' 'JAG1' 'JUNB' 'KCNT2' 'KLF2' 'LAMA2' 'LDLRAD3' 'LEPR'
#  'LINC01504' 'MPPED2' 'MYH11' 'MYOCD' 'NFKBIZ' 'NR4A1' 'NR4A2' 'NR4A3'
#  'P2RY14' 'PDLIM3' 'PIP5K1B' 'PRDM1' 'PRRX1' 'RNF152' 'SDK2' 'SLC38A2'
#  'SNCAIP' 'STX17-AS1' 'SVEP1' 'TAGLN' 'TBX2' 'TGFBR3' 'TOB1' 'TPM2'
#  'TXNIP' 'YBX3' 'ZNF331']
# Negative positive genes: ['A2M' 'ABCA1' 'ABCA2' 'ADAM12' 'APOE' 'AR' 'ARSJ' 'BACE2' 'CADPS2' 'CAV1'
#  'CD14' 'CD44' 'CH25H' 'CLSTN2' 'CLU' 'COL11A1' 'DGKB' 'EFNA5' 'ESR1'
#  'ESR2' 'F13A1' 'FAS' 'FGF1' 'FRMD6' 'GREM2' 'GRIN3A' 'GRN' 'HACD1'
#  'HLA-A' 'HMOX1' 'HSPA5' 'IL6R' 'LIPC' 'LMNA' 'LPL' 'LRP2' 'MAOA' 'MEF2A'
#  'MX1' 'NEDD9' 'NGB' 'OGFRL1' 'PCDH11X' 'PCED1B' 'PLA2G4A' 'PPARG'
#  'PPP1R3B' 'PTGS2' 'RELN' 'RUNX1' 'SDC2' 'SLC19A1' 'SLC2A9' 'SNTG1'
#  'SORCS2' 'SORCS3' 'SST' 'TBX3' 'TGFB1' 'TP63' 'VEGFA' 'WWC1' 'XBP1']
#
# c28x_AD_strict_VLMC_regulon_list.csv - AD_strict - VLMC
# Average positive percentile of 0.474
# Positive unknown genes: ['ABCA6' 'ACKR3' 'AGBL1' 'ALDH1A1' 'ALPL' 'ANTXR2' 'APCDD1' 'B4GALT1'
#  'BCL2' 'BMPER' 'BMPR1B' 'CACNA2D3' 'CD55' 'CNN3' 'COBLL1' 'COL6A3'
#  'CXCL12' 'DCN' 'DISC1' 'EBF1' 'FAM124A' 'FAM126A' 'FAP' 'FAT3' 'GGT5'
#  'GRK5' 'IFI16' 'IFI44L' 'IGFBP5' 'IL16' 'IL1R1' 'IQGAP2' 'ITGA11' 'OAF'
#  'PALD1' 'PLEKHG1' 'PRDM1' 'PREX2' 'PRRX1' 'PTPRE' 'RARB' 'RBMS3'
#  'RBMS3-AS3' 'RND3' 'RNF144B' 'RNF220' 'RUNX2' 'SAT1' 'SFMBT2' 'SLC38A2'
#  'SLC47A1' 'SLC4A4' 'SLC6A13' 'SLIT2' 'SMAD9' 'SOX5' 'SPON1' 'SPRY4'
#  'SYNPO2' 'TBC1D16' 'TBX18' 'TNFRSF19' 'TRPS1' 'TWIST2' 'UBASH3B' 'VIT'
#  'WWTR1' 'ZFHX3' 'ZHX2']
# Negative positive genes: ['A2M' 'ABCA1' 'ABCA2' 'ACAN' 'ADAM12' 'ALOX5' 'APOE' 'ARSJ' 'ATP7B'
#  'BACE2' 'CADPS2' 'CCL2' 'CD14' 'CD44' 'CDKN2A' 'CFH' 'CH25H' 'CHRNA7'
#  'CLSTN2' 'CLU' 'COL25A1' 'DCHS2' 'DHCR24' 'EFNA5' 'ESR2' 'F13A1' 'FAS'
#  'FGF1' 'GBP2' 'GPX1' 'HCRTR2' 'HMOX1' 'HSD11B1' 'HSPA5' 'HSPG2' 'IGF1'
#  'IL18' 'LDLR' 'LIPC' 'LMNA' 'LPL' 'LRRK2' 'MAOA' 'MEF2A' 'MME' 'MTHFD1L'
#  'NEDD9' 'NGF' 'NGFR' 'NINJ2' 'NLRP3' 'NOS1' 'NOS3' 'NPC2' 'PLA2G4A'
#  'PON2' 'PON3' 'PPARG' 'SDC2' 'SLC2A9' 'SOAT1' 'SORCS1' 'SORCS2' 'TGFB1'
#  'TP63' 'VEGFA' 'WWC1' 'XBP1' 'ZCWPW1']
#
# c28x_ctl_Astro_regulon_list.csv - ctl - Astro
#
# c28x_ctl_Endo_regulon_list.csv - ctl - Endo
#
# c28x_ctl_EN_L2_3_IT_regulon_list.csv - ctl - EN_L2_3_IT
#
# c28x_ctl_EN_L3_5_IT_1_regulon_list.csv - ctl - EN_L3_5_IT_1
#
# c28x_ctl_EN_L3_5_IT_2_regulon_list.csv - ctl - EN_L3_5_IT_2
#
# c28x_ctl_EN_L3_5_IT_3_regulon_list.csv - ctl - EN_L3_5_IT_3
#
# c28x_ctl_EN_L5_6_NP_regulon_list.csv - ctl - EN_L5_6_NP
#
# c28x_ctl_EN_L5_ET_regulon_list.csv - ctl - EN_L5_ET
#
# c28x_ctl_EN_L6B_regulon_list.csv - ctl - EN_L6B
#
# c28x_ctl_EN_L6_CT_regulon_list.csv - ctl - EN_L6_CT
#
# c28x_ctl_EN_L6_IT_1_regulon_list.csv - ctl - EN_L6_IT_1
#
# c28x_ctl_EN_L6_IT_2_regulon_list.csv - ctl - EN_L6_IT_2
#
# c28x_ctl_EN_NF_regulon_list.csv - ctl - EN_NF
#
# c28x_ctl_Immune_regulon_list.csv - ctl - Immune
#
# c28x_ctl_IN_ADARB2_regulon_list.csv - ctl - IN_ADARB2
#
# c28x_ctl_IN_LAMP5_LHX6_regulon_list.csv - ctl - IN_LAMP5_LHX6
#
# c28x_ctl_IN_LAMP5_RELN_regulon_list.csv - ctl - IN_LAMP5_RELN
#
# c28x_ctl_IN_PVALB_CHC_regulon_list.csv - ctl - IN_PVALB_CHC
#
# c28x_ctl_IN_PVALB_regulon_list.csv - ctl - IN_PVALB
#
# c28x_ctl_IN_SST_regulon_list.csv - ctl - IN_SST
#
# c28x_ctl_IN_VIP_regulon_list.csv - ctl - IN_VIP
#
# c28x_ctl_Micro_regulon_list.csv - ctl - Micro
#
# c28x_ctl_OPC_regulon_list.csv - ctl - OPC
#
# c28x_ctl_PC_regulon_list.csv - ctl - PC
#
# c28x_ctl_PVM_regulon_list.csv - ctl - PVM
#
# c28x_ctl_SMC_regulon_list.csv - ctl - SMC
#
# c28x_ctl_VLMC_regulon_list.csv - ctl - VLMC
#
# r01x_0_ctl_Astro_regulon_list.csv - ctl - Astro
#
# r01x_0_ctl_Endo_regulon_list.csv - ctl - Endo
#
# r01x_0_ctl_EN_L2_3_IT_regulon_list.csv - ctl - EN_L2_3_IT
#
# r01x_0_ctl_EN_L3_5_IT_1_regulon_list.csv - ctl - EN_L3_5_IT_1
#
# r01x_0_ctl_EN_L3_5_IT_2_regulon_list.csv - ctl - EN_L3_5_IT_2
#
# r01x_0_ctl_EN_L3_5_IT_3_regulon_list.csv - ctl - EN_L3_5_IT_3
#
# r01x_0_ctl_EN_L5_6_NP_regulon_list.csv - ctl - EN_L5_6_NP
#
# r01x_0_ctl_EN_L5_ET_regulon_list.csv - ctl - EN_L5_ET
#
# r01x_0_ctl_EN_L6B_regulon_list.csv - ctl - EN_L6B
#
# r01x_0_ctl_EN_L6_CT_regulon_list.csv - ctl - EN_L6_CT
#
# r01x_0_ctl_EN_L6_IT_1_regulon_list.csv - ctl - EN_L6_IT_1
#
# r01x_0_ctl_EN_L6_IT_2_regulon_list.csv - ctl - EN_L6_IT_2
#
# r01x_0_ctl_EN_NF_regulon_list.csv - ctl - EN_NF
#
# r01x_0_ctl_Immune_regulon_list.csv - ctl - Immune
#
# r01x_0_ctl_IN_ADARB2_regulon_list.csv - ctl - IN_ADARB2
#
# r01x_0_ctl_IN_LAMP5_LHX6_regulon_list.csv - ctl - IN_LAMP5_LHX6
#
# r01x_0_ctl_IN_LAMP5_RELN_regulon_list.csv - ctl - IN_LAMP5_RELN
#
# r01x_0_ctl_IN_PVALB_CHC_regulon_list.csv - ctl - IN_PVALB_CHC
#
# r01x_0_ctl_IN_PVALB_regulon_list.csv - ctl - IN_PVALB
#
# r01x_0_ctl_IN_SST_regulon_list.csv - ctl - IN_SST
#
# r01x_0_ctl_IN_VIP_regulon_list.csv - ctl - IN_VIP
#
# r01x_0_ctl_Micro_regulon_list.csv - ctl - Micro
#
# r01x_0_ctl_Oligo_regulon_list.csv - ctl - Oligo
#
# r01x_0_ctl_OPC_regulon_list.csv - ctl - OPC
#
# r01x_0_ctl_PC_regulon_list.csv - ctl - PC
#
# r01x_0_ctl_PVM_regulon_list.csv - ctl - PVM
#
# r01x_0_ctl_SMC_regulon_list.csv - ctl - SMC
#
# r01x_0_ctl_VLMC_regulon_list.csv - ctl - VLMC
#
# r01x_1_ctl_Astro_regulon_list.csv - ctl - Astro
#
# r01x_1_ctl_Endo_regulon_list.csv - ctl - Endo
#
# r01x_1_ctl_EN_L2_3_IT_regulon_list.csv - ctl - EN_L2_3_IT
#
# r01x_1_ctl_EN_L3_5_IT_1_regulon_list.csv - ctl - EN_L3_5_IT_1
#
# r01x_1_ctl_EN_L3_5_IT_2_regulon_list.csv - ctl - EN_L3_5_IT_2
#
# r01x_1_ctl_EN_L3_5_IT_3_regulon_list.csv - ctl - EN_L3_5_IT_3
#
# r01x_1_ctl_EN_L5_6_NP_regulon_list.csv - ctl - EN_L5_6_NP
#
# r01x_1_ctl_EN_L5_ET_regulon_list.csv - ctl - EN_L5_ET
#
# r01x_1_ctl_EN_L6B_regulon_list.csv - ctl - EN_L6B
#
# r01x_1_ctl_EN_L6_CT_regulon_list.csv - ctl - EN_L6_CT
#
# r01x_1_ctl_EN_L6_IT_1_regulon_list.csv - ctl - EN_L6_IT_1
#
# r01x_1_ctl_EN_L6_IT_2_regulon_list.csv - ctl - EN_L6_IT_2
#
# r01x_1_ctl_EN_NF_regulon_list.csv - ctl - EN_NF
#
# r01x_1_ctl_Immune_regulon_list.csv - ctl - Immune
#
# r01x_1_ctl_IN_ADARB2_regulon_list.csv - ctl - IN_ADARB2
#
# r01x_1_ctl_IN_LAMP5_LHX6_regulon_list.csv - ctl - IN_LAMP5_LHX6
#
# r01x_1_ctl_IN_LAMP5_RELN_regulon_list.csv - ctl - IN_LAMP5_RELN
#
# r01x_1_ctl_IN_PVALB_CHC_regulon_list.csv - ctl - IN_PVALB_CHC
#
# r01x_1_ctl_IN_PVALB_regulon_list.csv - ctl - IN_PVALB
#
# r01x_1_ctl_IN_SST_regulon_list.csv - ctl - IN_SST
#
# r01x_1_ctl_IN_VIP_regulon_list.csv - ctl - IN_VIP
#
# r01x_1_ctl_Micro_regulon_list.csv - ctl - Micro
#
# r01x_1_ctl_Oligo_regulon_list.csv - ctl - Oligo
#
# r01x_1_ctl_OPC_regulon_list.csv - ctl - OPC
#
# r01x_1_ctl_PC_regulon_list.csv - ctl - PC
#
# r01x_1_ctl_PVM_regulon_list.csv - ctl - PVM
#
# r01x_1_ctl_SMC_regulon_list.csv - ctl - SMC
#
# r01x_1_ctl_VLMC_regulon_list.csv - ctl - VLMC
#
# r01x_2_ctl_Astro_regulon_list.csv - ctl - Astro
#
# r01x_2_ctl_Endo_regulon_list.csv - ctl - Endo
#
# r01x_2_ctl_EN_L2_3_IT_regulon_list.csv - ctl - EN_L2_3_IT
#
# r01x_2_ctl_EN_L3_5_IT_1_regulon_list.csv - ctl - EN_L3_5_IT_1
#
# r01x_2_ctl_EN_L3_5_IT_2_regulon_list.csv - ctl - EN_L3_5_IT_2
#
# r01x_2_ctl_EN_L3_5_IT_3_regulon_list.csv - ctl - EN_L3_5_IT_3
#
# r01x_2_ctl_EN_L5_6_NP_regulon_list.csv - ctl - EN_L5_6_NP
#
# r01x_2_ctl_EN_L5_ET_regulon_list.csv - ctl - EN_L5_ET
#
# r01x_2_ctl_EN_L6B_regulon_list.csv - ctl - EN_L6B
#
# r01x_2_ctl_EN_L6_CT_regulon_list.csv - ctl - EN_L6_CT
#
# r01x_2_ctl_EN_L6_IT_1_regulon_list.csv - ctl - EN_L6_IT_1
#
# r01x_2_ctl_EN_L6_IT_2_regulon_list.csv - ctl - EN_L6_IT_2
#
# r01x_2_ctl_EN_NF_regulon_list.csv - ctl - EN_NF
#
# r01x_2_ctl_Immune_regulon_list.csv - ctl - Immune
#
# r01x_2_ctl_IN_ADARB2_regulon_list.csv - ctl - IN_ADARB2
#
# r01x_2_ctl_IN_LAMP5_LHX6_regulon_list.csv - ctl - IN_LAMP5_LHX6
#
# r01x_2_ctl_IN_LAMP5_RELN_regulon_list.csv - ctl - IN_LAMP5_RELN
#
# r01x_2_ctl_IN_PVALB_CHC_regulon_list.csv - ctl - IN_PVALB_CHC
#
# r01x_2_ctl_IN_PVALB_regulon_list.csv - ctl - IN_PVALB
#
# r01x_2_ctl_IN_SST_regulon_list.csv - ctl - IN_SST
#
# r01x_2_ctl_IN_VIP_regulon_list.csv - ctl - IN_VIP
#
# r01x_2_ctl_Micro_regulon_list.csv - ctl - Micro
#
# r01x_2_ctl_Oligo_regulon_list.csv - ctl - Oligo
#
# r01x_2_ctl_OPC_regulon_list.csv - ctl - OPC
#
# r01x_2_ctl_PC_regulon_list.csv - ctl - PC
#
# r01x_2_ctl_PVM_regulon_list.csv - ctl - PVM
#
# r01x_2_ctl_SMC_regulon_list.csv - ctl - SMC
#
# r01x_2_ctl_VLMC_regulon_list.csv - ctl - VLMC
#
# r01x_3_ctl_Astro_regulon_list.csv - ctl - Astro
#
# r01x_3_ctl_Endo_regulon_list.csv - ctl - Endo
#
# r01x_3_ctl_EN_L2_3_IT_regulon_list.csv - ctl - EN_L2_3_IT
#
# r01x_3_ctl_EN_L3_5_IT_1_regulon_list.csv - ctl - EN_L3_5_IT_1
#
# r01x_3_ctl_EN_L3_5_IT_2_regulon_list.csv - ctl - EN_L3_5_IT_2
#
# r01x_3_ctl_EN_L3_5_IT_3_regulon_list.csv - ctl - EN_L3_5_IT_3
#
# r01x_3_ctl_EN_L5_6_NP_regulon_list.csv - ctl - EN_L5_6_NP
#
# r01x_3_ctl_EN_L5_ET_regulon_list.csv - ctl - EN_L5_ET
#
# r01x_3_ctl_EN_L6B_regulon_list.csv - ctl - EN_L6B
#
# r01x_3_ctl_EN_L6_CT_regulon_list.csv - ctl - EN_L6_CT
#
# r01x_3_ctl_EN_L6_IT_1_regulon_list.csv - ctl - EN_L6_IT_1
#
# r01x_3_ctl_EN_L6_IT_2_regulon_list.csv - ctl - EN_L6_IT_2
#
# r01x_3_ctl_EN_NF_regulon_list.csv - ctl - EN_NF
#
# r01x_3_ctl_Immune_regulon_list.csv - ctl - Immune
#
# r01x_3_ctl_IN_ADARB2_regulon_list.csv - ctl - IN_ADARB2
#
# r01x_3_ctl_IN_LAMP5_LHX6_regulon_list.csv - ctl - IN_LAMP5_LHX6
#
# r01x_3_ctl_IN_LAMP5_RELN_regulon_list.csv - ctl - IN_LAMP5_RELN
#
# r01x_3_ctl_IN_PVALB_CHC_regulon_list.csv - ctl - IN_PVALB_CHC
#
# r01x_3_ctl_IN_PVALB_regulon_list.csv - ctl - IN_PVALB
#
# r01x_3_ctl_IN_SST_regulon_list.csv - ctl - IN_SST
#
# r01x_3_ctl_IN_VIP_regulon_list.csv - ctl - IN_VIP
#
# r01x_3_ctl_Micro_regulon_list.csv - ctl - Micro
#
# r01x_3_ctl_Oligo_regulon_list.csv - ctl - Oligo
#
# r01x_3_ctl_OPC_regulon_list.csv - ctl - OPC
#
# r01x_3_ctl_PC_regulon_list.csv - ctl - PC
#
# r01x_3_ctl_PVM_regulon_list.csv - ctl - PVM
#
# r01x_3_ctl_SMC_regulon_list.csv - ctl - SMC
#
# r01x_3_ctl_VLMC_regulon_list.csv - ctl - VLMC
#
# r01x_4_ctl_Astro_regulon_list.csv - ctl - Astro
#
# r01x_4_ctl_Endo_regulon_list.csv - ctl - Endo
#
# r01x_4_ctl_EN_L2_3_IT_regulon_list.csv - ctl - EN_L2_3_IT
#
# r01x_4_ctl_EN_L3_5_IT_1_regulon_list.csv - ctl - EN_L3_5_IT_1
#
# r01x_4_ctl_EN_L3_5_IT_2_regulon_list.csv - ctl - EN_L3_5_IT_2
#
# r01x_4_ctl_EN_L3_5_IT_3_regulon_list.csv - ctl - EN_L3_5_IT_3
#
# r01x_4_ctl_EN_L5_6_NP_regulon_list.csv - ctl - EN_L5_6_NP
#
# r01x_4_ctl_EN_L5_ET_regulon_list.csv - ctl - EN_L5_ET
#
# r01x_4_ctl_EN_L6B_regulon_list.csv - ctl - EN_L6B
#
# r01x_4_ctl_EN_L6_CT_regulon_list.csv - ctl - EN_L6_CT
#
# r01x_4_ctl_EN_L6_IT_1_regulon_list.csv - ctl - EN_L6_IT_1
#
# r01x_4_ctl_EN_L6_IT_2_regulon_list.csv - ctl - EN_L6_IT_2
#
# r01x_4_ctl_EN_NF_regulon_list.csv - ctl - EN_NF
#
# r01x_4_ctl_Immune_regulon_list.csv - ctl - Immune
#
# r01x_4_ctl_IN_ADARB2_regulon_list.csv - ctl - IN_ADARB2
#
# r01x_4_ctl_IN_LAMP5_LHX6_regulon_list.csv - ctl - IN_LAMP5_LHX6
#
# r01x_4_ctl_IN_LAMP5_RELN_regulon_list.csv - ctl - IN_LAMP5_RELN
#
# r01x_4_ctl_IN_PVALB_CHC_regulon_list.csv - ctl - IN_PVALB_CHC
#
# r01x_4_ctl_IN_PVALB_regulon_list.csv - ctl - IN_PVALB
#
# r01x_4_ctl_IN_SST_regulon_list.csv - ctl - IN_SST
#
# r01x_4_ctl_IN_VIP_regulon_list.csv - ctl - IN_VIP
#
# r01x_4_ctl_Micro_regulon_list.csv - ctl - Micro
#
# r01x_4_ctl_Oligo_regulon_list.csv - ctl - Oligo
#
# r01x_4_ctl_OPC_regulon_list.csv - ctl - OPC
#
# r01x_4_ctl_PC_regulon_list.csv - ctl - PC
#
# r01x_4_ctl_PVM_regulon_list.csv - ctl - PVM
#
# r01x_4_ctl_SMC_regulon_list.csv - ctl - SMC
#
# r01x_4_ctl_VLMC_regulon_list.csv - ctl - VLMC
#
# r01x_5_ctl_Astro_regulon_list.csv - ctl - Astro
#
# r01x_5_ctl_Endo_regulon_list.csv - ctl - Endo
#
# r01x_5_ctl_EN_L2_3_IT_regulon_list.csv - ctl - EN_L2_3_IT
#
# r01x_5_ctl_EN_L3_5_IT_1_regulon_list.csv - ctl - EN_L3_5_IT_1
#
# r01x_5_ctl_EN_L3_5_IT_2_regulon_list.csv - ctl - EN_L3_5_IT_2
#
# r01x_5_ctl_EN_L3_5_IT_3_regulon_list.csv - ctl - EN_L3_5_IT_3
#
# r01x_5_ctl_EN_L5_6_NP_regulon_list.csv - ctl - EN_L5_6_NP
#
# r01x_5_ctl_EN_L5_ET_regulon_list.csv - ctl - EN_L5_ET
#
# r01x_5_ctl_EN_L6B_regulon_list.csv - ctl - EN_L6B
#
# r01x_5_ctl_EN_L6_CT_regulon_list.csv - ctl - EN_L6_CT
#
# r01x_5_ctl_EN_L6_IT_1_regulon_list.csv - ctl - EN_L6_IT_1
#
# r01x_5_ctl_EN_L6_IT_2_regulon_list.csv - ctl - EN_L6_IT_2
#
# r01x_5_ctl_EN_NF_regulon_list.csv - ctl - EN_NF
#
# r01x_5_ctl_Immune_regulon_list.csv - ctl - Immune
#
# r01x_5_ctl_IN_ADARB2_regulon_list.csv - ctl - IN_ADARB2
#
# r01x_5_ctl_IN_LAMP5_LHX6_regulon_list.csv - ctl - IN_LAMP5_LHX6
#
# r01x_5_ctl_IN_LAMP5_RELN_regulon_list.csv - ctl - IN_LAMP5_RELN
#
# r01x_5_ctl_IN_PVALB_CHC_regulon_list.csv - ctl - IN_PVALB_CHC
#
# r01x_5_ctl_IN_PVALB_regulon_list.csv - ctl - IN_PVALB
#
# r01x_5_ctl_IN_SST_regulon_list.csv - ctl - IN_SST
#
# r01x_5_ctl_IN_VIP_regulon_list.csv - ctl - IN_VIP
#
# r01x_5_ctl_Micro_regulon_list.csv - ctl - Micro
#
# r01x_5_ctl_Oligo_regulon_list.csv - ctl - Oligo
#
# r01x_5_ctl_OPC_regulon_list.csv - ctl - OPC
#
# r01x_5_ctl_PC_regulon_list.csv - ctl - PC
#
# r01x_5_ctl_PVM_regulon_list.csv - ctl - PVM
#
# r01x_5_ctl_SMC_regulon_list.csv - ctl - SMC
#
# r01x_5_ctl_VLMC_regulon_list.csv - ctl - VLMC
#
# r01x_6_ctl_Endo_regulon_list.csv - ctl - Endo
#
# r01x_6_ctl_EN_L3_5_IT_1_regulon_list.csv - ctl - EN_L3_5_IT_1
#
# r01x_6_ctl_EN_L3_5_IT_2_regulon_list.csv - ctl - EN_L3_5_IT_2
#
# r01x_6_ctl_EN_L3_5_IT_3_regulon_list.csv - ctl - EN_L3_5_IT_3
#
# r01x_6_ctl_EN_L5_6_NP_regulon_list.csv - ctl - EN_L5_6_NP
#
# r01x_6_ctl_EN_L5_ET_regulon_list.csv - ctl - EN_L5_ET
#
# r01x_6_ctl_EN_L6B_regulon_list.csv - ctl - EN_L6B
#
# r01x_6_ctl_EN_L6_CT_regulon_list.csv - ctl - EN_L6_CT
#
# r01x_6_ctl_EN_L6_IT_1_regulon_list.csv - ctl - EN_L6_IT_1
#
# r01x_6_ctl_EN_L6_IT_2_regulon_list.csv - ctl - EN_L6_IT_2
#
# r01x_6_ctl_EN_NF_regulon_list.csv - ctl - EN_NF
#
# r01x_6_ctl_Immune_regulon_list.csv - ctl - Immune
#
# r01x_6_ctl_IN_ADARB2_regulon_list.csv - ctl - IN_ADARB2
#
# r01x_6_ctl_IN_LAMP5_LHX6_regulon_list.csv - ctl - IN_LAMP5_LHX6
#
# r01x_6_ctl_IN_LAMP5_RELN_regulon_list.csv - ctl - IN_LAMP5_RELN
#
# r01x_6_ctl_IN_PVALB_CHC_regulon_list.csv - ctl - IN_PVALB_CHC
#
# r01x_6_ctl_IN_PVALB_regulon_list.csv - ctl - IN_PVALB
#
# r01x_6_ctl_IN_VIP_regulon_list.csv - ctl - IN_VIP
#
# r01x_6_ctl_Micro_regulon_list.csv - ctl - Micro
#
# r01x_6_ctl_OPC_regulon_list.csv - ctl - OPC

# %% [markdown]
# ### Node2Vec Analysis

# %%
class MLP(torch.nn.Module):
    def __init__(self, input_size, dropout=.6):
        super().__init__()
        self.mlp = nn.Sequential(
            # Multiple layer
            # nn.Linear(input_size, input_size//2),
            # nn.Dropout(dropout),
            # nn.BatchNorm1d(input_size//2),
            # nn.LeakyReLU(),

            # nn.Linear(input_size//2, input_size//4),
            # nn.Dropout(dropout),
            # nn.BatchNorm1d(input_size//4),
            # nn.LeakyReLU(),

            # nn.Linear(input_size//4, 2),
            # nn.Dropout(dropout),
            # nn.BatchNorm1d(2),
            # nn.Softmax(1),

            # Single hidden layer
            # nn.Linear(input_size, 64),
            # nn.Dropout(dropout),
            # nn.BatchNorm1d(64),
            # nn.LeakyReLU(),

            # nn.Linear(64, 2),
            # nn.Dropout(dropout),
            # nn.BatchNorm1d(2),
            # nn.Softmax(1),

            # Single layer
            nn.Linear(input_size, 2),
            nn.BatchNorm1d(2),
            nn.Softmax(1),
        )

    def forward(self, X):
        return self.mlp(X)

# %%
# # Parameters
# dim = 64  # Automatic if `features``=='coex'
# lr = 1e-1
# gamma = .96
# features = ('embeddings', 'coex')[0]

# replications = 3
# folds = 5  # 1 indicates 80-20 validation, 0 indicates no validation
# max_epochs = 1_001
# batch_size = 64
# max_lapses = 20

# # Books
# graph_type = []
# app_list = []
# auprc_list = []
# auroc_list = []

# # Loop
# for fname in fnames:
#     ### Reading
#     # Choose graph
#     contrast = get_contrast(fname)
#     group = get_group(fname)
#     cell_type = get_cell_type(fname)
#     print(' - '.join([fname, group, cell_type]))

#     # Escape if not compatible
#     if group not in gene_lists:
#         print()
#         continue

#     # Get TF-TG linkages
#     graph_list = pd.read_csv(os.path.join(dir, fname), index_col=0)
#     graph_list = graph_list.rename(columns={'gene': 'TG', 'CoexWeight': 'coex'})

#     # Get matrix
#     graph_matrix = graph_list.pivot(index='TF', columns='TG', values='coex').fillna(0)
#     # Make square
#     all_genes = np.unique(list(graph_matrix.index) + list(graph_matrix.columns))
#     for gene in all_genes:
#         if gene not in graph_matrix.index: graph_matrix.loc[gene] = 0
#         if gene not in graph_matrix.columns: graph_matrix[gene] = 0


#     ### Processing
#     for replication in range(replications):
#         print(f'Replication {replication:02d}')
#         # Reproducibility
#         replication_seed = 42+replication
#         np.random.seed(replication_seed)

#         # Split into folds
#         if folds > 1:
#             folds_idx = np.array_split(np.array(range(np.unique(np.concatenate([np.unique(graph_list['TF']), np.unique(graph_list['TG'])])).shape[0])), folds)
#         elif folds == 1:
#             folds_idx = np.array(list(range(np.unique(np.concatenate([np.unique(graph_list['TF']), np.unique(graph_list['TG'])])).shape[0])))
#             np.random.shuffle(folds_idx)
#             split_idx = int(.8 * folds_idx.shape[0])
#             folds_idx = [folds_idx[:split_idx], folds_idx[split_idx:]]
#         else:
#             folds = 1
#             folds_idx = [np.array(list(range(np.unique(np.concatenate([np.unique(graph_list['TF']), np.unique(graph_list['TG'])])).shape[0])))] * 2

#         # Run folds
#         for fold in range(folds):
#             print(f'Fold {fold:02d}')

#             # Reproducibility
#             fold_seed = 42+replication*folds+fold
#             np.random.seed(fold_seed)
#             torch.manual_seed(fold_seed)

#             # Testing
#             # graph_type.append(f'{contrast}_{group}_{cell_type}_{replication}_{fold}')
#             # performance.append(np.random.rand())
#             # continue

#             # Convenience
#             fold_idx = np.concatenate([idx for i, idx in enumerate(folds_idx) if i != fold])
#             val_idx = folds_idx[fold]

#             # Generate embeddings
#             if features == 'embeddings':
#                 graph_list[['TF', 'TG', 'coex']].to_csv('_elist.edg', sep='\t', header=None, index=None)
#                 g = pp.pecanpy.SparseOTF(p=1, q=1, workers=8, verbose=False, random_state=fold_seed)
#                 g.read_edg('_elist.edg', weighted=True, directed=True)  # False if coexpression
#                 embeddings = g.embed(dim=dim, num_walks=10, walk_length=80, window_size=10, epochs=1)
#                 labels = np.array(g._node_ids)  # As long as no removing, `_node_idmap` isn't needed
#             elif features == 'coex':
#                 labels = graph_matrix.index.to_numpy()
#                 embeddings_from = graph_matrix.loc[labels].to_numpy()
#                 embeddings_to = graph_matrix[labels].to_numpy().T
#                 embeddings = np.concatenate((embeddings_from, embeddings_to), axis=1)
#                 dim = embeddings.shape[1]

#             # Annotate
#             gene_list = gene_lists[group]
#             annotation = np.array([g in gene_list for g in labels])

#             # Predict relevancy
#             X = torch.Tensor(embeddings)
#             unique, inverse = np.unique(annotation, return_inverse=True)
#             y = np.zeros((annotation.shape[0], unique.shape[0]))
#             y[np.arange(y.shape[0]), inverse] = 1
#             y = torch.Tensor(y)

#             # Make model
#             model = MLP(dim)
#             optimizer = torch.optim.Adam(model.parameters(), lr=lr)
#             scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer=optimizer, gamma=gamma)

#             # Train model
#             model.train()
#             lapses = 0; best_loss = np.inf
#             for epoch in range(max_epochs):
#                 epoch_loss = []
#                 epoch_val_loss = []
#                 for batch in range(fold_idx.shape[0] // batch_size):
#                     # Sample

#                     # Training
#                     batch_idx = np.random.choice(fold_idx, batch_size)
#                     batch_X = X[batch_idx]
#                     batch_y = y[batch_idx]
#                     logits = model(batch_X)
#                     loss = ((logits - batch_y)**2).mean()
#                     epoch_loss.append(loss.detach())

#                     # Validation
#                     val_X = X[val_idx]
#                     val_y = y[val_idx]
#                     logits = model(val_X)
#                     val_loss = ((logits - val_y)**2).mean()
#                     epoch_val_loss.append(val_loss.detach())

#                     # Iterate
#                     optimizer.zero_grad()
#                     loss.backward()
#                     optimizer.step()
#                     scheduler.step()
#                 epoch_loss = torch.Tensor(epoch_loss).mean()
#                 epoch_val_loss = torch.Tensor(epoch_val_loss).mean()

#                 # Early stopping
#                 if epoch_val_loss < best_loss:
#                     best_loss = epoch_val_loss
#                     lapses = 0
#                 else:
#                     lapses += 1
#                 if epoch % (max_epochs // 5) == 0 or lapses >= max_lapses: print(f'Epoch: {epoch:03d}\tLoss: {epoch_loss:.4f}\tValidation Loss: {epoch_val_loss:.4f}')
#                 if lapses >= max_lapses:
#                     break

#             model.eval()

#             ### Analysis
#             # Processing
#             logits = model(X[val_idx]).detach()
#             probability = logits[:, 1]
#             sorted_idx = torch.argsort(probability).flip(dims=(0,))
#             true = annotation[val_idx][sorted_idx]

#             # Outcomes
#             if true.sum() != 0:
#                 average_positive_percentile = np.linspace(1, 0, num=val_idx.shape[0])[true].mean()
#             else:
#                 average_positive_percentile = np.nan
#             print(f'Average positive percentile of {average_positive_percentile:.3f}')
#             if np.unique(true).shape[0] != 1:
#                 auprc = sklearn.metrics.average_precision_score(true, probability)
#             else:
#                 auprc = np.nan
#             print(f'AUPRC of {auprc:.3f}')
#             if np.unique(true).shape[0] != 1:
#                 auroc = sklearn.metrics.roc_auc_score(true, probability)
#             else:
#                 auroc = np.nan
#             print(f'AUROC of {auroc:.3f}')

#             ### Books
#             graph_type.append(f'{contrast}_{group}_{cell_type}_{replication}_{fold}')
#             app_list.append(average_positive_percentile)
#             auprc_list.append(auprc)
#             auroc_list.append(auroc)

#             print()
#         print()
#     print()

# ### Format
# graph_type = np.array(graph_type).reshape((-1, replications, folds))
# app_list = np.array(app_list).reshape((-1, replications, folds))
# auprc_list = np.array(auprc_list).reshape((-1, replications, folds))
# auroc_list = np.array(auroc_list).reshape((-1, replications, folds))

# %%
# # Format
# m2 = re.compile('^([cr]\d+x(_\d+)?)_([a-zA-Z]+(_(resilient|strict))?)_((?!resilient|strict)\w+)_(\d+)_(\d+)$')
# df_get_contrast = lambda s: m2.match(s).group(1)
# df_get_group = lambda s: m2.match(s).group(3)
# df_get_cell_type = lambda s: m2.match(s).group(6)
# df_get_replication = lambda s: m2.match(s).group(7)
# df_get_fold = lambda s: m2.match(s).group(8)
# df = pd.DataFrame({
#     'Contrast': np.vectorize(df_get_contrast)(graph_type.flatten()),
#     'Group': np.vectorize(df_get_group)(graph_type.flatten()),
#     'Cell Type': np.vectorize(df_get_cell_type)(graph_type.flatten()),
#     'Replication': np.vectorize(df_get_replication)(graph_type.flatten()),
#     'Fold': np.vectorize(df_get_fold)(graph_type.flatten()),
#     'Average Positive Percentile': app_list.flatten(),
#     'AUPRC': auprc_list.flatten(),
#     'AUROC': auroc_list.flatten(),
# })
# df.to_csv('results.csv')

# # Parameters
# statistic = 'AUROC'
# statistic_minimum = .5

# # Collapse folds
# df = df.groupby(['Contrast', 'Group', 'Cell Type', 'Replication']).mean().reset_index()

# # Collapse all
# df_summary = df.groupby(['Contrast', 'Group', 'Cell Type']).mean().reset_index()

# # Filter
# df_avg = df.groupby(['Contrast', 'Group', 'Cell Type']).mean().reset_index()
# df_avg.index = df_avg.apply(lambda r: '_'.join([r['Contrast'], r['Group'], r['Cell Type']]), axis=1)
# df.index = df.apply(lambda r: '_'.join([r['Contrast'], r['Group'], r['Cell Type']]), axis=1)
# df = df.loc[df_avg.index[df_avg[statistic] > statistic_minimum].to_numpy()]
# df = df.reset_index(drop=True)

# # Sort
# df = df.sort_values('Cell Type')
# df_summary = df_summary.sort_values('Cell Type')

# # Visualize boxplot
# fig, ax = plt.subplots(1, 1, figsize=(18, 9))
# sns.boxplot(df, x='Cell Type', y=statistic, hue='Group', ax=ax)
# plt.axhline(.5, color='black', linestyle='--')
# plt.xticks(rotation=90)
# plt.tight_layout()
# fig.savefig(f'./plots/grn_performance.pdf', format='pdf', transparent=True)
# plt.close()

# # Visualize line plot
# # fig, ax = plt.subplots(1, 1, figsize=(9, 9))
# # sns.lineplot(df_summary.sort_values('Cell Type'), x='Cell Type', y=statistic, hue='Group', ax=ax)
# # plt.axhline(.5, color='black', linestyle='--')
# # plt.xticks(rotation=90)
# # plt.tight_layout()
# # fig.savefig(f'./plots/grn_performance.pdf', format='pdf', transparent=True)
# # plt.close()

# %% [markdown]
# ### GCN Analysis

# %%
def pd_to_tg_data(df):
    "Convert pd edgelist into torch_geometric data"
    # Format
    unique = np.unique(list(df['TF'])+list(df['TG']))
    x = np.eye(unique.shape[0])
    node_dict = {k: v for v, k in enumerate(unique)}
    node_dict_rev = {v: k for k, v in node_dict.items()}
    from_edges = df['TF'].apply(lambda x: node_dict[x]).to_numpy()
    to_edges = df['TG'].apply(lambda x: node_dict[x]).to_numpy()
    edge_index = np.stack((from_edges, to_edges), axis=0)
    edge_weight = df['coex'].to_numpy()
    if 'Cell Type' in df:
        unique = np.unique(df['Cell Type'])
        edge_ct_dict = {k: v for v, k in enumerate(unique)}
        edge_ct = df['Cell Type'].apply(lambda x: edge_ct_dict[x]).to_numpy()
        edge_attr = np.expand_dims(edge_ct, axis=-1)

    # Get y data
    # -1 is unknown, 0 is no disease, 1 is disease
    y = np.zeros(x.shape[0])-1
    y[[node_dict_rev[i] in gene_lists[group] for i in range(x.shape[0])]] = 1
    # Randomly assign negatives for now
    # TODO: Replace this once more data comes in
    y[np.random.choice(np.argwhere(y!=1).flatten(), 100, replace=False)] = 0

    # Cast to tensors
    x = torch.tensor(x).float()
    edge_index = torch.tensor(edge_index).long()
    edge_weight = torch.tensor(edge_weight).float()
    if 'Cell Type' in df: edge_attr = torch.tensor(edge_attr).float()
    y = torch.tensor(y).long()

    # Torch data
    data = torch_geometric.data.Data(
        x=x,
        edge_index=edge_index,
        edge_weight=edge_weight,
        edge_attr=edge_attr if 'Cell Type' in df else None,
        y=y)

    # Additional attributes
    data.known_mask = y!=-1

    ret = (data, node_dict)
    if 'Cell Type' in df: ret += (edge_ct_dict,)
    return ret


def aggregate_graph_fnames(fnames):
    "Aggregate dfs from file list into one graph"
    df = pd.DataFrame()
    for fname in fnames:
        # Get list
        graph_list = pd.read_csv(os.path.join(dir, fname), index_col=0)
        graph_list = graph_list.rename(columns={'gene': 'TG', 'CoexWeight': 'coex'})
        graph_list['Cell Type'] = get_cell_type(fname)
        df = pd.concat((df, graph_list), axis=0)

    return df

# %%
class GCN(torch.nn.Module):
    # NOTES:
    # Edge weights drastically increase performance
    # Right now, very prone to overfitting if initial embedding dimension is too high
    # RESOURCES:
    # Layer cheatsheet: https://pytorch-geometric.readthedocs.io/en/latest/notes/cheatsheet.html
    def __init__(self, input_dim):
        super().__init__()

        self.input_dim = input_dim

        self.net = gnn.Sequential('x, edge_index, edge_weight', [
            (gnn.GCNConv(self.input_dim, 32), 'x, edge_index, edge_weight -> x'),
            nn.ReLU(),
            nn.Dropout(.5),
            (gnn.GCNConv(32, 16), 'x, edge_index, edge_weight -> x'),
            nn.ReLU(),
            nn.Dropout(.5),
            (gnn.GCNConv(16, 2), 'x, edge_index, edge_weight -> x'),
            nn.ReLU(),
        ])

    def forward(self, x, edge_index, edge_weight):
        return self.net(x, edge_index, edge_weight)

# %%
# Seed
np.random.seed(42)
torch.manual_seed(42)

# Aggregate fnames by contrast+group
contrast_group_fnames = defaultdict(lambda: [])
for fname in fnames:
    # Get data
    contrast = get_contrast(fname)
    group = get_group(fname)
    contrast_group_fnames[(contrast, group)].append(fname)
contrast_group_fnames = dict(contrast_group_fnames)

# Compound graphs
for (contrast, group), cg_fnames in contrast_group_fnames.items():
    print(' - '.join([contrast, group]))

    # Escape if not compatible
    if group not in gene_lists:
        print()
        continue

    # Get list
    graph_list = aggregate_graph_fnames(cg_fnames)

    # Convert
    data, node_dict, edge_ct_dict = pd_to_tg_data(graph_list)

    # Create folds
    folds = torch.randperm(data.x.shape[0]).split(int(np.ceil(data.x.shape[0]/5)))
    data.train_idx, data.test_idx = torch.concat(folds[:-1]), folds[-1]
    data.train_mask = torch.zeros(data.x.shape[0], dtype=torch.bool); data.train_mask[data.train_idx] = True
    data.test_mask = torch.zeros(data.x.shape[0], dtype=torch.bool); data.test_mask[data.test_idx] = True
    data.train_mask *= data.known_mask; data.test_mask *= data.known_mask

    # Make model
    model = GCN(data.x.shape[1])
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)
    scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer=optimizer, gamma=.96)

    # Run through data
    model.train()
    for epoch in range(201):
        # Reset
        optimizer.zero_grad()

        # Forward
        z = model(data.x, data.edge_index, data.edge_weight)

        # Loss
        # Sample even positive and negatives
        positives = (data.y==1).argwhere().flatten()
        negatives = (data.y==0).argwhere().flatten()
        num_per_class = min(positives.shape[0], negatives.shape[0])
        positives = positives[torch.randperm(positives.shape[0])[:num_per_class]]
        negatives = negatives[torch.randperm(negatives.shape[0])[:num_per_class]]
        idx = torch.concat((positives, negatives))
        mask = torch.zeros(data.x.shape[0], dtype=torch.bool); mask[idx] = True
        loss = criterion(z[data.train_mask*mask], data.y[data.train_mask*mask])

        # Backward
        loss.backward()
        optimizer.step()
        scheduler.step()

        # Reporting
        if epoch % 20 == 0:
            # Get new logits
            model.eval()
            z = model(data.x, data.edge_index, data.edge_weight)
            model.train()

            # Train and validation loss
            loss = criterion(z[data.train_mask], data.y[data.train_mask]).detach()
            val_loss = criterion(z[data.test_mask], data.y[data.test_mask]).detach()

            # Statistics
            pred = z.argmax(dim=1).detach(); true = data.y
            acc = (pred==true)[data.train_mask].sum() / true[data.train_mask].shape[0]
            val_acc = (z.argmax(dim=1) == data.y)[data.test_mask].sum() / data.y[data.test_mask].shape[0]
            bal_acc = sklearn.metrics.balanced_accuracy_score(true[data.train_mask], pred[data.train_mask])
            val_bal_acc = sklearn.metrics.balanced_accuracy_score(true[data.test_mask], pred[data.test_mask])

            # CLI
            print(
                ' - '.join([
                f'Epoch: {epoch:03d}',
                f'Loss: {loss:.3f}',
                f'Acc: {acc:.3f}',
                f'Balanced Acc: {bal_acc:.3f}',
                f'Val Loss: {val_loss:.3f}',
                f'Val Acc: {val_acc:.3f}',
                f'Val Balanced Acc: {val_bal_acc:.3f}',
            ]))
    model.eval()

    print()
# Out:
# c02x - AD
# Epoch: 000 - Loss: 0.693 - Acc: 0.432 - Balanced Acc: 0.500 - Val Loss: 0.693 - Val Acc: 0.377 - Val Balanced Acc: 0.500
# Epoch: 020 - Loss: 0.693 - Acc: 0.432 - Balanced Acc: 0.500 - Val Loss: 0.693 - Val Acc: 0.377 - Val Balanced Acc: 0.500
# Epoch: 040 - Loss: 0.693 - Acc: 0.432 - Balanced Acc: 0.500 - Val Loss: 0.693 - Val Acc: 0.377 - Val Balanced Acc: 0.500
# Epoch: 060 - Loss: 0.693 - Acc: 0.432 - Balanced Acc: 0.500 - Val Loss: 0.693 - Val Acc: 0.377 - Val Balanced Acc: 0.500
# Epoch: 080 - Loss: 0.693 - Acc: 0.432 - Balanced Acc: 0.500 - Val Loss: 0.693 - Val Acc: 0.377 - Val Balanced Acc: 0.500
# Epoch: 100 - Loss: 0.693 - Acc: 0.432 - Balanced Acc: 0.500 - Val Loss: 0.693 - Val Acc: 0.377 - Val Balanced Acc: 0.500
# Epoch: 120 - Loss: 0.693 - Acc: 0.432 - Balanced Acc: 0.500 - Val Loss: 0.693 - Val Acc: 0.377 - Val Balanced Acc: 0.500
# Epoch: 140 - Loss: 0.693 - Acc: 0.432 - Balanced Acc: 0.500 - Val Loss: 0.693 - Val Acc: 0.377 - Val Balanced Acc: 0.500
# Epoch: 160 - Loss: 0.693 - Acc: 0.432 - Balanced Acc: 0.500 - Val Loss: 0.693 - Val Acc: 0.377 - Val Balanced Acc: 0.500
# Epoch: 180 - Loss: 0.693 - Acc: 0.432 - Balanced Acc: 0.500 - Val Loss: 0.693 - Val Acc: 0.377 - Val Balanced Acc: 0.500
# Epoch: 200 - Loss: 0.693 - Acc: 0.432 - Balanced Acc: 0.500 - Val Loss: 0.693 - Val Acc: 0.377 - Val Balanced Acc: 0.500
#
# c02x - ctl
#
# c07x - scz
# Epoch: 000 - Loss: 0.690 - Acc: 0.625 - Balanced Acc: 0.500 - Val Loss: 0.691 - Val Acc: 0.571 - Val Balanced Acc: 0.500
# Epoch: 020 - Loss: 0.668 - Acc: 0.625 - Balanced Acc: 0.500 - Val Loss: 0.684 - Val Acc: 0.571 - Val Balanced Acc: 0.500
# Epoch: 040 - Loss: 0.647 - Acc: 0.625 - Balanced Acc: 0.500 - Val Loss: 0.681 - Val Acc: 0.571 - Val Balanced Acc: 0.500
# Epoch: 060 - Loss: 0.632 - Acc: 0.625 - Balanced Acc: 0.500 - Val Loss: 0.681 - Val Acc: 0.571 - Val Balanced Acc: 0.500
# Epoch: 080 - Loss: 0.626 - Acc: 0.625 - Balanced Acc: 0.500 - Val Loss: 0.682 - Val Acc: 0.571 - Val Balanced Acc: 0.500
# Epoch: 100 - Loss: 0.624 - Acc: 0.625 - Balanced Acc: 0.500 - Val Loss: 0.682 - Val Acc: 0.571 - Val Balanced Acc: 0.500
# Epoch: 120 - Loss: 0.624 - Acc: 0.625 - Balanced Acc: 0.500 - Val Loss: 0.682 - Val Acc: 0.571 - Val Balanced Acc: 0.500
# Epoch: 140 - Loss: 0.623 - Acc: 0.625 - Balanced Acc: 0.500 - Val Loss: 0.682 - Val Acc: 0.571 - Val Balanced Acc: 0.500
# Epoch: 160 - Loss: 0.623 - Acc: 0.625 - Balanced Acc: 0.500 - Val Loss: 0.682 - Val Acc: 0.571 - Val Balanced Acc: 0.500
# Epoch: 180 - Loss: 0.623 - Acc: 0.625 - Balanced Acc: 0.500 - Val Loss: 0.682 - Val Acc: 0.571 - Val Balanced Acc: 0.500
# Epoch: 200 - Loss: 0.623 - Acc: 0.625 - Balanced Acc: 0.500 - Val Loss: 0.682 - Val Acc: 0.571 - Val Balanced Acc: 0.500
#
# c28x - AD_resilient
# Epoch: 000 - Loss: 0.693 - Acc: 0.451 - Balanced Acc: 0.504 - Val Loss: 0.693 - Val Acc: 0.302 - Val Balanced Acc: 0.500
# Epoch: 020 - Loss: 0.686 - Acc: 0.554 - Balanced Acc: 0.500 - Val Loss: 0.680 - Val Acc: 0.698 - Val Balanced Acc: 0.500
# Epoch: 040 - Loss: 0.682 - Acc: 0.574 - Balanced Acc: 0.530 - Val Loss: 0.677 - Val Acc: 0.674 - Val Balanced Acc: 0.483
# Epoch: 060 - Loss: 0.683 - Acc: 0.615 - Balanced Acc: 0.590 - Val Loss: 0.681 - Val Acc: 0.674 - Val Balanced Acc: 0.571
# Epoch: 080 - Loss: 0.681 - Acc: 0.590 - Balanced Acc: 0.560 - Val Loss: 0.678 - Val Acc: 0.674 - Val Balanced Acc: 0.571
# Epoch: 100 - Loss: 0.680 - Acc: 0.610 - Balanced Acc: 0.579 - Val Loss: 0.677 - Val Acc: 0.651 - Val Balanced Acc: 0.532
# Epoch: 120 - Loss: 0.680 - Acc: 0.590 - Balanced Acc: 0.560 - Val Loss: 0.677 - Val Acc: 0.674 - Val Balanced Acc: 0.571
# Epoch: 140 - Loss: 0.680 - Acc: 0.590 - Balanced Acc: 0.560 - Val Loss: 0.677 - Val Acc: 0.674 - Val Balanced Acc: 0.571
# Epoch: 160 - Loss: 0.680 - Acc: 0.590 - Balanced Acc: 0.560 - Val Loss: 0.677 - Val Acc: 0.674 - Val Balanced Acc: 0.571
# Epoch: 180 - Loss: 0.680 - Acc: 0.590 - Balanced Acc: 0.560 - Val Loss: 0.677 - Val Acc: 0.674 - Val Balanced Acc: 0.571
# Epoch: 200 - Loss: 0.680 - Acc: 0.590 - Balanced Acc: 0.560 - Val Loss: 0.677 - Val Acc: 0.674 - Val Balanced Acc: 0.571
#
# c28x - AD_strict
# Epoch: 000 - Loss: 0.693 - Acc: 0.429 - Balanced Acc: 0.500 - Val Loss: 0.693 - Val Acc: 0.388 - Val Balanced Acc: 0.500
# Epoch: 020 - Loss: 0.686 - Acc: 0.603 - Balanced Acc: 0.566 - Val Loss: 0.685 - Val Acc: 0.735 - Val Balanced Acc: 0.687
# Epoch: 040 - Loss: 0.681 - Acc: 0.608 - Balanced Acc: 0.596 - Val Loss: 0.680 - Val Acc: 0.694 - Val Balanced Acc: 0.702
# Epoch: 060 - Loss: 0.677 - Acc: 0.593 - Balanced Acc: 0.580 - Val Loss: 0.675 - Val Acc: 0.673 - Val Balanced Acc: 0.675
# Epoch: 080 - Loss: 0.678 - Acc: 0.614 - Balanced Acc: 0.620 - Val Loss: 0.681 - Val Acc: 0.592 - Val Balanced Acc: 0.618
# Epoch: 100 - Loss: 0.676 - Acc: 0.603 - Balanced Acc: 0.608 - Val Loss: 0.678 - Val Acc: 0.612 - Val Balanced Acc: 0.635
# Epoch: 120 - Loss: 0.675 - Acc: 0.603 - Balanced Acc: 0.608 - Val Loss: 0.677 - Val Acc: 0.612 - Val Balanced Acc: 0.635
# Epoch: 140 - Loss: 0.675 - Acc: 0.603 - Balanced Acc: 0.608 - Val Loss: 0.677 - Val Acc: 0.633 - Val Balanced Acc: 0.652
# Epoch: 160 - Loss: 0.675 - Acc: 0.608 - Balanced Acc: 0.613 - Val Loss: 0.677 - Val Acc: 0.633 - Val Balanced Acc: 0.652
# Epoch: 180 - Loss: 0.675 - Acc: 0.603 - Balanced Acc: 0.608 - Val Loss: 0.677 - Val Acc: 0.612 - Val Balanced Acc: 0.635
# Epoch: 200 - Loss: 0.675 - Acc: 0.603 - Balanced Acc: 0.608 - Val Loss: 0.677 - Val Acc: 0.612 - Val Balanced Acc: 0.635
#
# c28x - ctl
#
# r01x_0 - ctl
#
# r01x_1 - ctl
#
# r01x_2 - ctl
#
# r01x_3 - ctl
#
# r01x_4 - ctl
#
# r01x_5 - ctl
#
# r01x_6 - ctl
