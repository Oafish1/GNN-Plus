# %%
import os
import re

import matplotlib
from matplotlib.colors import LogNorm
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pecanpy as pp
import seaborn as sns
import sklearn.metrics
import torch
import torch.nn as nn

# Style
sns.set_theme(context='talk', style='white', palette='Set2')
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %% [markdown]
# # Preparation

# %%
# Get files for contrast
# contrast = 'c02x'
dir = '../data/scenic_outs/'
# fnames = [fname for fname in os.listdir(dir) if fname.startswith(f'{contrast}_')]
fnames = os.listdir(dir)

# Get groups and cell-type based on fname
# TODO: Doesn't work for groups like 'AD_resilient'
m1 = re.compile('^([cr]\d+x(_\d+)?)_([a-zA-Z]+(_(resilient|strict))?)_((?!resilient|strict)\w+)_regulon_list.csv$')
get_contrast = lambda fname: m1.match(fname).group(1)
get_group = lambda fname: m1.match(fname).group(3)
get_cell_type = lambda fname: m1.match(fname).group(6)

# Get labels
gene_dir = '../data/new_labels/'
gene_fnames = [fname for fname in os.listdir(gene_dir) if fname.endswith('.txt')]
gene_lists = {'.'.join(fname.split('.')[:-1]): np.loadtxt(os.path.join(gene_dir, fname), dtype=str) for fname in gene_fnames}

# Special cases
gene_lists['scz'] = gene_lists['SCZ']
gene_lists['AD_resilient'] = gene_lists['AD_strict'] = gene_lists['AD']

# %% [markdown]
# # Analyses

# %% [markdown]
# ### TF Dot Analysis

# %%
for fname in fnames:
    ### Reading
    # Choose graph
    contrast = get_contrast(fname)
    group = get_group(fname)
    cell_type = get_cell_type(fname)
    print(' - '.join([fname, group, cell_type]))

    # Escape if not compatible
    if group not in gene_lists:
        print()
        continue

    # Get TF-TG linkages
    graph_list = pd.read_csv(os.path.join(dir, fname), index_col=0)
    graph_list = graph_list.rename(columns={'gene': 'TG', 'CoexWeight': 'coex'})

    # Get matrix
    graph_matrix = graph_list.pivot(index='TF', columns='TG', values='coex').fillna(0)

    # Get tf matrix
    # tf_matrix = pd.DataFrame(graph_matrix.to_numpy() @ graph_matrix.to_numpy().T, index=graph_matrix.index, columns=graph_matrix.index)  # TF
    tf_matrix = pd.DataFrame(graph_matrix.to_numpy().T @ graph_matrix.to_numpy(), index=graph_matrix.columns, columns=graph_matrix.columns)  # TG

    # Annotate
    gene_list = gene_lists[group]
    annotation = tf_matrix.index.map(lambda g: g in gene_list).to_numpy()

    # Sort based on annotation
    # annotation_sort_idx = list(annotation.argsort())[::-1]
    # tf_matrix = tf_matrix.iloc[annotation_sort_idx, annotation_sort_idx]
    # annotation = annotation[annotation_sort_idx]

    ### Processing
    # Sort genes based on dot with known TFs
    score = (tf_matrix.to_numpy() - np.diag(tf_matrix.to_numpy().diagonal()))[:, annotation].sum(axis=1)
    score[annotation] *= float(len(annotation)) / (len(annotation) - 1)
    sorted_idx = score.argsort()[::-1]

    ### Analysis
    # Evaluate performance
    if annotation[sorted_idx].sum() != 0:
        average_positive_percentile = np.linspace(1, 0, num=tf_matrix.shape[0])[annotation[sorted_idx]].mean()
    else:
        average_positive_percentile = np.nan
    print(f'Average positive percentile of {average_positive_percentile:.3f}')
    positive_unknown_genes = tf_matrix.index.to_numpy()[(score >= np.percentile(score, 100 - 100*float(annotation.sum()) / score.shape[0])) * ~annotation]
    print(f'Positive unknown genes: {positive_unknown_genes}')
    negative_positive_genes = tf_matrix.index.to_numpy()[(score < np.percentile(score, 100 - 100*float(annotation.sum()) / score.shape[0])) * annotation]
    print(f'Negative positive genes: {negative_positive_genes}')
    df = pd.DataFrame({
        # 'TF': tf_matrix.index.to_numpy()[sorted_idx],  # TF
        'TG': tf_matrix.index.to_numpy()[sorted_idx],  # TG
        'score': score[sorted_idx],
        'percentile': np.linspace(1, 0, num=tf_matrix.shape[0]),
        'annotation': annotation[sorted_idx],
    })

    ### Visualization
    # Sort based on score
    score_sort_idx = list(score.argsort())[::-1]
    tf_matrix_sort_score = tf_matrix.iloc[score_sort_idx, score_sort_idx]
    annotation_sort_score = annotation[score_sort_idx]
    # Plot
    fig, ax = plt.subplots(1, 1, figsize=(9, 9))
    plt.title(f'{group}_{cell_type} - APP {average_positive_percentile:.3f}')
    # tf_matrix_no_diag = tf_matrix.copy()
    # for i in range(tf_matrix.shape[0]): tf_matrix_no_diag.iloc[i, i] = 0
    sns.heatmap(tf_matrix_sort_score, norm=LogNorm(), cmap='mako_r', ax=ax)
    for i in np.argwhere(annotation_sort_score): plt.axhline(y=i, color='red', linewidth=1)
    fig.savefig(f'./plots/tf_matrix_{contrast}_{group}_{cell_type}.pdf', format='pdf', transparent=True)
    plt.tight_layout()
    plt.close()

    print()
# Out:
# c02x_AD_Astro_regulon_list.csv - AD - Astro
# Average positive percentile of 0.469
# Positive unknown genes: ['AEBP1' 'ANGPTL4' 'ANOS1' 'APLNR' 'ARID5A' 'ATF3' 'BAG3' 'BARD1' 'BCL6'
#  'BHLHE40' 'BTG2' 'C1R' 'C1RL' 'C4orf19' 'CACHD1' 'CDKN1A' 'CEBPB' 'CEBPD'
#  'CLIC4' 'CNN3' 'CRISPLD1' 'CRYAB' 'CSRNP1' 'CYCS' 'DBI' 'DDIT4' 'DTNA'
#  'DUSP1' 'ELL2' 'EMP1' 'EPAS1' 'ETV6' 'FGF2' 'FOS' 'FOSL2' 'GADD45A'
#  'GADD45B' 'GEM' 'GFAP' 'GHR' 'GPCPD1' 'GRIA1' 'HELB' 'HES1' 'HMGCS1'
#  'HSP90AA1' 'HSPA1A' 'HSPB1' 'HSPB8' 'HSPD1' 'HSPH1' 'ID2' 'ID3' 'IDI1'
#  'IER2' 'IGFBP7' 'IL13RA1' 'IL1R1' 'ITPKB' 'JUN' 'JUNB' 'KIAA0040' 'KLF6'
#  'LAMA1' 'LIMK2' 'LMO2' 'LTBP1' 'MAP3K14' 'MATN2' 'MIDN' 'MSN' 'NAMPT'
#  'NFIL3' 'NR4A1' 'NRP1' 'NRP2' 'OSMR' 'P2RY6' 'PAM' 'PARP9' 'PDPN'
#  'PFKFB2' 'PLSCR1' 'PMP2' 'RASD1' 'RELL1' 'RFX4' 'RGS16' 'RND3' 'RNF122'
#  'SAMD4A' 'SBNO2' 'SCARA3' 'SH3GL2' 'SLC38A1' 'SLC38A2' 'SMAD3' 'SOCS3'
#  'STOM' 'SULF1' 'TANC1' 'TEAD3' 'TEAD4' 'TIPARP' 'TNFRSF1A' 'TOB1'
#  'TRIP10' 'TXNIP' 'UBASH3B' 'UBC' 'WIPF1' 'WWTR1' 'YBX3' 'YOD1' 'ZBTB7C'
#  'ZCCHC24' 'ZFP36' 'ZFP36L1' 'ZFP36L2' 'ZIC1']
# Negative positive genes: ['A2M' 'ABCA1' 'ABCA2' 'ABCG2' 'ACAN' 'ADRB2' 'AGER' 'ALOX5' 'APOC1'
#  'APOD' 'APOE' 'AR' 'ARSJ' 'ATP7B' 'BCHE' 'BDNF' 'CADPS2' 'CARD8' 'CASS4'
#  'CAV1' 'CCL3' 'CD14' 'CD36' 'CDKN2A' 'CFH' 'CH25H' 'CHRNA7' 'CLSTN2'
#  'CLU' 'COL11A1' 'COL25A1' 'CST3' 'CTSS' 'DCHS2' 'DGKB' 'DHCR24' 'EFNA5'
#  'ESR1' 'ESR2' 'F13A1' 'FAS' 'FCER1G' 'FGF1' 'FRMD6' 'FSHR' 'GBP2' 'GPX1'
#  'GREM2' 'GRIN3A' 'GRN' 'GSTP1' 'HACD1' 'HCRTR2' 'HFE' 'HHEX' 'HLA-A'
#  'HLA-DQB1' 'HLA-DRA' 'HLA-DRB1' 'HMOX1' 'HSD11B1' 'HSPA5' 'HSPG2' 'IGF1'
#  'IL18' 'IL1B' 'IL33' 'IL6R' 'INPP5D' 'LIPC' 'LMNA' 'LPL' 'LRRK2' 'MAOA'
#  'MEF2A' 'MME' 'MTHFD1L' 'MX1' 'NEDD9' 'NGB' 'NGF' 'NGFR' 'NINJ2' 'NLRP1'
#  'NOS1' 'NOS3' 'NPC2' 'NXPH1' 'OGFRL1' 'OLR1' 'PCDH11X' 'PCED1B' 'PLA2G4A'
#  'PLXNA4' 'PON2' 'PON3' 'PPARG' 'PPP1R3B' 'PTGS2' 'RELN' 'RUNX1' 'SAMSN1'
#  'SDC2' 'SLC2A9' 'SNTG1' 'SOAT1' 'SORCS1' 'SORCS3' 'SORL1' 'SST' 'TBX3'
#  'TF' 'TGFB1' 'TLR2' 'TP53' 'TP63' 'VEGFA' 'WWC1' 'XBP1' 'ZCWPW1']
#
# c02x_AD_Endo_regulon_list.csv - AD - Endo
# Average positive percentile of 0.486
# Positive unknown genes: ['ACER2' 'ACSL5' 'ADAMTS9' 'AKAP12' 'ANGPT2' 'APOLD1' 'ARHGEF28' 'ARID5A'
#  'ARRDC3' 'ATP10A' 'B2M' 'BCL6' 'BHLHE40' 'C4orf19' 'CASP4' 'CDKN1A'
#  'CEBPD' 'CHST15' 'CLDN5' 'CLEC1A' 'CLEC2B' 'CLIC1' 'CLIC5' 'COL4A2' 'CP'
#  'CREM' 'CSRNP1' 'DUSP1' 'DUSP16' 'DUSP5' 'DUSP6' 'EFNA1' 'EGR1' 'ELL2'
#  'EMP2' 'ERG' 'ETS2' 'FLT1' 'FOS' 'FOSL2' 'GADD45B' 'GALNT18' 'GJA1'
#  'GNA13' 'GNB4' 'GRAMD1A' 'HES1' 'ID1' 'IER2' 'IFI16' 'IFITM3' 'IL4R'
#  'IL6ST' 'ITGA6' 'JUN' 'JUNB' 'KLF2' 'KLF4' 'KLF6' 'LDLRAD3' 'LIMS2'
#  'LRRC32' 'MAFF' 'MAP3K8' 'MCL1' 'MCTP1' 'MID1' 'MT1E' 'MT2A' 'MYO1E'
#  'NAMPT' 'NDRG1' 'NFKBIA' 'NFKBIZ' 'NR4A1' 'OSMR' 'P4HA1' 'PAPSS2'
#  'PITPNC1' 'PLA1A' 'PLEKHG1' 'PLOD2' 'PLSCR1' 'PLSCR4' 'PODXL' 'PTMA'
#  'PXN' 'RBMS2' 'RELL1' 'RGCC' 'RHOJ' 'RIMKLB' 'RNF19A' 'RPS23' 'S1PR1'
#  'SAMD4A' 'SCARB1' 'SDCBP' 'SEMA6A' 'SERPINH1' 'SLC16A1' 'SLC19A3'
#  'SLC26A2' 'SLC2A3' 'SLC38A2' 'SLC4A7' 'SLC6A6' 'SLCO4A1' 'SMAD6' 'SMAD7'
#  'SOCS3' 'SOX7' 'SRGN' 'STARD8' 'SVIL' 'TAGLN2' 'TGFBR2' 'TIPARP' 'TMSB10'
#  'TNS1' 'TPT1' 'TSHZ2' 'UBC' 'YBX3' 'ZFP36']
# Negative positive genes: ['A2M' 'ABCA1' 'ABCA2' 'ABCG2' 'ACAN' 'ADAM12' 'ADRB2' 'AGER' 'ALOX5'
#  'APOC1' 'APOD' 'APOE' 'AR' 'ARSJ' 'ATP7B' 'BCHE' 'BDNF' 'CADPS2' 'CARD8'
#  'CASS4' 'CAV1' 'CCL2' 'CCL3' 'CD14' 'CD33' 'CD36' 'CD44' 'CDKN2A' 'CH25H'
#  'CHRNA7' 'CLSTN2' 'CLU' 'COL11A1' 'COL25A1' 'CST3' 'CTSS' 'DCHS2' 'DGKB'
#  'DHCR24' 'EFNA5' 'ESR1' 'ESR2' 'F13A1' 'FAS' 'FCER1G' 'FGF1' 'FRMD6'
#  'FSHR' 'GBP2' 'GPX1' 'GREM2' 'GRIN3A' 'GRN' 'HACD1' 'HCRTR2' 'HHEX'
#  'HLA-A' 'HLA-DRA' 'HLA-DRB1' 'HLA-DRB5' 'HMOX1' 'HSD11B1' 'HSPG2' 'ICAM1'
#  'IGF1' 'IL18' 'IL1B' 'IL33' 'INPP5D' 'LDLR' 'LIPC' 'LMNA' 'LPL' 'LRP2'
#  'LRRK2' 'MAOA' 'MEF2A' 'MME' 'MS4A4A' 'MX1' 'NEDD9' 'NGB' 'NGF' 'NGFR'
#  'NINJ2' 'NLRP1' 'NLRP3' 'NOS1' 'NOS3' 'NPC2' 'NXPH1' 'OGFRL1' 'OLR1'
#  'PCDH11X' 'PCED1B' 'PLA2G4A' 'PLXNA4' 'PON3' 'PPARG' 'PPP1R3B' 'PTGS2'
#  'RELN' 'RUNX1' 'S100B' 'SAMSN1' 'SDC2' 'SLC19A1' 'SLC2A9' 'SNTG1' 'SOAT1'
#  'SORCS1' 'SORCS3' 'SORL1' 'SST' 'TBX3' 'TF' 'TGFB1' 'TLR2' 'TP53' 'TP63'
#  'TREM2' 'VEGFA' 'WWC1' 'XBP1' 'ZCWPW1']
#
# c02x_AD_EN_L3_5_IT_1_regulon_list.csv - AD - EN_L3_5_IT_1
# Average positive percentile of 0.511
# Positive unknown genes: ['ABCB1' 'ADGRL2' 'AFAP1L2' 'ANKUB1' 'ANTXR2' 'ARHGAP15' 'ATP8B1' 'B3GNT5'
#  'BCL2L14' 'CCDC168' 'CCK' 'CCND3' 'CDH19' 'CDH7' 'CEMIP' 'CHODL' 'CHRDL1'
#  'CHRM2' 'CHST9' 'CLMP' 'CNR1' 'COBLL1' 'COL12A1' 'COL5A2' 'COL8A1'
#  'CREB5' 'CSGALNACT1' 'CTNNA2' 'CUX2' 'DCC' 'ENPP1' 'EPHA7' 'FGFR1'
#  'FILIP1L' 'FMO5' 'FN1' 'FOXO1' 'FOXP2' 'GLIPR1L1' 'GNG4' 'GPR149'
#  'GPRIN3' 'GRM8' 'HGF' 'HS3ST2' 'HSPA1A' 'HTR1F' 'HTR2B' 'ID2' 'IER5'
#  'IFIT3' 'IL12RB2' 'IL1RAP' 'ITGA11' 'KCNH5' 'KCNK2' 'KCNQ5' 'KCTD8'
#  'LAMA2' 'LDLRAD3' 'LRTM1' 'MAMDC2' 'MAN1A1' 'MAN2A1' 'MCMDC2' 'MEGF11'
#  'MGST1' 'MLIP' 'MMP16' 'MPPED2' 'MYOCD' 'NFE2L3' 'NPAS4' 'NRP2' 'OPRM1'
#  'P2RY12' 'P2RY14' 'PDE1C' 'PDZRN4' 'PHLDB2' 'PLCH1' 'PLCXD3' 'PLEKHG1'
#  'PLOD2' 'PLSCR4' 'PLXDC2' 'PNRC1' 'POU6F2' 'PPFIBP1' 'PRELID2' 'PROX1'
#  'PTCHD4' 'PTMA' 'RALYL' 'RASD1' 'RIN3' 'RORB' 'RSPO2' 'RUNX2' 'SEMA3E'
#  'SEMA5A' 'SFMBT2' 'SGK1' 'SLA' 'SLC35F1' 'SNCAIP' 'SOX5' 'SPARC' 'SPATA1'
#  'ST8SIA4' 'STX19' 'STXBP6' 'SULF2' 'SYT17' 'TBL1X' 'THSD7B' 'TMSB4X'
#  'TMTC2' 'TOX' 'TRPM3' 'TSHZ2' 'TTN' 'UBC' 'UNC5D' 'VWC2L' 'ZFHX3' 'ZFPM2'
#  'ZNF213' 'ZNF385B']
# Negative positive genes: ['A2M' 'ABCA1' 'ABCA2' 'ABCG2' 'ACAN' 'ADAM12' 'ADRB2' 'AGER' 'ALOX5'
#  'APOC1' 'APOD' 'APOE' 'AR' 'ARSJ' 'ATP7B' 'BACE2' 'BCHE' 'BDNF' 'CADPS2'
#  'CARD8' 'CASS4' 'CAV1' 'CCL2' 'CD14' 'CD33' 'CD36' 'CD44' 'CDKN2A'
#  'CH25H' 'CHRNA7' 'CLSTN2' 'CLU' 'COL11A1' 'COL25A1' 'CR1' 'CST3' 'CTSS'
#  'DCHS2' 'DGKB' 'DHCR24' 'EFNA5' 'ESR2' 'F13A1' 'FAS' 'FCER1G' 'FGF1'
#  'FRMD6' 'FSHR' 'GBP2' 'GPX1' 'GRIN3A' 'GRN' 'GSTP1' 'HACD1' 'HCRTR2'
#  'HHEX' 'HLA-A' 'HLA-DQB1' 'HLA-DRB1' 'HLA-DRB5' 'HMOX1' 'HSD11B1' 'HSPA5'
#  'HSPG2' 'ICAM1' 'IGF1' 'IL18' 'IL1B' 'IL33' 'IL6R' 'INPP5D' 'LDLR' 'LIPC'
#  'LMNA' 'LPL' 'LRP2' 'LRRK2' 'MALRD1' 'MAOA' 'MS4A4A' 'MS4A6A' 'MTHFD1L'
#  'MX1' 'NEDD9' 'NGB' 'NGF' 'NGFR' 'NINJ2' 'NLRP1' 'NLRP3' 'NOS1' 'NOS3'
#  'NPC2' 'NXPH1' 'OGFRL1' 'OLR1' 'PCED1B' 'PLA2G4A' 'PLXNA4' 'PON2' 'PON3'
#  'PPARG' 'PPP1R3B' 'PTGS2' 'RELN' 'RUNX1' 'S100B' 'SAMSN1' 'SDC2'
#  'SLC19A1' 'SLC2A9' 'SNTG1' 'SOAT1' 'SORCS1' 'SORCS2' 'SORCS3' 'SORL1'
#  'SST' 'TBX3' 'TF' 'TGFB1' 'TLR2' 'TP53' 'TP63' 'TREM2' 'VEGFA' 'WWC1'
#  'XBP1' 'ZCWPW1']
#
# c02x_AD_EN_L3_5_IT_3_regulon_list.csv - AD - EN_L3_5_IT_3
# Average positive percentile of 0.507
# Positive unknown genes: ['ABCB1' 'ACTA2' 'ADGRG2' 'AMZ1' 'ANGPT2' 'ANKUB1' 'ARHGAP15' 'ARHGAP9'
#  'ASB14' 'ASPN' 'B3GNT5' 'BCL2L14' 'C11orf65' 'C4orf45' 'CABLES1' 'CAV3'
#  'CCDC60' 'CCK' 'CDH13' 'CEACAM1' 'CEMIP' 'CHST9' 'CLMP' 'CPB2' 'CRLF1'
#  'CUX2' 'CYP3A5' 'DCC' 'DOCK6' 'DUSP16' 'ECM2' 'EGR1' 'ENPP2' 'EPHA3'
#  'ETV6' 'EYS' 'FILIP1L' 'FLRT2' 'FMO5' 'FN1' 'FOXP2' 'FPR3' 'FSIP2' 'FTH1'
#  'GCNT1' 'GLRA2' 'GLRX' 'GPC6' 'GRIP1' 'HHIP' 'HSP90AA1' 'HTR2B' 'ID2'
#  'IFIT2' 'IFIT3' 'IGSF6' 'ITGBL1' 'KAZN' 'KHDRBS3' 'KIAA1217' 'LENG9'
#  'LINGO2' 'LPAR6' 'LRTM1' 'MEGF11' 'MFSD4B' 'MGST1' 'MROH9' 'MYOT'
#  'NFE2L3' 'NHS' 'NPAS4' 'NPNT' 'NTNG1' 'OGN' 'OMD' 'OPRM1' 'OSMR' 'P2RY12'
#  'P2RY14' 'PALLD' 'PAPPA' 'PGM5' 'PIGC' 'PLCB4' 'PLCXD3' 'POU6F2' 'PRSS23'
#  'PTMA' 'PTPRO' 'PYGL' 'RALYL' 'RARB' 'RFX4' 'RHD' 'RPL35A' 'RPS27'
#  'RPS4X' 'RPS7' 'RUNX2' 'SCG2' 'SEMA3E' 'SEMA6D' 'SFRP4' 'SLC22A24'
#  'SLC22A25' 'SLC26A5' 'SLC38A2' 'SPATA1' 'STX19' 'SVIL' 'TBL1X' 'TCF7L2'
#  'TIMP3' 'TMSB10' 'TP53TG5' 'TRPC3' 'TSHR' 'TTN' 'UBC' 'USP13' 'UTRN'
#  'WNT5B' 'ZFHX3' 'ZNF213']
# Negative positive genes: ['ABCA1' 'ABCA2' 'ABCG2' 'ACAN' 'ADAM12' 'ADRB2' 'AGER' 'ALOX5' 'APOC1'
#  'APOD' 'APOE' 'AR' 'ARSJ' 'ATP7B' 'BACE2' 'BCHE' 'BDNF' 'CADPS2' 'CARD8'
#  'CASS4' 'CAV1' 'CCL2' 'CCL3' 'CD14' 'CD33' 'CD36' 'CD44' 'CDKN2A' 'CFH'
#  'CH25H' 'CHRNA7' 'CLU' 'COL11A1' 'COL25A1' 'CR1' 'CST3' 'CTSS' 'DCHS2'
#  'DHCR24' 'EFNA5' 'ESR1' 'ESR2' 'F13A1' 'FAS' 'FCER1G' 'FRMD6' 'FSHR'
#  'GBP2' 'GPX1' 'GREM2' 'GRIN3A' 'GSTP1' 'HACD1' 'HCRTR2' 'HFE' 'HHEX'
#  'HLA-A' 'HLA-DRA' 'HLA-DRB1' 'HLA-DRB5' 'HMOX1' 'HSD11B1' 'HSPA5' 'HSPG2'
#  'ICAM1' 'IGF1' 'IL1B' 'IL33' 'IL6R' 'INPP5D' 'LDLR' 'LIPC' 'LMNA' 'LPL'
#  'LRP2' 'LRRK2' 'MALRD1' 'MAOA' 'MEF2A' 'MME' 'MS4A4A' 'MTHFD1L' 'MX1'
#  'NEDD9' 'NGB' 'NGF' 'NGFR' 'NINJ2' 'NLRP1' 'NLRP3' 'NOS1' 'NOS3' 'NPC2'
#  'NXPH1' 'OGFRL1' 'OLR1' 'PCDH11X' 'PCED1B' 'PLA2G4A' 'PLXNA4' 'PON2'
#  'PON3' 'PPARG' 'PPP1R3B' 'PTGS2' 'RELN' 'RUNX1' 'S100B' 'SAMSN1' 'SDC2'
#  'SLC19A1' 'SLC2A9' 'SOAT1' 'SORCS1' 'SORCS3' 'SORL1' 'SST' 'TBX3' 'TLR2'
#  'TP53' 'TP63' 'VEGFA' 'WWC1' 'XBP1' 'ZCWPW1']
#
# c02x_AD_EN_L5_ET_regulon_list.csv - AD - EN_L5_ET
# Average positive percentile of 0.533
# Positive unknown genes: ['ABCB1' 'ACTA2' 'ADAM28' 'ADAMTS1' 'ALK' 'ANGPT2' 'ANKUB1' 'ANO4'
#  'ARHGAP15' 'B3GNT5' 'BCL2L14' 'BMX' 'C11orf65' 'C4orf45' 'CACNB2' 'CAV3'
#  'CFTR' 'CHST9' 'CNR1' 'COL10A1' 'COL12A1' 'CPS1' 'CREB5' 'CREM' 'CYP1B1'
#  'DNAJB1' 'DUSP16' 'ECM2' 'EFCAB13' 'ENO4' 'EYS' 'FILIP1L' 'FMO5' 'FN1'
#  'FSIP2' 'GABRA2' 'GCNT1' 'GLIPR1L1' 'GRM1' 'HHIP' 'HTR2B' 'IFIT2' 'IFIT3'
#  'IGSF6' 'KCNMB4' 'KCNQ1' 'LAMC1' 'LENG9' 'LPAR6' 'LRTM1' 'MFSD4B' 'MGST1'
#  'MROH9' 'NDST3' 'NETO1' 'NFE2L3' 'NPNT' 'OGN' 'OPRM1' 'OSMR' 'P2RY12'
#  'P2RY14' 'P4HA3' 'PHEX' 'PIPOX' 'PRSS23' 'PRSS48' 'PTPRE' 'PYGL' 'PZP'
#  'RARRES1' 'RUNX2' 'SCN9A' 'SERPINE2' 'SFRP4' 'SGMS2' 'SHISA6' 'SHROOM3'
#  'SLC26A5' 'SMIM4' 'SPI1' 'STX19' 'SVIL' 'TIMP3' 'TMEM132D' 'TMSB4X'
#  'TNFRSF11A' 'TRIM5' 'TRPS1' 'TTN' 'USP13' 'WNT5B' 'ZNF213' 'ZNF565']
# Negative positive genes: ['A2M' 'ABCA1' 'ABCG2' 'ACAN' 'ADAM12' 'ALOX5' 'APOD' 'APOE' 'AR' 'ARSJ'
#  'ATP7B' 'BACE2' 'BCHE' 'BDNF' 'CADPS2' 'CARD8' 'CASS4' 'CAV1' 'CD36'
#  'CD44' 'CDKN2A' 'CFH' 'CHRNA7' 'CLSTN2' 'CLU' 'COL11A1' 'COL25A1' 'CTSS'
#  'DCHS2' 'DGKB' 'DHCR24' 'EFNA5' 'ESR2' 'F13A1' 'FAS' 'FGF1' 'FRMD6'
#  'FSHR' 'GBP2' 'GREM2' 'GRIN3A' 'HACD1' 'HCRTR2' 'HLA-DRA' 'HLA-DRB1'
#  'HSPA5' 'HSPG2' 'ICAM1' 'IGF1' 'IL18' 'IL33' 'IL6R' 'INPP5D' 'LDLR'
#  'LIPC' 'LMNA' 'LPL' 'LRP2' 'MALRD1' 'MAOA' 'MEF2A' 'MME' 'MS4A4A' 'MX1'
#  'NEDD9' 'NGF' 'NINJ2' 'NLRP1' 'NOS1' 'NPC2' 'NXPH1' 'OGFRL1' 'PCED1B'
#  'PLA2G4A' 'PLXNA4' 'PPARG' 'PPP1R3B' 'PTGS2' 'RELN' 'RUNX1' 'SAMSN1'
#  'SDC2' 'SNTG1' 'SOAT1' 'SORL1' 'SST' 'TF' 'TLR2' 'TP53' 'TP63' 'VEGFA'
#  'WWC1' 'XBP1' 'ZCWPW1']

# %% [markdown]
# ### Node2Vec Analysis

# %%
class MLP(torch.nn.Module):
    def __init__(self, input_size, dropout=.6):
        super().__init__()
        self.mlp = nn.Sequential(
            # Multiple layer
            # nn.Linear(input_size, input_size//2),
            # nn.Dropout(dropout),
            # nn.BatchNorm1d(input_size//2),
            # nn.LeakyReLU(),

            # nn.Linear(input_size//2, input_size//4),
            # nn.Dropout(dropout),
            # nn.BatchNorm1d(input_size//4),
            # nn.LeakyReLU(),

            # nn.Linear(input_size//4, 2),
            # nn.Dropout(dropout),
            # nn.BatchNorm1d(2),
            # nn.Softmax(1),

            # Single hidden layer
            # nn.Linear(input_size, 64),
            # nn.Dropout(dropout),
            # nn.BatchNorm1d(64),
            # nn.LeakyReLU(),

            # nn.Linear(64, 2),
            # nn.Dropout(dropout),
            # nn.BatchNorm1d(2),
            # nn.Softmax(1),

            # Single layer
            nn.Linear(input_size, 2),
            nn.BatchNorm1d(2),
            nn.Softmax(1),
        )

    def forward(self, X):
        return self.mlp(X)

# %%
# Parameters
dim = 64  # Automatic if `features``=='coex'
lr = 1e-1
gamma = .96
features = ('embeddings', 'coex')[0]

replications = 3
folds = 5  # 1 indicates 80-20 validation, 0 indicates no validation
max_epochs = 1_001
batch_size = 64
max_lapses = 20

# Books
graph_type = []
app_list = []
auprc_list = []
auroc_list = []

# Loop
for fname in fnames:
    ### Reading
    # Choose graph
    contrast = get_contrast(fname)
    group = get_group(fname)
    cell_type = get_cell_type(fname)
    print(' - '.join([fname, group, cell_type]))

    # Escape if not compatible
    if group not in gene_lists:
        print()
        continue

    # Get TF-TG linkages
    graph_list = pd.read_csv(os.path.join(dir, fname), index_col=0)
    graph_list = graph_list.rename(columns={'gene': 'TG', 'CoexWeight': 'coex'})

    # Get matrix
    graph_matrix = graph_list.pivot(index='TF', columns='TG', values='coex').fillna(0)
    # Make square
    all_genes = np.unique(list(graph_matrix.index) + list(graph_matrix.columns))
    for gene in all_genes:
        if gene not in graph_matrix.index: graph_matrix.loc[gene] = 0
        if gene not in graph_matrix.columns: graph_matrix[gene] = 0


    ### Processing
    for replication in range(replications):
        print(f'Replication {replication:02d}')
        # Reproducibility
        replication_seed = 42+replication
        np.random.seed(replication_seed)

        # Split into folds
        if folds > 1:
            folds_idx = np.array_split(np.array(range(np.unique(np.concatenate([np.unique(graph_list['TF']), np.unique(graph_list['TG'])])).shape[0])), folds)
        elif folds == 1:
            folds_idx = np.array(list(range(np.unique(np.concatenate([np.unique(graph_list['TF']), np.unique(graph_list['TG'])])).shape[0])))
            np.random.shuffle(folds_idx)
            split_idx = int(.8 * folds_idx.shape[0])
            folds_idx = [folds_idx[:split_idx], folds_idx[split_idx:]]
        else:
            folds = 1
            folds_idx = [np.array(list(range(np.unique(np.concatenate([np.unique(graph_list['TF']), np.unique(graph_list['TG'])])).shape[0])))] * 2

        # Run folds
        for fold in range(folds):
            print(f'Fold {fold:02d}')

            # Reproducibility
            fold_seed = 42+replication*folds+fold
            np.random.seed(fold_seed)
            torch.manual_seed(fold_seed)

            # Testing
            # graph_type.append(f'{contrast}_{group}_{cell_type}_{replication}_{fold}')
            # performance.append(np.random.rand())
            # continue

            # Convenience
            fold_idx = np.concatenate([idx for i, idx in enumerate(folds_idx) if i != fold])
            val_idx = folds_idx[fold]

            # Generate embeddings
            if features == 'embeddings':
                graph_list[['TF', 'TG', 'coex']].to_csv('_elist.edg', sep='\t', header=None, index=None)
                g = pp.pecanpy.SparseOTF(p=1, q=1, workers=8, verbose=False, random_state=fold_seed)
                g.read_edg('_elist.edg', weighted=True, directed=True)  # False if coexpression
                embeddings = g.embed(dim=dim, num_walks=10, walk_length=80, window_size=10, epochs=1)
                labels = np.array(g._node_ids)  # As long as no removing, `_node_idmap` isn't needed
            elif features == 'coex':
                labels = graph_matrix.index.to_numpy()
                embeddings_from = graph_matrix.loc[labels].to_numpy()
                embeddings_to = graph_matrix[labels].to_numpy().T
                embeddings = np.concatenate((embeddings_from, embeddings_to), axis=1)
                dim = embeddings.shape[1]

            # Annotate
            gene_list = gene_lists[group]
            annotation = np.array([g in gene_list for g in labels])

            # Predict relevancy
            X = torch.Tensor(embeddings)
            unique, inverse = np.unique(annotation, return_inverse=True)
            y = np.zeros((annotation.shape[0], unique.shape[0]))
            y[np.arange(y.shape[0]), inverse] = 1
            y = torch.Tensor(y)

            # Make model
            model = MLP(dim)
            optimizer = torch.optim.Adam(model.parameters(), lr=lr)
            scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer=optimizer, gamma=gamma)

            # Train model
            model.train()
            lapses = 0; best_loss = np.inf
            for epoch in range(max_epochs):
                epoch_loss = []
                epoch_val_loss = []
                for batch in range(fold_idx.shape[0] // batch_size):
                    # Sample

                    # Training
                    batch_idx = np.random.choice(fold_idx, batch_size)
                    batch_X = X[batch_idx]
                    batch_y = y[batch_idx]
                    logits = model(batch_X)
                    loss = ((logits - batch_y)**2).mean()
                    epoch_loss.append(loss.detach())

                    # Validation
                    val_X = X[val_idx]
                    val_y = y[val_idx]
                    logits = model(val_X)
                    val_loss = ((logits - val_y)**2).mean()
                    epoch_val_loss.append(val_loss.detach())

                    # Iterate
                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()
                    scheduler.step()
                epoch_loss = torch.Tensor(epoch_loss).mean()
                epoch_val_loss = torch.Tensor(epoch_val_loss).mean()

                # Early stopping
                if epoch_val_loss < best_loss:
                    best_loss = epoch_val_loss
                    lapses = 0
                else:
                    lapses += 1
                if epoch % (max_epochs // 5) == 0 or lapses >= max_lapses: print(f'Epoch: {epoch:03d}\tLoss: {epoch_loss:.4f}\tValidation Loss: {epoch_val_loss:.4f}')
                if lapses >= max_lapses:
                    break

            model.eval()

            ### Analysis
            # Processing
            logits = model(X[val_idx]).detach()
            probability = logits[:, 1]
            sorted_idx = torch.argsort(probability).flip(dims=(0,))
            true = annotation[val_idx][sorted_idx]

            # Outcomes
            if true.sum() != 0:
                average_positive_percentile = np.linspace(1, 0, num=val_idx.shape[0])[true].mean()
            else:
                average_positive_percentile = np.nan
            print(f'Average positive percentile of {average_positive_percentile:.3f}')
            if np.unique(true).shape[0] != 1:
                auprc = sklearn.metrics.average_precision_score(true, probability)
            else:
                auprc = np.nan
            print(f'AUPRC of {auprc:.3f}')
            if np.unique(true).shape[0] != 1:
                auroc = sklearn.metrics.roc_auc_score(true, probability)
            else:
                auroc = np.nan
            print(f'AUROC of {auroc:.3f}')

            ### Books
            graph_type.append(f'{contrast}_{group}_{cell_type}_{replication}_{fold}')
            app_list.append(average_positive_percentile)
            auprc_list.append(auprc)
            auroc_list.append(auroc)

            print()
        print()
    print()

### Format
graph_type = np.array(graph_type).reshape((-1, replications, folds))
app_list = np.array(app_list).reshape((-1, replications, folds))
auprc_list = np.array(auprc_list).reshape((-1, replications, folds))
auroc_list = np.array(auroc_list).reshape((-1, replications, folds))
# Out:
# c02x_AD_Astro_regulon_list.csv - AD - Astro
# Replication 00
# Fold 00
# Epoch: 000	Loss: 0.0723	Validation Loss: 0.0801
# Epoch: 029	Loss: 0.0392	Validation Loss: 0.0492
# Average positive percentile of 0.480
# AUPRC of 0.055
# AUROC of 0.525
#
# Fold 01
# Epoch: 000	Loss: 0.0721	Validation Loss: 0.0718
# Epoch: 028	Loss: 0.0361	Validation Loss: 0.0386
# Average positive percentile of 0.568
# AUPRC of 0.087
# AUROC of 0.610
#
# Fold 02
# Epoch: 000	Loss: 0.0817	Validation Loss: 0.0966
# Epoch: 029	Loss: 0.0321	Validation Loss: 0.0563
# Average positive percentile of 0.478
# AUPRC of 0.102
# AUROC of 0.580
#
# Fold 03
# Epoch: 000	Loss: 0.0771	Validation Loss: 0.0732
# Epoch: 029	Loss: 0.0435	Validation Loss: 0.0313
# Average positive percentile of 0.581
# AUPRC of 0.093
# AUROC of 0.499
#
# Fold 04
# Epoch: 000	Loss: 0.0827	Validation Loss: 0.0710
# Epoch: 029	Loss: 0.0398	Validation Loss: 0.0271
# Average positive percentile of 0.399
# AUPRC of 0.034
# AUROC of 0.531
#
#
# Replication 01
# Fold 00
# Epoch: 000	Loss: 0.0705	Validation Loss: 0.0775
# Epoch: 028	Loss: 0.0395	Validation Loss: 0.0489
# Average positive percentile of 0.468
# AUPRC of 0.064
# AUROC of 0.510
#
# Fold 01
# Epoch: 000	Loss: 0.0830	Validation Loss: 0.0767
# Epoch: 029	Loss: 0.0350	Validation Loss: 0.0386
# Average positive percentile of 0.584
# AUPRC of 0.033
# AUROC of 0.423
#
# Fold 02
# Epoch: 000	Loss: 0.0743	Validation Loss: 0.0912
# Epoch: 029	Loss: 0.0361	Validation Loss: 0.0564
# Average positive percentile of 0.432
# AUPRC of 0.092
# AUROC of 0.552
#
# Fold 03
# Epoch: 000	Loss: 0.0828	Validation Loss: 0.0743
# Epoch: 028	Loss: 0.0405	Validation Loss: 0.0311
# Average positive percentile of 0.705
# AUPRC of 0.035
# AUROC of 0.395
#
# Fold 04
# Epoch: 000	Loss: 0.0772	Validation Loss: 0.0714
# Epoch: 028	Loss: 0.0410	Validation Loss: 0.0273
# Average positive percentile of 0.545
# AUPRC of 0.034
# AUROC of 0.477
#
#
# Replication 02
# Fold 00
# Epoch: 000	Loss: 0.0734	Validation Loss: 0.0814
# Epoch: 028	Loss: 0.0320	Validation Loss: 0.0488
# Average positive percentile of 0.497
# AUPRC of 0.064
# AUROC of 0.509
#
# Fold 01
# Epoch: 000	Loss: 0.0818	Validation Loss: 0.0979
# Epoch: 029	Loss: 0.0429	Validation Loss: 0.0385
# Average positive percentile of 0.479
# AUPRC of 0.062
# AUROC of 0.470
#
# Fold 02
# Epoch: 000	Loss: 0.0785	Validation Loss: 0.0943
# Epoch: 027	Loss: 0.0409	Validation Loss: 0.0561
# Average positive percentile of 0.480
# AUPRC of 0.067
# AUROC of 0.520
#
# Fold 03
# Epoch: 000	Loss: 0.0822	Validation Loss: 0.0712
# Epoch: 028	Loss: 0.0491	Validation Loss: 0.0314
# Average positive percentile of 0.566
# AUPRC of 0.031
# AUROC of 0.479
#
# Fold 04
# Epoch: 000	Loss: 0.0802	Validation Loss: 0.0660
# Epoch: 028	Loss: 0.0481	Validation Loss: 0.0271
# Average positive percentile of 0.552
# AUPRC of 0.028
# AUROC of 0.482
#
#
#
# c02x_AD_Endo_regulon_list.csv - AD - Endo
# Replication 00
# Fold 00
# Epoch: 000	Loss: 0.0786	Validation Loss: 0.0912
# Epoch: 029	Loss: 0.0393	Validation Loss: 0.0552
# Average positive percentile of 0.511
# AUPRC of 0.063
# AUROC of 0.463
#
# Fold 01
# Epoch: 000	Loss: 0.0883	Validation Loss: 0.1209
# Epoch: 030	Loss: 0.0561	Validation Loss: 0.0451
# Average positive percentile of 0.437
# AUPRC of 0.042
# AUROC of 0.541
#
# Fold 02
# Epoch: 000	Loss: 0.0824	Validation Loss: 0.0911
# Epoch: 030	Loss: 0.0321	Validation Loss: 0.0581
# Average positive percentile of 0.472
# AUPRC of 0.077
# AUROC of 0.568
#
# Fold 03
# Epoch: 000	Loss: 0.0821	Validation Loss: 0.0773
# Epoch: 028	Loss: 0.0439	Validation Loss: 0.0331
# Average positive percentile of 0.624
# AUPRC of 0.049
# AUROC of 0.550
#
# Fold 04
# Epoch: 000	Loss: 0.0930	Validation Loss: 0.1180
# Epoch: 031	Loss: 0.0588	Validation Loss: 0.0325
# Average positive percentile of 0.492
# AUPRC of 0.041
# AUROC of 0.529
#
#
# Replication 01
# Fold 00
# Epoch: 000	Loss: 0.0784	Validation Loss: 0.0872
# Epoch: 027	Loss: 0.0321	Validation Loss: 0.0549
# Average positive percentile of 0.558
# AUPRC of 0.072
# AUROC of 0.494
#
# Fold 01
# Epoch: 000	Loss: 0.0774	Validation Loss: 0.0720
# Epoch: 028	Loss: 0.0407	Validation Loss: 0.0379
# Average positive percentile of 0.392
# AUPRC of 0.048
# AUROC of 0.455
#
# Fold 02
# Epoch: 000	Loss: 0.0910	Validation Loss: 0.1157
# Epoch: 022	Loss: 0.0394	Validation Loss: 0.0579
# Average positive percentile of 0.492
# AUPRC of 0.051
# AUROC of 0.416
#
# Fold 03
# Epoch: 000	Loss: 0.1058	Validation Loss: 0.1271
# Epoch: 029	Loss: 0.0385	Validation Loss: 0.0329
# Average positive percentile of 0.525
# AUPRC of 0.032
# AUROC of 0.483
#
# Fold 04
# Epoch: 000	Loss: 0.0844	Validation Loss: 0.0678
# Epoch: 029	Loss: 0.0475	Validation Loss: 0.0262
# Average positive percentile of 0.600
# AUPRC of 0.044
# AUROC of 0.455
#
#
# Replication 02
# Fold 00
# Epoch: 000	Loss: 0.0793	Validation Loss: 0.0908
# Epoch: 028	Loss: 0.0441	Validation Loss: 0.0549
# Average positive percentile of 0.539
# AUPRC of 0.089
# AUROC of 0.466
#
# Fold 01
# Epoch: 000	Loss: 0.0855	Validation Loss: 0.0953
# Epoch: 028	Loss: 0.0452	Validation Loss: 0.0374
# Average positive percentile of 0.425
# AUPRC of 0.039
# AUROC of 0.500
#
# Fold 02
# Epoch: 000	Loss: 0.0737	Validation Loss: 0.0907
# Epoch: 027	Loss: 0.0369	Validation Loss: 0.0580
# Average positive percentile of 0.477
# AUPRC of 0.069
# AUROC of 0.523
#
# Fold 03
# Epoch: 000	Loss: 0.0871	Validation Loss: 0.0878
# Epoch: 028	Loss: 0.0409	Validation Loss: 0.0330
# Average positive percentile of 0.548
# AUPRC of 0.031
# AUROC of 0.459
#
# Fold 04
# Epoch: 000	Loss: 0.0776	Validation Loss: 0.0687
# Epoch: 030	Loss: 0.0452	Validation Loss: 0.0258
# Average positive percentile of 0.546
# AUPRC of 0.022
# AUROC of 0.427
#
#
#
# c02x_AD_EN_L3_5_IT_1_regulon_list.csv - AD - EN_L3_5_IT_1
# Replication 00
# Fold 00
# Epoch: 000	Loss: 0.0804	Validation Loss: 0.0860
# Epoch: 021	Loss: 0.0391	Validation Loss: 0.0537
# Average positive percentile of 0.578
# AUPRC of 0.057
# AUROC of 0.449
#
# Fold 01
# Epoch: 000	Loss: 0.0823	Validation Loss: 0.0725
# Epoch: 028	Loss: 0.0430	Validation Loss: 0.0378
# Average positive percentile of 0.367
# AUPRC of 0.069
# AUROC of 0.516
#
# Fold 02
# Epoch: 000	Loss: 0.0717	Validation Loss: 0.0944
# Epoch: 021	Loss: 0.0390	Validation Loss: 0.0673
# Average positive percentile of 0.553
# AUPRC of 0.099
# AUROC of 0.529
#
# Fold 03
# Epoch: 000	Loss: 0.0801	Validation Loss: 0.0623
# Epoch: 029	Loss: 0.0466	Validation Loss: 0.0274
# Average positive percentile of 0.490
# AUPRC of 0.033
# AUROC of 0.572
#
# Fold 04
# Epoch: 000	Loss: 0.0803	Validation Loss: 0.0635
# Epoch: 029	Loss: 0.0422	Validation Loss: 0.0273
# Average positive percentile of 0.496
# AUPRC of 0.026
# AUROC of 0.472
#
#
# Replication 01
# Fold 00
# Epoch: 000	Loss: 0.0740	Validation Loss: 0.0885
# Epoch: 027	Loss: 0.0411	Validation Loss: 0.0542
# Average positive percentile of 0.505
# AUPRC of 0.100
# AUROC of 0.551
#
# Fold 01
# Epoch: 000	Loss: 0.0788	Validation Loss: 0.0759
# Epoch: 028	Loss: 0.0414	Validation Loss: 0.0374
# Average positive percentile of 0.393
# AUPRC of 0.035
# AUROC of 0.435
#
# Fold 02
# Epoch: 000	Loss: 0.0763	Validation Loss: 0.0998
# Epoch: 021	Loss: 0.0390	Validation Loss: 0.0675
# Average positive percentile of 0.523
# AUPRC of 0.071
# AUROC of 0.504
#
# Fold 03
# Epoch: 000	Loss: 0.0759	Validation Loss: 0.0715
# Epoch: 030	Loss: 0.0473	Validation Loss: 0.0277
# Average positive percentile of 0.570
# AUPRC of 0.036
# AUROC of 0.545
#
# Fold 04
# Epoch: 000	Loss: 0.0796	Validation Loss: 0.0664
# Epoch: 028	Loss: 0.0469	Validation Loss: 0.0272
# Average positive percentile of 0.485
# AUPRC of 0.031
# AUROC of 0.513
#
#
# Replication 02
# Fold 00
# Epoch: 000	Loss: 0.0823	Validation Loss: 0.0864
# Epoch: 027	Loss: 0.0390	Validation Loss: 0.0544
# Average positive percentile of 0.491
# AUPRC of 0.055
# AUROC of 0.418
#
# Fold 01
# Epoch: 000	Loss: 0.0783	Validation Loss: 0.0894
# Epoch: 028	Loss: 0.0479	Validation Loss: 0.0370
# Average positive percentile of 0.543
# AUPRC of 0.048
# AUROC of 0.525
#
# Fold 02
# Epoch: 000	Loss: 0.0762	Validation Loss: 0.0967
# Epoch: 021	Loss: 0.0370	Validation Loss: 0.0673
# Average positive percentile of 0.500
# AUPRC of 0.077
# AUROC of 0.463
#
# Fold 03
# Epoch: 000	Loss: 0.0802	Validation Loss: 0.0690
# Epoch: 030	Loss: 0.0471	Validation Loss: 0.0280
# Average positive percentile of 0.461
# AUPRC of 0.030
# AUROC of 0.544
#
# Fold 04
# Epoch: 000	Loss: 0.0797	Validation Loss: 0.0713
# Epoch: 028	Loss: 0.0472	Validation Loss: 0.0277
# Average positive percentile of 0.487
# AUPRC of 0.044
# AUROC of 0.573
#
#
#
# c02x_AD_EN_L3_5_IT_3_regulon_list.csv - AD - EN_L3_5_IT_3
# Replication 00
# Fold 00
# Epoch: 000	Loss: 0.0753	Validation Loss: 0.0894
# Epoch: 028	Loss: 0.0349	Validation Loss: 0.0561
# Average positive percentile of 0.443
# AUPRC of 0.065
# AUROC of 0.507
#
# Fold 01
# Epoch: 000	Loss: 0.0795	Validation Loss: 0.0835
# Epoch: 028	Loss: 0.0437	Validation Loss: 0.0356
# Average positive percentile of 0.500
# AUPRC of 0.041
# AUROC of 0.442
#
# Fold 02
# Epoch: 000	Loss: 0.0715	Validation Loss: 0.0972
# Epoch: 022	Loss: 0.0331	Validation Loss: 0.0605
# Average positive percentile of 0.483
# AUPRC of 0.067
# AUROC of 0.485
#
# Fold 03
# Epoch: 000	Loss: 0.0749	Validation Loss: 0.0705
# Epoch: 029	Loss: 0.0404	Validation Loss: 0.0333
# Average positive percentile of 0.602
# AUPRC of 0.044
# AUROC of 0.546
#
# Fold 04
# Epoch: 000	Loss: 0.0807	Validation Loss: 0.0724
# Epoch: 029	Loss: 0.0510	Validation Loss: 0.0229
# Average positive percentile of 0.401
# AUPRC of 0.030
# AUROC of 0.449
#
#
# Replication 01
# Fold 00
# Epoch: 000	Loss: 0.0792	Validation Loss: 0.0867
# Epoch: 029	Loss: 0.0410	Validation Loss: 0.0561
# Average positive percentile of 0.510
# AUPRC of 0.052
# AUROC of 0.436
#
# Fold 01
# Epoch: 000	Loss: 0.0793	Validation Loss: 0.0745
# Epoch: 030	Loss: 0.0406	Validation Loss: 0.0359
# Average positive percentile of 0.533
# AUPRC of 0.033
# AUROC of 0.358
#
# Fold 02
# Epoch: 000	Loss: 0.0809	Validation Loss: 0.0975
# Epoch: 022	Loss: 0.0329	Validation Loss: 0.0604
# Average positive percentile of 0.563
# AUPRC of 0.061
# AUROC of 0.476
#
# Fold 03
# Epoch: 000	Loss: 0.0788	Validation Loss: 0.0728
# Epoch: 030	Loss: 0.0462	Validation Loss: 0.0329
# Average positive percentile of 0.632
# AUPRC of 0.071
# AUROC of 0.675
#
# Fold 04
# Epoch: 000	Loss: 0.0820	Validation Loss: 0.0603
# Epoch: 027	Loss: 0.0416	Validation Loss: 0.0232
# Average positive percentile of 0.340
# AUPRC of 0.027
# AUROC of 0.464
#
#
# Replication 02
# Fold 00
# Epoch: 000	Loss: 0.0758	Validation Loss: 0.0870
# Epoch: 028	Loss: 0.0344	Validation Loss: 0.0566
# Average positive percentile of 0.408
# AUPRC of 0.063
# AUROC of 0.505
#
# Fold 01
# Epoch: 000	Loss: 0.0760	Validation Loss: 0.0694
# Epoch: 028	Loss: 0.0469	Validation Loss: 0.0359
# Average positive percentile of 0.545
# AUPRC of 0.050
# AUROC of 0.576
#
# Fold 02
# Epoch: 000	Loss: 0.0829	Validation Loss: 0.1125
# Epoch: 022	Loss: 0.0427	Validation Loss: 0.0605
# Average positive percentile of 0.500
# AUPRC of 0.058
# AUROC of 0.454
#
# Fold 03
# Epoch: 000	Loss: 0.0891	Validation Loss: 0.0780
# Epoch: 029	Loss: 0.0482	Validation Loss: 0.0330
# Average positive percentile of 0.597
# AUPRC of 0.052
# AUROC of 0.552
#
# Fold 04
# Epoch: 000	Loss: 0.0792	Validation Loss: 0.0634
# Epoch: 028	Loss: 0.0453	Validation Loss: 0.0227
# Average positive percentile of 0.576
# AUPRC of 0.028
# AUROC of 0.574
#
#
#
# c02x_AD_EN_L5_ET_regulon_list.csv - AD - EN_L5_ET
# Replication 00
# Fold 00
# Epoch: 000	Loss: 0.0733	Validation Loss: 0.0872
# Epoch: 031	Loss: 0.0327	Validation Loss: 0.0487
# Average positive percentile of 0.530
# AUPRC of 0.091
# AUROC of 0.511
#
# Fold 01
# Epoch: 000	Loss: 0.0834	Validation Loss: 0.0867
# Epoch: 029	Loss: 0.0367	Validation Loss: 0.0402
# Average positive percentile of 0.545
# AUPRC of 0.043
# AUROC of 0.524
#
# Fold 02
# Epoch: 000	Loss: 0.0877	Validation Loss: 0.1024
# Epoch: 029	Loss: 0.0331	Validation Loss: 0.0504
# Average positive percentile of 0.549
# AUPRC of 0.090
# AUROC of 0.606
#
# Fold 03
# Epoch: 000	Loss: 0.0848	Validation Loss: 0.0684
# Epoch: 031	Loss: 0.0439	Validation Loss: 0.0208
# Average positive percentile of 0.565
# AUPRC of 0.020
# AUROC of 0.499
#
# Fold 04
# Epoch: 000	Loss: 0.0795	Validation Loss: 0.0644
# Epoch: 030	Loss: 0.0472	Validation Loss: 0.0244
# Average positive percentile of 0.393
# AUPRC of 0.026
# AUROC of 0.497
#
#
# Replication 01
# Fold 00
# Epoch: 000	Loss: 0.0796	Validation Loss: 0.0853
# Epoch: 030	Loss: 0.0352	Validation Loss: 0.0490
# Average positive percentile of 0.432
# AUPRC of 0.059
# AUROC of 0.515
#
# Fold 01
# Epoch: 000	Loss: 0.0775	Validation Loss: 0.0815
# Epoch: 030	Loss: 0.0368	Validation Loss: 0.0406
# Average positive percentile of 0.459
# AUPRC of 0.077
# AUROC of 0.605
#
# Fold 02
# Epoch: 000	Loss: 0.0786	Validation Loss: 0.0878
# Epoch: 030	Loss: 0.0363	Validation Loss: 0.0505
# Average positive percentile of 0.471
# AUPRC of 0.044
# AUROC of 0.407
#
# Fold 03
# Epoch: 000	Loss: 0.0854	Validation Loss: 0.0740
# Epoch: 031	Loss: 0.0430	Validation Loss: 0.0209
# Average positive percentile of 0.722
# AUPRC of 0.021
# AUROC of 0.510
#
# Fold 04
# Epoch: 000	Loss: 0.0853	Validation Loss: 0.0758
# Epoch: 030	Loss: 0.0403	Validation Loss: 0.0239
# Average positive percentile of 0.521
# AUPRC of 0.017
# AUROC of 0.340
#
#
# Replication 02
# Fold 00
# Epoch: 000	Loss: 0.0809	Validation Loss: 0.0849
# Epoch: 030	Loss: 0.0331	Validation Loss: 0.0489
# Average positive percentile of 0.475
# AUPRC of 0.053
# AUROC of 0.524
#
# Fold 01
# Epoch: 000	Loss: 0.0884	Validation Loss: 0.0953
# Epoch: 029	Loss: 0.0330	Validation Loss: 0.0403
# Average positive percentile of 0.495
# AUPRC of 0.033
# AUROC of 0.368
#
# Fold 02
# Epoch: 000	Loss: 0.0786	Validation Loss: 0.0841
# Epoch: 030	Loss: 0.0321	Validation Loss: 0.0508
# Average positive percentile of 0.366
# AUPRC of 0.088
# AUROC of 0.499
#
# Fold 03
# Epoch: 000	Loss: 0.0848	Validation Loss: 0.0663
# Epoch: 032	Loss: 0.0489	Validation Loss: 0.0209
# Average positive percentile of 0.589
# AUPRC of 0.020
# AUROC of 0.500
#
# Fold 04
# Epoch: 000	Loss: 0.0810	Validation Loss: 0.0668
# Epoch: 030	Loss: 0.0443	Validation Loss: 0.0242
# Average positive percentile of 0.434
# AUPRC of 0.019
# AUROC of 0.380
#
#
#
# c02x_AD_EN_L6B_regulon_list.csv - AD - EN_L6B
# Replication 00
# Fold 00
# Epoch: 000	Loss: 0.0766	Validation Loss: 0.0820
# Epoch: 022	Loss: 0.0412	Validation Loss: 0.0500
# Average positive percentile of 0.517
# AUPRC of 0.087
# AUROC of 0.643
#
# Fold 01
# Epoch: 000	Loss: 0.0877	Validation Loss: 0.0866
# Epoch: 028	Loss: 0.0401	Validation Loss: 0.0367
# Average positive percentile of 0.541
# AUPRC of 0.088
# AUROC of 0.453
#
# Fold 02
# Epoch: 000	Loss: 0.0747	Validation Loss: 0.0968
# Epoch: 027	Loss: 0.0330	Validation Loss: 0.0653
# Average positive percentile of 0.530
# AUPRC of 0.112
# AUROC of 0.473
#
# Fold 03
# Epoch: 000	Loss: 0.0870	Validation Loss: 0.0648
# Epoch: 029	Loss: 0.0444	Validation Loss: 0.0252
# Average positive percentile of 0.445
# AUPRC of 0.023
# AUROC of 0.468
#
# Fold 04
# Epoch: 000	Loss: 0.0812	Validation Loss: 0.0750
# Epoch: 030	Loss: 0.0438	Validation Loss: 0.0295
# Average positive percentile of 0.489
# AUPRC of 0.031
# AUROC of 0.427
#
#
# Replication 01
# Fold 00
# Epoch: 000	Loss: 0.0825	Validation Loss: 0.0906
# Epoch: 029	Loss: 0.0392	Validation Loss: 0.0505
# Average positive percentile of 0.534
# AUPRC of 0.087
# AUROC of 0.624
#
# Fold 01
# Epoch: 000	Loss: 0.0836	Validation Loss: 0.0836
# Epoch: 028	Loss: 0.0431	Validation Loss: 0.0369
# Average positive percentile of 0.368
# AUPRC of 0.033
# AUROC of 0.450
#
# Fold 02
# Epoch: 000	Loss: 0.0733	Validation Loss: 0.0968
# Epoch: 028	Loss: 0.0307	Validation Loss: 0.0654
# Average positive percentile of 0.512
# AUPRC of 0.092
# AUROC of 0.495
#
# Fold 03
# Epoch: 000	Loss: 0.0798	Validation Loss: 0.0655
# Epoch: 029	Loss: 0.0471	Validation Loss: 0.0254
# Average positive percentile of 0.605
# AUPRC of 0.040
# AUROC of 0.469
#
# Fold 04
# Epoch: 000	Loss: 0.0928	Validation Loss: 0.0781
# Epoch: 029	Loss: 0.0478	Validation Loss: 0.0298
# Average positive percentile of 0.471
# AUPRC of 0.032
# AUROC of 0.520
#
#
# Replication 02
# Fold 00
# Epoch: 000	Loss: 0.0711	Validation Loss: 0.0821
# Epoch: 028	Loss: 0.0411	Validation Loss: 0.0501
# Average positive percentile of 0.488
# AUPRC of 0.043
# AUROC of 0.400
#
# Fold 01
# Epoch: 000	Loss: 0.0832	Validation Loss: 0.0736
# Epoch: 029	Loss: 0.0567	Validation Loss: 0.0376
# Average positive percentile of 0.415
# AUPRC of 0.039
# AUROC of 0.478
#
# Fold 02
# Epoch: 000	Loss: 0.0742	Validation Loss: 0.0949
# Epoch: 028	Loss: 0.0435	Validation Loss: 0.0654
# Average positive percentile of 0.476
# AUPRC of 0.067
# AUROC of 0.466
#
# Fold 03
# Epoch: 000	Loss: 0.0803	Validation Loss: 0.0633
# Epoch: 029	Loss: 0.0484	Validation Loss: 0.0253
# Average positive percentile of 0.606
# AUPRC of 0.025
# AUROC of 0.469
#
# Fold 04
# Epoch: 000	Loss: 0.0798	Validation Loss: 0.0747
# Epoch: 028	Loss: 0.0506	Validation Loss: 0.0295
# Average positive percentile of 0.571
# AUPRC of 0.036
# AUROC of 0.519
#
#
#
# c02x_AD_EN_L6_CT_regulon_list.csv - AD - EN_L6_CT
# Replication 00
# Fold 00
# Epoch: 000	Loss: 0.0847	Validation Loss: 0.0848
# Epoch: 029	Loss: 0.0385	Validation Loss: 0.0558
# Average positive percentile of 0.392
# AUPRC of 0.060
# AUROC of 0.466
#
# Fold 01
# Epoch: 000	Loss: 0.0846	Validation Loss: 0.0777
# Epoch: 028	Loss: 0.0438	Validation Loss: 0.0349
# Average positive percentile of 0.447
# AUPRC of 0.036
# AUROC of 0.469
#
# Fold 02
# Epoch: 000	Loss: 0.0785	Validation Loss: 0.1171
# Epoch: 022	Loss: 0.0345	Validation Loss: 0.0659
# Average positive percentile of 0.514
# AUPRC of 0.077
# AUROC of 0.523
#
# Fold 03
# Epoch: 000	Loss: 0.0832	Validation Loss: 0.0678
# Epoch: 029	Loss: 0.0414	Validation Loss: 0.0278
# Average positive percentile of 0.631
# AUPRC of 0.049
# AUROC of 0.598
#
# Fold 04
# Epoch: 000	Loss: 0.0826	Validation Loss: 0.0679
# Epoch: 030	Loss: 0.0407	Validation Loss: 0.0284
# Average positive percentile of 0.521
# AUPRC of 0.027
# AUROC of 0.498
#
#
# Replication 01
# Fold 00
# Epoch: 000	Loss: 0.0800	Validation Loss: 0.0871
# Epoch: 028	Loss: 0.0401	Validation Loss: 0.0556
# Average positive percentile of 0.468
# AUPRC of 0.088
# AUROC of 0.478
#
# Fold 01
# Epoch: 000	Loss: 0.0853	Validation Loss: 0.0705
# Epoch: 028	Loss: 0.0460	Validation Loss: 0.0352
# Average positive percentile of 0.556
# AUPRC of 0.034
# AUROC of 0.458
#
# Fold 02
# Epoch: 000	Loss: 0.0765	Validation Loss: 0.1045
# Epoch: 021	Loss: 0.0353	Validation Loss: 0.0657
# Average positive percentile of 0.530
# AUPRC of 0.092
# AUROC of 0.566
#
# Fold 03
# Epoch: 000	Loss: 0.0816	Validation Loss: 0.0687
# Epoch: 028	Loss: 0.0458	Validation Loss: 0.0274
# Average positive percentile of 0.458
# AUPRC of 0.032
# AUROC of 0.527
#
# Fold 04
# Epoch: 000	Loss: 0.0858	Validation Loss: 0.0735
# Epoch: 029	Loss: 0.0492	Validation Loss: 0.0277
# Average positive percentile of 0.500
# AUPRC of 0.025
# AUROC of 0.412
#
#
# Replication 02
# Fold 00
# Epoch: 000	Loss: 0.0855	Validation Loss: 0.0875
# Epoch: 027	Loss: 0.0371	Validation Loss: 0.0554
# Average positive percentile of 0.474
# AUPRC of 0.059
# AUROC of 0.426
#
# Fold 01
# Epoch: 000	Loss: 0.0825	Validation Loss: 0.0778
# Epoch: 028	Loss: 0.0443	Validation Loss: 0.0349
# Average positive percentile of 0.497
# AUPRC of 0.029
# AUROC of 0.395
#
# Fold 02
# Epoch: 000	Loss: 0.0808	Validation Loss: 0.0960
# Epoch: 021	Loss: 0.0441	Validation Loss: 0.0658
# Average positive percentile of 0.488
# AUPRC of 0.067
# AUROC of 0.429
#
# Fold 03
# Epoch: 000	Loss: 0.0797	Validation Loss: 0.0716
# Epoch: 028	Loss: 0.0537	Validation Loss: 0.0275
# Average positive percentile of 0.609
# AUPRC of 0.030
# AUROC of 0.498
#
# Fold 04
# Epoch: 000	Loss: 0.0783	Validation Loss: 0.0681
# Epoch: 030	Loss: 0.0431	Validation Loss: 0.0277
# Average positive percentile of 0.487
# AUPRC of 0.030
# AUROC of 0.469
#
#
#
# c02x_AD_EN_L6_IT_1_regulon_list.csv - AD - EN_L6_IT_1
# Replication 00
# Fold 00
# Epoch: 000	Loss: 0.0837	Validation Loss: 0.0836
# Epoch: 028	Loss: 0.0444	Validation Loss: 0.0501
# Average positive percentile of 0.488
# AUPRC of 0.050
# AUROC of 0.419
#
# Fold 01
# Epoch: 000	Loss: 0.0749	Validation Loss: 0.0734
# Epoch: 028	Loss: 0.0428	Validation Loss: 0.0372
# Average positive percentile of 0.439
# AUPRC of 0.058
# AUROC of 0.481
#
# Fold 02
# Epoch: 000	Loss: 0.0754	Validation Loss: 0.0935
# Epoch: 022	Loss: 0.0371	Validation Loss: 0.0646
# Average positive percentile of 0.511
# AUPRC of 0.079
# AUROC of 0.509
#
# Fold 03
# Epoch: 000	Loss: 0.0803	Validation Loss: 0.0718
# Epoch: 029	Loss: 0.0388	Validation Loss: 0.0286
# Average positive percentile of 0.463
# AUPRC of 0.024
# AUROC of 0.382
#
# Fold 04
# Epoch: 000	Loss: 0.0857	Validation Loss: 0.0782
# Epoch: 029	Loss: 0.0453	Validation Loss: 0.0242
# Average positive percentile of 0.651
# AUPRC of 0.019
# AUROC of 0.401
#
#
# Replication 01
# Fold 00
# Epoch: 000	Loss: 0.0735	Validation Loss: 0.0850
# Epoch: 028	Loss: 0.0387	Validation Loss: 0.0501
# Average positive percentile of 0.545
# AUPRC of 0.053
# AUROC of 0.460
#
# Fold 01
# Epoch: 000	Loss: 0.0740	Validation Loss: 0.0740
# Epoch: 028	Loss: 0.0422	Validation Loss: 0.0371
# Average positive percentile of 0.495
# AUPRC of 0.038
# AUROC of 0.490
#
# Fold 02
# Epoch: 000	Loss: 0.0753	Validation Loss: 0.1030
# Epoch: 021	Loss: 0.0314	Validation Loss: 0.0644
# Average positive percentile of 0.650
# AUPRC of 0.074
# AUROC of 0.533
#
# Fold 03
# Epoch: 000	Loss: 0.0813	Validation Loss: 0.0708
# Epoch: 028	Loss: 0.0449	Validation Loss: 0.0288
# Average positive percentile of 0.522
# AUPRC of 0.021
# AUROC of 0.320
#
# Fold 04
# Epoch: 000	Loss: 0.0916	Validation Loss: 0.0798
# Epoch: 029	Loss: 0.0423	Validation Loss: 0.0250
# Average positive percentile of 0.528
# AUPRC of 0.025
# AUROC of 0.424
#
#
# Replication 02
# Fold 00
# Epoch: 000	Loss: 0.0724	Validation Loss: 0.0802
# Epoch: 030	Loss: 0.0437	Validation Loss: 0.0502
# Average positive percentile of 0.471
# AUPRC of 0.053
# AUROC of 0.507
#
# Fold 01
# Epoch: 000	Loss: 0.0866	Validation Loss: 0.0786
# Epoch: 029	Loss: 0.0418	Validation Loss: 0.0378
# Average positive percentile of 0.479
# AUPRC of 0.032
# AUROC of 0.434
#
# Fold 02
# Epoch: 000	Loss: 0.0740	Validation Loss: 0.0977
# Epoch: 022	Loss: 0.0307	Validation Loss: 0.0646
# Average positive percentile of 0.502
# AUPRC of 0.081
# AUROC of 0.533
#
# Fold 03
# Epoch: 000	Loss: 0.0880	Validation Loss: 0.0789
# Epoch: 028	Loss: 0.0434	Validation Loss: 0.0288
# Average positive percentile of 0.543
# AUPRC of 0.024
# AUROC of 0.417
#
# Fold 04
# Epoch: 000	Loss: 0.0858	Validation Loss: 0.0684
# Epoch: 029	Loss: 0.0491	Validation Loss: 0.0245
# Average positive percentile of 0.505
# AUPRC of 0.038
# AUROC of 0.588
#
#
#
# c02x_AD_EN_L6_IT_2_regulon_list.csv - AD - EN_L6_IT_2
# Replication 00
# Fold 00
# Epoch: 000	Loss: 0.0786	Validation Loss: 0.0875
# Epoch: 028	Loss: 0.0402	Validation Loss: 0.0543
# Average positive percentile of 0.457
# AUPRC of 0.070
# AUROC of 0.526
#
# Fold 01
# Epoch: 000	Loss: 0.0951	Validation Loss: 0.1024
# Epoch: 028	Loss: 0.0416	Validation Loss: 0.0366
# Average positive percentile of 0.544
# AUPRC of 0.062
# AUROC of 0.555
#
# Fold 02
# Epoch: 000	Loss: 0.0885	Validation Loss: 0.1146
# Epoch: 021	Loss: 0.0399	Validation Loss: 0.0648
# Average positive percentile of 0.464
# AUPRC of 0.077
# AUROC of 0.480
#
# Fold 03
# Epoch: 000	Loss: 0.0787	Validation Loss: 0.0664
# Epoch: 030	Loss: 0.0479	Validation Loss: 0.0283
# Average positive percentile of 0.553
# AUPRC of 0.022
# AUROC of 0.341
#
# Fold 04
# Epoch: 000	Loss: 0.0841	Validation Loss: 0.0671
# Epoch: 031	Loss: 0.0501	Validation Loss: 0.0280
# Average positive percentile of 0.488
# AUPRC of 0.053
# AUROC of 0.548
#
#
# Replication 01
# Fold 00
# Epoch: 000	Loss: 0.0748	Validation Loss: 0.0831
# Epoch: 029	Loss: 0.0412	Validation Loss: 0.0545
# Average positive percentile of 0.404
# AUPRC of 0.066
# AUROC of 0.518
#
# Fold 01
# Epoch: 000	Loss: 0.0784	Validation Loss: 0.0739
# Epoch: 029	Loss: 0.0406	Validation Loss: 0.0368
# Average positive percentile of 0.543
# AUPRC of 0.048
# AUROC of 0.480
#
# Fold 02
# Epoch: 000	Loss: 0.0761	Validation Loss: 0.0980
# Epoch: 029	Loss: 0.0400	Validation Loss: 0.0650
# Average positive percentile of 0.448
# AUPRC of 0.101
# AUROC of 0.579
#
# Fold 03
# Epoch: 000	Loss: 0.0846	Validation Loss: 0.0681
# Epoch: 029	Loss: 0.0502	Validation Loss: 0.0280
# Average positive percentile of 0.484
# AUPRC of 0.089
# AUROC of 0.516
#
# Fold 04
# Epoch: 000	Loss: 0.0865	Validation Loss: 0.0787
# Epoch: 028	Loss: 0.0478	Validation Loss: 0.0273
# Average positive percentile of 0.514
# AUPRC of 0.030
# AUROC of 0.426
#
#
# Replication 02
# Fold 00
# Epoch: 000	Loss: 0.0865	Validation Loss: 0.1006
# Epoch: 022	Loss: 0.0364	Validation Loss: 0.0541
# Average positive percentile of 0.557
# AUPRC of 0.108
# AUROC of 0.544
#
# Fold 01
# Epoch: 000	Loss: 0.0926	Validation Loss: 0.0972
# Epoch: 028	Loss: 0.0361	Validation Loss: 0.0365
# Average positive percentile of 0.412
# AUPRC of 0.074
# AUROC of 0.653
#
# Fold 02
# Epoch: 000	Loss: 0.0768	Validation Loss: 0.0935
# Epoch: 021	Loss: 0.0382	Validation Loss: 0.0648
# Average positive percentile of 0.420
# AUPRC of 0.061
# AUROC of 0.437
#
# Fold 03
# Epoch: 000	Loss: 0.0857	Validation Loss: 0.0671
# Epoch: 029	Loss: 0.0467	Validation Loss: 0.0278
# Average positive percentile of 0.496
# AUPRC of 0.024
# AUROC of 0.431
#
# Fold 04
# Epoch: 000	Loss: 0.0959	Validation Loss: 0.0831
# Epoch: 030	Loss: 0.0454	Validation Loss: 0.0278
# Average positive percentile of 0.585
# AUPRC of 0.020
# AUROC of 0.323
#
#
#
# c02x_AD_EN_NF_regulon_list.csv - AD - EN_NF
# Replication 00
# Fold 00
# Epoch: 000	Loss: 0.1554	Validation Loss: 0.1705
# Epoch: 045	Loss: 0.0529	Validation Loss: 0.0413
# Average positive percentile of 0.635
# AUPRC of 0.060
# AUROC of 0.611
#
# Fold 01
# Epoch: 000	Loss: 0.1434	Validation Loss: 0.1752
# Epoch: 024	Loss: 0.0319	Validation Loss: 0.0428
# Average positive percentile of 0.277
# AUPRC of 0.051
# AUROC of 0.531
#
# Fold 02
# Epoch: 000	Loss: 0.1571	Validation Loss: 0.1824
# Epoch: 026	Loss: 0.0453	Validation Loss: 0.0521
# Average positive percentile of 0.290
# AUPRC of 0.072
# AUROC of 0.547
#
# Fold 03
# Epoch: 000	Loss: 0.1525	Validation Loss: 0.1813
# Epoch: 027	Loss: 0.0401	Validation Loss: 0.0275
# Average positive percentile of 0.575
# AUPRC of 0.027
# AUROC of 0.444
#
# Fold 04
# Epoch: 000	Loss: 0.1448	Validation Loss: 0.1646
# Epoch: 023	Loss: 0.0491	Validation Loss: 0.0657
# Average positive percentile of 0.403
# AUPRC of 0.081
# AUROC of 0.564
#
#
# Replication 01
# Fold 00
# Epoch: 000	Loss: 0.1617	Validation Loss: 0.1749
# Epoch: 047	Loss: 0.0503	Validation Loss: 0.0414
# Average positive percentile of 0.632
# AUPRC of 0.110
# AUROC of 0.663
#
# Fold 01
# Epoch: 000	Loss: 0.1689	Validation Loss: 0.1775
# Epoch: 045	Loss: 0.0489	Validation Loss: 0.0415
# Average positive percentile of 0.692
# AUPRC of 0.053
# AUROC of 0.531
#
# Fold 02
# Epoch: 000	Loss: 0.1638	Validation Loss: 0.1624
# Epoch: 035	Loss: 0.0478	Validation Loss: 0.0513
# Average positive percentile of 0.497
# AUPRC of 0.052
# AUROC of 0.452
#
# Fold 03
# Epoch: 000	Loss: 0.1567	Validation Loss: 0.1736
# Epoch: 040	Loss: 0.0467	Validation Loss: 0.0274
# Average positive percentile of 0.679
# AUPRC of 0.064
# AUROC of 0.615
#
# Fold 04
# Epoch: 000	Loss: 0.1516	Validation Loss: 0.1830
# Epoch: 023	Loss: 0.0551	Validation Loss: 0.0644
# Average positive percentile of 0.633
# AUPRC of 0.123
# AUROC of 0.592
#
#
# Replication 02
# Fold 00
# Epoch: 000	Loss: 0.1533	Validation Loss: 0.1588
# Epoch: 052	Loss: 0.0556	Validation Loss: 0.0417
# Average positive percentile of 0.614
# AUPRC of 0.068
# AUROC of 0.603
#
# Fold 01
# Epoch: 000	Loss: 0.1513	Validation Loss: 0.1725
# Epoch: 045	Loss: 0.0498	Validation Loss: 0.0418
# Average positive percentile of 0.450
# AUPRC of 0.058
# AUROC of 0.560
#
# Fold 02
# Epoch: 000	Loss: 0.1617	Validation Loss: 0.1821
# Epoch: 024	Loss: 0.0403	Validation Loss: 0.0509
# Average positive percentile of 0.741
# AUPRC of 0.058
# AUROC of 0.449
#
# Fold 03
# Epoch: 000	Loss: 0.1608	Validation Loss: 0.1719
# Epoch: 027	Loss: 0.0506	Validation Loss: 0.0280
# Average positive percentile of 0.373
# AUPRC of 0.051
# AUROC of 0.455
#
# Fold 04
# Epoch: 000	Loss: 0.1667	Validation Loss: 0.1974
# Epoch: 023	Loss: 0.0435	Validation Loss: 0.0652
# Average positive percentile of 0.440
# AUPRC of 0.090
# AUROC of 0.507
#
#
#
# c02x_AD_Immune_regulon_list.csv - AD - Immune
# Replication 00
# Fold 00
# Epoch: 000	Loss: 0.0860	Validation Loss: 0.1026
# Epoch: 027	Loss: 0.0415	Validation Loss: 0.0557
# Average positive percentile of 0.406
# AUPRC of 0.058
# AUROC of 0.484
#
# Fold 01
# Epoch: 000	Loss: 0.0807	Validation Loss: 0.0761
# Epoch: 028	Loss: 0.0437	Validation Loss: 0.0410
# Average positive percentile of 0.495
# AUPRC of 0.077
# AUROC of 0.608
#
# Fold 02
# Epoch: 000	Loss: 0.0745	Validation Loss: 0.0905
# Epoch: 028	Loss: 0.0384	Validation Loss: 0.0570
# Average positive percentile of 0.498
# AUPRC of 0.050
# AUROC of 0.395
#
# Fold 03
# Epoch: 000	Loss: 0.0816	Validation Loss: 0.0730
# Epoch: 028	Loss: 0.0438	Validation Loss: 0.0327
# Average positive percentile of 0.501
# AUPRC of 0.037
# AUROC of 0.438
#
# Fold 04
# Epoch: 000	Loss: 0.0933	Validation Loss: 0.0778
# Epoch: 030	Loss: 0.0451	Validation Loss: 0.0266
# Average positive percentile of 0.511
# AUPRC of 0.021
# AUROC of 0.414
#
#
# Replication 01
# Fold 00
# Epoch: 000	Loss: 0.0717	Validation Loss: 0.0895
# Epoch: 028	Loss: 0.0360	Validation Loss: 0.0557
# Average positive percentile of 0.452
# AUPRC of 0.052
# AUROC of 0.435
#
# Fold 01
# Epoch: 000	Loss: 0.0844	Validation Loss: 0.0888
# Epoch: 030	Loss: 0.0382	Validation Loss: 0.0408
# Average positive percentile of 0.523
# AUPRC of 0.043
# AUROC of 0.507
#
# Fold 02
# Epoch: 000	Loss: 0.0886	Validation Loss: 0.1043
# Epoch: 028	Loss: 0.0439	Validation Loss: 0.0570
# Average positive percentile of 0.462
# AUPRC of 0.069
# AUROC of 0.466
#
# Fold 03
# Epoch: 000	Loss: 0.0863	Validation Loss: 0.0763
# Epoch: 029	Loss: 0.0470	Validation Loss: 0.0320
# Average positive percentile of 0.500
# AUPRC of 0.033
# AUROC of 0.481
#
# Fold 04
# Epoch: 000	Loss: 0.0734	Validation Loss: 0.0665
# Epoch: 028	Loss: 0.0513	Validation Loss: 0.0263
# Average positive percentile of 0.540
# AUPRC of 0.055
# AUROC of 0.700
#
#
# Replication 02
# Fold 00
# Epoch: 000	Loss: 0.0927	Validation Loss: 0.1056
# Epoch: 028	Loss: 0.0378	Validation Loss: 0.0557
# Average positive percentile of 0.449
# AUPRC of 0.072
# AUROC of 0.552
#
# Fold 01
# Epoch: 000	Loss: 0.0733	Validation Loss: 0.0761
# Epoch: 028	Loss: 0.0395	Validation Loss: 0.0408
# Average positive percentile of 0.537
# AUPRC of 0.040
# AUROC of 0.452
#
# Fold 02
# Epoch: 000	Loss: 0.0771	Validation Loss: 0.0984
# Epoch: 029	Loss: 0.0384	Validation Loss: 0.0572
# Average positive percentile of 0.474
# AUPRC of 0.083
# AUROC of 0.571
#
# Fold 03
# Epoch: 000	Loss: 0.0919	Validation Loss: 0.0806
# Epoch: 029	Loss: 0.0423	Validation Loss: 0.0323
# Average positive percentile of 0.402
# AUPRC of 0.031
# AUROC of 0.465
#
# Fold 04
# Epoch: 000	Loss: 0.0851	Validation Loss: 0.0642
# Epoch: 029	Loss: 0.0515	Validation Loss: 0.0264
# Average positive percentile of 0.572
# AUPRC of 0.026
# AUROC of 0.493
#
#
#
# c02x_AD_IN_LAMP5_LHX6_regulon_list.csv - AD - IN_LAMP5_LHX6
# Replication 00
# Fold 00
# Epoch: 000	Loss: 0.0796	Validation Loss: 0.0857
# Epoch: 028	Loss: 0.0382	Validation Loss: 0.0568
# Average positive percentile of 0.491
# AUPRC of 0.100
# AUROC of 0.493
#
# Fold 01
# Epoch: 000	Loss: 0.0871	Validation Loss: 0.0863
# Epoch: 030	Loss: 0.0546	Validation Loss: 0.0332
# Average positive percentile of 0.440
# AUPRC of 0.032
# AUROC of 0.485
#
# Fold 02
# Epoch: 000	Loss: 0.0782	Validation Loss: 0.0991
# Epoch: 022	Loss: 0.0314	Validation Loss: 0.0642
# Average positive percentile of 0.490
# AUPRC of 0.079
# AUROC of 0.519
#
# Fold 03
# Epoch: 000	Loss: 0.0803	Validation Loss: 0.0702
# Epoch: 029	Loss: 0.0435	Validation Loss: 0.0276
# Average positive percentile of 0.523
# AUPRC of 0.033
# AUROC of 0.564
#
# Fold 04
# Epoch: 000	Loss: 0.0929	Validation Loss: 0.0900
# Epoch: 030	Loss: 0.0488	Validation Loss: 0.0239
# Average positive percentile of 0.504
# AUPRC of 0.023
# AUROC of 0.495
#
#
# Replication 01
# Fold 00
# Epoch: 000	Loss: 0.0735	Validation Loss: 0.0872
# Epoch: 022	Loss: 0.0365	Validation Loss: 0.0566
# Average positive percentile of 0.549
# AUPRC of 0.055
# AUROC of 0.448
#
# Fold 01
# Epoch: 000	Loss: 0.0726	Validation Loss: 0.0684
# Epoch: 028	Loss: 0.0468	Validation Loss: 0.0332
# Average positive percentile of 0.577
# AUPRC of 0.090
# AUROC of 0.503
#
# Fold 02
# Epoch: 000	Loss: 0.0744	Validation Loss: 0.0936
# Epoch: 022	Loss: 0.0376	Validation Loss: 0.0642
# Average positive percentile of 0.529
# AUPRC of 0.063
# AUROC of 0.448
#
# Fold 03
# Epoch: 000	Loss: 0.0802	Validation Loss: 0.0670
# Epoch: 028	Loss: 0.0464	Validation Loss: 0.0282
# Average positive percentile of 0.505
# AUPRC of 0.034
# AUROC of 0.512
#
# Fold 04
# Epoch: 000	Loss: 0.0856	Validation Loss: 0.0600
# Epoch: 028	Loss: 0.0480	Validation Loss: 0.0233
# Average positive percentile of 0.318
# AUPRC of 0.042
# AUROC of 0.570
#
#
# Replication 02
# Fold 00
# Epoch: 000	Loss: 0.0697	Validation Loss: 0.0832
# Epoch: 028	Loss: 0.0467	Validation Loss: 0.0569
# Average positive percentile of 0.427
# AUPRC of 0.063
# AUROC of 0.489
#
# Fold 01
# Epoch: 000	Loss: 0.0822	Validation Loss: 0.0724
# Epoch: 028	Loss: 0.0374	Validation Loss: 0.0336
# Average positive percentile of 0.493
# AUPRC of 0.051
# AUROC of 0.595
#
# Fold 02
# Epoch: 000	Loss: 0.0744	Validation Loss: 0.0903
# Epoch: 023	Loss: 0.0406	Validation Loss: 0.0642
# Average positive percentile of 0.455
# AUPRC of 0.084
# AUROC of 0.477
#
# Fold 03
# Epoch: 000	Loss: 0.0878	Validation Loss: 0.0745
# Epoch: 029	Loss: 0.0469	Validation Loss: 0.0277
# Average positive percentile of 0.514
# AUPRC of 0.034
# AUROC of 0.520
#
# Fold 04
# Epoch: 000	Loss: 0.0786	Validation Loss: 0.0626
# Epoch: 029	Loss: 0.0474	Validation Loss: 0.0234
# Average positive percentile of 0.450
# AUPRC of 0.036
# AUROC of 0.540
#
#
#
# c02x_AD_IN_LAMP5_RELN_regulon_list.csv - AD - IN_LAMP5_RELN
# Replication 00
# Fold 00
# Epoch: 000	Loss: 0.0720	Validation Loss: 0.0842
# Epoch: 029	Loss: 0.0360	Validation Loss: 0.0562
# Average positive percentile of 0.412
# AUPRC of 0.048
# AUROC of 0.408
#
# Fold 01
# Epoch: 000	Loss: 0.0742	Validation Loss: 0.0731
# Epoch: 028	Loss: 0.0424	Validation Loss: 0.0353
# Average positive percentile of 0.535
# AUPRC of 0.048
# AUROC of 0.556
#
# Fold 02
# Epoch: 000	Loss: 0.0722	Validation Loss: 0.0944
# Epoch: 028	Loss: 0.0402	Validation Loss: 0.0623
# Average positive percentile of 0.477
# AUPRC of 0.085
# AUROC of 0.486
#
# Fold 03
# Epoch: 000	Loss: 0.0755	Validation Loss: 0.0704
# Epoch: 029	Loss: 0.0437	Validation Loss: 0.0298
# Average positive percentile of 0.549
# AUPRC of 0.031
# AUROC of 0.490
#
# Fold 04
# Epoch: 000	Loss: 0.0790	Validation Loss: 0.0658
# Epoch: 029	Loss: 0.0489	Validation Loss: 0.0238
# Average positive percentile of 0.473
# AUPRC of 0.023
# AUROC of 0.459
#
#
# Replication 01
# Fold 00
# Epoch: 000	Loss: 0.0780	Validation Loss: 0.0848
# Epoch: 029	Loss: 0.0362	Validation Loss: 0.0563
# Average positive percentile of 0.473
# AUPRC of 0.062
# AUROC of 0.475
#
# Fold 01
# Epoch: 000	Loss: 0.0780	Validation Loss: 0.0708
# Epoch: 029	Loss: 0.0432	Validation Loss: 0.0355
# Average positive percentile of 0.409
# AUPRC of 0.050
# AUROC of 0.482
#
# Fold 02
# Epoch: 000	Loss: 0.0758	Validation Loss: 0.0927
# Epoch: 028	Loss: 0.0346	Validation Loss: 0.0623
# Average positive percentile of 0.450
# AUPRC of 0.074
# AUROC of 0.544
#
# Fold 03
# Epoch: 000	Loss: 0.0810	Validation Loss: 0.0766
# Epoch: 029	Loss: 0.0444	Validation Loss: 0.0294
# Average positive percentile of 0.630
# AUPRC of 0.044
# AUROC of 0.518
#
# Fold 04
# Epoch: 000	Loss: 0.0841	Validation Loss: 0.0656
# Epoch: 029	Loss: 0.0530	Validation Loss: 0.0237
# Average positive percentile of 0.442
# AUPRC of 0.030
# AUROC of 0.553
#
#
# Replication 02
# Fold 00
# Epoch: 000	Loss: 0.0768	Validation Loss: 0.0863
# Epoch: 028	Loss: 0.0348	Validation Loss: 0.0562
# Average positive percentile of 0.539
# AUPRC of 0.065
# AUROC of 0.481
#
# Fold 01
# Epoch: 000	Loss: 0.0808	Validation Loss: 0.0693
# Epoch: 028	Loss: 0.0381	Validation Loss: 0.0356
# Average positive percentile of 0.590
# AUPRC of 0.041
# AUROC of 0.442
#
# Fold 02
# Epoch: 000	Loss: 0.0907	Validation Loss: 0.1261
# Epoch: 022	Loss: 0.0328	Validation Loss: 0.0623
# Average positive percentile of 0.497
# AUPRC of 0.100
# AUROC of 0.573
#
# Fold 03
# Epoch: 000	Loss: 0.0791	Validation Loss: 0.0701
# Epoch: 028	Loss: 0.0485	Validation Loss: 0.0295
# Average positive percentile of 0.558
# AUPRC of 0.025
# AUROC of 0.440
#
# Fold 04
# Epoch: 000	Loss: 0.0763	Validation Loss: 0.0616
# Epoch: 029	Loss: 0.0429	Validation Loss: 0.0237
# Average positive percentile of 0.412
# AUPRC of 0.024
# AUROC of 0.506
#
#
#
# c02x_AD_IN_PVALB_CHC_regulon_list.csv - AD - IN_PVALB_CHC
# Replication 00
# Fold 00
# Epoch: 000	Loss: 0.0763	Validation Loss: 0.0902
# Epoch: 031	Loss: 0.0411	Validation Loss: 0.0571
# Average positive percentile of 0.501
# AUPRC of 0.056
# AUROC of 0.393
#
# Fold 01
# Epoch: 000	Loss: 0.0937	Validation Loss: 0.0955
# Epoch: 029	Loss: 0.0428	Validation Loss: 0.0304
# Average positive percentile of 0.545
# AUPRC of 0.034
# AUROC of 0.416
#
# Fold 02
# Epoch: 000	Loss: 0.0772	Validation Loss: 0.1026
# Epoch: 029	Loss: 0.0414	Validation Loss: 0.0650
# Average positive percentile of 0.415
# AUPRC of 0.074
# AUROC of 0.530
#
# Fold 03
# Epoch: 000	Loss: 0.0804	Validation Loss: 0.0722
# Epoch: 029	Loss: 0.0490	Validation Loss: 0.0290
# Average positive percentile of 0.549
# AUPRC of 0.030
# AUROC of 0.502
#
# Fold 04
# Epoch: 000	Loss: 0.0776	Validation Loss: 0.0701
# Epoch: 030	Loss: 0.0424	Validation Loss: 0.0258
# Average positive percentile of 0.518
# AUPRC of 0.031
# AUROC of 0.525
#
#
# Replication 01
# Fold 00
# Epoch: 000	Loss: 0.0762	Validation Loss: 0.0881
# Epoch: 030	Loss: 0.0367	Validation Loss: 0.0571
# Average positive percentile of 0.462
# AUPRC of 0.067
# AUROC of 0.465
#
# Fold 01
# Epoch: 000	Loss: 0.0807	Validation Loss: 0.0699
# Epoch: 029	Loss: 0.0528	Validation Loss: 0.0305
# Average positive percentile of 0.515
# AUPRC of 0.032
# AUROC of 0.481
#
# Fold 02
# Epoch: 000	Loss: 0.0769	Validation Loss: 0.1014
# Epoch: 022	Loss: 0.0393	Validation Loss: 0.0644
# Average positive percentile of 0.577
# AUPRC of 0.064
# AUROC of 0.405
#
# Fold 03
# Epoch: 000	Loss: 0.0873	Validation Loss: 0.0750
# Epoch: 029	Loss: 0.0434	Validation Loss: 0.0290
# Average positive percentile of 0.561
# AUPRC of 0.025
# AUROC of 0.424
#
# Fold 04
# Epoch: 000	Loss: 0.0831	Validation Loss: 0.0694
# Epoch: 028	Loss: 0.0451	Validation Loss: 0.0259
# Average positive percentile of 0.612
# AUPRC of 0.030
# AUROC of 0.525
#
#
# Replication 02
# Fold 00
# Epoch: 000	Loss: 0.0729	Validation Loss: 0.0894
# Epoch: 030	Loss: 0.0399	Validation Loss: 0.0570
# Average positive percentile of 0.499
# AUPRC of 0.094
# AUROC of 0.607
#
# Fold 01
# Epoch: 000	Loss: 0.0791	Validation Loss: 0.0706
# Epoch: 029	Loss: 0.0434	Validation Loss: 0.0305
# Average positive percentile of 0.446
# AUPRC of 0.038
# AUROC of 0.564
#
# Fold 02
# Epoch: 000	Loss: 0.0754	Validation Loss: 0.0978
# Epoch: 030	Loss: 0.0305	Validation Loss: 0.0646
# Average positive percentile of 0.517
# AUPRC of 0.076
# AUROC of 0.519
#
# Fold 03
# Epoch: 000	Loss: 0.0858	Validation Loss: 0.0728
# Epoch: 028	Loss: 0.0438	Validation Loss: 0.0288
# Average positive percentile of 0.536
# AUPRC of 0.025
# AUROC of 0.418
#
# Fold 04
# Epoch: 000	Loss: 0.0827	Validation Loss: 0.0702
# Epoch: 030	Loss: 0.0467	Validation Loss: 0.0260
# Average positive percentile of 0.547
# AUPRC of 0.042
# AUROC of 0.657
#
#
#
# c02x_AD_IN_PVALB_regulon_list.csv - AD - IN_PVALB
# Replication 00
# Fold 00
# Epoch: 000	Loss: 0.0789	Validation Loss: 0.0841
# Epoch: 031	Loss: 0.0454	Validation Loss: 0.0557
# Average positive percentile of 0.544
# AUPRC of 0.058
# AUROC of 0.453
#
# Fold 01
# Epoch: 000	Loss: 0.0830	Validation Loss: 0.0782
# Epoch: 028	Loss: 0.0469	Validation Loss: 0.0376
# Average positive percentile of 0.465
# AUPRC of 0.068
# AUROC of 0.613
#
# Fold 02
# Epoch: 000	Loss: 0.0796	Validation Loss: 0.0990
# Epoch: 030	Loss: 0.0407	Validation Loss: 0.0604
# Average positive percentile of 0.492
# AUPRC of 0.086
# AUROC of 0.529
#
# Fold 03
# Epoch: 000	Loss: 0.0796	Validation Loss: 0.0716
# Epoch: 029	Loss: 0.0495	Validation Loss: 0.0302
# Average positive percentile of 0.539
# AUPRC of 0.049
# AUROC of 0.549
#
# Fold 04
# Epoch: 000	Loss: 0.0898	Validation Loss: 0.0748
# Epoch: 028	Loss: 0.0374	Validation Loss: 0.0271
# Average positive percentile of 0.578
# AUPRC of 0.023
# AUROC of 0.400
#
#
# Replication 01
# Fold 00
# Epoch: 000	Loss: 0.0778	Validation Loss: 0.0921
# Epoch: 029	Loss: 0.0362	Validation Loss: 0.0560
# Average positive percentile of 0.502
# AUPRC of 0.083
# AUROC of 0.572
#
# Fold 01
# Epoch: 000	Loss: 0.0765	Validation Loss: 0.0714
# Epoch: 028	Loss: 0.0455	Validation Loss: 0.0372
# Average positive percentile of 0.630
# AUPRC of 0.033
# AUROC of 0.418
#
# Fold 02
# Epoch: 000	Loss: 0.0735	Validation Loss: 0.0944
# Epoch: 029	Loss: 0.0373	Validation Loss: 0.0605
# Average positive percentile of 0.467
# AUPRC of 0.063
# AUROC of 0.481
#
# Fold 03
# Epoch: 000	Loss: 0.0836	Validation Loss: 0.0742
# Epoch: 030	Loss: 0.0435	Validation Loss: 0.0303
# Average positive percentile of 0.542
# AUPRC of 0.045
# AUROC of 0.455
#
# Fold 04
# Epoch: 000	Loss: 0.0761	Validation Loss: 0.0724
# Epoch: 028	Loss: 0.0404	Validation Loss: 0.0271
# Average positive percentile of 0.583
# AUPRC of 0.036
# AUROC of 0.557
#
#
# Replication 02
# Fold 00
# Epoch: 000	Loss: 0.0768	Validation Loss: 0.0836
# Epoch: 028	Loss: 0.0381	Validation Loss: 0.0557
# Average positive percentile of 0.574
# AUPRC of 0.057
# AUROC of 0.480
#
# Fold 01
# Epoch: 000	Loss: 0.0901	Validation Loss: 0.0815
# Epoch: 028	Loss: 0.0442	Validation Loss: 0.0369
# Average positive percentile of 0.518
# AUPRC of 0.053
# AUROC of 0.496
#
# Fold 02
# Epoch: 000	Loss: 0.0709	Validation Loss: 0.0902
# Epoch: 028	Loss: 0.0361	Validation Loss: 0.0603
# Average positive percentile of 0.468
# AUPRC of 0.059
# AUROC of 0.447
#
# Fold 03
# Epoch: 000	Loss: 0.0854	Validation Loss: 0.0681
# Epoch: 029	Loss: 0.0447	Validation Loss: 0.0302
# Average positive percentile of 0.405
# AUPRC of 0.035
# AUROC of 0.376
#
# Fold 04
# Epoch: 000	Loss: 0.0798	Validation Loss: 0.0674
# Epoch: 029	Loss: 0.0447	Validation Loss: 0.0273
# Average positive percentile of 0.512
# AUPRC of 0.030
# AUROC of 0.537
#
#
#
# c02x_AD_IN_SST_regulon_list.csv - AD - IN_SST
# Replication 00
# Fold 00
# Epoch: 000	Loss: 0.0718	Validation Loss: 0.0833
# Epoch: 028	Loss: 0.0395	Validation Loss: 0.0512
# Average positive percentile of 0.452
# AUPRC of 0.051
# AUROC of 0.433
#
# Fold 01
# Epoch: 000	Loss: 0.0794	Validation Loss: 0.0930
# Epoch: 028	Loss: 0.0411	Validation Loss: 0.0379
# Average positive percentile of 0.490
# AUPRC of 0.082
# AUROC of 0.454
#
# Fold 02
# Epoch: 000	Loss: 0.0825	Validation Loss: 0.1004
# Epoch: 021	Loss: 0.0361	Validation Loss: 0.0614
# Average positive percentile of 0.571
# AUPRC of 0.060
# AUROC of 0.406
#
# Fold 03
# Epoch: 000	Loss: 0.0971	Validation Loss: 0.0820
# Epoch: 030	Loss: 0.0399	Validation Loss: 0.0272
# Average positive percentile of 0.490
# AUPRC of 0.031
# AUROC of 0.513
#
# Fold 04
# Epoch: 000	Loss: 0.0795	Validation Loss: 0.0641
# Epoch: 029	Loss: 0.0444	Validation Loss: 0.0252
# Average positive percentile of 0.444
# AUPRC of 0.025
# AUROC of 0.514
#
#
# Replication 01
# Fold 00
# Epoch: 000	Loss: 0.0813	Validation Loss: 0.0816
# Epoch: 028	Loss: 0.0325	Validation Loss: 0.0513
# Average positive percentile of 0.460
# AUPRC of 0.048
# AUROC of 0.441
#
# Fold 01
# Epoch: 000	Loss: 0.0688	Validation Loss: 0.0715
# Epoch: 028	Loss: 0.0429	Validation Loss: 0.0380
# Average positive percentile of 0.437
# AUPRC of 0.065
# AUROC of 0.496
#
# Fold 02
# Epoch: 000	Loss: 0.0718	Validation Loss: 0.0867
# Epoch: 023	Loss: 0.0326	Validation Loss: 0.0616
# Average positive percentile of 0.449
# AUPRC of 0.073
# AUROC of 0.482
#
# Fold 03
# Epoch: 000	Loss: 0.0771	Validation Loss: 0.0633
# Epoch: 029	Loss: 0.0478	Validation Loss: 0.0265
# Average positive percentile of 0.540
# AUPRC of 0.023
# AUROC of 0.425
#
# Fold 04
# Epoch: 000	Loss: 0.0767	Validation Loss: 0.0667
# Epoch: 029	Loss: 0.0433	Validation Loss: 0.0249
# Average positive percentile of 0.641
# AUPRC of 0.023
# AUROC of 0.387
#
#
# Replication 02
# Fold 00
# Epoch: 000	Loss: 0.0794	Validation Loss: 0.0884
# Epoch: 028	Loss: 0.0363	Validation Loss: 0.0511
# Average positive percentile of 0.564
# AUPRC of 0.057
# AUROC of 0.523
#
# Fold 01
# Epoch: 000	Loss: 0.0906	Validation Loss: 0.0821
# Epoch: 028	Loss: 0.0403	Validation Loss: 0.0381
# Average positive percentile of 0.455
# AUPRC of 0.045
# AUROC of 0.533
#
# Fold 02
# Epoch: 000	Loss: 0.0725	Validation Loss: 0.0894
# Epoch: 029	Loss: 0.0356	Validation Loss: 0.0618
# Average positive percentile of 0.469
# AUPRC of 0.058
# AUROC of 0.471
#
# Fold 03
# Epoch: 000	Loss: 0.0866	Validation Loss: 0.0701
# Epoch: 030	Loss: 0.0468	Validation Loss: 0.0265
# Average positive percentile of 0.544
# AUPRC of 0.119
# AUROC of 0.613
#
# Fold 04
# Epoch: 000	Loss: 0.0921	Validation Loss: 0.0714
# Epoch: 029	Loss: 0.0474	Validation Loss: 0.0244
# Average positive percentile of 0.386
# AUPRC of 0.022
# AUROC of 0.446
#
#
#
# c02x_AD_IN_VIP_regulon_list.csv - AD - IN_VIP
# Replication 00
# Fold 00
# Epoch: 000	Loss: 0.0784	Validation Loss: 0.0799
# Epoch: 028	Loss: 0.0350	Validation Loss: 0.0496
# Average positive percentile of 0.454
# AUPRC of 0.059
# AUROC of 0.478
#
# Fold 01
# Epoch: 000	Loss: 0.0780	Validation Loss: 0.0743
# Epoch: 029	Loss: 0.0468	Validation Loss: 0.0381
# Average positive percentile of 0.442
# AUPRC of 0.047
# AUROC of 0.545
#
# Fold 02
# Epoch: 000	Loss: 0.0756	Validation Loss: 0.0932
# Epoch: 021	Loss: 0.0372	Validation Loss: 0.0671
# Average positive percentile of 0.525
# AUPRC of 0.082
# AUROC of 0.534
#
# Fold 03
# Epoch: 000	Loss: 0.0781	Validation Loss: 0.0662
# Epoch: 028	Loss: 0.0474	Validation Loss: 0.0266
# Average positive percentile of 0.496
# AUPRC of 0.022
# AUROC of 0.425
#
# Fold 04
# Epoch: 000	Loss: 0.0785	Validation Loss: 0.0718
# Epoch: 029	Loss: 0.0467	Validation Loss: 0.0292
# Average positive percentile of 0.581
# AUPRC of 0.033
# AUROC of 0.503
#
#
# Replication 01
# Fold 00
# Epoch: 000	Loss: 0.0764	Validation Loss: 0.0799
# Epoch: 028	Loss: 0.0398	Validation Loss: 0.0494
# Average positive percentile of 0.470
# AUPRC of 0.063
# AUROC of 0.484
#
# Fold 01
# Epoch: 000	Loss: 0.0981	Validation Loss: 0.1029
# Epoch: 030	Loss: 0.0435	Validation Loss: 0.0384
# Average positive percentile of 0.492
# AUPRC of 0.038
# AUROC of 0.451
#
# Fold 02
# Epoch: 000	Loss: 0.0770	Validation Loss: 0.0973
# Epoch: 030	Loss: 0.0277	Validation Loss: 0.0673
# Average positive percentile of 0.447
# AUPRC of 0.080
# AUROC of 0.493
#
# Fold 03
# Epoch: 000	Loss: 0.0937	Validation Loss: 0.0826
# Epoch: 028	Loss: 0.0497	Validation Loss: 0.0262
# Average positive percentile of 0.446
# AUPRC of 0.043
# AUROC of 0.404
#
# Fold 04
# Epoch: 000	Loss: 0.0843	Validation Loss: 0.0694
# Epoch: 029	Loss: 0.0490	Validation Loss: 0.0291
# Average positive percentile of 0.392
# AUPRC of 0.061
# AUROC of 0.601
#
#
# Replication 02
# Fold 00
# Epoch: 000	Loss: 0.0774	Validation Loss: 0.0838
# Epoch: 028	Loss: 0.0425	Validation Loss: 0.0494
# Average positive percentile of 0.537
# AUPRC of 0.116
# AUROC of 0.558
#
# Fold 01
# Epoch: 000	Loss: 0.0802	Validation Loss: 0.0807
# Epoch: 028	Loss: 0.0395	Validation Loss: 0.0378
# Average positive percentile of 0.446
# AUPRC of 0.060
# AUROC of 0.476
#
# Fold 02
# Epoch: 000	Loss: 0.0688	Validation Loss: 0.1022
# Epoch: 021	Loss: 0.0352	Validation Loss: 0.0671
# Average positive percentile of 0.512
# AUPRC of 0.070
# AUROC of 0.472
#
# Fold 03
# Epoch: 000	Loss: 0.0822	Validation Loss: 0.0624
# Epoch: 028	Loss: 0.0418	Validation Loss: 0.0264
# Average positive percentile of 0.400
# AUPRC of 0.026
# AUROC of 0.462
#
# Fold 04
# Epoch: 000	Loss: 0.0763	Validation Loss: 0.0662
# Epoch: 027	Loss: 0.0497	Validation Loss: 0.0292
# Average positive percentile of 0.511
# AUPRC of 0.026
# AUROC of 0.426
#
#
#
# c02x_AD_Micro_regulon_list.csv - AD - Micro
# Replication 00
# Fold 00
# Epoch: 000	Loss: 0.0730	Validation Loss: 0.0878
# Epoch: 027	Loss: 0.0368	Validation Loss: 0.0536
# Average positive percentile of 0.522
# AUPRC of 0.061
# AUROC of 0.430
#
# Fold 01
# Epoch: 000	Loss: 0.0842	Validation Loss: 0.0918
# Epoch: 028	Loss: 0.0404	Validation Loss: 0.0384
# Average positive percentile of 0.582
# AUPRC of 0.056
# AUROC of 0.636
#
# Fold 02
# Epoch: 000	Loss: 0.0766	Validation Loss: 0.1087
# Epoch: 021	Loss: 0.0326	Validation Loss: 0.0666
# Average positive percentile of 0.432
# AUPRC of 0.094
# AUROC of 0.481
#
# Fold 03
# Epoch: 000	Loss: 0.0806	Validation Loss: 0.0725
# Epoch: 029	Loss: 0.0465	Validation Loss: 0.0265
# Average positive percentile of 0.455
# AUPRC of 0.036
# AUROC of 0.462
#
# Fold 04
# Epoch: 000	Loss: 0.0941	Validation Loss: 0.1029
# Epoch: 030	Loss: 0.0537	Validation Loss: 0.0320
# Average positive percentile of 0.597
# AUPRC of 0.027
# AUROC of 0.484
#
#
# Replication 01
# Fold 00
# Epoch: 000	Loss: 0.0716	Validation Loss: 0.0910
# Epoch: 028	Loss: 0.0456	Validation Loss: 0.0536
# Average positive percentile of 0.546
# AUPRC of 0.075
# AUROC of 0.580
#
# Fold 01
# Epoch: 000	Loss: 0.0716	Validation Loss: 0.0750
# Epoch: 028	Loss: 0.0427	Validation Loss: 0.0385
# Average positive percentile of 0.499
# AUPRC of 0.035
# AUROC of 0.452
#
# Fold 02
# Epoch: 000	Loss: 0.0740	Validation Loss: 0.0963
# Epoch: 029	Loss: 0.0390	Validation Loss: 0.0667
# Average positive percentile of 0.452
# AUPRC of 0.073
# AUROC of 0.495
#
# Fold 03
# Epoch: 000	Loss: 0.0724	Validation Loss: 0.0641
# Epoch: 028	Loss: 0.0447	Validation Loss: 0.0264
# Average positive percentile of 0.479
# AUPRC of 0.020
# AUROC of 0.385
#
# Fold 04
# Epoch: 000	Loss: 0.0815	Validation Loss: 0.0703
# Epoch: 028	Loss: 0.0444	Validation Loss: 0.0264
# Average positive percentile of 0.443
# AUPRC of 0.051
# AUROC of 0.579
#
#
# Replication 02
# Fold 00
# Epoch: 000	Loss: 0.0727	Validation Loss: 0.0802
# Epoch: 029	Loss: 0.0400	Validation Loss: 0.0537
# Average positive percentile of 0.551
# AUPRC of 0.062
# AUROC of 0.511
#
# Fold 01
# Epoch: 000	Loss: 0.0832	Validation Loss: 0.0872
# Epoch: 028	Loss: 0.0466	Validation Loss: 0.0391
# Average positive percentile of 0.545
# AUPRC of 0.053
# AUROC of 0.541
#
# Fold 02
# Epoch: 000	Loss: 0.0746	Validation Loss: 0.1038
# Epoch: 027	Loss: 0.0327	Validation Loss: 0.0666
# Average positive percentile of 0.477
# AUPRC of 0.076
# AUROC of 0.481
#
# Fold 03
# Epoch: 000	Loss: 0.0811	Validation Loss: 0.0652
# Epoch: 028	Loss: 0.0525	Validation Loss: 0.0263
# ...
# Epoch: 038	Loss: 0.0465	Validation Loss: 0.0565
# Average positive percentile of 0.393
# AUPRC of 0.071
# AUROC of 0.492
#
# Fold 01
# Epoch: 000	Loss: 0.1202	Validation Loss: 0.1277
# Epoch: 038	Loss: 0.0417	Validation Loss: 0.0502
# Average positive percentile of 0.561
# AUPRC of 0.065
# AUROC of 0.547
#
# Fold 02
# Epoch: 000	Loss: 0.1212	Validation Loss: 0.1198
# Epoch: 039	Loss: 0.0497	Validation Loss: 0.0384
# Average positive percentile of 0.417
# AUPRC of 0.039
# AUROC of 0.472
#
# Fold 03
# Epoch: 000	Loss: 0.1095	Validation Loss: 0.1122
# Epoch: 038	Loss: 0.0412	Validation Loss: 0.0321
# Average positive percentile of 0.505
# AUPRC of 0.032
# AUROC of 0.450
#
# Fold 04
# Epoch: 000	Loss: 0.1133	Validation Loss: 0.1213
# Epoch: 038	Loss: 0.0424	Validation Loss: 0.0412
# Average positive percentile of 0.622
# AUPRC of 0.035
# AUROC of 0.363
#
#
# Replication 02
# Fold 00
# Epoch: 000	Loss: 0.1200	Validation Loss: 0.1244
# Epoch: 022	Loss: 0.0427	Validation Loss: 0.0559
# Average positive percentile of 0.605
# AUPRC of 0.151
# AUROC of 0.620
#
# Fold 01
# Epoch: 000	Loss: 0.1213	Validation Loss: 0.1421
# Epoch: 038	Loss: 0.0375	Validation Loss: 0.0500
# Average positive percentile of 0.498
# AUPRC of 0.059
# AUROC of 0.545
#
# Fold 02
# Epoch: 000	Loss: 0.1303	Validation Loss: 0.1438
# Epoch: 037	Loss: 0.0458	Validation Loss: 0.0379
# Average positive percentile of 0.431
# AUPRC of 0.037
# AUROC of 0.406
#
# Fold 03
# Epoch: 000	Loss: 0.1103	Validation Loss: 0.1168
# Epoch: 025	Loss: 0.0474	Validation Loss: 0.0321
# Average positive percentile of 0.552
# AUPRC of 0.050
# AUROC of 0.533
#
# Fold 04
# Epoch: 000	Loss: 0.1221	Validation Loss: 0.1319
# Epoch: 041	Loss: 0.0372	Validation Loss: 0.0412
# Average positive percentile of 0.464
# AUPRC of 0.051
# AUROC of 0.549
#
#
#
# c28x_AD_strict_VLMC_regulon_list.csv - AD_strict - VLMC
# Replication 00
# Fold 00
# Epoch: 000	Loss: 0.0939	Validation Loss: 0.1116
# Epoch: 024	Loss: 0.0337	Validation Loss: 0.0599
# Average positive percentile of 0.555
# AUPRC of 0.083
# AUROC of 0.533
#
# Fold 01
# Epoch: 000	Loss: 0.0999	Validation Loss: 0.0913
# Epoch: 033	Loss: 0.0366	Validation Loss: 0.0320
# Average positive percentile of 0.440
# AUPRC of 0.035
# AUROC of 0.465
#
# Fold 02
# Epoch: 000	Loss: 0.1002	Validation Loss: 0.1289
# Epoch: 023	Loss: 0.0402	Validation Loss: 0.0458
# Average positive percentile of 0.596
# AUPRC of 0.043
# AUROC of 0.434
#
# Fold 03
# Epoch: 000	Loss: 0.1042	Validation Loss: 0.0976
# Epoch: 035	Loss: 0.0385	Validation Loss: 0.0303
# Average positive percentile of 0.501
# AUPRC of 0.029
# AUROC of 0.478
#
# Fold 04
# Epoch: 000	Loss: 0.1151	Validation Loss: 0.1026
# Epoch: 034	Loss: 0.0409	Validation Loss: 0.0254
# Average positive percentile of 0.496
# AUPRC of 0.049
# AUROC of 0.630
#
#
# Replication 01
# Fold 00
# Epoch: 000	Loss: 0.0919	Validation Loss: 0.1105
# Epoch: 030	Loss: 0.0381	Validation Loss: 0.0601
# Average positive percentile of 0.505
# AUPRC of 0.073
# AUROC of 0.487
#
# Fold 01
# Epoch: 000	Loss: 0.0962	Validation Loss: 0.1042
# Epoch: 033	Loss: 0.0410	Validation Loss: 0.0326
# Average positive percentile of 0.424
# AUPRC of 0.055
# AUROC of 0.580
#
# Fold 02
# Epoch: 000	Loss: 0.0934	Validation Loss: 0.0989
# Epoch: 033	Loss: 0.0278	Validation Loss: 0.0461
# Average positive percentile of 0.484
# AUPRC of 0.066
# AUROC of 0.531
#
# Fold 03
# Epoch: 000	Loss: 0.0929	Validation Loss: 0.0963
# Epoch: 033	Loss: 0.0415	Validation Loss: 0.0296
# Average positive percentile of 0.551
# AUPRC of 0.046
# AUROC of 0.490
#
# Fold 04
# Epoch: 000	Loss: 0.0989	Validation Loss: 0.0941
# Epoch: 034	Loss: 0.0409	Validation Loss: 0.0252
# Average positive percentile of 0.579
# AUPRC of 0.041
# AUROC of 0.467
#
#
# Replication 02
# Fold 00
# Epoch: 000	Loss: 0.1033	Validation Loss: 0.1177
# Epoch: 032	Loss: 0.0284	Validation Loss: 0.0603
# Average positive percentile of 0.448
# AUPRC of 0.067
# AUROC of 0.474
#
# Fold 01
# Epoch: 000	Loss: 0.1047	Validation Loss: 0.1103
# Epoch: 033	Loss: 0.0450	Validation Loss: 0.0322
# Average positive percentile of 0.572
# AUPRC of 0.027
# AUROC of 0.354
#
# Fold 02
# Epoch: 000	Loss: 0.0940	Validation Loss: 0.1053
# Epoch: 036	Loss: 0.0350	Validation Loss: 0.0465
# Average positive percentile of 0.523
# AUPRC of 0.044
# AUROC of 0.443
#
# Fold 03
# Epoch: 000	Loss: 0.1081	Validation Loss: 0.1137
# Epoch: 033	Loss: 0.0354	Validation Loss: 0.0300
# Average positive percentile of 0.561
# AUPRC of 0.022
# AUROC of 0.338
#
# Fold 04
# Epoch: 000	Loss: 0.1003	Validation Loss: 0.0900
# Epoch: 033	Loss: 0.0393	Validation Loss: 0.0256
# Average positive percentile of 0.617
# AUPRC of 0.021
# AUROC of 0.386
#
#
#
# c28x_ctl_Astro_regulon_list.csv - ctl - Astro
#
# c28x_ctl_Endo_regulon_list.csv - ctl - Endo
#
# c28x_ctl_EN_L2_3_IT_regulon_list.csv - ctl - EN_L2_3_IT
#
# c28x_ctl_EN_L3_5_IT_1_regulon_list.csv - ctl - EN_L3_5_IT_1
#
# c28x_ctl_EN_L3_5_IT_2_regulon_list.csv - ctl - EN_L3_5_IT_2
#
# c28x_ctl_EN_L3_5_IT_3_regulon_list.csv - ctl - EN_L3_5_IT_3
#
# c28x_ctl_EN_L5_6_NP_regulon_list.csv - ctl - EN_L5_6_NP
#
# c28x_ctl_EN_L5_ET_regulon_list.csv - ctl - EN_L5_ET
#
# c28x_ctl_EN_L6B_regulon_list.csv - ctl - EN_L6B
#
# c28x_ctl_EN_L6_CT_regulon_list.csv - ctl - EN_L6_CT
#
# c28x_ctl_EN_L6_IT_1_regulon_list.csv - ctl - EN_L6_IT_1
#
# c28x_ctl_EN_L6_IT_2_regulon_list.csv - ctl - EN_L6_IT_2
#
# c28x_ctl_EN_NF_regulon_list.csv - ctl - EN_NF
#
# c28x_ctl_Immune_regulon_list.csv - ctl - Immune
#
# c28x_ctl_IN_ADARB2_regulon_list.csv - ctl - IN_ADARB2
#
# c28x_ctl_IN_LAMP5_LHX6_regulon_list.csv - ctl - IN_LAMP5_LHX6
#
# c28x_ctl_IN_LAMP5_RELN_regulon_list.csv - ctl - IN_LAMP5_RELN
#
# c28x_ctl_IN_PVALB_CHC_regulon_list.csv - ctl - IN_PVALB_CHC
#
# c28x_ctl_IN_PVALB_regulon_list.csv - ctl - IN_PVALB
#
# c28x_ctl_IN_SST_regulon_list.csv - ctl - IN_SST
#
# c28x_ctl_IN_VIP_regulon_list.csv - ctl - IN_VIP
#
# c28x_ctl_Micro_regulon_list.csv - ctl - Micro
#
# c28x_ctl_OPC_regulon_list.csv - ctl - OPC
#
# c28x_ctl_PC_regulon_list.csv - ctl - PC
#
# c28x_ctl_PVM_regulon_list.csv - ctl - PVM
#
# c28x_ctl_SMC_regulon_list.csv - ctl - SMC
#
# c28x_ctl_VLMC_regulon_list.csv - ctl - VLMC
#
# r01x_0_ctl_Astro_regulon_list.csv - ctl - Astro
#
# r01x_0_ctl_Endo_regulon_list.csv - ctl - Endo
#
# r01x_0_ctl_EN_L2_3_IT_regulon_list.csv - ctl - EN_L2_3_IT
#
# r01x_0_ctl_EN_L3_5_IT_1_regulon_list.csv - ctl - EN_L3_5_IT_1
#
# r01x_0_ctl_EN_L3_5_IT_2_regulon_list.csv - ctl - EN_L3_5_IT_2
#
# r01x_0_ctl_EN_L3_5_IT_3_regulon_list.csv - ctl - EN_L3_5_IT_3
#
# r01x_0_ctl_EN_L5_6_NP_regulon_list.csv - ctl - EN_L5_6_NP
#
# r01x_0_ctl_EN_L5_ET_regulon_list.csv - ctl - EN_L5_ET
#
# r01x_0_ctl_EN_L6B_regulon_list.csv - ctl - EN_L6B
#
# r01x_0_ctl_EN_L6_CT_regulon_list.csv - ctl - EN_L6_CT
#
# r01x_0_ctl_EN_L6_IT_1_regulon_list.csv - ctl - EN_L6_IT_1
#
# r01x_0_ctl_EN_L6_IT_2_regulon_list.csv - ctl - EN_L6_IT_2
#
# r01x_0_ctl_EN_NF_regulon_list.csv - ctl - EN_NF
#
# r01x_0_ctl_Immune_regulon_list.csv - ctl - Immune
#
# r01x_0_ctl_IN_ADARB2_regulon_list.csv - ctl - IN_ADARB2
#
# r01x_0_ctl_IN_LAMP5_LHX6_regulon_list.csv - ctl - IN_LAMP5_LHX6
#
# r01x_0_ctl_IN_LAMP5_RELN_regulon_list.csv - ctl - IN_LAMP5_RELN
#
# r01x_0_ctl_IN_PVALB_CHC_regulon_list.csv - ctl - IN_PVALB_CHC
#
# r01x_0_ctl_IN_PVALB_regulon_list.csv - ctl - IN_PVALB
#
# r01x_0_ctl_IN_SST_regulon_list.csv - ctl - IN_SST
#
# r01x_0_ctl_IN_VIP_regulon_list.csv - ctl - IN_VIP
#
# r01x_0_ctl_Micro_regulon_list.csv - ctl - Micro
#
# r01x_0_ctl_Oligo_regulon_list.csv - ctl - Oligo
#
# r01x_0_ctl_OPC_regulon_list.csv - ctl - OPC
#
# r01x_0_ctl_PC_regulon_list.csv - ctl - PC
#
# r01x_0_ctl_PVM_regulon_list.csv - ctl - PVM
#
# r01x_0_ctl_SMC_regulon_list.csv - ctl - SMC
#
# r01x_0_ctl_VLMC_regulon_list.csv - ctl - VLMC
#
# r01x_1_ctl_Astro_regulon_list.csv - ctl - Astro
#
# r01x_1_ctl_Endo_regulon_list.csv - ctl - Endo
#
# r01x_1_ctl_EN_L2_3_IT_regulon_list.csv - ctl - EN_L2_3_IT
#
# r01x_1_ctl_EN_L3_5_IT_1_regulon_list.csv - ctl - EN_L3_5_IT_1
#
# r01x_1_ctl_EN_L3_5_IT_2_regulon_list.csv - ctl - EN_L3_5_IT_2
#
# r01x_1_ctl_EN_L3_5_IT_3_regulon_list.csv - ctl - EN_L3_5_IT_3
#
# r01x_1_ctl_EN_L5_6_NP_regulon_list.csv - ctl - EN_L5_6_NP
#
# r01x_1_ctl_EN_L5_ET_regulon_list.csv - ctl - EN_L5_ET
#
# r01x_1_ctl_EN_L6B_regulon_list.csv - ctl - EN_L6B
#
# r01x_1_ctl_EN_L6_CT_regulon_list.csv - ctl - EN_L6_CT
#
# r01x_1_ctl_EN_L6_IT_1_regulon_list.csv - ctl - EN_L6_IT_1
#
# r01x_1_ctl_EN_L6_IT_2_regulon_list.csv - ctl - EN_L6_IT_2
#
# r01x_1_ctl_EN_NF_regulon_list.csv - ctl - EN_NF
#
# r01x_1_ctl_Immune_regulon_list.csv - ctl - Immune
#
# r01x_1_ctl_IN_ADARB2_regulon_list.csv - ctl - IN_ADARB2
#
# r01x_1_ctl_IN_LAMP5_LHX6_regulon_list.csv - ctl - IN_LAMP5_LHX6
#
# r01x_1_ctl_IN_LAMP5_RELN_regulon_list.csv - ctl - IN_LAMP5_RELN
#
# r01x_1_ctl_IN_PVALB_CHC_regulon_list.csv - ctl - IN_PVALB_CHC
#
# r01x_1_ctl_IN_PVALB_regulon_list.csv - ctl - IN_PVALB
#
# r01x_1_ctl_IN_SST_regulon_list.csv - ctl - IN_SST
#
# r01x_1_ctl_IN_VIP_regulon_list.csv - ctl - IN_VIP
#
# r01x_1_ctl_Micro_regulon_list.csv - ctl - Micro
#
# r01x_1_ctl_Oligo_regulon_list.csv - ctl - Oligo
#
# r01x_1_ctl_OPC_regulon_list.csv - ctl - OPC
#
# r01x_1_ctl_PC_regulon_list.csv - ctl - PC
#
# r01x_1_ctl_PVM_regulon_list.csv - ctl - PVM
#
# r01x_1_ctl_SMC_regulon_list.csv - ctl - SMC
#
# r01x_1_ctl_VLMC_regulon_list.csv - ctl - VLMC
#
# r01x_2_ctl_Astro_regulon_list.csv - ctl - Astro
#
# r01x_2_ctl_Endo_regulon_list.csv - ctl - Endo
#
# r01x_2_ctl_EN_L2_3_IT_regulon_list.csv - ctl - EN_L2_3_IT
#
# r01x_2_ctl_EN_L3_5_IT_1_regulon_list.csv - ctl - EN_L3_5_IT_1
#
# r01x_2_ctl_EN_L3_5_IT_2_regulon_list.csv - ctl - EN_L3_5_IT_2
#
# r01x_2_ctl_EN_L3_5_IT_3_regulon_list.csv - ctl - EN_L3_5_IT_3
#
# r01x_2_ctl_EN_L5_6_NP_regulon_list.csv - ctl - EN_L5_6_NP
#
# r01x_2_ctl_EN_L5_ET_regulon_list.csv - ctl - EN_L5_ET
#
# r01x_2_ctl_EN_L6B_regulon_list.csv - ctl - EN_L6B
#
# r01x_2_ctl_EN_L6_CT_regulon_list.csv - ctl - EN_L6_CT
#
# r01x_2_ctl_EN_L6_IT_1_regulon_list.csv - ctl - EN_L6_IT_1
#
# r01x_2_ctl_EN_L6_IT_2_regulon_list.csv - ctl - EN_L6_IT_2
#
# r01x_2_ctl_EN_NF_regulon_list.csv - ctl - EN_NF
#
# r01x_2_ctl_Immune_regulon_list.csv - ctl - Immune
#
# r01x_2_ctl_IN_ADARB2_regulon_list.csv - ctl - IN_ADARB2
#
# r01x_2_ctl_IN_LAMP5_LHX6_regulon_list.csv - ctl - IN_LAMP5_LHX6
#
# r01x_2_ctl_IN_LAMP5_RELN_regulon_list.csv - ctl - IN_LAMP5_RELN
#
# r01x_2_ctl_IN_PVALB_CHC_regulon_list.csv - ctl - IN_PVALB_CHC
#
# r01x_2_ctl_IN_PVALB_regulon_list.csv - ctl - IN_PVALB
#
# r01x_2_ctl_IN_SST_regulon_list.csv - ctl - IN_SST
#
# r01x_2_ctl_IN_VIP_regulon_list.csv - ctl - IN_VIP
#
# r01x_2_ctl_Micro_regulon_list.csv - ctl - Micro
#
# r01x_2_ctl_Oligo_regulon_list.csv - ctl - Oligo
#
# r01x_2_ctl_OPC_regulon_list.csv - ctl - OPC
#
# r01x_2_ctl_PC_regulon_list.csv - ctl - PC
#
# r01x_2_ctl_PVM_regulon_list.csv - ctl - PVM
#
# r01x_2_ctl_SMC_regulon_list.csv - ctl - SMC
#
# r01x_2_ctl_VLMC_regulon_list.csv - ctl - VLMC
#
# r01x_3_ctl_Astro_regulon_list.csv - ctl - Astro
#
# r01x_3_ctl_Endo_regulon_list.csv - ctl - Endo
#
# r01x_3_ctl_EN_L2_3_IT_regulon_list.csv - ctl - EN_L2_3_IT
#
# r01x_3_ctl_EN_L3_5_IT_1_regulon_list.csv - ctl - EN_L3_5_IT_1
#
# r01x_3_ctl_EN_L3_5_IT_2_regulon_list.csv - ctl - EN_L3_5_IT_2
#
# r01x_3_ctl_EN_L3_5_IT_3_regulon_list.csv - ctl - EN_L3_5_IT_3
#
# r01x_3_ctl_EN_L5_6_NP_regulon_list.csv - ctl - EN_L5_6_NP
#
# r01x_3_ctl_EN_L5_ET_regulon_list.csv - ctl - EN_L5_ET
#
# r01x_3_ctl_EN_L6B_regulon_list.csv - ctl - EN_L6B
#
# r01x_3_ctl_EN_L6_CT_regulon_list.csv - ctl - EN_L6_CT
#
# r01x_3_ctl_EN_L6_IT_1_regulon_list.csv - ctl - EN_L6_IT_1
#
# r01x_3_ctl_EN_L6_IT_2_regulon_list.csv - ctl - EN_L6_IT_2
#
# r01x_3_ctl_EN_NF_regulon_list.csv - ctl - EN_NF
#
# r01x_3_ctl_Immune_regulon_list.csv - ctl - Immune
#
# r01x_3_ctl_IN_ADARB2_regulon_list.csv - ctl - IN_ADARB2
#
# r01x_3_ctl_IN_LAMP5_LHX6_regulon_list.csv - ctl - IN_LAMP5_LHX6
#
# r01x_3_ctl_IN_LAMP5_RELN_regulon_list.csv - ctl - IN_LAMP5_RELN
#
# r01x_3_ctl_IN_PVALB_CHC_regulon_list.csv - ctl - IN_PVALB_CHC
#
# r01x_3_ctl_IN_PVALB_regulon_list.csv - ctl - IN_PVALB
#
# r01x_3_ctl_IN_SST_regulon_list.csv - ctl - IN_SST
#
# r01x_3_ctl_IN_VIP_regulon_list.csv - ctl - IN_VIP
#
# r01x_3_ctl_Micro_regulon_list.csv - ctl - Micro
#
# r01x_3_ctl_Oligo_regulon_list.csv - ctl - Oligo
#
# r01x_3_ctl_OPC_regulon_list.csv - ctl - OPC
#
# r01x_3_ctl_PC_regulon_list.csv - ctl - PC
#
# r01x_3_ctl_PVM_regulon_list.csv - ctl - PVM
#
# r01x_3_ctl_SMC_regulon_list.csv - ctl - SMC
#
# r01x_3_ctl_VLMC_regulon_list.csv - ctl - VLMC
#
# r01x_4_ctl_Astro_regulon_list.csv - ctl - Astro
#
# r01x_4_ctl_Endo_regulon_list.csv - ctl - Endo
#
# r01x_4_ctl_EN_L2_3_IT_regulon_list.csv - ctl - EN_L2_3_IT
#
# r01x_4_ctl_EN_L3_5_IT_1_regulon_list.csv - ctl - EN_L3_5_IT_1
#
# r01x_4_ctl_EN_L3_5_IT_2_regulon_list.csv - ctl - EN_L3_5_IT_2
#
# r01x_4_ctl_EN_L3_5_IT_3_regulon_list.csv - ctl - EN_L3_5_IT_3
#
# r01x_4_ctl_EN_L5_6_NP_regulon_list.csv - ctl - EN_L5_6_NP
#
# r01x_4_ctl_EN_L5_ET_regulon_list.csv - ctl - EN_L5_ET
#
# r01x_4_ctl_EN_L6B_regulon_list.csv - ctl - EN_L6B
#
# r01x_4_ctl_EN_L6_CT_regulon_list.csv - ctl - EN_L6_CT
#
# r01x_4_ctl_EN_L6_IT_1_regulon_list.csv - ctl - EN_L6_IT_1
#
# r01x_4_ctl_EN_L6_IT_2_regulon_list.csv - ctl - EN_L6_IT_2
#
# r01x_4_ctl_EN_NF_regulon_list.csv - ctl - EN_NF
#
# r01x_4_ctl_Immune_regulon_list.csv - ctl - Immune
#
# r01x_4_ctl_IN_ADARB2_regulon_list.csv - ctl - IN_ADARB2
#
# r01x_4_ctl_IN_LAMP5_LHX6_regulon_list.csv - ctl - IN_LAMP5_LHX6
#
# r01x_4_ctl_IN_LAMP5_RELN_regulon_list.csv - ctl - IN_LAMP5_RELN
#
# r01x_4_ctl_IN_PVALB_CHC_regulon_list.csv - ctl - IN_PVALB_CHC
#
# r01x_4_ctl_IN_PVALB_regulon_list.csv - ctl - IN_PVALB
#
# r01x_4_ctl_IN_SST_regulon_list.csv - ctl - IN_SST
#
# r01x_4_ctl_IN_VIP_regulon_list.csv - ctl - IN_VIP
#
# r01x_4_ctl_Micro_regulon_list.csv - ctl - Micro
#
# r01x_4_ctl_Oligo_regulon_list.csv - ctl - Oligo
#
# r01x_4_ctl_OPC_regulon_list.csv - ctl - OPC
#
# r01x_4_ctl_PC_regulon_list.csv - ctl - PC
#
# r01x_4_ctl_PVM_regulon_list.csv - ctl - PVM
#
# r01x_4_ctl_SMC_regulon_list.csv - ctl - SMC
#
# r01x_4_ctl_VLMC_regulon_list.csv - ctl - VLMC
#
# r01x_5_ctl_Astro_regulon_list.csv - ctl - Astro
#
# r01x_5_ctl_Endo_regulon_list.csv - ctl - Endo
#
# r01x_5_ctl_EN_L2_3_IT_regulon_list.csv - ctl - EN_L2_3_IT
#
# r01x_5_ctl_EN_L3_5_IT_1_regulon_list.csv - ctl - EN_L3_5_IT_1
#
# r01x_5_ctl_EN_L3_5_IT_2_regulon_list.csv - ctl - EN_L3_5_IT_2
#
# r01x_5_ctl_EN_L3_5_IT_3_regulon_list.csv - ctl - EN_L3_5_IT_3
#
# r01x_5_ctl_EN_L5_6_NP_regulon_list.csv - ctl - EN_L5_6_NP
#
# r01x_5_ctl_EN_L5_ET_regulon_list.csv - ctl - EN_L5_ET
#
# r01x_5_ctl_EN_L6B_regulon_list.csv - ctl - EN_L6B
#
# r01x_5_ctl_EN_L6_CT_regulon_list.csv - ctl - EN_L6_CT
#
# r01x_5_ctl_EN_L6_IT_1_regulon_list.csv - ctl - EN_L6_IT_1
#
# r01x_5_ctl_EN_L6_IT_2_regulon_list.csv - ctl - EN_L6_IT_2
#
# r01x_5_ctl_EN_NF_regulon_list.csv - ctl - EN_NF
#
# r01x_5_ctl_Immune_regulon_list.csv - ctl - Immune
#
# r01x_5_ctl_IN_ADARB2_regulon_list.csv - ctl - IN_ADARB2
#
# r01x_5_ctl_IN_LAMP5_LHX6_regulon_list.csv - ctl - IN_LAMP5_LHX6
#
# r01x_5_ctl_IN_LAMP5_RELN_regulon_list.csv - ctl - IN_LAMP5_RELN
#
# r01x_5_ctl_IN_PVALB_CHC_regulon_list.csv - ctl - IN_PVALB_CHC
#
# r01x_5_ctl_IN_PVALB_regulon_list.csv - ctl - IN_PVALB
#
# r01x_5_ctl_IN_SST_regulon_list.csv - ctl - IN_SST
#
# r01x_5_ctl_IN_VIP_regulon_list.csv - ctl - IN_VIP
#
# r01x_5_ctl_Micro_regulon_list.csv - ctl - Micro
#
# r01x_5_ctl_Oligo_regulon_list.csv - ctl - Oligo
#
# r01x_5_ctl_OPC_regulon_list.csv - ctl - OPC
#
# r01x_5_ctl_PC_regulon_list.csv - ctl - PC
#
# r01x_5_ctl_PVM_regulon_list.csv - ctl - PVM
#
# r01x_5_ctl_SMC_regulon_list.csv - ctl - SMC
#
# r01x_5_ctl_VLMC_regulon_list.csv - ctl - VLMC
#
# r01x_6_ctl_Endo_regulon_list.csv - ctl - Endo
#
# r01x_6_ctl_EN_L3_5_IT_1_regulon_list.csv - ctl - EN_L3_5_IT_1
#
# r01x_6_ctl_EN_L3_5_IT_2_regulon_list.csv - ctl - EN_L3_5_IT_2
#
# r01x_6_ctl_EN_L3_5_IT_3_regulon_list.csv - ctl - EN_L3_5_IT_3
#
# r01x_6_ctl_EN_L5_6_NP_regulon_list.csv - ctl - EN_L5_6_NP
#
# r01x_6_ctl_EN_L5_ET_regulon_list.csv - ctl - EN_L5_ET
#
# r01x_6_ctl_EN_L6B_regulon_list.csv - ctl - EN_L6B
#
# r01x_6_ctl_EN_L6_CT_regulon_list.csv - ctl - EN_L6_CT
#
# r01x_6_ctl_EN_L6_IT_1_regulon_list.csv - ctl - EN_L6_IT_1
#
# r01x_6_ctl_EN_L6_IT_2_regulon_list.csv - ctl - EN_L6_IT_2
#
# r01x_6_ctl_EN_NF_regulon_list.csv - ctl - EN_NF
#
# r01x_6_ctl_Immune_regulon_list.csv - ctl - Immune
#
# r01x_6_ctl_IN_ADARB2_regulon_list.csv - ctl - IN_ADARB2
#
# r01x_6_ctl_IN_LAMP5_LHX6_regulon_list.csv - ctl - IN_LAMP5_LHX6
#
# r01x_6_ctl_IN_LAMP5_RELN_regulon_list.csv - ctl - IN_LAMP5_RELN
#
# r01x_6_ctl_IN_PVALB_CHC_regulon_list.csv - ctl - IN_PVALB_CHC
#
# r01x_6_ctl_IN_PVALB_regulon_list.csv - ctl - IN_PVALB
#
# r01x_6_ctl_IN_VIP_regulon_list.csv - ctl - IN_VIP
#
# r01x_6_ctl_Micro_regulon_list.csv - ctl - Micro
#
# r01x_6_ctl_OPC_regulon_list.csv - ctl - OPC

# %%
# Format
m2 = re.compile('^([cr]\d+x(_\d+)?)_([a-zA-Z]+(_(resilient|strict))?)_((?!resilient|strict)\w+)_(\d+)_(\d+)$')
df_get_contrast = lambda s: m2.match(s).group(1)
df_get_group = lambda s: m2.match(s).group(3)
df_get_cell_type = lambda s: m2.match(s).group(6)
df_get_replication = lambda s: m2.match(s).group(7)
df_get_fold = lambda s: m2.match(s).group(8)
df = pd.DataFrame({
    'Contrast': np.vectorize(df_get_contrast)(graph_type.flatten()),
    'Group': np.vectorize(df_get_group)(graph_type.flatten()),
    'Cell Type': np.vectorize(df_get_cell_type)(graph_type.flatten()),
    'Replication': np.vectorize(df_get_replication)(graph_type.flatten()),
    'Fold': np.vectorize(df_get_fold)(graph_type.flatten()),
    'Average Positive Percentile': app_list.flatten(),
    'AUPRC': auprc_list.flatten(),
    'AUROC': auroc_list.flatten(),
})
df.to_csv('results.csv')

# Parameters
statistic = 'AUROC'
statistic_minimum = .5

# Collapse folds
df = df.groupby(['Contrast', 'Group', 'Cell Type', 'Replication']).mean().reset_index()

# Collapse all
df_summary = df.groupby(['Contrast', 'Group', 'Cell Type']).mean().reset_index()

# Filter
df_avg = df.groupby(['Contrast', 'Group', 'Cell Type']).mean().reset_index()
df_avg.index = df_avg.apply(lambda r: '_'.join([r['Contrast'], r['Group'], r['Cell Type']]), axis=1)
df.index = df.apply(lambda r: '_'.join([r['Contrast'], r['Group'], r['Cell Type']]), axis=1)
df = df.loc[df_avg.index[df_avg[statistic] > statistic_minimum].to_numpy()]
df = df.reset_index(drop=True)

# Sort
df = df.sort_values('Cell Type')
df_summary = df_summary.sort_values('Cell Type')

# Visualize boxplot
fig, ax = plt.subplots(1, 1, figsize=(18, 9))
sns.boxplot(df, x='Cell Type', y=statistic, hue='Group', ax=ax)
plt.axhline(.5, color='black', linestyle='--')
plt.xticks(rotation=90)
plt.tight_layout()
fig.savefig(f'./plots/grn_performance.pdf', format='pdf', transparent=True)
plt.close()

# Visualize line plot
# fig, ax = plt.subplots(1, 1, figsize=(9, 9))
# sns.lineplot(df_summary.sort_values('Cell Type'), x='Cell Type', y=statistic, hue='Group', ax=ax)
# plt.axhline(.5, color='black', linestyle='--')
# plt.xticks(rotation=90)
# plt.tight_layout()
# fig.savefig(f'./plots/grn_performance.pdf', format='pdf', transparent=True)
# plt.close()
